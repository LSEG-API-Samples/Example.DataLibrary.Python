# %% [markdown]
# # Refinitiv Data Platform Library for Python
# ## Delivery - EndPoint - News Headlines

# %% [markdown]
# This notebook demonstrates how to use the Delivery Layer of the library to retrieve News headlines from the Refinitiv Data Platform.

# %% [markdown]
# ## Import the library and load credentials
#
# Credentials used by this and the other tutorials notebooks are stored in the **Configuration/credentials.ipynb** file.
#
# You should have edited the **Configuration/credentials.ipynb** to set your credentials as part of the **Quick Start** step.

# %%
from refinitiv.data.delivery import endpoint_request
import datetime
import json
# %run ../../Configuration/credentials.ipynb

# %% [markdown]
# ## Open the session of your choice
#
# Use our helper function in the Credentials notebook, **open_session(session_type)**, to create and open a session to connect to the
# - Refinitiv Data Platform directly (session_type="rdp") or via
# - Eikon 4 or Refinitiv Workspace (session_type="desktop")
#
# You can also set a default in the **credentials** notebook
#
# **Note**: You cannot currently perform Symbology Conversion using a Deployed session

# %%
open_session('rdp')
# Out:
# <refinitiv.data.session._platform_session.Definition object at 0x2785ee37130 {session_name='default-session'}>

# %% [markdown]
# # Example

# %% [markdown]
# ## Define the endpoint request

# %%
# Correct syntax but does not work yet
request_definition = rd.delivery.endpoint_request.Definition(
    url = "/data/news/v1/headlines",
    method = rd.delivery.endpoint_request.RequestMethod.GET,
    query_parameters = {"query": "CRUDE OIL"}
)

# %% [markdown]
# ## Send a request

# %%
response = request_definition.get_data()

# %% [markdown]
# ## Display the result

# %%
response.data.raw
# Out:
# {'data': [{'storyId': 'urn:newsml:reuters.com:20210903:nL1N2Q50NO:2',
#    'newsItem': {'_version': 2,
#     'contentMeta': {'audience': [{'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:PEN'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'U:C'},
#       {'_qcode': 'MCC:OEC'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'MCCL:OEC'},
#       {'_qcode': 'F:8'},
#       {'_qcode': 'G:T'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'G:25'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'G:BN'},
#       {'_qcode': 'M:MR'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'G:2EK'},
#       {'_qcode': 'M:1RT'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'U:9B'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'U:9K'},
#       {'_qcode': 'G:CI'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'P:4296944136'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-03T09:47:11Z'},
#      'versionCreated': {'$': '2021-09-03T09:47:11Z'},
#      'title': [{'$': 'Indonesia sets August Minas crude at $67.99/bbl'}],
#      'instanceOf': [{'_qcode': '1250'}, {'_qcode': '2114'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210903:nIGB5BDC30:2',
#    'newsItem': {'_version': 2,
#     'contentMeta': {'audience': [{'_qcode': 'NP:O'}, {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'M:2CS'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'U:9T'},
#       {'_qcode': 'G:A4'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:9T'},
#       {'_qcode': 'U:9K'},
#       {'_qcode': 'U:9B'},
#       {'_qcode': 'M:23N'},
#       {'_qcode': 'U:A8'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'M:DU'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-03T09:37:02.174Z'},
#      'versionCreated': {'$': '2021-09-03T09:37:06.03Z'},
#      'title': [{'$': 'Table - Crude OSP (Updates UAE)'}],
#      'instanceOf': [{'_qcode': '552'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210903:nL4N2Q51ZV:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:GFN'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'G:5B'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'U:9T'},
#       {'_qcode': 'B:227'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'B:6'},
#       {'_qcode': 'G:BU'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'U:A8'},
#       {'_qcode': 'G:H'},
#       {'_qcode': 'B:20'},
#       {'_qcode': 'B:12'},
#       {'_qcode': 'M:B6'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'G:BR'},
#       {'_qcode': 'R:ADNOC.UL'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'B:229'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'B:1086'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'M:Z'},
#       {'_qcode': 'G:A4'},
#       {'_qcode': 'B:19'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:1TF'},
#       {'_qcode': 'B:228'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'B:1003'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'B:22'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'P:5000061603'}],
#      'urgency': {'$': 2}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-03T08:17:31Z'},
#      'versionCreated': {'$': '2021-09-03T08:28:14Z'},
#      'title': [{'$': "UAE's ADNOC sets October Murban crude OSP at $69.73/bbl"}],
#      'instanceOf': [{'_qcode': '2114'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210903:nL4N2Q51ZV:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:E'},
#       {'_qcode': 'NP:C'},
#       {'_qcode': 'NP:D'},
#       {'_qcode': 'NP:M'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:T'},
#       {'_qcode': 'NP:U'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:NAT'},
#       {'_qcode': 'NP:UKI'},
#       {'_qcode': 'NP:GRO'},
#       {'_qcode': 'NP:MTL'},
#       {'_qcode': 'NP:SOF'},
#       {'_qcode': 'NP:GFN'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'U:C'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'M:2CY'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'U:9T'},
#       {'_qcode': 'B:227'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'B:6'},
#       {'_qcode': 'G:BU'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'U:A8'},
#       {'_qcode': 'G:H'},
#       {'_qcode': 'B:20'},
#       {'_qcode': 'B:12'},
#       {'_qcode': 'M:B6'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2D1'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'G:BR'},
#       {'_qcode': 'R:ADNOC.UL'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'B:229'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'B:1086'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'M:Z'},
#       {'_qcode': 'G:A4'},
#       {'_qcode': 'B:19'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'B:228'},
#       {'_qcode': 'M:9X'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'B:1003'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'B:22'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'P:5000061603'}],
#      'urgency': {'$': 1}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-03T08:17:31Z'},
#      'versionCreated': {'$': '2021-09-03T08:17:31Z'},
#      'title': [{'$': "UAE'S ADNOC SETS OCTOBER MURBAN CRUDE OSP AT $69.73/BBL"}],
#      'instanceOf': [{'_qcode': '2114'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210903:nL4N2Q4383:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:E'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:PSC'},
#       {'_qcode': 'NP:RNP'},
#       {'_qcode': 'NP:PCO'},
#       {'_qcode': 'NP:PEN'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'U:C'},
#       {'_qcode': 'MCC:OEC'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'U:78'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'MCCL:OEC'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'B:234'},
#       {'_qcode': 'U:B'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'U:A8'},
#       {'_qcode': 'B:125'},
#       {'_qcode': 'B:56'},
#       {'_qcode': 'B:7'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'I:C6'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'B:261'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'B:63'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'M:Z'},
#       {'_qcode': 'R:KOILC.UL'},
#       {'_qcode': 'U:9T'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'E:9'},
#       {'_qcode': 'U:5K'},
#       {'_qcode': 'B:244'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:AE'},
#       {'_qcode': 'B:62'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'B:34'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'P:5000023088'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-03T06:03:13Z'},
#      'versionCreated': {'$': '2021-09-03T06:03:13Z'},
#      'title': [{'$': "CORRECTED-TABLE-S.Korea's crude oil imports in Feb, Jan, Oct"}],
#      'instanceOf': [{'_qcode': '686'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210903:nL4N2Q509K:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:Z'},
#       {'_qcode': 'NP:C'},
#       {'_qcode': 'NP:GRO'},
#       {'_qcode': 'NP:MTL'},
#       {'_qcode': 'NP:SOF'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'M:2CS'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'G:B1'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'R:ILUZ1'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'A:7'},
#       {'_qcode': 'B:6'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'E:5'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'M:2CX'},
#       {'_qcode': 'M:9X'},
#       {'_qcode': 'R:SFUF2'},
#       {'_qcode': 'B:1003'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'U:23'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'R:ISCV1'}],
#      'urgency': {'$': 1}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-03T01:01:20Z'},
#      'versionCreated': {'$': '2021-09-03T01:01:20Z'},
#      'title': [{'$': 'MOST-TRADED SHANGHAI CRUDE OIL FUTURES CONTRACT <ISCV1> RISES 3.8% IN EARLY FRIDAY TRADE, FUEL OIL <SFUF2> UP 2.4%, LOW-SULPHUR FUEL OIL <ILUZ1> UP 3%'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210902:nL1N2Q42MS:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:CAN'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:DNP'},
#       {'_qcode': 'NP:PEN'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'a1312cat:f'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'R:ENB.TO'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'U:8J'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'U:8T'},
#       {'_qcode': 'G:CF'},
#       {'_qcode': 'G:8W'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'G:BM'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'M:2D1'},
#       {'_qcode': 'P:4295860623'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-02T21:26:29Z'},
#      'versionCreated': {'$': '2021-09-02T21:26:29Z'},
#      'title': [{'$': 'CANADA-CRUDE-Heavy crude discount edges wider; strong Gulf Coast prices support'}],
#      'instanceOf': [{'_qcode': '5427'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210902:nL4N2Q43GB:3',
#    'newsItem': {'_version': 3,
#     'contentMeta': {'audience': [{'_qcode': 'NP:E'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:U'},
#       {'_qcode': 'NP:NAW'},
#       {'_qcode': 'NP:UKI'},
#       {'_qcode': 'NP:EMK'},
#       {'_qcode': 'NP:PSC'},
#       {'_qcode': 'NP:RNP'},
#       {'_qcode': 'NP:DNP'},
#       {'_qcode': 'NP:PCO'},
#       {'_qcode': 'NP:PEN'},
#       {'_qcode': 'NP:PCU'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'U:CX'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'U:8J'},
#       {'_qcode': 'M:2CY'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'B:6'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'M:E7'},
#       {'_qcode': 'E:5J'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'G:G'},
#       {'_qcode': 'U:8K'},
#       {'_qcode': 'G:3'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'B:185'},
#       {'_qcode': 'M:2B'},
#       {'_qcode': 'R:RDSa.L'},
#       {'_qcode': 'G:2V'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'U:D2'},
#       {'_qcode': 'B:181'},
#       {'_qcode': 'B:7'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'M:1LY'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2D1'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'B:1831'},
#       {'_qcode': 'M:MR'},
#       {'_qcode': 'M:1Z6'},
#       {'_qcode': 'M:1RT'},
#       {'_qcode': 'M:Z'},
#       {'_qcode': 'B:1006'},
#       {'_qcode': 'M:1V0'},
#       {'_qcode': 'M:1Z4'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:H'},
#       {'_qcode': 'M:23N'},
#       {'_qcode': 'G:7'},
#       {'_qcode': 'M:NY'},
#       {'_qcode': 'R:RDSa.AS'},
#       {'_qcode': 'B:1003'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'U:I'},
#       {'_qcode': 'M:1ZT'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'G:7J'},
#       {'_qcode': 'P:4295885039'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-02T21:23:39Z'},
#      'versionCreated': {'$': '2021-09-02T21:23:39Z'},
#      'title': [{'$': 'UPDATE 1-Shell finds damage to crude transfer station in Gulf Of Mexico from Hurricane Ida'}],
#      'instanceOf': [{'_qcode': '1250'}, {'_qcode': '9092'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210902:nL4N2Q43DK:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:O'}, {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'a1312cat:f'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'U:8J'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'G:CF'},
#       {'_qcode': 'U:91'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'M:Z'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'G:6J'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-02T20:52:15Z'},
#      'versionCreated': {'$': '2021-09-02T20:52:15Z'},
#      'title': [{'$': 'U.S. cash crude deals'}],
#      'instanceOf': [{'_qcode': '1709'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210902:nL4N2Q43CH:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:MF'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'a1312cat:f'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'U:8J'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'B:227'},
#       {'_qcode': 'G:CF'},
#       {'_qcode': 'B:1004'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'B:6'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'R:MUR.N'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'G:BM'},
#       {'_qcode': 'B:20'},
#       {'_qcode': 'B:1085'},
#       {'_qcode': 'R:PSX.N'},
#       {'_qcode': 'R:BLT.L'},
#       {'_qcode': 'B:24'},
#       {'_qcode': 'B:12'},
#       {'_qcode': 'B:7'},
#       {'_qcode': 'M:B6'},
#       {'_qcode': 'R:BHP.AX'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'I:C6'},
#       {'_qcode': 'R:MPC.N'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'B:229'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'U:91'},
#       {'_qcode': 'R:VLO.N'},
#       {'_qcode': 'B:1010'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'M:Z'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'B:19'},
#       {'_qcode': 'G:5'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'R:XOM.N'},
#       {'_qcode': 'R:PBF.N'},
#       {'_qcode': 'B:228'},
#       {'_qcode': 'B:1003'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'G:2H'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'P:5000007215'},
#       {'_qcode': 'P:5037128948'},
#       {'_qcode': 'P:4295856983'},
#       {'_qcode': 'P:4295904564'},
#       {'_qcode': 'P:5036398194'},
#       {'_qcode': 'P:5073223402'},
#       {'_qcode': 'P:4295912121'},
#       {'_qcode': 'P:8589934154'},
#       {'_qcode': 'P:5000661878'},
#       {'_qcode': 'P:4295905198'},
#       {'_qcode': 'P:4298007836'},
#       {'_qcode': 'P:5034844537'},
#       {'_qcode': 'P:5001438555'},
#       {'_qcode': 'P:5000089102'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-02T20:46:29Z'},
#      'versionCreated': {'$': '2021-09-02T20:46:29Z'},
#      'title': [{'$': 'U.S. Cash Crude-Mars Sour trades at a premium as cos strain to restart operations after Hurricane Ida'}],
#      'instanceOf': [{'_qcode': '1910'}]}}}],
#  'meta': {'count': 10,
#   'pageLimit': 10,
#   'next': '',
#   'prev': ''}}

# %% [markdown]
# ## Close the session

# %%
close_session()
