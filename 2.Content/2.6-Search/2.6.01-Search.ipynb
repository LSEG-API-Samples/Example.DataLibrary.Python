# %% [markdown]
# # Refinitiv Data Library for Python
# ## Content - Search, Lookup and View Metadata
# This notebook demonstrates how to utilise the Search API using the Refinitiv Data Platform OR via Refinitiv Eikon/Workspace.
#
# For more details on the Search API refer to the following:
#
# * The article, [Building Search into your Application Workflow](https://developers.refinitiv.com/en/article-catalog/article/building-search-into-your-application-workflow), provides an overview of the capabilities of the Search service including tips and tricks and many useful techniques.
#
# * Search API documentation: [Search Reference Guide](https://apidocs.refinitiv.com/Apps/ApiDocs#/details/L2Rpc2NvdmVyeS9zZWFyY2gvdjE=/Lw==/POST/README)

# %% [markdown]
# ## Import the library and load credentials
#
# Credentials used by this and the other tutorials notebooks are stored in the **Configuration/credentials.ipynb** file.
#
# You should have edited the **Configuration/credentials.ipynb** to set your credentials as part of the **Quick Start** step.

# %%
from refinitiv.data.content import search
import pandas as pd
import json

# %run ../../Configuration/credentials.ipynb

# %% [markdown]
# ## Open the session of your choice
#
# Use our helper function in the Credentials notebook, **open_session(session_type)**, to create and open a session to connect to the
# - Refinitiv Data Platform directly (session_type="rdp") or via
# - Eikon 4 or Refinitiv Workspace (session_type="desktop")
#
# You can also set a default in the **credentials** notebook
#
# **Note**: You cannot currently use the Search API via a Deployed session

# %%
open_session()

# %% [markdown]
# #### General Search

# %%
response = search.Definition("IBM Bonds").get_data()
response.data.df
# Out:
#          PermID           RIC  \
# 0   46638470066  US137584115=
# 1   44657599150    459200HX2=
# 2   46642939296    459200JQ5=
# 3  192841929423    459200JX0=
# 4   44640212240    459200HG9=
# 5   46635711098  US127166528=
# 6   46637038358    459200JC6=
# 7  192826899363  US194445601=
# 8   44657843041  US114316318=
# 9   44649129642    459200HP9=
#
#                                        DocumentTitle                  PI  \
# 0  International Business Machines Corp, Plain Va...  0x00102c2565da06a0
# 1  International Business Machines Corp, Fixed Ma...  0x0004051b94d20854
# 2  International Business Machines Corp, Plain Va...  0x00102c28b5f20b58
# 3  International Business Machines Corp, Plain Va...  0x00102c2452251a75
# 4  International Business Machines Corp, Plain Va...  0x0004050e34388b88
# 5  International Business Machines Corp, Plain Va...  0x00102c05c4dd0222
# 6  International Business Machines Corp, Plain Va...  0x00102c80bf6b046c
# 7  International Business Machines Corp, Plain Va...  0x00102c53ff1f1897
# 8  International Business Machines Corp, Plain Va...  0x0004051bd47954e3
# 9  International Business Machines Corp, Plain Va...  0x00040513a4865c6c
#
#                    BusinessEntity
# 0  INSTRUMENTxFIXEDINCOMExGOVCORP
# 1  INSTRUMENTxFIXEDINCOMExGOVCORP
# 2  INSTRUMENTxFIXEDINCOMExGOVCORP
# 3  INSTRUMENTxFIXEDINCOMExGOVCORP
# 4  INSTRUMENTxFIXEDINCOMExGOVCORP
# 5  INSTRUMENTxFIXEDINCOMExGOVCORP
# 6  INSTRUMENTxFIXEDINCOMExGOVCORP
# 7  INSTRUMENTxFIXEDINCOMExGOVCORP
# 8  INSTRUMENTxFIXEDINCOMExGOVCORP
# 9  INSTRUMENTxFIXEDINCOMExGOVCORP

# %% [markdown]
# #### Specify number of rows to fetch

# %%
response = search.Definition("IBM Bonds", top=100).get_data()
response.data.df
# Out:
#           PermID           RIC  \
# 0    46638470066  US137584115=
# 1    44657599150    459200HX2=
# 2    46642939296    459200JQ5=
# 3   192841929423    459200JX0=
# 4    44640212240    459200HG9=
# ..           ...           ...
# 95          <NA>          <NA>
# 96          <NA>          <NA>
# 97          <NA>          <NA>
# 98          <NA>          <NA>
# 99          <NA>          <NA>
#
#                                         DocumentTitle                  PI  \
# 0   International Business Machines Corp, Plain Va...  0x00102c2565da06a0
# 1   International Business Machines Corp, Fixed Ma...  0x0004051b94d20854
# 2   International Business Machines Corp, Plain Va...  0x00102c28b5f20b58
# 3   International Business Machines Corp, Plain Va...  0x00102c2452251a75
# 4   International Business Machines Corp, Plain Va...  0x0004050e34388b88
# ..                                                ...                 ...
# 95  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...  0x000034000037ecef
# 96  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...  0x000034000037edee
# 97  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...  0x000034000037eeed
# 98  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...  0x000034000037efec
# 99  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...  0x000034000037f0f3
#
#                     BusinessEntity
# 0   INSTRUMENTxFIXEDINCOMExGOVCORP
# 1   INSTRUMENTxFIXEDINCOMExGOVCORP
# 2   INSTRUMENTxFIXEDINCOMExGOVCORP
# 3   INSTRUMENTxFIXEDINCOMExGOVCORP
# 4   INSTRUMENTxFIXEDINCOMExGOVCORP
# ..                             ...
# 95  INSTRUMENTxFIXEDINCOMExGOVCORP
# 96  INSTRUMENTxFIXEDINCOMExGOVCORP
# 97  INSTRUMENTxFIXEDINCOMExGOVCORP
# 98  INSTRUMENTxFIXEDINCOMExGOVCORP
# 99  INSTRUMENTxFIXEDINCOMExGOVCORP
#
# [100 rows x 5 columns]

# %% [markdown]
# #### Filter Expressions

# %%
response = search.Definition(
    view=search.SearchViews.GOV_CORP_INSTRUMENTS,
    select="ISIN,RIC,IssueDate,Currency,FaceIssuedTotal,CouponRate,MaturityDate", 
    filter="IssuerTicker eq 'IBM' and IsActive eq true and AssetStatus ne 'MAT'"
).get_data()
response.data.df
# Out:
#             RIC          ISIN  FaceIssuedTotal  CouponRate Currency  \
# 0    45920FTU2=  US45920FTU20             <NA>         0.0      USD
# 1    45920FTV0=  US45920FTV03             <NA>         0.0      USD
# 2    45920FTW8=  US45920FTW85             <NA>         0.0      USD
# 3  US137584115=  XS1375841159     1000000000.0         0.5      EUR
# 4    459200HX2=  US459200HX26     1100000000.0     0.75538      USD
# 5    459200JQ5=  US459200JQ56     1000000000.0         2.5      USD
# 6    459200JX0=  US459200JX08     2750000000.0        2.85      USD
# 7    459200HG9=  US459200HG92     1000000000.0       1.875      USD
# 8  US127166528=  XS1271665280      300000000.0       2.625      GBP
# 9    459200JC6=  US459200JC60      900000000.0       2.875      USD
#
#                MaturityDate                 IssueDate
# 0  2021-06-28T00:00:00.000Z  2021-06-15T00:00:00.000Z
# 1  2021-06-29T00:00:00.000Z  2021-06-15T00:00:00.000Z
# 2  2021-06-30T00:00:00.000Z  2021-06-15T00:00:00.000Z
# 3  2021-09-07T00:00:00.000Z  2016-03-07T00:00:00.000Z
# 4  2021-11-06T00:00:00.000Z  2014-11-06T00:00:00.000Z
# 5  2022-01-27T00:00:00.000Z  2017-01-27T00:00:00.000Z
# 6  2022-05-13T00:00:00.000Z  2019-05-15T00:00:00.000Z
# 7  2022-08-01T00:00:00.000Z  2012-07-30T00:00:00.000Z
# 8  2022-08-05T00:00:00.000Z  2015-08-05T00:00:00.000Z
# 9  2022-11-09T00:00:00.000Z  2015-11-09T00:00:00.000Z

# %% [markdown]
# #### Properties - Metadata

# %%
response = search.metadata.Definition(
    view = search.SearchViews.GOV_CORP_INSTRUMENTS  # Required parameterc
).get_data()

# for Pandas Display purpose only
pd.set_option("display.max_columns", None) 
pd.set_option("display.max_rows", 10)  # Just show 10 rows
pd.set_option("display.max_colwidth", 1)  

response.data.df
# Out:
#                                                         Type  Searchable  \
# AccrualDate               AccrualDate                Date     True
# AccruedInterest           AccruedInterest            Double   True
# ActiveEstimatesExist      ActiveEstimatesExist       Boolean  True
# AdtLocalCurrencyValue     AdtLocalCurrencyValue      String   True
# AdtLocalCurrencyValueName AdtLocalCurrencyValueName  String   True
# ...                                                     ...    ...
# WorstStandardYield        WorstStandardYield         Double   True
# WorstYearsToRedem         WorstYearsToRedem          Double   True
# YieldCurveBenchmarkRIC    YieldCurveBenchmarkRIC     String   False
# YieldTypeDescription      YieldTypeDescription       String   True
# ZCodeValue                ZCodeValue                 String   True
#
#                                                      Sortable  Navigable  \
# AccrualDate               AccrualDate                True      True
# AccruedInterest           AccruedInterest            True      True
# ActiveEstimatesExist      ActiveEstimatesExist       False     False
# AdtLocalCurrencyValue     AdtLocalCurrencyValue      False     False
# AdtLocalCurrencyValueName AdtLocalCurrencyValueName  False     False
# ...                                                    ...       ...
# WorstStandardYield        WorstStandardYield         True      True
# WorstYearsToRedem         WorstYearsToRedem          True      True
# YieldCurveBenchmarkRIC    YieldCurveBenchmarkRIC     False     False
# YieldTypeDescription      YieldTypeDescription       False     False
# ZCodeValue                ZCodeValue                 True      False
#
#                                                      Groupable  Exact  Symbol
# AccrualDate               AccrualDate                False      False  False
# AccruedInterest           AccruedInterest            False      False  False
# ActiveEstimatesExist      ActiveEstimatesExist       False      False  False
# AdtLocalCurrencyValue     AdtLocalCurrencyValue      False      False  False
# AdtLocalCurrencyValueName AdtLocalCurrencyValueName  False      False  False
# ...                                                    ...        ...    ...
# WorstStandardYield        WorstStandardYield         False      False  False
# WorstYearsToRedem         WorstYearsToRedem          False      False  False
# YieldCurveBenchmarkRIC    YieldCurveBenchmarkRIC     False      False  False
# YieldTypeDescription      YieldTypeDescription       False      False  False
# ZCodeValue                ZCodeValue                 False      False  True
#
# [1123 rows x 7 columns]

# %% [markdown]
# #### Navigators

# %%
response = search.Definition(
    top=0,
    navigators="RCSTRBC2012Leaf"
).get_data()

# %% [markdown]
# #### Response Data Structure

# %%
# Check if request was successful
if (response.is_success):
    # Should have raw data when is_success==true
    if response.data.raw:
        display(response.data.raw)
    else:
        print("Response does not contain raw data")    
    # Check if the response contains a Dataframe too?
    if (not response.data.df.empty):
        display(response.data.df)
    else:
        print("\nResponse does not contain DataFrame")
else: 
    # Something went wrong
    print(f"Not Sucessful : {response.http_status}")
# Out:
# {'Total': 150640918,
#  'Hits': [],
#  'Navigators': {'RCSTRBC2012Leaf': {'Buckets': [{'Label': 'Banks (NEC)',
#      'Count': 3775012},
#     {'Label': 'Corporate Financial Services (NEC)', 'Count': 2886825},
#     {'Label': 'Corporate Banks', 'Count': 1522264},
#     {'Label': 'Retail & Mortgage Banks', 'Count': 1298579},
#     {'Label': 'Public Finance Activities', 'Count': 788526},
#     {'Label': 'Investment Banking & Brokerage Services (NEC)',
#      'Count': 684525},
#     {'Label': 'Investment Management & Fund Operators (NEC)', 'Count': 379386},
#     {'Label': 'Consumer Lending (NEC)', 'Count': 366663},
#     {'Label': 'Electric Utilities (NEC)', 'Count': 296868},
#     {'Label': 'Diversified Investment Services', 'Count': 292815},
#     {'Label': 'Investment Holding Companies (NEC)', 'Count': 281637},
#     {'Label': 'Professional Information Services (NEC)', 'Count': 276399},
#     {'Label': 'Wealth Management', 'Count': 272168},
#     {'Label': 'Construction & Engineering (NEC)', 'Count': 251743},
#     {'Label': 'Real Estate Rental, Development & Operations (NEC)',
#      'Count': 249863},
#     {'Label': 'Business Support Services (NEC)', 'Count': 226756},
#     {'Label': 'Building Contractors', 'Count': 201991},
#     {'Label': 'Government & Government Finance (NEC)', 'Count': 186137},
#     {'Label': 'Financial & Commodity Market Operators & Service Providers (NEC)',
#      'Count': 182470},
#     {'Label': 'Management Consulting Services', 'Count': 164239},
#     {'Label': 'Investment Banking', 'Count': 149835},
#     {'Label': 'UK Investment Trusts', 'Count': 139471},
#     {'Label': 'Software (NEC)', 'Count': 132638},
#     {'Label': 'IT Services & Consulting (NEC)', 'Count': 132541},
#     {'Label': 'Real Estate Services (NEC)', 'Count': 113948},
#     {'Label': 'Consumer Leasing', 'Count': 111398},
#     {'Label': 'Investment Management', 'Count': 103672},
#     {'Label': 'Supermarkets & Convenience Stores', 'Count': 101387},
#     {'Label': 'Hedge Funds', 'Count': 97473},
#     {'Label': 'Pharmaceuticals (NEC)', 'Count': 95695},
#     {'Label': 'Integrated Telecommunications Services (NEC)', 'Count': 92734},
#     {'Label': 'Oil & Gas Exploration and Production (NEC)', 'Count': 85934},
#     {'Label': 'Hospitals, Clinics & Primary Care Services', 'Count': 84013},
#     {'Label': 'Brokerage Services', 'Count': 82242},
#     {'Label': 'Industrial Machinery & Equipment (NEC)', 'Count': 81834},
#     {'Label': 'Commodity Chemicals (NEC)', 'Count': 79239},
#     {'Label': 'Insurance Brokers', 'Count': 74741},
#     {'Label': 'Food Processing (NEC)', 'Count': 73713},
#     {'Label': 'Auto Vehicles, Parts & Service Retailers (NEC)',
#      'Count': 72708},
#     {'Label': 'Restaurants & Bars (NEC)', 'Count': 68322},
#     {'Label': 'Industrial Machinery', 'Count': 64387},
#     {'Label': 'Residential Builders - Single Homes', 'Count': 62864},
#     {'Label': 'Miscellaneous Educational Service Providers', 'Count': 61772},
#     {'Label': 'Construction Materials (NEC)', 'Count': 60027},
#     {'Label': 'Multiline Utilities', 'Count': 58558},
#     {'Label': 'Electrical Components & Equipment (NEC)', 'Count': 58153},
#     {'Label': 'Auto, Truck & Motorcycle Parts (NEC)', 'Count': 56186},
#     {'Label': 'Government Administration Activities', 'Count': 55322},
#     {'Label': 'Closed End Funds', 'Count': 55093},
#     {'Label': 'Hotels & Motels', 'Count': 54066},
#     {'Label': 'Land Division & Subdivision', 'Count': 52575},
#     {'Label': 'Freight Trucking', 'Count': 51759},
#     {'Label': 'Biotechnology & Medical Research (NEC)', 'Count': 50738},
#     {'Label': 'Consumer Goods Conglomerates', 'Count': 50672},
#     {'Label': 'Shell Companies', 'Count': 50124},
#     {'Label': 'Commercial Loans', 'Count': 49190},
#     {'Label': 'Highway & Bridge Construction', 'Count': 48958},
#     {'Label': 'Auto & Truck Manufacturers (NEC)', 'Count': 48790},
#     {'Label': 'Civil Engineers & Architects', 'Count': 48690},
#     {'Label': 'Life & Health Insurance (NEC)', 'Count': 48397},
#     {'Label': 'Oil & Gas Refining and Marketing (NEC)', 'Count': 47664},
#     {'Label': 'Plastics', 'Count': 47268},
#     {'Label': 'Iron & Steel (NEC)', 'Count': 47182},
#     {'Label': 'Metallic Rolling & Drawing Products', 'Count': 46257},
#     {'Label': 'Personal Services (NEC)', 'Count': 45802},
#     {'Label': 'Office Real Estate Rental & Development', 'Count': 43245},
#     {'Label': 'Drug Retailers (NEC)', 'Count': 43054},
#     {'Label': 'Healthcare Facilities & Services (NEC)', 'Count': 43006},
#     {'Label': 'Plumbing Fixtures & Fittings', 'Count': 42951},
#     {'Label': 'Oil & Gas Transportation Services (NEC)', 'Count': 40467},
#     {'Label': 'Diversified Mining', 'Count': 39617},
#     {'Label': 'Credit Unions', 'Count': 39315},
#     {'Label': 'Wireless Telecommunications Services (NEC)', 'Count': 38929},
#     {'Label': 'Commercial Leasing', 'Count': 38605},
#     {'Label': 'Passenger Transportation, Ground & Sea (NEC)', 'Count': 37918},
#     {'Label': 'Semiconductors (NEC)', 'Count': 37663},
#     {'Label': 'Homebuilding (NEC)', 'Count': 37551},
#     {'Label': 'Maintenance & Repair Services', 'Count': 37385},
#     {'Label': 'Gasoline Stations', 'Count': 37196},
#     {'Label': 'Waste Management, Disposal & Recycling Services',
#      'Count': 36311},
#     {'Label': 'Property & Casualty Insurance (NEC)', 'Count': 35567},
#     {'Label': 'Legal Services', 'Count': 35313},
#     {'Label': 'Medical Equipment, Supplies & Distribution (NEC)',
#      'Count': 34931},
#     {'Label': 'Residential Real Estate Rental & Development', 'Count': 34524},
#     {'Label': 'Petroleum Refining', 'Count': 34229},
#     {'Label': 'Private Banks', 'Count': 34044},
#     {'Label': 'Commercial Buildings', 'Count': 33416},
#     {'Label': 'Coal (NEC)', 'Count': 32610},
#     {'Label': 'Broadcasting (NEC)', 'Count': 32409},
#     {'Label': 'Freight Logistics', 'Count': 32093},
#     {'Label': 'Cement & Concrete Manufacturing', 'Count': 32076},
#     {'Label': 'Natural Gas Utilities (NEC)', 'Count': 31988},
#     {'Label': 'Commercial REITs (NEC)', 'Count': 31882},
#     {'Label': 'Child Care & Family Services', 'Count': 31121},
#     {'Label': 'Advertising Agency', 'Count': 30877},
#     {'Label': 'Bio Therapeutic Drugs', 'Count': 30838},
#     {'Label': 'Communications & Networking (NEC)', 'Count': 30395},
#     {'Label': 'Gold Mining', 'Count': 30276},
#     {'Label': 'Personal & Car Loans', 'Count': 30115},
#     {'Label': 'Apparel & Accessories (NEC)', 'Count': 29908}]}}}
# Response does not contain DataFrame

# %% [markdown]
# #### Search with Navigator option

# %%
response = search.Definition(
    view=search.SearchViews.COMMODITY_QUOTES,
    query="cheese",
    navigators="ExchangeName"
).get_data()

response.data.df
# Out:
#         PermID    RIC  \
# 0  21622940491  CSCc1
# 1  21701993019  CSCM1
# 2  21705602183  CSCN1
# 3  21710249450  CSCQ1
# 4  21714572907  CSCU1
# 5  21718846354  CSCV1
# 6  21723899060  CSCX1
# 7  21727643040  CSCZ1
# 8  21733097271  CSCF2
# 9  21737604992  CSCG2
#
#                                                                                                        DocumentTitle  \
# 0  CME Cash Settled Cheese Electronic Commodity Future Continuation 1, Commodity Future, Chicago Mercantile Exchange
# 1  CME Cash Settled Cheese Electronic Commodity Future Jun 2021, Commodity Future, Chicago Mercantile Exchange
# 2  CME Cash Settled Cheese Electronic Commodity Future Jul 2021, Commodity Future, Chicago Mercantile Exchange
# 3  CME Cash Settled Cheese Electronic Commodity Future Aug 2021, Commodity Future, Chicago Mercantile Exchange
# 4  CME Cash Settled Cheese Electronic Commodity Future Sep 2021, Commodity Future, Chicago Mercantile Exchange
# 5  CME Cash Settled Cheese Electronic Commodity Future Oct 2021, Commodity Future, Chicago Mercantile Exchange
# 6  CME Cash Settled Cheese Electronic Commodity Future Nov 2021, Commodity Future, Chicago Mercantile Exchange
# 7  CME Cash Settled Cheese Electronic Commodity Future Dec 2021, Commodity Future, Chicago Mercantile Exchange
# 8  CME Cash Settled Cheese Electronic Commodity Future Jan 2022, Commodity Future, Chicago Mercantile Exchange
# 9  CME Cash Settled Cheese Electronic Commodity Future Feb 2022, Commodity Future, Chicago Mercantile Exchange
#
#           PI   BusinessEntity
# 0  273610776  QUOTExCOMMODITY
# 1  374717665  QUOTExCOMMODITY
# 2  379195159  QUOTExCOMMODITY
# 3  384919875  QUOTExCOMMODITY
# 4  390497653  QUOTExCOMMODITY
# 5  396055563  QUOTExCOMMODITY
# 6  402256891  QUOTExCOMMODITY
# 7  406809544  QUOTExCOMMODITY
# 8  413501786  QUOTExCOMMODITY
# 9  419119906  QUOTExCOMMODITY

# %%
response.data.raw["Navigators"]['ExchangeName']
# Out:
# {'Buckets': [{'Label': 'CME:Index and Options Market', 'Count': 18994},
#   {'Label': 'Chicago Mercantile Exchange', 'Count': 5522},
#   {'Label': 'INTL FCStone Inc', 'Count': 2550},
#   {'Label': 'Source is a Refinitiv Contributor', 'Count': 1498},
#   {'Label': 'US Department of Agriculture', 'Count': 93},
#   {'Label': 'Commodity Futures Trading Commission', 'Count': 66},
#   {'Label': 'Complete Intelligence', 'Count': 37},
#   {'Label': 'Intercontinental Exchange US', 'Count': 31},
#   {'Label': 'US Bureau Of Labor Statistics', 'Count': 10},
#   {'Label': 'DCA Markets B.V. - DCA-Markets-PRA Price Reporting Agent',
#    'Count': 4},
#   {'Label': 'European Energy Exchange', 'Count': 4},
#   {'Label': 'European Commission', 'Count': 3},
#   {'Label': 'ESALQ', 'Count': 2},
#   {'Label': 'CME:International Monetary Market', 'Count': 1}]}

# %%
response = search.Definition(
    view=search.SearchViews.GOV_CORP_INSTRUMENTS,
    top=0,
    navigators="Currency(buckets:10,desc:sum_FaceOutstandingUSD,calc:max_CouponRate)"
).get_data()

response.data.raw
# Out:
# {'Total': 8197963,
#  'Hits': [],
#  'Navigators': {'Currency': {'Buckets': [{'Label': 'USD',
#      'Count': 3375680,
#      'max_CouponRate': 1800.0,
#      'sum_FaceOutstandingUSD': 47436167201705.0},
#     {'Label': 'EUR',
#      'Count': 1015933,
#      'max_CouponRate': 500.0,
#      'sum_FaceOutstandingUSD': 23960096412656.0},
#     {'Label': 'CNY',
#      'Count': 278928,
#      'max_CouponRate': 72.0,
#      'sum_FaceOutstandingUSD': 18025225051926.0},
#     {'Label': 'JPY',
#      'Count': 420867,
#      'max_CouponRate': 500.0,
#      'sum_FaceOutstandingUSD': 12995691062214.018},
#     {'Label': 'GBP',
#      'Count': 178402,
#      'max_CouponRate': 120.0,
#      'sum_FaceOutstandingUSD': 4754746999620.0},
#     {'Label': 'INR',
#      'Count': 102331,
#      'max_CouponRate': 42.75,
#      'sum_FaceOutstandingUSD': 2576371812533.0},
#     {'Label': 'CAD',
#      'Count': 292471,
#      'max_CouponRate': 100.0,
#      'sum_FaceOutstandingUSD': 2558111967771.0},
#     {'Label': 'KRW',
#      'Count': 372927,
#      'max_CouponRate': 42.0,
#      'sum_FaceOutstandingUSD': 2341010079416.714},
#     {'Label': 'AUD',
#      'Count': 129013,
#      'max_CouponRate': 120.96,
#      'sum_FaceOutstandingUSD': 1571593670146.761},
#     {'Label': 'BRL',
#      'Count': 41004,
#      'max_CouponRate': 108.5,
#      'sum_FaceOutstandingUSD': 935952535159.9685}]}}}

# %% [markdown]
# #### Sub-navigator

# %%
response = search.Definition(
    view=search.SearchViews.PEOPLE,
    top=0,
    navigators="FirstName(buckets:3,sub:LastName(buckets:2))"
).get_data()

response.data.raw["Navigators"]["FirstName"]["Buckets"]
# Out:
# [{'Label': 'John',
#   'Count': 39045,
#   'LastName': {'Buckets': [{'Label': 'Lee', 'Count': 101},
#     {'Label': 'Murphy', 'Count': 100}]}},
#  {'Label': 'David',
#   'Count': 37491,
#   'LastName': {'Buckets': [{'Label': 'Smith', 'Count': 225},
#     {'Label': 'Williams', 'Count': 150}]}},
#  {'Label': 'Michael',
#   'Count': 36203,
#   'LastName': {'Buckets': [{'Label': 'Smith', 'Count': 177},
#     {'Label': 'Brown', 'Count': 117}]}}]

# %% [markdown]
# #### Search with order_by option

# %%
response = search.Definition(
    view=search.SearchViews.PEOPLE,
    query="ceo",
    order_by="YearOfBirth desc,LastName,FirstName",
    select="YearOfBirth,DocumentTitle"
).get_data()

response.data.df
# Out:
#                                                                                                                                   DocumentTitle  \
# 0  Shu Yao - Dongjiang Environmental Co Ltd - Ex-Chief Executive Officer, Executive Director
# 1  Connor Campbell - Osler Diagnostics Ltd - Chief Executive Officer, Co-Founder
# 2  Christian Besenbruch - Deep Render Ltd - Chief Executive Officer and Co-Founder
# 3  Ed Leon Klinger - Flock Ltd - Chief Executive Officer
# 4  Ivan Aleksandrovich Plekhanov - Territorial'naya Generiruyushchaya Kompaniya No2 PAO - Executive Director, Adviser to General Director (CEO)
# 5  Grigory Sergeevich Sandulov - Omskiy Rechnoy Port AO - General Director (CEO), Director
# 6  Yehonatan Shachar - Upsellon Brands Holdings Ltd - Chief Executive Officer
# 7  Myeong Jin Chae - Arion Technology Inc - Chief Executive Officer, Director
# 8  Pedro de Godoy Bueno - Diagnosticos da America SA - Chief Executive Officer, Director
# 9  Hikaru Ohno - Cyber Security Cloud Inc - President, Chief Executive Officer, Representative Director
#
#    YearOfBirth
# 0  1996
# 1  1994
# 2  1992
# 3  1992
# 4  1992
# 5  1991
# 6  1991
# 7  1990
# 8  1990
# 9  1990

# %% [markdown]
# #### Search with group_by option

# %%
response = search.Definition(
    view=search.SearchViews.INDICATOR_QUOTES,
    query="rate",
    group_by="CentralBankName",
    group_count=2,
    select="CentralBankName,DocumentTitle,RIC"
).get_data()

response.data.df
# Out:
#                           CentralBankName  \
# 0  Federal Reserve System
# 1  Federal Reserve System
# 2  European Central Bank
# 3  European Central Bank
# 4  Bank of Canada
# 5  Bank of Canada
# 6  Central Bank of the Russian Federation
# 7  Central Bank of the Russian Federation
# 8  Bank of Mauritius
# 9  National Bank of Poland
#
#                                                                                                                          DocumentTitle  \
# 0  United States, Policy Rates, Fed Funds Target Rate, Reuters Polls, Daily, The Federal Open Market Committee
# 1  United States, Policy Rates, Fed Overnight Repo, Reuters Polls, Daily, Federal Reserve, United States
# 2  Euro Zone, Policy Rates, ECB Main refinancing, Fixed Rate (Announcement Dates), Reuters Polls, Monthly, ECB - European Central Bank
# 3  Euro Zone, Policy Rates, ECB Deposit Rate, Reuters Polls, Monthly, ECB - European Central Bank
# 4  Canada, Policy Rates, Overnight Target Rate, Reuters Polls, Daily, Bank of Canada
# 5  Canada, OVERNIGHT TARGET RATE - BRITISH COLUMBIA, Reuters Polls, Daily, Reuters
# 6  Russia, Central bank key rate, Reuters Polls, Monthly, The Central Bank of the Russian Federation
# 7  Russia, CENTRAL BANK KEY RATE - SBERBANK CIB, Reuters Polls, Monthly, Reuters
# 8  Mauritius, Policy Rates, Key Repo Rate, Reuters Polls, Quarterly, Bank of Mauritius
# 9  Poland, Policy Rates, Reference Rate (7-Day NBP Bill Rate), Reuters Polls, Monthly, National Bank of Poland
#
#                   RIC
# 0  USFOMC=ECI
# 1  USRRP=ECI
# 2  EUECBR=ECI
# 3  EUECBD=ECI
# 4  CABOCR=ECI
# 5  pCABOCR=4295895833
# 6  RUCBIR=ECI
# 7  pRUCBIR=4298348094
# 8  MUCBIR=ECI
# 9  PLINTR=ECI

# %% [markdown]
# #### Search For People

# %%
response = search.Definition(
    query="cfo",
    view=search.SearchViews.PEOPLE
).get_data()

response.data.df
# Out:
#             PI BusinessEntity  \
# 0  34415553383  PERSON
# 1  34414554748  PERSON
# 2  34417610894  PERSON
# 3  34413960665  PERSON
# 4  34414804241  PERSON
# 5  34413152672  PERSON
# 6  34414966250  PERSON
# 7  34414263702  PERSON
# 8  34414907131  PERSON
# 9  34413340523  PERSON
#
#                                                                                        DocumentTitle  \
# 0  Amy E. Hood - Microsoft Corp - Chief Financial Officer, Executive Vice President
# 1  Luca Maestri - Apple Inc - Chief Financial Officer, Senior Vice President
# 2  Brian T. Olsavsky - Amazon.com Inc - Chief Financial Officer, Senior Vice President
# 3  Ruth M. Porat - Alphabet Inc - Chief Financial Officer, Senior Vice President
# 4  David M. Wehner - Facebook Inc - Chief Financial Officer
# 5  Marc D. Hamburg - Berkshire Hathaway Inc - Chief Financial Officer, Senior Vice President
# 6  Andrew K. Klatt - Berkshire Hathaway Inc - CFO & COO
# 7  Maggie Wu - Alibaba Group Holding Ltd - Chief Financial Officer and Head of Strategic Investments
# 8  John Lo - Tencent Holdings Ltd - Chief Financial Officer, Senior Vice President
# 9  Vasant M. Prabhu - Visa Inc - Vice Chairman of the Board, Chief Financial Officer
#
#         PermID
# 0  34415553383
# 1  34414554748
# 2  34417610894
# 3  34413960665
# 4  34414804241
# 5  34413152672
# 6  34414966250
# 7  34414263702
# 8  34414907131
# 9  34413340523

# %% [markdown]
# ### Lookup

# %%
response = search.lookup.Definition(
    view=search.SearchViews.INSTRUMENTS,                               # Required parameter
    scope="RIC",                                                       # Required parameter
    terms="MSFT.O,AAPL.O,GOOG.O,IBM.N,KBANK.BK,SCC.BK",                # Required parameter
    select="BusinessEntity,DocumentTitle,CUSIP,SEDOL",                 # Required parameter
).get_data()

response.data.df
# Out:
#              BusinessEntity                     DocumentTitle      CUSIP  \
# MSFT.O    INSTRUMENTxEQUITY  Microsoft Corp, Ordinary Share    594918104
# AAPL.O    INSTRUMENTxEQUITY  Apple Inc, Ordinary Share         037833100
# GOOG.O    INSTRUMENTxEQUITY  Alphabet Inc, Ordinary Share      02079K107
# KBANK.BK  INSTRUMENTxEQUITY  Kasikornbank PCL, Ordinary Share  <NA>
# SCC.BK    INSTRUMENTxEQUITY  Siam Cement PCL, Ordinary Share   <NA>
#
#             SEDOL
# MSFT.O    <NA>
# AAPL.O    <NA>
# GOOG.O    <NA>
# KBANK.BK  6888783
# SCC.BK    6609917

# %%
response = search.lookup.Definition(
    view=search.SearchViews.SEARCH_ALL,                              # Required parameter
    scope="RIC",                                                     # Required parameter
    terms="A,B,NOSUCHRIC,C,D",                                       # Required parameter
    select="BusinessEntity,DocumentTitle",                           # Required parameter
).get_data()

response.data.df
# Out:
#   BusinessEntity                                                DocumentTitle
# A  QUOTExEQUITY   Agilent Technologies Inc, Ordinary Share, NYSE Consolidated
# B  QUOTExEQUITY   Barnes Group Inc, Ordinary Share, NYSE Consolidated
# C  QUOTExEQUITY   Citigroup Inc, Ordinary Share, NYSE Consolidated
# D  QUOTExEQUITY   Dominion Energy Inc, Ordinary Share, NYSE Consolidated

# %% [markdown]
# ## Close the session

# %%
close_session()
