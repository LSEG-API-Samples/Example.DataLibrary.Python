# %% [markdown]
# # Refinitiv Data Library for Python
# ## Content - Search, Lookup and View Metadata
# This notebook demonstrates how to utilise the Search API using the Refinitiv Data Platform OR via Refinitiv Eikon/Workspace.
#
# For more details on the Search API refer to the following:
#
# * The article, [Building Search into your Application Workflow](https://developers.refinitiv.com/en/article-catalog/article/building-search-into-your-application-workflow), provides an overview of the capabilities of the Search service including tips and tricks and many useful techniques.
#
# * Search API documentation: [Search Reference Guide](https://apidocs.refinitiv.com/Apps/ApiDocs#/details/L2Rpc2NvdmVyeS9zZWFyY2gvdjE=/Lw==/POST/README)

# %% [markdown]
# ## Import the library and load credentials
#
# Credentials used by this and the other tutorials notebooks are stored in the **Configuration/credentials.ipynb** file.
#
# You should have edited the **Configuration/credentials.ipynb** to set your credentials as part of the **Quick Start** step.

# %%
from refinitiv.data.content import search
import pandas as pd
import json

# %run ../../Configuration/credentials.ipynb

# %% [markdown]
# ## Open the session of your choice
#
# Use our helper function in the Credentials notebook, **open_session(session_type)**, to create and open a session to connect to the
# - Refinitiv Data Platform directly (session_type="rdp") or via
# - Eikon 4 or Refinitiv Workspace (session_type="desktop")
#
# You can also set a default in the **credentials** notebook
#
# **Note**: You cannot currently use the Search API via a Deployed session

# %%
open_session()
# Out:
# <refinitiv.data.session._platform_session.Definition object at 0x23b5c9d5310 {session_name='default-session'}>

# %% [markdown]
# #### General Search

# %%
response = search.Definition("IBM Bonds").get_data()
response.data.df
# Out:
#          PermID           RIC                  PI  \
# 0   46638470066  US137584115=  0x00102c2565da06a0
# 1   44657599150    459200HX2=  0x0004051b94d20854
# 2   46642939296    459200JQ5=  0x00102c28b5f20b58
# 3  192841929423    459200JX0=  0x00102c2452251a75
# 4   44640212240    459200HG9=  0x0004050e34388b88
# 5   46635711098  US127166528=  0x00102c05c4dd0222
# 6   46637038358    459200JC6=  0x00102c80bf6b046c
# 7  192826899363  US194445601=  0x00102c53ff1f1897
# 8   44657843041  US114316318=  0x0004051bd47954e3
# 9   44649129642    459200HP9=  0x00040513a4865c6c
#
#                    BusinessEntity  \
# 0  INSTRUMENTxFIXEDINCOMExGOVCORP
# 1  INSTRUMENTxFIXEDINCOMExGOVCORP
# 2  INSTRUMENTxFIXEDINCOMExGOVCORP
# 3  INSTRUMENTxFIXEDINCOMExGOVCORP
# 4  INSTRUMENTxFIXEDINCOMExGOVCORP
# 5  INSTRUMENTxFIXEDINCOMExGOVCORP
# 6  INSTRUMENTxFIXEDINCOMExGOVCORP
# 7  INSTRUMENTxFIXEDINCOMExGOVCORP
# 8  INSTRUMENTxFIXEDINCOMExGOVCORP
# 9  INSTRUMENTxFIXEDINCOMExGOVCORP
#
#                                        DocumentTitle
# 0  International Business Machines Corp, Plain Va...
# 1  International Business Machines Corp, Fixed Ma...
# 2  International Business Machines Corp, Plain Va...
# 3  International Business Machines Corp, Plain Va...
# 4  International Business Machines Corp, Plain Va...
# 5  International Business Machines Corp, Plain Va...
# 6  International Business Machines Corp, Plain Va...
# 7  International Business Machines Corp, Plain Va...
# 8  International Business Machines Corp, Plain Va...
# 9  International Business Machines Corp, Plain Va...

# %% [markdown]
# #### Specify number of rows to fetch

# %%
response = search.Definition("IBM Bonds", top=100).get_data()
response.data.df
# Out:
#           PermID           RIC                  PI  \
# 0    46638470066  US137584115=  0x00102c2565da06a0
# 1    44657599150    459200HX2=  0x0004051b94d20854
# 2    46642939296    459200JQ5=  0x00102c28b5f20b58
# 3   192841929423    459200JX0=  0x00102c2452251a75
# 4    44640212240    459200HG9=  0x0004050e34388b88
# ..           ...           ...                 ...
# 95          <NA>          <NA>  0x000034000037ecef
# 96          <NA>          <NA>  0x000034000037edee
# 97          <NA>          <NA>  0x000034000037eeed
# 98          <NA>          <NA>  0x000034000037efec
# 99          <NA>          <NA>  0x000034000037f0f3
#
#                     BusinessEntity  \
# 0   INSTRUMENTxFIXEDINCOMExGOVCORP
# 1   INSTRUMENTxFIXEDINCOMExGOVCORP
# 2   INSTRUMENTxFIXEDINCOMExGOVCORP
# 3   INSTRUMENTxFIXEDINCOMExGOVCORP
# 4   INSTRUMENTxFIXEDINCOMExGOVCORP
# ..                             ...
# 95  INSTRUMENTxFIXEDINCOMExGOVCORP
# 96  INSTRUMENTxFIXEDINCOMExGOVCORP
# 97  INSTRUMENTxFIXEDINCOMExGOVCORP
# 98  INSTRUMENTxFIXEDINCOMExGOVCORP
# 99  INSTRUMENTxFIXEDINCOMExGOVCORP
#
#                                         DocumentTitle
# 0   International Business Machines Corp, Plain Va...
# 1   International Business Machines Corp, Fixed Ma...
# 2   International Business Machines Corp, Plain Va...
# 3   International Business Machines Corp, Plain Va...
# 4   International Business Machines Corp, Plain Va...
# ..                                                ...
# 95  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...
# 96  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...
# 97  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...
# 98  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...
# 99  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...
#
# [100 rows x 5 columns]

# %% [markdown]
# #### Filter Expressions

# %%
response = search.Definition(
    view=search.SearchViews.GOV_CORP_INSTRUMENTS,
    select="ISIN,RIC,IssueDate,Currency,FaceIssuedTotal,CouponRate,MaturityDate", 
    filter="IssuerTicker eq 'IBM' and IsActive eq true and AssetStatus ne 'MAT'"
).get_data()
response.data.df
# Out:
#             RIC  CouponRate  FaceIssuedTotal                 IssueDate  \
# 0  US137584115=         0.5     1000000000.0  2016-03-07T00:00:00.000Z
# 1    45920FWT1=         0.0             <NA>  2021-08-25T00:00:00.000Z
# 2    45920FWU8=         0.0             <NA>  2021-08-25T00:00:00.000Z
# 3    45920FWV6=         0.0             <NA>  2021-08-25T00:00:00.000Z
# 4    45920FWW4=         0.0             <NA>  2021-08-25T00:00:00.000Z
# 5    459200HX2=     0.70175     1100000000.0  2014-11-06T00:00:00.000Z
# 6    459200JQ5=         2.5     1000000000.0  2017-01-27T00:00:00.000Z
# 7    459200JX0=        2.85     2750000000.0  2019-05-15T00:00:00.000Z
# 8    459200HG9=       1.875     1000000000.0  2012-07-30T00:00:00.000Z
# 9  US127166528=       2.625      300000000.0  2015-08-05T00:00:00.000Z
#
#                MaturityDate          ISIN Currency
# 0  2021-09-07T00:00:00.000Z  XS1375841159      EUR
# 1  2021-09-27T00:00:00.000Z  US45920FWT10      USD
# 2  2021-09-28T00:00:00.000Z  US45920FWU82      USD
# 3  2021-09-29T00:00:00.000Z  US45920FWV65      USD
# 4  2021-09-30T00:00:00.000Z  US45920FWW49      USD
# 5  2021-11-06T00:00:00.000Z  US459200HX26      USD
# 6  2022-01-27T00:00:00.000Z  US459200JQ56      USD
# 7  2022-05-13T00:00:00.000Z  US459200JX08      USD
# 8  2022-08-01T00:00:00.000Z  US459200HG92      USD
# 9  2022-08-05T00:00:00.000Z  XS1271665280      GBP

# %% [markdown]
# #### Properties - Metadata

# %%
response = search.metadata.Definition(
    view = search.SearchViews.GOV_CORP_INSTRUMENTS  # Required parameterc
).get_data()

# for Pandas Display purpose only
pd.set_option("display.max_columns", None) 
pd.set_option("display.max_rows", 10)  # Just show 10 rows
pd.set_option("display.max_colwidth", 1)  

response.data.df
# Out:
#                                                         Type  Searchable  \
# AccrualDate               AccrualDate                Date     True
# AccruedInterest           AccruedInterest            Double   True
# ActiveEstimatesExist      ActiveEstimatesExist       Boolean  True
# AdtLocalCurrencyValue     AdtLocalCurrencyValue      String   True
# AdtLocalCurrencyValueName AdtLocalCurrencyValueName  String   True
# ...                                                     ...    ...
# WorstStandardYield        WorstStandardYield         Double   True
# WorstYearsToRedem         WorstYearsToRedem          Double   True
# YieldCurveBenchmarkRIC    YieldCurveBenchmarkRIC     String   False
# YieldTypeDescription      YieldTypeDescription       String   True
# ZCodeValue                ZCodeValue                 String   True
#
#                                                      Sortable  Navigable  \
# AccrualDate               AccrualDate                True      True
# AccruedInterest           AccruedInterest            True      True
# ActiveEstimatesExist      ActiveEstimatesExist       False     False
# AdtLocalCurrencyValue     AdtLocalCurrencyValue      False     False
# AdtLocalCurrencyValueName AdtLocalCurrencyValueName  False     False
# ...                                                    ...       ...
# WorstStandardYield        WorstStandardYield         True      True
# WorstYearsToRedem         WorstYearsToRedem          True      True
# YieldCurveBenchmarkRIC    YieldCurveBenchmarkRIC     False     False
# YieldTypeDescription      YieldTypeDescription       False     False
# ZCodeValue                ZCodeValue                 True      False
#
#                                                      Groupable  Exact  Symbol
# AccrualDate               AccrualDate                False      False  False
# AccruedInterest           AccruedInterest            False      False  False
# ActiveEstimatesExist      ActiveEstimatesExist       False      False  False
# AdtLocalCurrencyValue     AdtLocalCurrencyValue      False      False  False
# AdtLocalCurrencyValueName AdtLocalCurrencyValueName  False      False  False
# ...                                                    ...        ...    ...
# WorstStandardYield        WorstStandardYield         False      False  False
# WorstYearsToRedem         WorstYearsToRedem          False      False  False
# YieldCurveBenchmarkRIC    YieldCurveBenchmarkRIC     False      False  False
# YieldTypeDescription      YieldTypeDescription       False      False  False
# ZCodeValue                ZCodeValue                 False      False  True
#
# [1125 rows x 7 columns]

# %% [markdown]
# #### Navigators

# %%
response = search.Definition(
    top=0,
    navigators="RCSTRBC2012Leaf"
).get_data()

# %% [markdown]
# #### Response Data Structure

# %%
# Check if request was successful
if (response.is_success):
    # Should have raw data when is_success==true
    if response.data.raw:
        display(response.data.raw)
    else:
        print("Response does not contain raw data")    
    # Check if the response contains a Dataframe too?
    if (not response.data.df.empty):
        display(response.data.df)
    else:
        print("\nResponse does not contain DataFrame")
else: 
    # Something went wrong
    print(f"Not Sucessful : {response.http_status}")
# Out:
# {'Total': 153904932,
#  'Hits': [],
#  'Navigators': {'RCSTRBC2012Leaf': {'Buckets': [{'Label': 'Banks (NEC)',
#      'Count': 3867120},
#     {'Label': 'Corporate Financial Services (NEC)', 'Count': 2923655},
#     {'Label': 'Corporate Banks', 'Count': 1487314},
#     {'Label': 'Retail & Mortgage Banks', 'Count': 1273828},
#     {'Label': 'Investment Banking & Brokerage Services (NEC)',
#      'Count': 704973},
#     {'Label': 'Public Finance Activities', 'Count': 694384},
#     {'Label': 'Investment Management & Fund Operators (NEC)', 'Count': 397181},
#     {'Label': 'Consumer Lending (NEC)', 'Count': 368560},
#     {'Label': 'Electric Utilities (NEC)', 'Count': 316257},
#     {'Label': 'Diversified Investment Services', 'Count': 290197},
#     {'Label': 'Wealth Management', 'Count': 285202},
#     {'Label': 'Government & Government Finance (NEC)', 'Count': 282033},
#     {'Label': 'Investment Holding Companies (NEC)', 'Count': 279838},
#     {'Label': 'Professional Information Services (NEC)', 'Count': 277890},
#     {'Label': 'Construction & Engineering (NEC)', 'Count': 262075},
#     {'Label': 'Real Estate Rental, Development & Operations (NEC)',
#      'Count': 254127},
#     {'Label': 'Business Support Services (NEC)', 'Count': 231637},
#     {'Label': 'Building Contractors', 'Count': 201077},
#     {'Label': 'Financial & Commodity Market Operators & Service Providers (NEC)',
#      'Count': 183207},
#     {'Label': 'Management Consulting Services', 'Count': 162845},
#     {'Label': 'Investment Banking', 'Count': 150214},
#     {'Label': 'Software (NEC)', 'Count': 134900},
#     {'Label': 'IT Services & Consulting (NEC)', 'Count': 132640},
#     {'Label': 'UK Investment Trusts', 'Count': 120271},
#     {'Label': 'Investment Management', 'Count': 111119},
#     {'Label': 'Real Estate Services (NEC)', 'Count': 108333},
#     {'Label': 'Consumer Leasing', 'Count': 105562},
#     {'Label': 'Hedge Funds', 'Count': 101699},
#     {'Label': 'Pharmaceuticals (NEC)', 'Count': 97982},
#     {'Label': 'Supermarkets & Convenience Stores', 'Count': 95947},
#     {'Label': 'Integrated Telecommunications Services (NEC)', 'Count': 93701},
#     {'Label': 'Government Administration Activities', 'Count': 90477},
#     {'Label': 'Oil & Gas Exploration and Production (NEC)', 'Count': 87511},
#     {'Label': 'Brokerage Services', 'Count': 83031},
#     {'Label': 'Industrial Machinery & Equipment (NEC)', 'Count': 82339},
#     {'Label': 'Commodity Chemicals (NEC)', 'Count': 80300},
#     {'Label': 'Hospitals, Clinics & Primary Care Services', 'Count': 79278},
#     {'Label': 'Food Processing (NEC)', 'Count': 74466},
#     {'Label': 'Insurance Brokers', 'Count': 73911},
#     {'Label': 'Auto Vehicles, Parts & Service Retailers (NEC)',
#      'Count': 72259},
#     {'Label': 'Restaurants & Bars (NEC)', 'Count': 68015},
#     {'Label': 'Industrial Machinery', 'Count': 63729},
#     {'Label': 'Residential Builders - Single Homes', 'Count': 61736},
#     {'Label': 'Multiline Utilities', 'Count': 60298},
#     {'Label': 'Construction Materials (NEC)', 'Count': 59274},
#     {'Label': 'Electrical Components & Equipment (NEC)', 'Count': 58139},
#     {'Label': 'Auto, Truck & Motorcycle Parts (NEC)', 'Count': 56195},
#     {'Label': 'Land Division & Subdivision', 'Count': 54391},
#     {'Label': 'Hotels & Motels', 'Count': 53600},
#     {'Label': 'Shell Companies', 'Count': 53453},
#     {'Label': 'Closed End Funds', 'Count': 53269},
#     {'Label': 'Miscellaneous Educational Service Providers', 'Count': 52226},
#     {'Label': 'Biotechnology & Medical Research (NEC)', 'Count': 52121},
#     {'Label': 'Auto & Truck Manufacturers (NEC)', 'Count': 51465},
#     {'Label': 'Freight Trucking', 'Count': 51321},
#     {'Label': 'Consumer Goods Conglomerates', 'Count': 51223},
#     {'Label': 'Commercial Loans', 'Count': 50680},
#     {'Label': 'Civil Engineers & Architects', 'Count': 48770},
#     {'Label': 'Oil & Gas Refining and Marketing (NEC)', 'Count': 48432},
#     {'Label': 'Highway & Bridge Construction', 'Count': 48170},
#     {'Label': 'Life & Health Insurance (NEC)', 'Count': 47536},
#     {'Label': 'Office Real Estate Rental & Development', 'Count': 46521},
#     {'Label': 'Iron & Steel (NEC)', 'Count': 46491},
#     {'Label': 'Plastics', 'Count': 46111},
#     {'Label': 'Metallic Rolling & Drawing Products', 'Count': 45714},
#     {'Label': 'Personal Services (NEC)', 'Count': 44486},
#     {'Label': 'Healthcare Facilities & Services (NEC)', 'Count': 43450},
#     {'Label': 'Plumbing Fixtures & Fittings', 'Count': 42454},
#     {'Label': 'Drug Retailers (NEC)', 'Count': 42414},
#     {'Label': 'Diversified Mining', 'Count': 40590},
#     {'Label': 'Oil & Gas Transportation Services (NEC)', 'Count': 40374},
#     {'Label': 'Wireless Telecommunications Services (NEC)', 'Count': 40274},
#     {'Label': 'Passenger Transportation, Ground & Sea (NEC)', 'Count': 38502},
#     {'Label': 'Semiconductors (NEC)', 'Count': 38180},
#     {'Label': 'Homebuilding (NEC)', 'Count': 38119},
#     {'Label': 'Maintenance & Repair Services', 'Count': 36929},
#     {'Label': 'Residential Real Estate Rental & Development', 'Count': 36738},
#     {'Label': 'Gasoline Stations', 'Count': 36649},
#     {'Label': 'Waste Management, Disposal & Recycling Services',
#      'Count': 35998},
#     {'Label': 'Medical Equipment, Supplies & Distribution (NEC)',
#      'Count': 35733},
#     {'Label': 'Commercial Leasing', 'Count': 35536},
#     {'Label': 'Legal Services', 'Count': 35036},
#     {'Label': 'Property & Casualty Insurance (NEC)', 'Count': 34367},
#     {'Label': 'Petroleum Refining', 'Count': 33824},
#     {'Label': 'Ground Freight & Logistics (NEC)', 'Count': 33624},
#     {'Label': 'Commercial Buildings', 'Count': 33291},
#     {'Label': 'Coal (NEC)', 'Count': 33173},
#     {'Label': 'Broadcasting (NEC)', 'Count': 33056},
#     {'Label': 'Natural Gas Utilities (NEC)', 'Count': 32731},
#     {'Label': 'Commercial REITs (NEC)', 'Count': 32670},
#     {'Label': 'Private Banks', 'Count': 32039},
#     {'Label': 'Cement & Concrete Manufacturing', 'Count': 31989},
#     {'Label': 'Bio Therapeutic Drugs', 'Count': 31638},
#     {'Label': 'Freight Logistics', 'Count': 31633},
#     {'Label': 'Personal Products (NEC)', 'Count': 31294},
#     {'Label': 'Food Retail & Distribution (NEC)', 'Count': 31095},
#     {'Label': 'Gold Mining', 'Count': 31057},
#     {'Label': 'Communications & Networking (NEC)', 'Count': 30584},
#     {'Label': 'Advertising Agency', 'Count': 30530},
#     {'Label': 'Industrial Equipment Rental', 'Count': 30519}]}}}
# Response does not contain DataFrame

# %% [markdown]
# #### Search with Navigator option

# %%
response = search.Definition(
    view=search.SearchViews.COMMODITY_QUOTES,
    query="cheese",
    navigators="ExchangeName"
).get_data()

response.data.df
# Out:
#         PermID     RIC         PI   BusinessEntity  \
# 0  21622940491  CSCc1   273610776  QUOTExCOMMODITY
# 1  21622425217  0#CSC:  272623267  QUOTExCOMMODITY
# 2  21718846354  CSCV1   396055563  QUOTExCOMMODITY
# 3  21710249450  CSCQ1   384919875  QUOTExCOMMODITY
# 4  21714572907  CSCU1   390497653  QUOTExCOMMODITY
# 5  21723899060  CSCX1   402256891  QUOTExCOMMODITY
# 6  21753182135  CSCK2   439042441  QUOTExCOMMODITY
# 7  21727643040  CSCZ1   406809544  QUOTExCOMMODITY
# 8  21733097271  CSCF2   413501786  QUOTExCOMMODITY
# 9  21737604992  CSCG2   419119906  QUOTExCOMMODITY
#
#                                                                                                        DocumentTitle
# 0  CME Cash Settled Cheese Electronic Commodity Future Continuation 1, Commodity Future, Chicago Mercantile Exchange
# 1  Cash Settled Cheese Futures Chain Contracts, Commodity Future, Chicago Mercantile Exchange
# 2  CME Cash Settled Cheese Electronic Commodity Future Oct 2021, Commodity Future, Chicago Mercantile Exchange
# 3  CME Cash Settled Cheese Electronic Commodity Future Aug 2021, Commodity Future, Chicago Mercantile Exchange
# 4  CME Cash Settled Cheese Electronic Commodity Future Sep 2021, Commodity Future, Chicago Mercantile Exchange
# 5  CME Cash Settled Cheese Electronic Commodity Future Nov 2021, Commodity Future, Chicago Mercantile Exchange
# 6  CME Cash Settled Cheese Electronic Commodity Future May 2022, Commodity Future, Chicago Mercantile Exchange
# 7  CME Cash Settled Cheese Electronic Commodity Future Dec 2021, Commodity Future, Chicago Mercantile Exchange
# 8  CME Cash Settled Cheese Electronic Commodity Future Jan 2022, Commodity Future, Chicago Mercantile Exchange
# 9  CME Cash Settled Cheese Electronic Commodity Future Feb 2022, Commodity Future, Chicago Mercantile Exchange

# %%
response.data.raw["Navigators"]['ExchangeName']
# Out:
# {'Buckets': [{'Label': 'CME:Index and Options Market', 'Count': 18183},
#   {'Label': 'Chicago Mercantile Exchange', 'Count': 4742},
#   {'Label': 'INTL FCStone Inc', 'Count': 2550},
#   {'Label': 'Source is a Refinitiv Contributor', 'Count': 1498},
#   {'Label': 'US Department of Agriculture', 'Count': 96},
#   {'Label': 'Commodity Futures Trading Commission', 'Count': 66},
#   {'Label': 'Complete Intelligence', 'Count': 40},
#   {'Label': 'Intercontinental Exchange US', 'Count': 31},
#   {'Label': 'US Bureau Of Labor Statistics', 'Count': 10},
#   {'Label': 'DCA Markets B.V. - DCA-Markets-PRA Price Reporting Agent',
#    'Count': 4},
#   {'Label': 'European Energy Exchange', 'Count': 4},
#   {'Label': 'European Commission', 'Count': 3},
#   {'Label': 'ESALQ', 'Count': 2},
#   {'Label': 'CME:International Monetary Market', 'Count': 1}]}

# %%
response = search.Definition(
    view=search.SearchViews.GOV_CORP_INSTRUMENTS,
    top=0,
    navigators="Currency(buckets:10,desc:sum_FaceOutstandingUSD,calc:max_CouponRate)"
).get_data()

response.data.raw
# Out:
# {'Total': 8427503,
#  'Hits': [],
#  'Navigators': {'Currency': {'Buckets': [{'Label': 'USD',
#      'Count': 3450885,
#      'max_CouponRate': 1800.0,
#      'sum_FaceOutstandingUSD': 47578348829005.0},
#     {'Label': 'EUR',
#      'Count': 1027809,
#      'max_CouponRate': 500.0,
#      'sum_FaceOutstandingUSD': 24162687043582.0},
#     {'Label': 'CNY',
#      'Count': 289912,
#      'max_CouponRate': 72.0,
#      'sum_FaceOutstandingUSD': 18643669477716.0},
#     {'Label': 'JPY',
#      'Count': 431370,
#      'max_CouponRate': 500.0,
#      'sum_FaceOutstandingUSD': 13199437626867.018},
#     {'Label': 'GBP',
#      'Count': 181933,
#      'max_CouponRate': 120.0,
#      'sum_FaceOutstandingUSD': 4759595936015.0},
#     {'Label': 'INR',
#      'Count': 103759,
#      'max_CouponRate': 42.75,
#      'sum_FaceOutstandingUSD': 2643901848810.0},
#     {'Label': 'CAD',
#      'Count': 296692,
#      'max_CouponRate': 100.0,
#      'sum_FaceOutstandingUSD': 2545574206391.0},
#     {'Label': 'KRW',
#      'Count': 377653,
#      'max_CouponRate': 46.41,
#      'sum_FaceOutstandingUSD': 2324090241628.748},
#     {'Label': 'AUD',
#      'Count': 132925,
#      'max_CouponRate': 120.96,
#      'sum_FaceOutstandingUSD': 1557849841343.7375},
#     {'Label': 'BRL',
#      'Count': 41581,
#      'max_CouponRate': 515.0,
#      'sum_FaceOutstandingUSD': 903141456382.9437}]}}}

# %% [markdown]
# #### Sub-navigator

# %%
response = search.Definition(
    view=search.SearchViews.PEOPLE,
    top=0,
    navigators="FirstName(buckets:3,sub:LastName(buckets:2))"
).get_data()

response.data.raw["Navigators"]["FirstName"]["Buckets"]
# Out:
# [{'Label': 'John',
#   'Count': 39745,
#   'LastName': {'Buckets': [{'Label': 'Murphy', 'Count': 105},
#     {'Label': 'Lee', 'Count': 104}]}},
#  {'Label': 'David',
#   'Count': 38389,
#   'LastName': {'Buckets': [{'Label': 'Smith', 'Count': 231},
#     {'Label': 'Williams', 'Count': 158}]}},
#  {'Label': 'Michael',
#   'Count': 36971,
#   'LastName': {'Buckets': [{'Label': 'Smith', 'Count': 179},
#     {'Label': 'Brown', 'Count': 119}]}}]

# %% [markdown]
# #### Search with order_by option

# %%
response = search.Definition(
    view=search.SearchViews.PEOPLE,
    query="ceo",
    order_by="YearOfBirth desc,LastName,FirstName",
    select="YearOfBirth,DocumentTitle"
).get_data()

response.data.df
# Out:
#    YearOfBirth  \
# 0  1996
# 1  1993
# 2  1992
# 3  1992
# 4  1991
# 5  1991
# 6  1991
# 7  1990
# 8  1990
# 9  1990
#
#                                                                                                                                   DocumentTitle
# 0  Shu Yao - Dongjiang Environmental Co Ltd - Ex-Chief Executive Officer, Executive Director
# 1  Alberto Rizzoli - V7 Ltd - Chief Executive Officer
# 2  Christian Besenbruch - Deep Render Ltd - Chief Executive Officer and Co-Founder
# 3  Ivan Aleksandrovich Plekhanov - Territorial'naya Generiruyushchaya Kompaniya No2 PAO - Executive Director, Adviser to General Director (CEO)
# 4  Tess Isabelle Cosad - Stepone Fertility Ltd - Chief Executive Officer and Marketing Strategist
# 5  Grigory Sergeevich Sandulov - Omskiy Rechnoy Port AO - General Director (CEO), Director
# 6  Yehonatan Shachar - Upsellon Brands Holdings Ltd - Chief Executive Officer
# 7  Myeong Jin Chae - Arion Technology Inc - Chief Executive Officer, Director
# 8  Pedro de Godoy Bueno - Diagnosticos da America SA - Chief Executive Officer, Director
# 9  Hikaru Ohno - Cyber Security Cloud Inc - President, Chief Executive Officer, Representative Director

# %% [markdown]
# #### Search with group_by option

# %%
response = search.Definition(
    view=search.SearchViews.INDICATOR_QUOTES,
    query="rate",
    group_by="CentralBankName",
    group_count=2,
    select="CentralBankName,DocumentTitle,RIC"
).get_data()

response.data.df
# Out:
#           CentralBankName                 RIC  \
# 0  Federal Reserve System  USFOMC=ECI
# 1  Federal Reserve System  USRRP=ECI
# 2  European Central Bank   EUECBR=ECI
# 3  European Central Bank   EUECBD=ECI
# 4  Bank of Korea           KROCRT=ECI
# 5  Bank of Korea           pKROCRT=4295880903
# 6  Magyar Nemzeti Bank     HUINT=ECI
# 7  Magyar Nemzeti Bank     HUOD2=ECI
# 8  Bank of Israel          ILINR=ECI
# 9  Bank of Israel          pILINR=L
#
#                                                                                                                          DocumentTitle
# 0  United States, Policy Rates, Fed Funds Target Rate, Reuters Polls, Daily, The Federal Open Market Committee
# 1  United States, Policy Rates, Fed Overnight Repo, Reuters Polls, Daily, Federal Reserve, United States
# 2  Euro Zone, Policy Rates, ECB Main refinancing, Fixed Rate (Announcement Dates), Reuters Polls, Monthly, ECB - European Central Bank
# 3  Euro Zone, Policy Rates, ECB Deposit Rate, Reuters Polls, Monthly, ECB - European Central Bank
# 4  South Korea, Policy Rates, Base Rate, Reuters Polls, Monthly, The Bank of Korea
# 5  South Korea, BASE RATE - BOOKOOK SEC, Reuters Polls, Monthly, Reuters
# 6  Hungary, Policy Rates, Base Rate, Reuters Polls, Monthly, National Bank of Hungary
# 7  Hungary, Policy Rates, Base Rate, Reuters Polls, Daily, National Bank of Hungary
# 8  Israel, Policy Rates, Bank of Israel Headline Rate, Reuters Polls, Monthly, Bank of Israel
# 9  Israel, Interest Rate Decision-Low, Reuters Polls, Monthly, Reuters

# %% [markdown]
# #### Search For People

# %%
response = search.Definition(
    query="cfo",
    view=search.SearchViews.PEOPLE
).get_data()

response.data.df
# Out:
#             PI       PermID BusinessEntity  \
# 0  34415553383  34415553383  PERSON
# 1  34414554748  34414554748  PERSON
# 2  34417610894  34417610894  PERSON
# 3  34413960665  34413960665  PERSON
# 4  34414804241  34414804241  PERSON
# 5  34413152672  34413152672  PERSON
# 6  34414966250  34414966250  PERSON
# 7  34414263702  34414263702  PERSON
# 8  34414907131  34414907131  PERSON
# 9  34413340523  34413340523  PERSON
#
#                                                                                DocumentTitle
# 0  Amy E. Hood - Microsoft Corp - Chief Financial Officer, Executive Vice President
# 1  Luca Maestri - Apple Inc - Chief Financial Officer, Senior Vice President
# 2  Brian T. Olsavsky - Amazon.com Inc - Chief Financial Officer, Senior Vice President
# 3  Ruth M. Porat - Alphabet Inc - Chief Financial Officer, Senior Vice President
# 4  David M. Wehner - Facebook Inc - Chief Financial Officer
# 5  Marc D. Hamburg - Berkshire Hathaway Inc - Chief Financial Officer, Senior Vice President
# 6  Andrew K. Klatt - Berkshire Hathaway Inc - CFO & COO
# 7  Maggie Wu - Alibaba Group Holding Ltd - Chief Financial Officer, Director
# 8  John Lo - Tencent Holdings Ltd - Chief Financial Officer, Senior Vice President
# 9  Vasant M. Prabhu - Visa Inc - Vice Chairman of the Board, Chief Financial Officer

# %% [markdown]
# ### Lookup

# %%
response = search.lookup.Definition(
    view=search.SearchViews.INSTRUMENTS,                               # Required parameter
    scope="RIC",                                                       # Required parameter
    terms="MSFT.O,AAPL.O,GOOG.O,IBM.N,KBANK.BK,SCC.BK",                # Required parameter
    select="BusinessEntity,DocumentTitle,CUSIP,SEDOL",                 # Required parameter
).get_data()

response.data.df
# Out:
#             SEDOL      CUSIP     BusinessEntity  \
# MSFT.O    <NA>     594918104  INSTRUMENTxEQUITY
# AAPL.O    <NA>     037833100  INSTRUMENTxEQUITY
# GOOG.O    <NA>     02079K107  INSTRUMENTxEQUITY
# KBANK.BK  6888783  <NA>       INSTRUMENTxEQUITY
# SCC.BK    6609917  <NA>       INSTRUMENTxEQUITY
#
#                              DocumentTitle
# MSFT.O    Microsoft Corp, Ordinary Share
# AAPL.O    Apple Inc, Ordinary Share
# GOOG.O    Alphabet Inc, Ordinary Share
# KBANK.BK  Kasikornbank PCL, Ordinary Share
# SCC.BK    Siam Cement PCL, Ordinary Share

# %%
response = search.lookup.Definition(
    view=search.SearchViews.SEARCH_ALL,                              # Required parameter
    scope="RIC",                                                     # Required parameter
    terms="A,B,NOSUCHRIC,C,D",                                       # Required parameter
    select="BusinessEntity,DocumentTitle",                           # Required parameter
).get_data()

response.data.df
# Out:
#   BusinessEntity                                                DocumentTitle
# A  QUOTExEQUITY   Agilent Technologies Inc, Ordinary Share, NYSE Consolidated
# B  QUOTExEQUITY   Barnes Group Inc, Ordinary Share, NYSE Consolidated
# C  QUOTExEQUITY   Citigroup Inc, Ordinary Share, NYSE Consolidated
# D  QUOTExEQUITY   Dominion Energy Inc, Ordinary Share, NYSE Consolidated

# %% [markdown]
# ## Close the session

# %%
close_session()
