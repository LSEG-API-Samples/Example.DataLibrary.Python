# %% [markdown]
# <div style="display: flex; align-items: center;">
#     <img src="https://developers.lseg.com/content/dam/devportal/icons/logo/lseg-logo.svg" width="20%" style="vertical-align: top;">
#     <h1 style="margin-left: 20px;">LD Lib. Python Tutorial 8 - Chain</h1>
# </div>

# %% [markdown]
# ## Chains
#
# We spoke at length about the LSEG Data Model. Let's not repeat ourselves, and instead forcuss on the task at hand: Chains.
#
# ### What are Chains?
#
# As best described by [Raksina](https://developers.lseg.com/en/article-catalog/article/Retrieve-underlying-Instrument-of-Chain-Symbol), "Chains are used to hold instrument names that have a common association. For example, a chain may contain the constituents of a market index like the Dow Jones or the list of strike prices on a particular option contract. It is important to note that chains contain the instrument names (a.k.a. RICs - Refinitiv Instrument Codes) but not the values of the instruments."
#
# ## Install & Import the LSEG Data Library
#
# To install libraries in python, you can find the command in PyPl with `pip install lseg.data`, in this instance, it is:

# %%
import lseg.data as ld
import datetime
from IPython.display import display, clear_output

# %% [markdown]
# There are two sessions you can use to authenticate yourself to the LSEG Data Platform, the Desktop Session and Platform Session.
#
# The Desktop Session allows you to access data in LSEG's Data Platform via the Desktop Workspace Application on the machine where you are running your code, meaning taht you need to have Workspace running on the machine where you are running your Python code. This is because this session funnels requests made to LSEG's servers through the desktop application. When using the Desktop Session, you need very little information, because you already inputed your username and password in the desktop application to logg in.
#
# The Platform Session allows you to authenticate yourself to LSEG's Data Platform without the Desktop Application. This does, however, mean that you have to entre your credentials (e.g.: in a [reference configuration file](https://developers.lseg.com/en/api-catalog/lseg-data-platform/lseg-data-library-for-python/tutorials#tutorial-3-sessions-configurations-data-model-and-get-data)).
#
# Let's start  with the Desktop Session:

# %% [markdown]
# ## Access Layer
#
# ### Desktop Session
#
# #### Authentification to LSEG Service
#
# Desktop session use-cases are the simples ones, so let's start there. We can authenticate ourselves with the Workspace Desktop App open with simply just the Python line:

# %%
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x27ae4259190 {name='workspace'}>

# %% [markdown]
# #### Create a chain object for the CAC40 index

# %%
fchi = ld.discovery.Chain("0#.FCHI")

# %%
print(fchi.constituents)
# Out:
# ['ACCP.PA', 'AIRP.PA', 'AIR.PA', 'MT.AS', 'AXAF.PA', 'BNPP.PA', 'BOUY.PA', 'BVI.PA', 'CAPP.PA', 'CARR.PA', 'CAGR.PA', 'DANO.PA', 'DAST.PA', 'EDEN.PA', 'ENGIE.PA', 'ESLX.PA', 'EUFI.PA', 'HRMS.PA', 'PRTP.PA', 'OREP.PA', 'LVMH.PA', 'LEGD.PA', 'MICP.PA', 'ORAN.PA', 'PERP.PA', 'PUBP.PA', 'RENA.PA', 'SAF.PA', 'SGOB.PA', 'SASY.PA', 'SCHN.PA', 'SOGN.PA', 'STLAM.PA', 'STMPA.PA', 'TEPRF.PA', 'TCFP.PA', 'TTEF.PA', 'URW.PA', 'VIE.PA', 'SGEF.PA', 'VIV.PA']

# %%
fchi.name
# Out:
# '0#.FCHI'

# %%
fchi.summary_links
# Out:
# ['.DJI', 'EUR=', '/.STOXX50E', '.FCHI', '.AD.FCHI']

# %% [markdown]
# #### Use the chain with get_history

# %%
ld.get_history(fchi, ['BID', 'ASK'])
# Out:
#            ACCP.PA        AIRP.PA          AIR.PA          MT.AS         \
#                BID    ASK     BID     ASK     BID     ASK    BID    ASK
# Date
# 2025-01-22   49.02  49.07  162.38  162.46   165.0  165.14   22.5  22.52
# 2025-01-23   48.57  48.58  161.72   161.8  166.66  166.68  22.97  22.98
# 2025-01-24   48.98  48.99  163.74  163.76   167.0  167.04  23.71  23.73
# 2025-01-27   48.88  48.93  165.92  165.96  165.84  166.52  23.75  23.76
# 2025-01-28   49.46  49.51  166.66  166.72  166.76   166.8  23.72  23.73
# 2025-01-29   49.37  49.45   167.0   167.4  166.62  166.76  23.79   23.8
# 2025-01-30   49.56  49.65  169.14  169.16  166.32  166.44  24.27  24.32
# 2025-01-31   49.75  49.77  168.46   168.6  167.12  167.14  24.17  24.21
# 2025-02-03   49.08  49.09   167.8  167.84  166.58   166.6  23.76  23.77
# 2025-02-04   49.35  49.36  168.28  168.32   166.0  166.04  24.18  24.23
# 2025-02-05   49.17  49.27  167.22  167.64   166.9  166.92  24.35  24.36
# ...

# %% [markdown]
# #### Use the chain with get_data: An Options Use Case

# %%
optns4AllMatur4DAX = ld.discovery.Chain("0#GDAX*.EX")
print(optns4AllMatur4DAX.constituents)
# Out:
# ['GDAX145000B5.EX', 'GDAX145000N5.EX', 'GDAX146000B5.EX', 'GDAX146000N5.EX', 'GDAX147000B5.EX', 'GDAX147000N5.EX', 'GDAX148000B5.EX', 'GDAX148000N5.EX', 'GDAX149000B5.EX', 'GDAX149000N5.EX', 'GDAX150000B5.EX', 'GDAX150000N5.EX', 'GDAX151000B5.EX', 'GDAX151000N5.EX', 'GDAX152000B5.EX', 'GDAX152000N5.EX', 'GDAX153000B5.EX', 'GDAX153000N5.EX', 'GDAX154000B5.EX', 'GDAX154000N5.EX', 'GDAX155000B5.EX', 'GDAX155000N5.EX', 'GDAX156000B5.EX', 'GDAX156000N5.EX', 'GDAX157000B5.EX', 'GDAX157000N5.EX', 'GDAX158000B5.EX', 'GDAX158000N5.EX', 'GDAX159000B5.EX', 'GDAX159000N5.EX', 'GDAX160000B5.EX', 'GDAX160000N5.EX', 'GDAX161000B5.EX', 'GDAX161000N5.EX', 'GDAX162000B5.EX', 'GDAX162000N5.EX', 'GDAX163000B5.EX', 'GDAX163000N5.EX', 'GDAX164000B5.EX', 'GDAX164000N5.EX', 'GDAX165000B5.EX', 'GDAX165000N5.EX', 'GDAX166000B5.EX', 'GDAX166000N5.EX', 'GDAX167000B5.EX', 'GDAX167000N5.EX', 'GDAX168000B5.EX', 'GDAX168000N5.EX', 'GDAX169000B5.EX', 'GDAX169000N5.EX', 'GDAX170000B5.EX', 'GDAX170000N5.EX', 'GDAX1710
# ...

# %%
dax = ld.get_data(optns4AllMatur4DAX, ['TR.InstrumentDescription', 'PUTCALLIND', 'STRIKE_PRC', 'CF_CLOSE', 'IMP_VOLT', 'EXPIR_DATE'])
dax.head()
# Out:
# c:\Users\U6082174\AppData\Local\Programs\Python\Python311\Lib\site-packages\lseg\data\_tools\_dataframe.py:177:FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#         Instrument                             Instrument Description  \
# 0  GDAX145000B5.EX  Eurex DAX Monthly Index Option 14500 Call Feb ...
# 1  GDAX145000N5.EX  Eurex DAX Monthly Index Option 14500 Put Feb 2025
# 2  GDAX146000B5.EX  Eurex DAX Monthly Index Option 14600 Call Feb ...
# 3  GDAX146000N5.EX  Eurex DAX Monthly Index Option 14600 Put Feb 2025
# 4  GDAX147000B5.EX  Eurex DAX Monthly Index Option 14700 Call Feb ...
#
#   PUTCALLIND  STRIKE_PRC  CF_CLOSE  IMP_VOLT EXPIR_DATE
# 0       CALL       14500    8375.0  218.7894 2025-02-21
# 1       PUT        14500       0.1  127.6744 2025-02-21
# ...

# %%
sepDax = dax[dax['Instrument Description'].str.contains('Sep 2025', na=False)] # Focus on one month

# %%
sepPuts = sepDax[sepDax['PUTCALLIND'] == 'PUT ']
sepCalls = dax[dax['PUTCALLIND'] == 'CALL']
display(sepPuts.head())
display(sepCalls.head())
# Out:
#            Instrument                             Instrument Description  \
# 1335  GDAX106000U5.EX  Eurex DAX Monthly Index Option 10600 Put Sep 2025
# 1337  GDAX108000U5.EX  Eurex DAX Monthly Index Option 10800 Put Sep 2025
# 1339  GDAX110000U5.EX  Eurex DAX Monthly Index Option 11000 Put Sep 2025
# 1341  GDAX112000U5.EX  Eurex DAX Monthly Index Option 11200 Put Sep 2025
# 1343  GDAX114000U5.EX  Eurex DAX Monthly Index Option 11400 Put Sep 2025
#
#      PUTCALLIND  STRIKE_PRC  CF_CLOSE  IMP_VOLT EXPIR_DATE
# 1335       PUT        10600      18.0   44.1577 2025-09-19
# 1337       PUT        10800      19.1   43.5145 2025-09-19
# 1339       PUT        11000      20.3   42.8914 2025-09-19
# 1341       PUT        11200      21.5   42.2588 2025-09-19
# 1343       PUT        11400      22.8   41.6435 2025-09-19
#         Instrument                             Instrument Description  \
# 0  GDAX145000B5.EX  Eurex DAX Monthly Index Option 14500 Call Feb ...
# ...

# %%
optns4AllMatur4DAX.summary_links
# Out:
# ['.GDAXI']

# %%
daxStrkPr = ld.get_data(optns4AllMatur4DAX.summary_links, ['CF_CLOSE'])
daxStrkPr
# Out:
#   Instrument  CF_CLOSE
# 0     .GDAXI   22844.5

# %%
print(f"Current strike price for GDAXI is {daxStrkPr['CF_CLOSE'].values[0]}")
# Out:
# Current strike price for GDAXI is 22844.5

# %%
limit = 2000
sepPutsCloseToTheMoney = sepPuts[abs(sepPuts['STRIKE_PRC'] - daxStrkPr['CF_CLOSE'].values[0]) < limit]
sepPutsCloseToTheMoney.head()
# Out:
#            Instrument                             Instrument Description  \
# 1481  GDAX209000U5.EX  Eurex DAX Monthly Index Option 20900 Put Sep 2025
# 1483  GDAX210000U5.EX  Eurex DAX Monthly Index Option 21000 Put Sep 2025
# 1485  GDAX211000U5.EX  Eurex DAX Monthly Index Option 21100 Put Sep 2025
# 1487  GDAX212000U5.EX  Eurex DAX Monthly Index Option 21200 Put Sep 2025
# 1489  GDAX213000U5.EX  Eurex DAX Monthly Index Option 21300 Put Sep 2025
#
#      PUTCALLIND  STRIKE_PRC  CF_CLOSE  IMP_VOLT EXPIR_DATE
# 1481       PUT        20900     378.8   17.7825 2025-09-19
# 1483       PUT        21000     393.5   17.5875 2025-09-19
# 1485       PUT        21100     408.9   17.3941 2025-09-19
# 1487       PUT        21200     425.1   17.2037 2025-09-19
# 1489       PUT        21300     442.0   17.0137 2025-09-19

# %%
sepPutsCloseToTheMoney.set_index('STRIKE_PRC').head()
# Out:
#                  Instrument  \
# STRIKE_PRC
# 20900       GDAX209000U5.EX
# 21000       GDAX210000U5.EX
# 21100       GDAX211000U5.EX
# 21200       GDAX212000U5.EX
# 21300       GDAX213000U5.EX
#
#                                        Instrument Description PUTCALLIND  \
# STRIKE_PRC
# 20900       Eurex DAX Monthly Index Option 20900 Put Sep 2025       PUT
# 21000       Eurex DAX Monthly Index Option 21000 Put Sep 2025       PUT
# 21100       Eurex DAX Monthly Index Option 21100 Put Sep 2025       PUT
# 21200       Eurex DAX Monthly Index Option 21200 Put Sep 2025       PUT
# 21300       Eurex DAX Monthly Index Option 21300 Put Sep 2025       PUT
#
#             CF_CLOSE  IMP_VOLT EXPIR_DATE
# STRIKE_PRC
# 20900          378.8   17.7825 2025-09-19
# 21000          393.5   17.5875 2025-09-19
# 21100          408.9   17.3941 2025-09-19
# 21200          425.1   17.2037 2025-09-19
# 21300          442.0   17.0137 2025-09-19

# %%
import cufflinks
import pandas as pd

sepPutsCleaned = sepPutsCloseToTheMoney.replace('', pd.NA).dropna()
sepPutsCleaned.set_index('STRIKE_PRC')[["CF_CLOSE", "IMP_VOLT"]].iplot(
    subplots=True,
    mode='lines+markers',
    symbol='x',
    size=6,
    title='Eurex DAX Monthly Index Option (close to the money) Put Sep 2025',
    xTitle='Strike price',
    yTitle='Price',
    secondary_y='IMP_VOLT'
)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.34.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="38a3f528-2f16-417c-9164-8f421aea1d35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
puts = dax[dax['PUTCALLIND'] == 'PUT ']
puts_close, puts_vols = pd.DataFrame(), pd.DataFrame()
for expiry in dax['EXPIR_DATE']:
    sub_set = puts[puts['EXPIR_DATE'] == expiry]
    puts_close[expiry] = sub_set.set_index('STRIKE_PRC')['CF_CLOSE']
    puts_vols[expiry] = sub_set.set_index('STRIKE_PRC')['IMP_VOLT']

puts_close.replace('', pd.NA).dropna().iplot(
    mode='markers',
    size=6,
    xTitle='strike price')
# Out:
# <div>                            <div id="939e456a-75b1-4d79-8b9e-8d3d18bb0a69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
puts_vols.replace('', pd.NA).dropna().iplot(
    mode='markers',
    size=6,
    xTitle='strike price')
# Out:
# <div>                            <div id="56953aa5-ec93-41c9-bb1d-2f165b1f4ab9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
calls = dax[dax['PUTCALLIND'] == 'CALL']
calls_close, calls_vols = pd.DataFrame(), pd.DataFrame()
for expiry in dax['EXPIR_DATE']:
    sub_set = calls[calls['EXPIR_DATE'] == expiry]
    calls_close[expiry] = sub_set.set_index('STRIKE_PRC')['CF_CLOSE']
    calls_vols[expiry] = sub_set.set_index('STRIKE_PRC')['IMP_VOLT']

calls_close.replace('', pd.NA).dropna().iplot(
    mode='markers',
    size=6,
    xTitle='strike price')
# Out:
# <div>                            <div id="dd0aadbe-ad24-4c59-9c06-5c60843e6ae0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
calls_vols.replace('', pd.NA).dropna().iplot(
    mode='markers',
    size=6,
    xTitle='strike price')
# Out:
# <div>                            <div id="63faf9ae-9da2-445d-98a6-2906cbcbf518" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# #### summary_links

# %% [markdown]
# All chains contains preliminary links before constituents. Usually, it's related indexes. TLSEG names it the "summary links":

# %%
fchi.summary_links
# Out:
# ['.DJI', 'EUR=', '/.STOXX50E', '.FCHI', '.AD.FCHI']

# %%
print(f"0#{fchi.summary_links[0]}")
ld.get_data(f"0#{fchi.summary_links[0]}", ['BID', 'ASK', 'TR.Revenue'])
# Out:
# 0#.DJI
# c:\Users\U6082174\AppData\Local\Programs\Python\Python311\Lib\site-packages\lseg\data\_tools\_dataframe.py:192: FutureWarning:
#
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# c:\Users\U6082174\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\cast.py:1056: RuntimeWarning:
#
# invalid value encountered in cast
#
# c:\Users\U6082174\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\cast.py:1080: RuntimeWarning:
#
# invalid value encountered in cast
#    Instrument       Revenue     BID     ASK
# 0        GS.N  126853000000     0.0     0.0
# 1       NKE.N   51362000000     0.0     0.0
# 2     CSCO.OQ   53803000000   64.59   64.94
# 3       JPM.N          <NA>     0.0     0.0
# ...

# %%
ld.close_session()

# %% [markdown]
# #### Use the chain with pricing streams

# %%
# import lseg.data as ld
# import datetime
# import time
# from IPython.display import display, clear_output
# session = ld.open_session()
# if session is not None:
#     fchi = ld.discovery.Chain("0#.FCHI")
#     def display_data(data, instrument, stream):
#         clear_output(wait=True)
#         current_time = datetime.datetime.now().time()
#         print(current_time, "- Data received for", instrument)
#         display(data)
#         time.sleep(0.5)
#     stream = ld.open_pricing_stream(fchi, ['BID', 'ASK'], on_data=display_data)
# else:
#     print("Can't open a session !")

# %%
# stream.close()
# ld.close_session()

# %% [markdown]
# #### N.B.: Building Historical Index Constituents
# The next topic that natuirally comes to mind here Historical Index Constituents. We now need to call upon [Dr.Aramyan's article](https://developers.lseg.com/en/article-catalog/article/building-historical-index-constituents) to build a functioan that Building historical index constituents

# %%
ld.open_session()

ric = '.FTSE'
start = '2014-01-01'
end = '2024-02-15'

# %%
def get_constituents_as_of(ric, date):
    initial_constituents = ld.get_data(
        universe=[f"0#{ric}({date.replace('-', '')})"],
        fields=["TR.PriceClose"],
        parameters={"SDATE":f"{date}", "EDATE":f"{date}"})
    initial_constituents = initial_constituents['Instrument'].to_list()
    return initial_constituents
initial_constituents = get_constituents_as_of(ric, start)
print(initial_constituents, len(initial_constituents))
# Out:
# ['ABF.L', 'SAB.L^J16', 'ABDN.L', 'ADN.L^H17', 'ADML.L', 'AGGK.L^H21', 'AMFW.L^J17', 'AAL.L', 'ANTO.L', 'AHT.L', 'AZN.L', 'AV.L', 'BAB.L', 'BAES.L', 'BARC.L', 'RRS.L^A19', 'BG.L^B16', 'BHPB.L^A22', 'BP.L', 'BATS.L', 'BLND.L', 'BT.L', 'BNZL.L', 'BRBY.L', 'CPI.L', 'CCL.L', 'CNA.L', 'CCH.L', 'CPG.L', 'CRH.L', 'DGE.L', 'EZJ.L', 'EXPN.L', 'FERG.L', 'FRAS.L', 'FRES.L', 'FLG.L^D15', 'GFS.L^E21', 'GKN.L^E18', 'GLEN.L', 'GSK.L', 'HMSO.L', 'HRGV.L', 'HSBA.L', 'ICAG.L', 'IMI.L', 'IMB.L', 'IHG.L', 'ITRK.L', 'IDSI.L', 'ITV.L', 'JMAT.L', 'KGF.L', 'LAND.L', 'LGEN.L', 'LLOY.L', 'LSEG.L', 'MKS.L', 'MGGT.L^I22', 'MRON.L', 'MNDI.L', 'NG.L', 'NWG.L', 'NXT.L', 'OMU.L', 'PSON.L', 'PSN.L', 'PFC.L', 'PRU.L', 'RKT.L', 'REL.L', 'REX.L^G16', 'RIO.L', 'RR.L', 'RSA.L^F21', 'SGE.L', 'SBRY.L', 'SDR.L', 'SVT.L', 'SHEL.L', 'RDSb.L^A22', 'SHP.L^A19', 'SKYB.L^K18', 'SN.L', 'SMIN.L', 'SSE.L', 'STAN.L', 'ARM.L^I16', 'TATE.L', 'TSCO.L', 'TPK.L', 'TT.L^L14', 'TLW.L', 'ULVR.L', 'UU.L', 'VOD.L', 'WEIR.L', 'WTB.L', 'WMH.L^D21
# ...

# %%
def get_constituent_changes(ric, start, end):
    return ld.get_data(
        universe=[ric],
        fields = [
            "TR.IndexJLConstituentRIC.date", "TR.IndexJLConstituentRIC",
            "TR.IndexJLConstituentName", "TR.IndexJLConstituentRIC.change"],
        parameters={"SDATE":f"{start}","EDATE":f"{end}", 'IC':'B'})
constituent_changes = get_constituent_changes(ric, start, end)
constituent_changes
# Out:
#     Instrument       Date Constituent RIC  Constituent Name  Change
# 0        .FTSE 2014-03-24           SJP.L  St James's Place  Joiner
# 1        .FTSE 2014-03-24          BTRW.L    Barratt Redrow  Joiner
# 2        .FTSE 2014-03-24      AMFW.L^J17       Amec Foster  Leaver
# 3        .FTSE 2014-03-24          TATE.L       Tate & Lyle  Leaver
# 4        .FTSE 2014-06-23           III.L          3i Group  Joiner
# ..         ...        ...             ...               ...     ...
# 210      .FTSE 2023-09-25          HWDN.L    Howden Joinery  Joiner
# 211      .FTSE 2023-12-18         ICGIN.L  Intermediate Cap  Joiner
# 212      .FTSE 2023-12-18          HRGV.L        Hargreaves  Leaver
# 213      .FTSE 2024-01-16       DPH.L^A24     Dechra Pharms  Leaver
# 214      .FTSE 2024-01-16           PSN.L         Persimmon  Joiner
#
# [215 rows x 5 columns]

# %%
import copy
import pandas as pd

def add_joiner(init_list, joiner_list):
    for joiner in joiner_list:
        if joiner not in init_list:
            init_list.append(joiner)
        else:
            print(f'{joiner} joiner is already in the list')
    return init_list

def remove_leaver(init_list, leaver_list):
    for leaver in leaver_list:
        if leaver in init_list:
            init_list.remove(leaver)
        else:
            print(f'{leaver} leaver is not in the list')
    return init_list

def update_constituents(start, constituents, constitent_changes):
    hist_constituents = pd.DataFrame([(start, ric) for ric in constituents], columns=['Date', 'RIC'])
    for date in constitent_changes['Date'].unique():
        const_changes_date = constitent_changes[constitent_changes['Date'] == date]
        joiners = const_changes_date[const_changes_date['Change']=='Joiner']['Constituent RIC'].to_list()
        leavers = const_changes_date[const_changes_date['Change']=='Leaver']['Constituent RIC'].to_list()
        joiners_unique = list(set(joiners) - set(leavers))
        leavers_unique = list(set(leavers) - set(joiners))
        if len(joiners_unique) > 0:
            constituents = add_joiner(constituents, joiners_unique)
        if len(leavers_unique) > 0:
            constituents = remove_leaver(constituents, leavers_unique)
        new_constituents = copy.deepcopy(constituents)
        new_constituents_df =  pd.DataFrame([(str(date)[:10], ric) for ric in new_constituents], columns=['Date', 'RIC'])
        hist_constituents = pd.concat([hist_constituents, new_constituents_df])
    hist_constituents = hist_constituents.reset_index(drop = True)
    
    return hist_constituents

historical_constituents = update_constituents(start, initial_constituents, constituent_changes)
historical_constituents
# Out:
#             Date        RIC
# 0     2014-01-01      ABF.L
# 1     2014-01-01  SAB.L^J16
# 2     2014-01-01     ABDN.L
# 3     2014-01-01  ADN.L^H17
# 4     2014-01-01     ADML.L
# ...          ...        ...
# 7560  2024-01-16     DPLM.L
# 7561  2024-01-16      MKS.L
# 7562  2024-01-16     HWDN.L
# 7563  2024-01-16    ICGIN.L
# 7564  2024-01-16      PSN.L
#
# [7565 rows x 2 columns]

# %%
def get_historical_constituents(index, start, end):
    initial_constituents = get_constituents_as_of(index, start)
    constitent_changes = get_constituent_changes(index, start, end)
    historical_constituents = update_constituents(start, initial_constituents, constitent_changes)
    return historical_constituents
ftse_constituents = get_historical_constituents('.FTSE', '2014-01-01', '2024-03-14')
ftse_constituents
# Out:
#             Date        RIC
# 0     2014-01-01      ABF.L
# 1     2014-01-01  SAB.L^J16
# 2     2014-01-01     ABDN.L
# 3     2014-01-01  ADN.L^H17
# 4     2014-01-01     ADML.L
# ...          ...        ...
# 7560  2024-01-16     DPLM.L
# 7561  2024-01-16      MKS.L
# 7562  2024-01-16     HWDN.L
# 7563  2024-01-16    ICGIN.L
# 7564  2024-01-16      PSN.L
#
# [7565 rows x 2 columns]

# %%
dict_of_ftse_constituents = {i: ftse_constituents[ftse_constituents['Date'] == i] for i in ftse_constituents['Date'].unique()}

# %%
dict_of_ftse_constituents['2014-01-01']
# Out:
#            Date        RIC
# 0    2014-01-01      ABF.L
# 1    2014-01-01  SAB.L^J16
# 2    2014-01-01     ABDN.L
# 3    2014-01-01  ADN.L^H17
# 4    2014-01-01     ADML.L
# ..          ...        ...
# 96   2014-01-01     WEIR.L
# 97   2014-01-01      WTB.L
# 98   2014-01-01  WMH.L^D21
# 99   2014-01-01  MRW.L^J21
# 100  2014-01-01      WPP.L
#
# [101 rows x 2 columns]

# %%
dict_of_ftse_constituents['2014-03-24']
# Out:
#            Date        RIC
# 101  2014-03-24      ABF.L
# 102  2014-03-24  SAB.L^J16
# 103  2014-03-24     ABDN.L
# 104  2014-03-24  ADN.L^H17
# 105  2014-03-24     ADML.L
# ..          ...        ...
# 197  2014-03-24  WMH.L^D21
# 198  2014-03-24  MRW.L^J21
# 199  2014-03-24      WPP.L
# 200  2014-03-24      SJP.L
# 201  2014-03-24     BTRW.L
#
# [101 rows x 2 columns]

# %% [markdown]
# #### Show sectoral distribution over time

# %%
sectors = ld.get_data(
    list(ftse_constituents['RIC'].unique()),
    ["TR.TRBCIndustryGroup", "TR.RIC"])
sectors
# Out:
#     Instrument                          TRBC Industry Group Name        RIC
# 0        ABF.L                                    Food & Tobacco      ABF.L
# 1    SAB.L^J16                                         Beverages  SAB.L^J16
# 2       ABDN.L          Investment Banking & Investment Services     ABDN.L
# 3    ADN.L^H17          Investment Banking & Investment Services  ADN.L^H17
# 4       ADML.L                                         Insurance     ADML.L
# ..         ...                                               ...        ...
# 163      HLN.L                                   Pharmaceuticals      HLN.L
# 164     FCIT.L                            Collective Investments     FCIT.L
# 165     BEZG.L                                         Insurance     BEZG.L
# 166      DWL.L                          Automobiles & Auto Parts      DWL.L
# 167     DPLM.L  Machinery, Tools, Heavy Vehicles, Trains & Ships     DPLM.L
#
# [168 rows x 3 columns]

# %%
sector_df = ftse_constituents.merge(sectors, on = 'RIC')
sector_df_grouped = sector_df.groupby(by = ["Date", "TRBC Industry Group Name"]).count()
sector_df_grouped = sector_df_grouped.reset_index()
sector_df_grouped
# Out:
#             Date          TRBC Industry Group Name  RIC  Instrument
# 0     2014-01-01               Aerospace & Defense    5           5
# 1     2014-01-01          Automobiles & Auto Parts    1           1
# 2     2014-01-01                  Banking Services    5           5
# 3     2014-01-01                         Beverages    3           3
# 4     2014-01-01  Biotechnology & Medical Research    1           1
# ...          ...                               ...  ...         ...
# 2510  2024-01-16    Residential & Commercial REITs    3           3
# 2511  2024-01-16            Software & IT Services    4           4
# 2512  2024-01-16               Specialty Retailers    5           5
# 2513  2024-01-16       Telecommunications Services    3           3
# 2514  2024-01-16         Water & Related Utilities    2           2
#
# [2515 rows x 4 columns]

# %%
import plotly.express as px

_sectors = [
    "Software & IT Services", "Banking Services", "Telecommunications Services",
    "Automobiles & Auto Parts", "Aerospace & Defense"]
fig = px.bar(
    sector_df_grouped[sector_df_grouped['TRBC Industry Group Name'].isin(_sectors)],
    x="Date",
    y="Instrument",
    color="TRBC Industry Group Name",
    width=1000,
    height=400)
 
fig.update_layout(
    xaxis=dict(
        type='category',
        categoryorder='array'))
fig.show()
# Out:
# <div>                            <div id="808ef3a7-c780-4402-8f3f-ef0b9ed87da6" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("808ef3a7-c780-4402-8f3f-ef0b9ed87da6")) {                    Plotly.newPlot(                        "808ef3a7-c780-4402-8f3f-ef0b9ed87da6",                        [{"alignmentgroup":"True","hovertemplate":"TRBC Industry Group Name=Aerospace & Defense\u003cbr\u003eDate=%{x}\u003cbr\u003eInstrument=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Aerospace & Defense","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Aerospace & Defense","offsetgroup":"Aerospace & Defense","orientation":"v","showlegend":true,"textposition":"auto","x":["2014-01-01","2014-03-24","2014-06-23","2014-09-22","2014-12-17","201
# ...

# %%
ld.close_session()

# %% [markdown]
# ## Platform Session
#
# Platform sessions allow us to use the LD Lib. without the Workspace Desktop App open. It was created for servers, and it is still aimed for data hungry users who require little human interation with the code at hand (e.g.: overnight data retraival). With that said, usecases have grown in breadth and complexity thoughout the years, and people may want such 'ping' services (i.e.: the ability to 'ping', to directly contact, the services that deliver data/calculations, without going through the Desktop App Proxy).
#
# Platform session use-cases are a little more complicated to the Desktop session ones. We can authenticate ourselves with the Workspace Desktop App open with simply just the Python line:

# %%
import datetime
import lseg.data as ld
ld.open_session(
    config_name="C:/Example.DataLibrary.Python-main/Configuration/lseg-data.config.json",
    name="platform.ldp")
# Out:
# <lseg.data.session.Definition object at 0x1b03f5af610 {name='ldp'}>

# %%
df = ld.get_data(
    universe=['JPY='],
    fields=['BID','ASK'])
df.index = [datetime.datetime.now().time()]
df.index.name = 'Time'
df
# Out:
#                 Instrument     BID     ASK
# Time
# 08:43:10.916671       JPY=  151.71  151.72
# [Error 400] - {'error': 'invalid_grant'}

# %%
import datetime
import time
from IPython.display import display, clear_output

fchi = ld.discovery.Chain("0#.FCHI")
def display_data(data, instrument, stream):
    clear_output(wait=True)
    current_time = datetime.datetime.now().time()
    print(current_time, "- Data received for", instrument)
    display(data)
    time.sleep(0.5)
stream = ld.open_pricing_stream(fchi, ['BID', 'ASK'], on_data=display_data)
# Out:
# 08:42:18.185923 - Data received for SGEF.PA
#           BID   ASK
# SGEF.PA  None  None

# %%
stream.close()
ld.close_session()
