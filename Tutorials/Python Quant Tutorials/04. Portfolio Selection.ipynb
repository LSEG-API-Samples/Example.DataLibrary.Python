# %% [markdown]
# # LSEG Data Libraries API

# %% [markdown]
# **Portfolio Selection**
#
# Dr. Yves J. Hilpisch | The Python Quants GmbH
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a> | <a href="mailto:training@tpq.io">training@tpq.io</a>
#
# <img src="http://hilpisch.com/images/tr_eikon_02.png" width=350px align=left>

# %% [markdown]
# ## The Agenda

# %% [markdown]
# This tutorial shows
#
# * how to retrieve historical data across asset classes via the Eikon Data API,
# * how to work with such data using `pandas`, `Plotly` and `Cufflinks` and
# * how to compose and analyze portfolios with regard to their expected return and volatility.

# %% [markdown]
# ## Portfolio Selection

# %% [markdown]
# Markowitz(1952): “Portfolio Selection”:
#
# > “Various reasons recommend the use of the expected return-variance of return rule, both as a hypothesis to explain well-established investment behavior and as a maxim to guide one's own action.”

# %% [markdown]
# In what follows, the composition of a portfolio made up of different risky assets is analyzed in light of the **Mean-Variance Portfolio Theory (MVP)** of Markowitz (1952), i.e. with regard to the resulting **expected portfolio return** and **expected portfolio volatility** (instead of variance).

# %% [markdown]
# ## Importing Required Packages

# %%
import math
import lseg.data as ld  # Importing LSEG data libraries
import numpy as np  # NumPy
import pandas as pd  # pandas
import cufflinks as cf  # Cufflinks
import configparser as cp
import scipy.optimize as sco  # optimization routines
cf.set_config_file(offline=True)  # set the plotting mode to offline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# The following **Python and package versions** are used.

# %%
import sys
print(sys.version)
# Out:
# 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]

# %%
ld.__version__
# Out:
# '2.0.0'

# %%
np.__version__
# Out:
# '1.22.1'

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
cf.__version__
# Out:
# '0.17.3'

# %% [markdown]
# ## Opening an LSEG data libraries session

# %%
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x26f626c7b80 {name='workspace'}>

# %% [markdown]
# ## Retrieving Cross-Asset Data

# %% [markdown]
# We first define a **small universe of `RICS`** for which to retrieve data.

# %%
rics = [
    'AAPL.O',  # Apple stock
    'AMZN.O',  # Amazon stock
    'SPY',  # S&P 500 ETF
    'GLD',  # Gold ETF
]

# %% [markdown]
# Second, **end-of-day (EOD) data** is retrieved.

# %%
data = ld.get_history(rics,  # the RICs
                      fields='TRDPRC_1',  # the required fields
                      start='2017-01-01',  # start date
                      end='2018-02-16')  # end date

# %%
ld.close_session()

# %%
data.head()  # first five rows
# Out:
# TRDPRC_1     AAPL.O   AMZN.O     SPY     GLD
# Date
# 2017-01-03  29.0375  37.6835  225.24  110.47
# 2017-01-04   29.005   37.859  226.58  110.86
# 2017-01-05  29.1525  39.0225   226.4  112.58
# 2017-01-06  29.4775  39.7995  227.21  111.75
# 2017-01-09  29.7475   39.846  226.46  112.67

# %%
data.tail()  # final five rows
# Out:
# TRDPRC_1     AAPL.O   AMZN.O     SPY     GLD
# Date
# 2018-02-12  40.6775  69.3115  265.34  125.37
# 2018-02-13   41.085  70.7255   266.0  126.08
# 2018-02-14  41.8425  72.5525  269.59  128.23
# 2018-02-15  43.2475   73.088  273.03  128.38
# 2018-02-16  43.1075  72.4345  273.11  127.96

# %% [markdown]
# Only complete data rows are selected.

# %%
data.dropna(inplace=True)  # deletes rows with NaN values

# %%
data.info()  # DataFrame meta information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 284 entries, 2017-01-03 to 2018-02-16
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL.O  284 non-null    Float64
#  1   AMZN.O  284 non-null    Float64
#  2   SPY     284 non-null    Float64
#  3   GLD     284 non-null    Float64
# dtypes: Float64(4)
# memory usage: 12.2 KB

# %%
data.normalize().iplot(kind='lines')
# Out:
# <div>                            <div id="db0d35dd-d11d-4901-971f-d7fb0b4cedd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("db0d35dd-d11d-4901-971f-d7fb0b4cedd6")) {                    Plotly.newPlot(                        "db0d35dd-d11d-4901-971f-d7fb0b4cedd6",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"AAPL.O","text":"","x":["2017-01-03","2017-01-04","2017-01-05","2017-01-06","2017-01-09","2017-01-10","2017-01-11","2017-01-12","2017-01-13","2017-01-17","2017-01-18","2017-01-19","2017-01-20","2017-01-23","2017-01-24","2017-01-25","2017-01-26","2017-01-27","2017-01-30","2017-01-31","2017-02-01","2017-02-02","2017-02-03","2017-02-06","2017-02-07","2017-02-08","2017-02-09","2017-02-10","2017-02-13","2017-02-14","2017-02-15","2017-02-16","2017-02-17","2017-02-21","2017-02-22","2017-02-23","2017-02-24","2017-02-27","2017-02-28","2017-03-01","2017-03-02","2017-03-03","2017-03-06","2017-03-07","2017-03-08","2017-03-09","2017-03-10","2017-03-13","2017-03-14","2017-03-15","2017-03-16","2017-03-17","2017-03-20","2017-03-21","2017-03-22","2017-03-23","2017-03-24","2017-03-27","2017-03-28","2017-03-29","2017-03-30","2017-03-31","2017-04-03","2017-04-04","2017-04-05","2017-04-06","2017-04-07","2017-04-10","2017-04-11","2017-04-12","2017-04-13","2017-04-17","2017-04-18","2017-04-19","2017-04-20","2017-04-21","2017-04-24","2017-04-25","2017-04-26","2017-04-27","2017-04-28","2017-05-01","2017-05-02","2017-05-03","2017-05-04","2017-05-05","2017-05-08","2017-05-09","2017-05-10","2017-05-11","2017-05-12","2017-05-15","2017-05-16","2017-05-17","2017-05-18","2017-05-19","2017-05-22","2017-05-23","2017-05-24","2017-05-25","2017-05-26","2017-05-30","2017-05-31","2017-06-01","2017-06-02","2017-06-05","2017-06-06","2017-06-07","2017-06-08","2017-06-09","2017-06-12","2017-06-13","2017-06-14","2017-06-15","2017-06-16","2017-06-19","2017-06-20","2017-06-21","2017-06-22","2017-06-23","2017-06-26","2017-06-27","2017-06-28","2017-06-29","2017-06-30","2017-07-03","2017-07-05","2017-07-06","2017-07-07","2017-07-10","2017-07-11","2017-07-12","2017-07-13","2017-07-14","2017-07-17","2017-07-18","2017-07-19","2017-07-20","2017-07-21","2017-07-24","2017-07-25","2017-07-26","2017-07-27","2017-07-28","2017-07-31","2017-08-01","2017-08-02","2017-08-03","2017-08-04","2017-08-07","2017-08-08","2017-08-09","2017-08-10","2017-08-11","2017-08-14","2017-08-15","2017-08-16","2017-08-17","2017-08-18","2017-08-21","2017-08-22","2017-08-23","2017-08-24","2017-08-25","2017-08-28","2017-08-29","2017-08-30","2017-08-31","2017-09-01","2017-09-05","2017-09-06","2017-09-07","2017-09-08","2017-09-11","2017-09-12","2017-09-13","2017-09-14","2017-09-15","2017-09-18","2017-09-19","2017-09-20","2017-09-21","2017-09-22","2017-09-25","2017-09-26","2017-09-27","2017-09-28","2017-09-29","2017-10-02","2017-10-03","2017-10-04","2017-10-05","2017-10-06","2017-10-09","2017-10-10","2017-10-11","2017-10-12","2017-10-13","2017-10-16","2017-10-17","2017-10-18","2017-10-19","2017-10-20","2017-10-23","2017-10-24","2017-10-25","2017-10-26","2017-10-27","2017-10-30","2017-10-31","2017-11-01","2017-11-02","2017-11-03","2017-11-06","2017-11-07","2017-11-08","2017-11-09","2017-11-10","2017-11-13","2017-11-14","2017-11-15","2017-11-16","2017-11-17","2017-11-20","2017-11-21","2017-11-22","2017-11-24","2017-11-27","2017-11-28","2017-11-29","2017-11-30","2017-12-01","2017-12-04","2017-12-05","2017-12-06","2017-12-07","2017-12-08","2017-12-11","2017-12-12","2017-12-13","2017-12-14","2017-12-15","2017-12-18","2017-12-19","2017-12-20","2017-12-21","2017-12-22","2017-12-26","2017-12-27","2017-12-28","2017-12-29","2018-01-02","2018-01-03","2018-01-04","2018-01-05","2018-01-08","2018-01-09","2018-01-10","2018-01-11","2018-01-12","2018-01-16","2018-01-17","2018-01-18","2018-01-19","2018-01-22","2018-01-23","2018-01-24","2018-01-25","2018-01-26","2018-01-29","2018-01-30","2018-01-31","2018-02-01","2018-02-02","2018-02-05 ...

# %% [markdown]
# ## Statistics for Single Instruments

# %% [markdown]
# We calculate the **log returns** in vectorized fashion for all financial instruments and all days available.

# %%
rets = np.log(data / data.shift(1))  # log returns in vectorized fashion
rets.dropna(inplace=True)  # deletes rows with NaN values

# %%
rets.head()
# Out:
# TRDPRC_1      AAPL.O    AMZN.O       SPY       GLD
# Date
# 2017-01-04  -0.00112  0.004646  0.005932  0.003524
# 2017-01-05  0.005072   0.03027 -0.000795  0.015396
# 2017-01-06  0.011087  0.019716  0.003571   -0.0074
# 2017-01-09  0.009118  0.001168 -0.003306  0.008199
# 2017-01-10  0.001008 -0.001281       0.0  0.004251

# %% [markdown]
# In MVP, the **average returns** of the financial instruments play an important role since they are used to approximate the **expected returns**.

# %%
rets.mean()  # daily mean returns
# Out:
# TRDPRC_1
# AAPL.O    0.001396
# AMZN.O    0.002309
# SPY       0.000681
# GLD       0.000519
# dtype: float64

# %%
rets.mean() * 252  # annualied mean returns
# Out:
# TRDPRC_1
# AAPL.O    0.351828
# AMZN.O    0.581880
# SPY       0.171599
# GLD       0.130874
# dtype: float64

# %%
(rets.mean() * 252).iplot(kind='bar')
# Out:
# <div>                            <div id="52c8523c-7a2c-4525-8bc0-0c7dedde4992" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("52c8523c-7a2c-4525-8bc0-0c7dedde4992")) {                    Plotly.newPlot(                        "52c8523c-7a2c-4525-8bc0-0c7dedde4992",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"None","orientation":"v","text":"","x":["AAPL.O","AMZN.O","SPY","GLD"],"y":[0.35182841782507757,0.5818799075445648,0.17159877137737817,0.1308741289670581],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl ...

# %% [markdown]
# On the other hand, the **historical volatility** (standard deviation of returns) plays an important role, although it is not used directly.

# %%
rets.std()  # daily volatilities
# Out:
# TRDPRC_1
# AAPL.O    0.012133
# AMZN.O    0.013946
# SPY       0.006010
# GLD       0.006269
# dtype: float64

# %%
rets.std() * math.sqrt(252)  # annualized volatilities
# Out:
# TRDPRC_1
# AAPL.O    0.192603
# AMZN.O    0.221386
# SPY       0.095412
# GLD       0.099521
# dtype: float64

# %%
(rets.std() * math.sqrt(252)).iplot(kind='bar')
# Out:
# <div>                            <div id="9edaad78-7674-45c2-a139-a18afd904a2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("9edaad78-7674-45c2-a139-a18afd904a2d")) {                    Plotly.newPlot(                        "9edaad78-7674-45c2-a139-a18afd904a2d",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"None","orientation":"v","text":"","x":["AAPL.O","AMZN.O","SPY","GLD"],"y":[0.19260321183685958,0.2213858470650831,0.0954117463719085,0.09952123043918648],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl ...

# %% [markdown]
# ## Portfolio Statistics

# %% [markdown]
# Assume a portfolio composed of **all financial instruments** with **equal weighting**.

# %%
weights = len(rics) * [1 / len(rics)]
weights
# Out:
# [0.25, 0.25, 0.25, 0.25]

# %% [markdown]
# The **expected portfolio return** according to MVP is the dot product of the expected returns and the weights.

# %%
np.dot(rets.mean() * 252, weights)
# Out:
# 0.30904530642851963

# %%
def portfolio_return(symbols, weights):
    return np.dot(rets[symbols].mean() * 252, weights)

# %%
portfolio_return(rics, weights)
# Out:
# 0.30904530642851963

# %% [markdown]
# `pandas` allows to derive the **covariance matrix** with a single method call. It plays a major role in the theory of Markowitz (1952) in that it accounts for **diversification** effects.

# %%
data.cov() * 252  # annualized covariance matrix by column
# Out:
# TRDPRC_1        AAPL.O        AMZN.O           SPY          GLD
# TRDPRC_1
# AAPL.O     3679.806010   6239.000965  12203.632285  2619.901119
# AMZN.O     6239.000965  16061.970983  26893.128699  5196.743242
# SPY       12203.632285  26893.128699  51693.162055  9651.703778
# GLD        2619.901119   5196.743242   9651.703778  3398.295109

# %% [markdown]
# With the covariance matrix, **expected portfolio variance** is calculated as follows.

# %%
np.dot(weights, np.dot(rets.cov() * 252, weights))
# Out:
# 0.011367596012406708

# %% [markdown]
# Accordingly, **expected portfolio volatility** is then given by:

# %%
math.sqrt(np.dot(weights, np.dot(rets.cov() * 252, weights)))
# Out:
# 0.10661892895919893

# %%
def portfolio_volatility(symbols, weights):
    return math.sqrt(np.dot(weights, np.dot(rets[symbols].cov() * 252, weights)))

# %%
portfolio_volatility(rics, weights)
# Out:
# 0.10661892895919893

# %% [markdown]
# ## Simulating Portfolio Compositions &mdash; Two Instruments

# %% [markdown]
# To get started, consider just two financial instruments for which **portfolio compositions** are simulated that add up to 100% (= 1).

# %%
fis = ['AAPL.O', 'AMZN.O']

# %%
w = np.random.random((500, len(fis)))  # random portfolio compositions ...

# %%
w[:5].round(2)  # ... that do not yet add up to 100%
# Out:
# array([[0.26, 0.13],
#        [0.31, 0.39],
#        [0.07, 0.52],
#        [0.56, 0.2 ],
#        [0.22, 0.82]])

# %%
w = (w.T / w.sum(axis=1)).T  # normalization ...

# %%
w[:5].round(2)  # ... let's the random numbers add up to 100%
# Out:
# array([[0.67, 0.33],
#        [0.45, 0.55],
#        [0.12, 0.88],
#        [0.74, 0.26],
#        [0.21, 0.79]])

# %%
w.sum(axis=1)[:5] # ... let's the random numbers add up to 100%
# Out:
# array([1., 1., 1., 1., 1.])

# %% [markdown]
# Given these random composition, the resulting **portfolio statistics** can be derived.

# %%
mvp = [(portfolio_volatility(fis, weights),
       portfolio_return(fis, weights))
         for weights in w]

# %%
mvp = pd.DataFrame(np.array(mvp), columns=['volatility', 'return'])
mvp.iloc[:5]
# Out:
#    volatility    return
# 0    0.176388  0.427911
# 1    0.180627  0.479371
# 2    0.206949  0.554178
# 3    0.177652  0.411828
# 4    0.197572  0.533348

# %% [markdown]
# These results can then be **visualized**.

# %%
mvp.iplot(x='volatility', y='return', kind='scatter', mode='markers', color='red')
# Out:
# <div>                            <div id="8df0fd69-1a25-4d1a-ba3f-3d247480cf22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("8df0fd69-1a25-4d1a-ba3f-3d247480cf22")) {                    Plotly.newPlot(                        "8df0fd69-1a25-4d1a-ba3f-3d247480cf22",                        [{"line":{"color":"rgba(219, 64, 82, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":12,"symbol":"circle"},"mode":"markers","name":"return","text":"","x":[0.17638809850844306,0.18062693844591096,0.20694944297472223,0.17765154232048844,0.19757236379187373,0.17931128025730259,0.18409606709454168,0.1816678287102184,0.17637890602026784,0.17646855701102415,0.17665164978229936,0.18267635381175648,0.1763581804338868,0.1762207067591038,0.17622012943225188,0.17929775138524787,0.18765058069446805,0.17631829076900973,0.18294576768989937,0.1805403431727087,0.1762514607046043,0.19562821675334768,0.19744006813584117,0.17944280745153116,0.17813905084047135,0.1827195351606825,0.20338974474176366,0.18919068100356895,0.1844424497101574,0.17635354580568363,0.1943704337653882,0.18729321974073798,0.18673875021025865,0.18015638923541422,0.17671179358901748,0.1917778117475192,0.18442882830681068,0.1804667116947139,0.1825746322921416,0.17678528521441803,0.1770149577960218,0.17851199810351104,0.17942248085737442,0.18188170758558928,0.20147081924975566,0.18831796760534927,0.17684941626704273,0.19104417044365907,0.18433806843364295,0.18892974548833502,0.2032631645580731,0.17919176225021075,0.17939742410554346,0.1795489423304703,0.1762633087482937,0.20311213738031783,0.19492295598568907,0.21290562391989107,0.17624078767500437,0.18390603115346535,0.18520737207797675,0.18262680962123956,0.18731080010010845,0.1892507363892727,0.18890466930913932,0.17654500970231538,0.1777849308896253,0.1775927286520672,0.17621966857362667,0.17737997787107526,0.1850810563773835,0.17989286617904693,0.1775850510042986,0.17641949346588054,0.17659975571519804,0.17945600061126293,0.17792170215493994,0.21354578410971978,0.18747438441277695,0.17967632966000704,0.18039918726226695,0.17827295505280566,0.18070870073873235,0.18237312921569301,0.1807731957111294,0.18047349728734705,0.2138579184777086,0.18328219234939438,0.177281861712009,0.18459399750872882,0.17869544951603566,0.17663513280886153,0.1796949564416848,0.2121092116168504,0.21865478267704413,0.17624666003201048,0.18260057314054604,0.17740527709784315,0.17635051500664642,0.21977081786022826,0.1765307912619845,0.1805629381377604,0.17698564414074788,0.17788574235340954,0.18593703694940306,0.17633421388331286,0.22056433827564,0.20052734326127486,0.17630314939804476,0.177014710398844,0.17772434915342156,0.18501109888472986,0.1808221956073347,0.17900172259949407,0.1780233971488518,0.17632957011276737,0.17643650686529444,0.18345555581266146,0.1825250489032163,0.21407091343426043,0.18379566320058577,0.17645642415607543,0.17625597324034153,0.20965159748399606,0.17845462223151776,0.18522843416504892,0.18101639021180474,0.177478223398698,0.18191171160288763,0.17659442420795207,0.1778344460903061,0.1819898286693044,0.18837767236994563,0.18797410314845733,0.17625903056341033,0.1824561083610842,0.20904716117639566,0.17793029095541532,0.18066434363724904,0.17822463305406877,0.20933212335815513,0.17679903672883232,0.1762196693048312,0.18943592409128518,0.20965188054961711,0.18014602468226368,0.17658599754173224,0.17828504979682605,0.18593982798982195,0.18959326782036426,0.18019565150946723,0.17768392169079217,0.17661786125650658,0.17641876084566552,0.19719150173538977,0.21497989434009168,0.17898838616098312,0.18873716906667026,0.1882683403993673,0.17740234687527154,0.22022215372366707,0.1800997811964967,0.17754149615146123,0.1816920352808152,0.1911794549928428,0.1777565290428736,0.18128704323073938,0.1950445341673575,0.18910779954446896,0.17630109229524196,0.19841632496934133,0.18354149464637343,0.18322448969594138,0.18095887926112628,0.19459854156269507,0.18084886100630249,0.18230203391565872,0.18134747119948655,0.17669688623259439,0 ...

# %% [markdown]
# ## Simulating Portfolio Compositions &mdash; All Instruments

# %% [markdown]
# Second, consider portfolio compositions for **all financial instruments**. The code is basically the same.

# %%
w = np.random.random((2500, len(rics)))  # random portfolio compositions ...

# %%
w[:5].round(2)  # ... that do not yet add up to 100%
# Out:
# array([[0.89, 0.09, 0.37, 0.49],
#        [0.94, 0.16, 0.86, 0.37],
#        [0.98, 0.56, 0.66, 0.97],
#        [0.88, 0.5 , 0.75, 0.99],
#        [0.54, 0.64, 0.56, 0.65]])

# %%
w = (w.T / w.sum(axis=1)).T  # normalization ...

# %%
w[:5].round(2)  # ... let's the random numbers add up to 100%
# Out:
# array([[0.48, 0.05, 0.2 , 0.26],
#        [0.4 , 0.07, 0.37, 0.16],
#        [0.31, 0.18, 0.21, 0.31],
#        [0.28, 0.16, 0.24, 0.32],
#        [0.23, 0.27, 0.23, 0.27]])

# %%
w.sum(axis=1)[:5] # ... let's the random numbers add up to 100%
# Out:
# array([1., 1., 1., 1., 1.])

# %% [markdown]
# Given these random composition, the resulting **portfolio statistics** can be derived.

# %%
mvp = [(portfolio_volatility(rics, weights),
       portfolio_return(rics, weights))
         for weights in w]

# %%
mvp = pd.DataFrame(np.array(mvp), columns=['volatility', 'return'])
mvp.iloc[:5]
# Out:
#    volatility    return
# 0    0.113006  0.267715
# 1    0.111249  0.265903
# 2    0.101910  0.287581
# 3    0.097126  0.275657
# 4    0.105878  0.311843

# %% [markdown]
# These results can then be **visualized**.

# %%
mvp.iplot(x='volatility', y='return', kind='scatter', mode='markers', color='red')
# Out:
# <div>                            <div id="377d6b8b-c3c0-40eb-8052-ed29996112fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("377d6b8b-c3c0-40eb-8052-ed29996112fa")) {                    Plotly.newPlot(                        "377d6b8b-c3c0-40eb-8052-ed29996112fa",                        [{"line":{"color":"rgba(219, 64, 82, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":12,"symbol":"circle"},"mode":"markers","name":"return","text":"","x":[0.11300603267016726,0.11124936878037793,0.10191024488426025,0.09712576475204583,0.10587806673966939,0.11877176692623258,0.10106949857366188,0.12843787259912187,0.11119868670652576,0.11605048881674215,0.11396761012458338,0.10400565623726757,0.13309397241968512,0.08848171608632091,0.11211783655679976,0.12697723065604702,0.08356209842109903,0.08474667277177002,0.1395366853700284,0.11933632238983939,0.08326094842170748,0.10361724275521889,0.14247724942613882,0.13078733741246945,0.10213314875664622,0.10175822373055579,0.16525386443855927,0.08736260885351864,0.10477477300703825,0.12558249731192903,0.11115562682464214,0.1119889313664996,0.12901268210695838,0.12046236177520805,0.0945273539535823,0.12772953091315034,0.09058480297010456,0.09215785068669968,0.15059937232077933,0.10369381545267536,0.13459064926503264,0.09482177293198206,0.09421478187124166,0.12901797576918042,0.09406608036736566,0.08186000027228515,0.10598299556225677,0.0920183291272908,0.11271109640245046,0.09747957844405344,0.15563982890675035,0.13130699694286554,0.08874037495540156,0.10259476856574445,0.12877638023337704,0.1344226990116363,0.15210645863130268,0.14654032839578401,0.11213401964841185,0.11132490374353249,0.1218035387989112,0.07241905666049656,0.09584688790816738,0.13684811308676628,0.10965180130841995,0.13138025156140498,0.109476725523605,0.08282669590002652,0.06795982096423225,0.12271540720900553,0.11159504904674131,0.1348102525848973,0.08671015452953118,0.1282217139494101,0.131785568600449,0.11402109313514924,0.07577703557061546,0.11869062308054078,0.08307945046767824,0.12911458639608048,0.11719012240164234,0.11347144116840518,0.088893903832936,0.10581228078861347,0.09020286403150628,0.09360923400926878,0.11533789168486945,0.09592875721999196,0.09616157623723902,0.11638762925222162,0.07348594374627422,0.12040394013869556,0.13399475248450765,0.10482381155002365,0.16161791549086615,0.10532072605954758,0.12712073552413244,0.10575047960020499,0.09699824235271985,0.12038611913048941,0.1380717332687017,0.12560780857614287,0.12833975015908272,0.10902318269918927,0.0781002925494291,0.08521369783438339,0.13635597676813346,0.12528532836891157,0.0942162375400451,0.09664567826450574,0.12776561370247663,0.13700298539205472,0.08617292702121242,0.09967799782556239,0.10810835865535914,0.08527785207626234,0.13815940848228278,0.09113220039961682,0.1066378030825093,0.10701117821967915,0.0886287330765686,0.09823584258232877,0.13795094246234305,0.10926890960718362,0.10647464503839815,0.14324235729283297,0.09832329675071746,0.12179866568421344,0.13400296885463012,0.09931859837604264,0.11905466630607253,0.09695891572897317,0.16838003205426277,0.08024025625451163,0.123969335938716,0.1360865334029576,0.1158271449971737,0.09632984843094229,0.09310769473576416,0.10172651694828476,0.09150122212541004,0.14380148621656716,0.08278184241194773,0.09692736687202125,0.1369008805829225,0.1020579359937926,0.095753793620601,0.09632067383868749,0.10716439264533444,0.08329008028554392,0.08569994575875294,0.11650670721653288,0.11618451627171719,0.10013128133765341,0.09944039297644773,0.09873800560538748,0.09951539263300146,0.11094114803997521,0.11912643939167551,0.13257689820141555,0.13900739710184667,0.1193372670705852,0.10884022670003134,0.14502879913166844,0.0883102585877473,0.10963726277985932,0.10550178911227187,0.08264235065834452,0.09223943728666352,0.1263498328974836,0.10765505969528726,0.16399346444425197,0.13289660548326676,0.08775804294502237,0.10104216082527856,0.1275322928059973,0.09800593503097302,0.07995708606731634,0.09 ...

# %% [markdown]
# ## Minimum Volatility Portfolio

# %% [markdown]
# Let us now derive the portfolio composition that **minimizes the expected volatility** of the portfolio. First, the **boundary conditions** for the single weights (between 0 and 1).

# %%
bounds = len(rics) * [(0, 1)]

# %%
bounds
# Out:
# [(0, 1), (0, 1), (0, 1), (0, 1)]

# %% [markdown]
# Second, the condition that the **weights add up to 100%**.

# %%
constraints = {'type': 'eq', 'fun': lambda weights: weights.sum() - 1}

# %% [raw]
# help(sco.minimize)

# %% [markdown]
# Third, the **function to be minimized**. This is the function `portfolio_volatility()` from above.

# %% [markdown]
# These three elements are used in combination with the **general minimizer function `sco.minimize()`** to derive the minimum volatility portfolio.

# %%
res = sco.minimize(lambda x: portfolio_volatility(rics, x),  # function to be minized
                   len(rics) * [1 / len(rics)],  # initial guess
                   bounds=bounds,  # boundary conditions
                   constraints=constraints  # single equality constraint
                  )

# %% [markdown]
# The **results** are:

# %%
res
# Out:
#      fun: 0.06476360145184672
#      jac: array([0.08022096, 0.07191757, 0.06489603, 0.0646203 ])
#  message: 'Optimization terminated successfully'
#     nfev: 35
#      nit: 7
#     njev: 7
#   status: 0
#  success: True
#        x: array([0.       , 0.       , 0.5197279, 0.4802721])

# %%
res['fun']  # minimum volatility
# Out:
# 0.06476360145184672

# %%
for r in zip(rics, res['x']):
    print('%7s | %7.3f' % (r[0], r[1])) # optimal portfolio composition
# Out:
#  AAPL.O |   0.000
#  AMZN.O |   0.000
#     SPY |   0.520
#     GLD |   0.480

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Based on this tutorial, we can conclude that
#
# * it is easy to retrieve **historical end-of-day across asset classes** via the LSEG Data Libraries,
# * `Plotly` and `Cufflinks` make **financial data visualization** convenient and
# * `pandas` is a powerful data analysis tool to implement **financial algorithms** efficiently, such as the portfolio selection approach from Markowitz (1952).

# %% [markdown]
# ## LSEG Data Libraries API Developer Resources

# %% [markdown]
# * [Overview](https://developers.thomsonreuters.com/eikon-data-apis)
# * [Quick Start ](https://developers.thomsonreuters.com/eikon-data-apis/quick-start)
# * [Documentation](https://developers.thomsonreuters.com/eikon-data-apis/docs)
# * [Downloads](https://developers.thomsonreuters.com/eikon-data-apis/downloads)
# * [Tutorials](https://developers.thomsonreuters.com/eikon-data-apis/learning)
# * [Q&A Forums](https://developers.thomsonreuters.com/eikon-data-apis/qa)
#
# Data Item Browser Application: Type `DIB` into Workspace Search Bar.
