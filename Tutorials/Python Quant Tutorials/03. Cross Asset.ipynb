# %% [markdown]
# <img src="https://developers.lseg.com/content/dam/devportal/icons/logo/lseg-logo.svg" width="28%" align="left" style="vertical-align: top; padding-top: 23px;">
# <img src="http://hilpisch.com/tpq_logo_long.png" width="36%" align="right" style="vertical-align: top;">

# %% [markdown]
# # LSEG Data Python Library

# %% [markdown]
# **Python Wrapper Package &mdash; Data Retrieval**
#
# Dr. Yves J. Hilpisch | The Python Quants GmbH
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a> | <a href="mailto:training@tpq.io">training@tpq.io</a>
#
# <img src="http://hilpisch.com/images/tr_eikon_02.png" width=350px align=left>

# %% [markdown]
# ## The Agenda

# %% [markdown]
# This tutorial shows
#
# * how to retrieve historical data across asset classes via the LSEG Data Python Library,
# * how to work with such data using `pandas`, `Plotly` and `Cufflinks` and
# * how to derive support for the Random Walk Hypothesis from financial time series data.

# %% [markdown]
# ## Random Walk Hypothesis

# %% [markdown]
# Eugene F. Fama (1965): “Random Walks in Stock Market Prices”:
#
# > “For many years, economists, statisticians, and teachers of finance have been interested in developing and testing models of stock price behavior. One important model that has evolved from this research is the theory of random walks. This theory casts serious doubt on many other methods for describing and predicting stock price behavior—methods that have considerable popularity outside the academic world. For example, we shall see later that, if the random-walk theory is an accurate description of reality, then the various “technical” or “chartist” procedures for predicting stock prices are completely without value.”

# %% [markdown]
# Michael Jensen (1978): “Some Anomalous Evidence Regarding Market Efficiency”:
#
# >“A market is efficient with respect to an information set S if it is impossible to make economic profits by trading on the basis of information set S.”

# %% [markdown]
# If a stock price follows a (simple) random walk (no drift & normally distributed returns), then it rises and falls with the same probability of 50% (“toss of a coin”).
#
# **In such a case, the best predictor of tomorrow’s stock price — in a least-squares sense — is today’s stock price.**

# %% [markdown]
# ## Importing Required Packages

# %%
import lseg.data as ld  # the LSEG Python wrapper package
import numpy as np  # NumPy
import pandas as pd  # pandas
import cufflinks as cf  # Cufflinks
import configparser as cp

# %% [markdown]
# The following **Python and package versions** are used.

# %%
import sys
print(sys.version)
# Out:
# 3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]

# %%
ld.__version__
# Out:
# '1.5.1.dev97+g1dedf55e'

# %%
np.__version__
# Out:
# '1.23.4'

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
cf.__version__
# Out:
# '0.17.3'

# %% [markdown]
# ## Connecting to LSEG's services

# %% [markdown]
# The LSEG Data Platform hosts many API Families which themselves host individual APIs which allow users to access data (e.g.: historical end-of-business-day (i.e.: close) prices for a company's publicly floated equity (i.e.: stock)) or services (e.g.: calculations). The [LSEG Data Python Library](https://developers.lseg.com/en) allows us to connect to this platform, and we can authenticate ourselves with the following code:

# %%
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x24f243c9490 {name='workspace'}>

# %% [markdown]
# ## Retrieving Cross-Asset Data

# %% [markdown]
# We first define a **small universe of `RICS`** for which to retrieve data.

# %%
rics = [
    'GE',  # General Electric stock
    'AAPL.O',  # Apple stock
    '.SPX',  # S&P 500 stock index
    '.VIX',  # VIX volatility index
    # 'EUR=',  # EUR/USD exchange rate
    # 'XAU=',  # Gold price
    # 'DE10YT=RR',  # 10yr Bund price
]

# %% [markdown]
# Second, **end-of-day (EOD) data** is retrieved.

# %%
data = ld.get_history(
    rics,  # the RICs
    fields='TR.PriceClose',  # close field
    start='2024-01-01T12:00:00',  # start date
    end='2024-05-20T12:00:00')  # end date

# %%
data.head()  # first five rows
# Out:
# Price Close          GE  AAPL.O     .SPX   .VIX
# Date
# 2023-12-29         <NA>    <NA>  4769.83  12.45
# 2024-01-02   100.449029  185.64  4742.83   13.2
# 2024-01-03    98.941696  184.25  4704.81  14.04
# 2024-01-04    99.420214  181.91  4688.68  14.13
# 2024-01-05    100.72019  181.18  4697.24  13.35

# %%
data.tail()  # final five rows
# Out:
# Price Close      GE  AAPL.O     .SPX   .VIX
# Date
# 2024-05-14    160.0  187.43  5246.68  13.42
# 2024-05-15   163.47  189.72  5308.15  12.45
# 2024-05-16   161.12  189.84   5297.1  12.42
# 2024-05-17   159.89  189.87  5303.27  11.99
# 2024-05-20   159.28  191.04  5308.13  12.15

# %% [markdown]
# Only complete data rows are selected.

# %%
data.dropna(inplace=True)  # deletes tows with NaN values

# %%
data.info()  # DataFrame meta information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97 entries, 2024-01-02 to 2024-05-20
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GE      97 non-null     Float64
#  1   AAPL.O  97 non-null     Float64
#  2   .SPX    97 non-null     Float64
#  3   .VIX    97 non-null     Float64
# dtypes: Float64(4)
# memory usage: 4.2 KB

# %% [markdown]
# ## Calculating the Log Returns

# %% [markdown]
# We next calculate the **log returns** in vectorized fashion.

# %%
rets = np.log(data / data.shift(1))  # log returns in vectorized fashion

# %%
rets.head()
# Out:
# Price Close        GE    AAPL.O      .SPX      .VIX
# Date
# 2024-01-02       <NA>      <NA>      <NA>      <NA>
# 2024-01-03   -0.01512 -0.007516 -0.008049  0.061694
# 2024-01-04   0.004825 -0.012781 -0.003434   0.00639
# 2024-01-05   0.012991 -0.004021  0.001824 -0.056784
# 2024-01-08   0.015635  0.023887  0.014016 -0.020432

# %% [markdown]
# `pandas` allows to derive the **correlation matrix** with a single method call.

# %%
data.corr()  # correlation matrix by column
# Out:
# Price Close        GE    AAPL.O      .SPX      .VIX
# Price Close
# GE           1.000000 -0.554317  0.781073  0.321908
# AAPL.O      -0.554317  1.000000 -0.419450 -0.619169
# .SPX         0.781073 -0.419450  1.000000 -0.007382
# .VIX         0.321908 -0.619169 -0.007382  1.000000

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# Using `Cufflinks`, we can plot the normalized financial time series as **line plots** for comparison.

# %%
cf.set_config_file(offline=True)  # set the plotting mode to offline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data.normalize().iplot(kind='lines')
# Out:
# <div>                            <div id="a6304098-fd16-4555-b58e-49b9cf365034" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("a6304098-fd16-4555-b58e-49b9cf365034")) {                    Plotly.newPlot(                        "a6304098-fd16-4555-b58e-49b9cf365034",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"GE","text":"","x":["2024-01-02","2024-01-03","2024-01-04","2024-01-05","2024-01-08","2024-01-09","2024-01-10","2024-01-11","2024-01-12","2024-01-16","2024-01-17","2024-01-18","2024-01-19","2024-01-22","2024-01-23","2024-01-24","2024-01-25","2024-01-26","2024-01-29","2024-01-30","2024-01-31","2024-02-01","2024-02-02","2024-02-05","2024-02-06","2024-02-07","2024-02-08","2024-02-09","2024-02-12","2024-02-13","2024-02-14","2024-02-15","2024-02-16","2024-02-20","2024-02-21","2024-02-22","2024-02-23","2024-02-26","2024-02-27","2024-02-28","2024-02-29","2024-03-01","2024-03-04","2024-03-05","2024-03-06","2024-03-07","2024-03-08","2024-03-11","2024-03-12","2024-03-13","2024-03-14","2024-03-15","2024-03-18","2024-03-19","2024-03-20","2024-03-21","2024-03-22","2024-03-25","2024-03-26","2024-03-27","2024-03-28","2024-04-01","2024-04-02","2024-04-03","2024-04-04","2024-04-05","2024-04-08","2024-04-09","2024-04-10","2024-04-11","2024-04-12","2024-04-15","2024-04-16","2024-04-17","2024-04-18","2024-04-19","2024-04-22","2024-04-23","2024-04-24","2024-04-25","2024-04-26","2024-04-29","2024-04-30","2024-05-01","2024-05-02","2024-05-03","2024-05-06","2024-05-07","2024-05-08","2024-05-09","2024-05-10","2024-05-13","2024-05-14","2024-05-15","2024-05-16","2024-05-17","2024-05-20"],"y":[100.0,98.4994045256054,98.97578404128622,100.26994839221912,101.84994045256055,102.24692338229455,102.97737197300516,103.08058753473601,103.0488289003573,101.60381103612544,100.73838824930527,102.0643112346169,103.06470821754665,104.19213973799127,103.17586343787217,103.15998412068281,103.15998412068281,104.16038110361254,104.0889241762604,106.33584755855499,105.13695911075824,107.51091703056768,108.40809845176658,109.33703850734418,109.23382294561334,109.96427153632393,110.40095275903137,110.58356490670901,111.29019452163558,112.56053989678445,116.31599841206828,117.80071456927352,118.42794759825328,117.99920603414054,118.35649067090117,120.42080190551808,121.738785232235,122.882096069869,122.26280269948393,123.54902739182214,124.56530369194125,125.962683604605,127.83644303294959,125.33545057562525,126.63755458515284,132.19531560142917,133.3545057562525,132.24295355299722,132.95752282651847,135.10123064708216,132.39380706629615,134.09289400555778,134.90273918221516,137.7213179833267,138.0944819372767,140.24612941643508,139.06312028582772,137.74513695911077,137.79277491067882,143.0091306073839,139.36482731242558,139.229853116316,135.85994881904756,144.96904628877925,146.7311339960388,155.60130431902348,155.82032087020826,153.79939542063937,155.90991855023844,156.97513541281907,153.93876958957514,153.0129268959303,156.0592480169553,154.97412055881242,152.25632426456463,147.39813894737438,149.51861737475454,161.8930525166961,158.4783853777693,160.53913201846274,161.6242594766056,163.7546932017669,161.09662869420586,158.98610556460682,161.91296311225832,163.3763918860841,167.2191368295993,168.02551594987062,168.1051583321197,166.75123783388634,162.64965514806175,158.78699960898427,159.28476449804066,162.7392528280919,160.39975784952694,159.17525622244824,158.56798305779947],"type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"AAPL.O","text":"","x":["2024-01-02","2024-01-03","2024-01-04","2024-01-05","2024-01-08","2024-01-09","2024-01-10","2024-01-11","2024-01-12","2024-01-16","2024-01-17","2024-01-18","2024-01-19","2024-01-22","2024-01-23","2024-01-24","2024-01-25","2024-01-26","2024-01-29","2024-01-30","2024-01-31","2024-02-01","2024-02-02","2024-02-05","2024-02-06","2024-02-07","2024-02-08","2024 ...

# %% [markdown]
# The frequeny distributions, i.e. the **histograms**, of the log returns per `RIC`.

# %%
rets.iplot(kind='histogram', subplots=True)
# Out:
# <div>                            <div id="2bf59321-9c08-4021-9a58-1fcf25a2f165" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("2bf59321-9c08-4021-9a58-1fcf25a2f165")) {                    Plotly.newPlot(                        "2bf59321-9c08-4021-9a58-1fcf25a2f165",                        [{"histfunc":"count","histnorm":"","marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"GE","opacity":0.8,"orientation":"v","x":[null,-0.015119683253647776,0.0048247118357331205,0.012990818277374043,0.015634525166875572,0.0038901472850832626,0.00711856921236076,0.0010018110497640655,-0.000308142672494617,-0.014121898250163073,-0.008554103562966648,0.013076175825360548,0.009753909193004515,0.010879666003292264,-0.009801747820696156,-0.00015391719285422545,0.0,0.009650810198293816,-0.0006862633232847244,0.021356884629376544,-0.011338585902330646,0.022328523498032576,0.008310398995401598,0.008532412748900162,-0.0009444586411664608,0.00666475952952519,0.003963255052580717,0.0016527147799597435,0.006369676215032671,0.011350054454573811,0.03281940232758177,0.012683725505580378,0.005310401347917824,-0.0036268425812968704,0.003023281553015841,0.017291113780966566,0.01088535338499212,0.0093476824763705,-0.005052478684346684,0.010465211791097002,0.008192045813445648,0.011155595184340299,0.014765956827642597,-0.019757910576590786,0.010335357944642711,0.042951387195599475,0.008730546395493994,-0.00837025094933388,0.005388911909627061,0.015994654115695808,-0.02024348609624865,0.012751930634096922,0.006021269667837257,0.020678140158642493,0.0027058941637522296,0.015460843668668645,-0.00847101344523452,-0.009522788805259294,0.00034578146955845443,0.03715755312557584,-0.02581332696511656,-0.0009689647086036744,-0.024501619904368947,0.0648956787165426,0.012081645882101396,0.058695102578764445,0.0014065599147807402,-0.013054428018253437,0.013629269154384092,0.00680902436612222,-0.019532496357125728,-0.006032515942788988,0.019713322786880462,-0.006977591283672787,-0.017692694431678868,-0.03242809060112676,0.014283562202537063,0.07951503156220217,-0.02131773341264702,0.012919511889831495,0.006736529291978932,0.013095279535211942,-0.01636517170437324,-0.01318755115872688,0.01824211409912439,0.008997765371445456,0.02324845733737494,0.004810699700908974,0.0004738775115334823,-0.008086617976232858,-0.0249045753513979,-0.024034853688823913,0.0031298930089275656,0.021455672029289826,-0.014480058292864428,-0.007663350172923326,-0.003822419041388046],"xaxis":"x","yaxis":"y","type":"histogram"},{"histfunc":"count","histnorm":"","marker":{"color":"rgba(55, 128, 191, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"AAPL.O","opacity":0.8,"orientation":"v","x":[null,-0.0075157833035290516,-0.012781471795321235,-0.004021047032982936,0.023887267642401212,-0.0022659842444777943,0.005655362068895832,-0.0032277181177477222,0.001776534073333066,-0.012393610132458198,-0.005186875214289937,0.03205143604083493,0.015413651116775463,0.012089912468505099,0.006631221770401398,-0.0034900466548141206,-0.0016980990521387232,-0.009053581073243873,-0.0035923506028184725,-0.019433426174370286,-0.01954739503343621,0.013252362242316237,-0.005419776621548585,0.009798488161904201,0.008594673310111774,0.0005809194533730344,-0.005771334156683685,0.0028104056464991977,-0.009042614808027809,-0.011338416427254269,-0.004821375032109306,-0.0015760444554656545,-0.008466063620235055,-0.0041223572271086705,0.004177207349163798,0.011181223144870737,-0.010084852023097546,-0.007479137371188802,0.008081629515937215,-0.006647463017152321,-0.003699924147923935,-0.006048685237813562,-0.025708936509254418,-0.028853168906373343,-0.005895548263505318,-0.0007098071988540113,0.01018464636006875,0.011762101364637088,0.002774728643070094,-0.012196689701489101,0.010868092908418524,-0.0021989477062673733,0.00635216087510961,0.013493629551585165,0.014602091726869399,-0.04171556727231797,0.0052960985131520685,-0.008335081624609079,-0.00669488053812676,0.020990800438109806,-0.0106 ...

# %% [markdown]
# The **heatmap** below visualizes the correlations between the financial time series.

# %%
data.corr().iplot(kind='heatmap', colorscale='blues')
# Out:
# <div>                            <div id="c319fe7a-b355-436b-9f8f-425e1ee365f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("c319fe7a-b355-436b-9f8f-425e1ee365f2")) {                    Plotly.newPlot(                        "c319fe7a-b355-436b-9f8f-425e1ee365f2",                        [{"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"x":["GE","AAPL.O",".SPX",".VIX"],"y":["GE","AAPL.O",".SPX",".VIX"],"z":[[1.0,-0.5543170682609867,0.781073374515014,0.3219077137674206],[-0.5543170682609867,1.0,-0.41945016855902306,-0.6191693797434838],[0.781073374515014,-0.41945016855902306,1.0,-0.007381830180643593],[0.3219077137674206,-0.6191693797434838,-0.007381830180643593,1.0]],"zmax":1.0,"zmin":-0.6191693797434838,"type":"heatmap"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"a ...

# %% [markdown]
# ## Preparing Lagged Data

# %% [markdown]
# To gain insights into whether the random walk hypothesis holds true, we work with **five lags**. The code that follows derives the **lagged data** for every single `RIC`. First, a function that adds columns with lagged data to a `DataFrame` object.

# %%
def add_lags(data, ric, lags):
    cols = []
    df = pd.DataFrame(data[ric])
    for lag in range(1, lags + 1):
        col = 'lag_{}'.format(lag)  # defines the column name
        df[col] = df[ric].shift(lag)  # creates the lagged data column
        cols.append(col)  # stores the column name
    df.dropna(inplace=True)  # gets rid of incomplete data rows
    return df, cols

# %% [markdown]
# Second, the iterations over all `RICs`, using the `add_lags` function and storing the resulting `DataFrame` objects in a dictonary.

# %%
lags = 5  # five historical lags

# %%
dfs = {}
for ric in rics:
    df, cols = add_lags(data, ric, lags)
    dfs[ric] = df

# %%
cols  # the column names for the lags
# Out:
# ['lag_1', 'lag_2', 'lag_3', 'lag_4', 'lag_5']

# %%
dfs.keys()  # the keys of the dictonary
# Out:
# dict_keys(['GE', 'AAPL.O', '.SPX', '.VIX'])

# %%
dfs['AAPL.O'].head(7)
# Out:
#             AAPL.O   lag_1   lag_2   lag_3   lag_4   lag_5
# Date
# 2024-01-09  185.14  185.56  181.18  181.91  184.25  185.64
# 2024-01-10  186.19  185.14  185.56  181.18  181.91  184.25
# 2024-01-11  185.59  186.19  185.14  185.56  181.18  181.91
# 2024-01-12  185.92  185.59  186.19  185.14  185.56  181.18
# 2024-01-16  183.63  185.92  185.59  186.19  185.14  185.56
# 2024-01-17  182.68  183.63  185.92  185.59  186.19  185.14
# 2024-01-18  188.63  182.68  183.63  185.92  185.59  186.19

# %% [markdown]
# ## Implementing OLS Regression

# %% [markdown]
# The matrix consisting of the lagged data columns is used to "predict" the next day's value of the `RIC` via **linear OLS regression**.

# %%
regs = {}
for ric in rics:
    df = dfs[ric]  # getting data for the RIC
    
    # tidying the data to fit the type nessesary for our OLS Python function `np.linalg.lstsq`
    x = np.vstack([float(i) for i in df[ric].values])
    A = np.vstack([
        np.array([float(j) for j in i]) for i in [
            row[1].values for row in df[cols].iterrows()]])
    
    reg = np.linalg.lstsq(A, x, rcond=None)[0]  # the OLS regression
    regs[ric] = np.array([i[0] for i in reg])  # storing the results

# %%
for ric in rics:
    print('{:10} | {}'.format(ric, regs[ric]))
# Out:
# GE         | [ 0.96099202 -0.04616513 -0.11861937  0.31735471 -0.10811975]
# AAPL.O     | [ 1.08669392 -0.10726631 -0.01355608  0.05522921 -0.02087889]
# .SPX       | [ 1.00869959 -0.24003522  0.23023117  0.1030741  -0.10064285]
# .VIX       | [ 1.04309786 -0.21866963  0.1325518   0.07127188 -0.0302332 ]

# %% [markdown]
# ## Taking a Closer Look

# %% [markdown]
# Let's pick one `RIC` and compare the original time series with the OLS predicted one.

# %%
ric = 'AAPL.O'

# %%
res = pd.DataFrame(dfs[ric][ric])  # picks the original time series

# %%
res['PRED'] = np.dot(dfs[ric][cols], regs[ric])  # creates the "prediction" values

# %% [markdown]
# The **predicted prices** are almost exactly the prices from the day before.

# %%
res.iloc[-50:].iplot()
# Out:
# <div>                            <div id="8357f42a-d1a8-42ee-8abf-ab479b779740" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("8357f42a-d1a8-42ee-8abf-ab479b779740")) {                    Plotly.newPlot(                        "8357f42a-d1a8-42ee-8abf-ab479b779740",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"AAPL.O","text":"","x":["2024-03-11","2024-03-12","2024-03-13","2024-03-14","2024-03-15","2024-03-18","2024-03-19","2024-03-20","2024-03-21","2024-03-22","2024-03-25","2024-03-26","2024-03-27","2024-03-28","2024-04-01","2024-04-02","2024-04-03","2024-04-04","2024-04-05","2024-04-08","2024-04-09","2024-04-10","2024-04-11","2024-04-12","2024-04-15","2024-04-16","2024-04-17","2024-04-18","2024-04-19","2024-04-22","2024-04-23","2024-04-24","2024-04-25","2024-04-26","2024-04-29","2024-04-30","2024-05-01","2024-05-02","2024-05-03","2024-05-06","2024-05-07","2024-05-08","2024-05-09","2024-05-10","2024-05-13","2024-05-14","2024-05-15","2024-05-16","2024-05-17","2024-05-20"],"y":[172.75,173.23,171.13,173.0,172.62,173.72,176.08,178.67,171.37,172.28,170.85,169.71,173.31,171.48,170.03,168.84,169.65,168.82,169.58,168.45,169.67,167.78,175.04,176.55,172.69,169.38,168.0,167.04,165.0,165.84,166.9,169.02,169.89,169.3,173.5,170.33,169.3,173.03,183.38,181.71,182.4,182.74,184.57,183.05,186.28,187.43,189.72,189.84,189.87,191.04],"type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"PRED","text":"","x":["2024-03-11","2024-03-12","2024-03-13","2024-03-14","2024-03-15","2024-03-18","2024-03-19","2024-03-20","2024-03-21","2024-03-22","2024-03-25","2024-03-26","2024-03-27","2024-03-28","2024-04-01","2024-04-02","2024-04-03","2024-04-04","2024-04-05","2024-04-08","2024-04-09","2024-04-10","2024-04-11","2024-04-12","2024-04-15","2024-04-16","2024-04-17","2024-04-18","2024-04-19","2024-04-22","2024-04-23","2024-04-24","2024-04-25","2024-04-26","2024-04-29","2024-04-30","2024-05-01","2024-05-02","2024-05-03","2024-05-06","2024-05-07","2024-05-08","2024-05-09","2024-05-10","2024-05-13","2024-05-14","2024-05-15","2024-05-16","2024-05-17","2024-05-20"],"y":[170.8503430134807,172.91026839766448,173.20600289721926,170.94312655273254,173.2694390480564,172.66870980383425,173.75348122852304,176.35236154634896,178.8388080052975,170.66481639788387,172.5090158290262,171.05016006709474,169.4951342121907,173.7515755789015,171.29424336540094,169.83292813402076,168.94273324160875,169.7940250903466,168.7794411690819,169.6479307821736,168.41927734301845,169.79320008778768,167.6831057311565,175.68042153848302,176.65916973997147,172.07428646731466,169.31133303354247,168.1508887681919,167.0558488600335,164.85846012054085,165.99601292552438,167.06125201126588,169.14732986714367,169.93996502719085,169.21775973143045,173.92832184215698,170.04476787930406,169.15782192475436,173.6089285660636,184.2073021575407,181.2410528167887,182.257211124376,183.06905606339564,184.70355242958522,182.92384715565487,186.5764771801216,187.5942808967334,189.79351081028383,189.87281100628476,189.85757122747444],"type":"scatter"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tic ...

# %%
res.head()
# Out:
#             AAPL.O        PRED
# Date
# 2024-01-09  185.14  186.046453
# 2024-01-10  186.19  185.029897
# 2024-01-11  185.59  186.165141
# 2024-01-12  185.92  185.663334
# 2024-01-16  183.63  185.957423

# %% [markdown]
# ## Analyzing the Results

# %% [markdown]
# Now analyzing the **regression results** a bit more formally.

# %%
rega = np.stack(regs.values())  # combines the regression results
rega
# Out:
# C:\Users\U6082174\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:3488: FutureWarning:
#
# arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
# array([[ 0.96099202, -0.04616513, -0.11861937,  0.31735471, -0.10811975],
#        [ 1.08669392, -0.10726631, -0.01355608,  0.05522921, -0.02087889],
#        [ 1.00869959, -0.24003522,  0.23023117,  0.1030741 , -0.10064285],
#        [ 1.04309786, -0.21866963,  0.1325518 ,  0.07127188, -0.0302332 ]])

# %% [markdown]
# Almost all the weight lies on the most recent price (`lag_1`).

# %%
rega.mean(axis=0)  # mean values by column
# Out:
# array([ 1.02487085, -0.15303407,  0.05765188,  0.13673247, -0.06496867])

# %%
regd = pd.DataFrame(rega, columns=cols, index=rics)  # converting the results to DataFrame

# %%
regd
# Out:
#            lag_1     lag_2     lag_3     lag_4     lag_5
# GE      0.960992 -0.046165 -0.118619  0.317355 -0.108120
# AAPL.O  1.086694 -0.107266 -0.013556  0.055229 -0.020879
# .SPX    1.008700 -0.240035  0.230231  0.103074 -0.100643
# .VIX    1.043098 -0.218670  0.132552  0.071272 -0.030233

# %%
regd.describe()  # summary statistics
# Out:
#           lag_1     lag_2     lag_3     lag_4     lag_5
# count  4.000000  4.000000  4.000000  4.000000  4.000000
# mean   1.024871 -0.153034  0.057652  0.136732 -0.064969
# std    0.053218  0.092002  0.154419  0.122045  0.045772
# min    0.960992 -0.240035 -0.118619  0.055229 -0.108120
# 25%    0.996773 -0.224011 -0.039822  0.067261 -0.102512
# 50%    1.025899 -0.162968  0.059498  0.087173 -0.065438
# 75%    1.053997 -0.091991  0.156972  0.156644 -0.027895
# max    1.086694 -0.046165  0.230231  0.317355 -0.020879

# %% [markdown]
# ## Visualizing the Results

# %% [markdown]
# The following bar chart illustrates that the results a qualitatively similar for all `RICS` analyzed &mdash; "_today's price is the best predictor, in a least-squares sense, for tomorrow's price_".

# %%
regd.iplot(kind='bar')
# Out:
# <div>                            <div id="b901ed0d-d47e-4bb6-9fa0-d1fc8c17d4e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("b901ed0d-d47e-4bb6-9fa0-d1fc8c17d4e1")) {                    Plotly.newPlot(                        "b901ed0d-d47e-4bb6-9fa0-d1fc8c17d4e1",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"lag_1","orientation":"v","text":"","x":["GE","AAPL.O",".SPX",".VIX"],"y":[0.9609920222238482,1.0866939214509588,1.0086995875702185,1.0430978573504566],"type":"bar"},{"marker":{"color":"rgba(55, 128, 191, 0.6)","line":{"color":"rgba(55, 128, 191, 1.0)","width":1}},"name":"lag_2","orientation":"v","text":"","x":["GE","AAPL.O",".SPX",".VIX"],"y":[-0.046165127651700784,-0.10726630814984112,-0.24003521549079257,-0.2186696252398737],"type":"bar"},{"marker":{"color":"rgba(50, 171, 96, 0.6)","line":{"color":"rgba(50, 171, 96, 1.0)","width":1}},"name":"lag_3","orientation":"v","text":"","x":["GE","AAPL.O",".SPX",".VIX"],"y":[-0.11861937227785474,-0.013556082115116427,0.23023116802722482,0.13255179936728326],"type":"bar"},{"marker":{"color":"rgba(128, 0, 128, 0.6)","line":{"color":"rgba(128, 0, 128, 1.0)","width":1}},"name":"lag_4","orientation":"v","text":"","x":["GE","AAPL.O",".SPX",".VIX"],"y":[0.3173547052360175,0.05522921264111069,0.10307410112763536,0.07127188018065973],"type":"bar"},{"marker":{"color":"rgba(219, 64, 82, 0.6)","line":{"color":"rgba(219, 64, 82, 1.0)","width":1}},"name":"lag_5","orientation":"v","text":"","x":["GE","AAPL.O",".SPX",".VIX"],"y":[-0.10811974864887,-0.020878887297062138,-0.10064284551271525,-0.03023320177142691],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777 ...

# %% [markdown]
# The **mean values** for the single optimal regression parameters.

# %%
regd.mean().iplot(kind='bar')
# Out:
# <div>                            <div id="c013e083-e0dd-4d67-8add-fe3cc182f63c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("c013e083-e0dd-4d67-8add-fe3cc182f63c")) {                    Plotly.newPlot(                        "c013e083-e0dd-4d67-8add-fe3cc182f63c",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"None","orientation":"v","text":"","x":["lag_1","lag_2","lag_3","lag_4","lag_5"],"y":[1.0248708471488706,-0.15303406913305206,0.057651878250384224,0.13673247479635584,-0.06496867080751857],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""} ...

# %% [markdown]
# ## Analyzing Intraday Data

# %% [markdown]
# Let us quickly check, whether the results are similar on an **intraday basis**.

# %%
data = ld.get_history(
    rics[0:2],  # RICs
    fields='BID',  # fields to be retrieved
    start='2024-05-20T14:00:00',  # start date
    end='2024-05-20T18:00:00',  # end date
    interval='minute')  # bar length

# %%
data
# Out:
# BID                      GE  AAPL.O
# Timestamp
# 2024-05-20 14:00:00   160.5  190.93
# 2024-05-20 14:01:00  160.51  190.83
# 2024-05-20 14:02:00   160.4  190.92
# 2024-05-20 14:03:00  160.58  191.08
# 2024-05-20 14:04:00   160.6  191.28
# ...                     ...     ...
# 2024-05-20 17:55:00   159.9  191.45
# 2024-05-20 17:56:00  159.88  191.43
# 2024-05-20 17:57:00   159.9  191.45
# 2024-05-20 17:58:00  159.96  191.47
# 2024-05-20 17:59:00  160.03   191.5
#
# [240 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 240 entries, 2024-05-20 14:00:00 to 2024-05-20 17:59:00
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GE      240 non-null    Float64
#  1   AAPL.O  240 non-null    Float64
# dtypes: Float64(2)
# memory usage: 6.1 KB

# %%
data.tail()
# Out:
# BID                      GE  AAPL.O
# Timestamp
# 2024-05-20 17:55:00   159.9  191.45
# 2024-05-20 17:56:00  159.88  191.43
# 2024-05-20 17:57:00   159.9  191.45
# 2024-05-20 17:58:00  159.96  191.47
# 2024-05-20 17:59:00  160.03   191.5

# %%
dfs = {}
for ric in rics[0:2]:
    df, cols = add_lags(data, ric, lags)
    dfs[ric] = df

# %%
regs = {}
for ric in rics[0:2]:
    df = dfs[ric]
    
    # tidying the data to fit the type nessesary for our OLS Python function `np.linalg.lstsq`
    x = np.vstack([float(i) for i in df[ric].values])
    A = np.vstack([
        np.array([float(j) for j in i]) for i in [
            row[1].values for row in df[cols].iterrows()]])
    
    reg = np.linalg.lstsq(A, x, rcond=None)[0]  # the OLS regression
    regs[ric] = np.array([i[0] for i in reg])  # storing the results

# %%
# regs = {}
# for ric in rics[0:2]:
#     df = dfs[ric]
#     reg = np.linalg.lstsq(df[cols], df[ric], rcond=-1)[0]
#     regs[ric] = reg

# %%
rega = np.stack(regs.values())
# Out:
# C:\Users\U6082174\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:3488: FutureWarning:
#
# arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.

# %%
regd = pd.DataFrame(rega, columns=cols, index=rics[0:2])

# %% [markdown]
# **Intraday** the optimal regression parameters show more variation.

# %%
regd.iplot(kind='bar')
# Out:
# <div>                            <div id="987b26d9-98b2-46ea-b7f4-cbd8896cf682" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("987b26d9-98b2-46ea-b7f4-cbd8896cf682")) {                    Plotly.newPlot(                        "987b26d9-98b2-46ea-b7f4-cbd8896cf682",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"lag_1","orientation":"v","text":"","x":["GE","AAPL.O"],"y":[0.9918102399663372,0.8231989537844475],"type":"bar"},{"marker":{"color":"rgba(55, 128, 191, 0.6)","line":{"color":"rgba(55, 128, 191, 1.0)","width":1}},"name":"lag_2","orientation":"v","text":"","x":["GE","AAPL.O"],"y":[-0.06557848413957987,0.022905798705188135],"type":"bar"},{"marker":{"color":"rgba(50, 171, 96, 0.6)","line":{"color":"rgba(50, 171, 96, 1.0)","width":1}},"name":"lag_3","orientation":"v","text":"","x":["GE","AAPL.O"],"y":[0.02088920864700416,0.20237488890928507],"type":"bar"},{"marker":{"color":"rgba(128, 0, 128, 0.6)","line":{"color":"rgba(128, 0, 128, 1.0)","width":1}},"name":"lag_4","orientation":"v","text":"","x":["GE","AAPL.O"],"y":[0.0472326128441992,-0.057851156820889885],"type":"bar"},{"marker":{"color":"rgba(219, 64, 82, 0.6)","line":{"color":"rgba(219, 64, 82, 1.0)","width":1}},"name":"lag_5","orientation":"v","text":"","x":["GE","AAPL.O"],"y":[0.005629074228359187,0.00937917250041538],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c17 ...

# %%
regd.mean().iplot(kind='bar')
# Out:
# <div>                            <div id="7f40f36a-a72c-47e4-ab1c-50efcbd6b57b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("7f40f36a-a72c-47e4-ab1c-50efcbd6b57b")) {                    Plotly.newPlot(                        "7f40f36a-a72c-47e4-ab1c-50efcbd6b57b",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"None","orientation":"v","text":"","x":["lag_1","lag_2","lag_3","lag_4","lag_5"],"y":[0.9075045968753923,-0.021336342717195866,0.11163204877814462,-0.005309271988345344,0.007504123364387284],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":" ...

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Based on this tutorial, we can conclude that
#
# * it is easy to retrieve **historical end-of-day and intraday data across asset classes** via the LSEG Data Python Library,
# * `Plotly` and `Cufflinks` make **financial data visualization** convenient and
# * there is **support for the Random Walk Hypothesis** based on the OLS regression analysis (both daily and a little bit less so intraday).

# %% [markdown]
# ## LSEG Data Developer Resources

# %% [markdown]
# * [API Pages](https://developers.lseg.com/en/api-catalog)
# * [Q&A Forums](https://community.developers.refinitiv.com/index.html)
#
# Data Item Browser Application: Type [`DIB`](https://developers.lseg.com/en/video-catalog/data-item-browser) into Workspace Search Bar.

# %% [markdown]
# <img src="https://developers.lseg.com/content/dam/devportal/icons/logo/lseg-logo.svg" width="28%" align="left" style="vertical-align: top; padding-top: 23px;">
# <img src="http://hilpisch.com/tpq_logo_long.png" width="36%" align="right" style="vertical-align: top;">
