# %% [markdown]
# <img src="https://developers.lseg.com/content/dam/devportal/icons/logo/lseg-logo.svg" width="28%" align="left" style="vertical-align: top; padding-top: 23px;">
# <img src="http://hilpisch.com/tpq_logo_long.png" width="36%" align="right" style="vertical-align: top;">

# %% [markdown]
# # LSEG Data Libraries for Python

# %% [markdown]
# **Data for Chains of Options**
#
# Dr. Yves J. Hilpisch | The Python Quants GmbH
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a> | <a href="mailto:training@tpq.io">training@tpq.io</a>
#
# <img src="http://hilpisch.com/images/tr_eikon_02.png" width=350px align=left>

# %% [markdown]
# ## The Agenda

# %% [markdown]
# This tutorial covers
#
# * Retrieving Options Data &mdash; Single Maturity
# * Retrieving Options Data &mdash; Multiple Maturities
# * Selecting Sub Sets of the Options Data
# * Visualization of Sub Sets of the Options Data

# %% [markdown]
# ## Imports and Versions

# %% [markdown]
# The following imports several **packages** as used in the following.

# %%
import lseg.data as ld  # the LSEG Data Libraries for Python wrapper package
import numpy as np  # NumPy
import pandas as pd  # pandas
import cufflinks as cf  # Cufflinks
cf.set_config_file(offline=True)  # set the plotting mode to offline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# The following **Python and package versions** are used.

# %%
import sys
print(sys.version)
# Out:
# 3.9.6 (default, Aug 11 2023, 19:44:49)
# [Clang 15.0.0 (clang-1500.0.40.1)]

# %%
ld.__version__
# Out:
# '2.0.0'

# %%
np.__version__
# Out:
# '1.23.4'

# %%
pd.__version__
# Out:
# '2.0.2'

# %%
cf.__version__
# Out:
# '0.17.3'

# %% [markdown]
# ## Connecting to LSEG Data Libraries

# %%
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x137727790 {name='workspace'}>

# %% [markdown]
# ## Retrieving Options Data &mdash; Single Maturity

# %% [markdown]
# The `RIC` structure provides access to groups of `RICs` that have a common association &mdash; for example, the constituent members of the DAX 30 index or a list of options for a particular underlying contract, such as the DAX 30 index.

# %% [markdown]
# For example:
#
# * `0#.GDAX` gives you a list of DAX 30 constituents
#
# * `0#GDAX*.EX` gives you a list of all options for all maturities for the DAX index
#
# * `0#GDAXM5*.EX` gives you a list of all options for June 2025 maturity for the DAX index

# %% [markdown]
# ### The Raw Data

# %% [markdown]
# In what follows, data is retrieved that comprises fields for the **option type (put or call), the strike price, the closing price and the implied volatility**.

# %%
fields = ['PUTCALLIND', 'STRIKE_PRC', 'CF_CLOSE', 'IMP_VOLT']

# %% [markdown]
# Using the `ld.get_data()` method, allows data retrieval for a **single maturity of index options and multiple data fields** at the same time.

# %%
dax = ld.get_data('0#GDAXM5*.EX', fields=fields)

# %%
dax.head()
# Out:
#        Instrument PUTCALLIND  STRIKE_PRC  CF_CLOSE  IMP_VOLT
# 0          .GDAXI       <NA>        <NA>  18557.27      <NA>
# 1  GDAX90000F5.EX       CALL        9000   10088.0   51.0017
# 2  GDAX90000R5.EX       PUT         9000      20.5   33.7916
# 3  GDAX92000F5.EX       CALL        9200    9896.5   49.7975
# 4  GDAX92000R5.EX       PUT         9200      22.1   33.2396

# %% [markdown]
# Let us pick and store the closing value for the index.

# %%
GDAXI = dax.iloc[0]['CF_CLOSE']

# %%
GDAXI
# Out:
# 18557.27

# %% [markdown]
# To work with the data, the put options related data rows and call options related data rows are separated into two different `DataFrame` objects.

# %%
puts = dax[dax['PUTCALLIND'] == 'PUT ']
calls = dax[dax['PUTCALLIND'] == 'CALL']

# %%
puts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84 entries, 2 to 168
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Instrument  84 non-null     string
#  1   PUTCALLIND  84 non-null     string
#  2   STRIKE_PRC  84 non-null     Int64
#  3   CF_CLOSE    84 non-null     Float64
#  4   IMP_VOLT    80 non-null     Float64
# dtypes: Float64(2), Int64(1), string(2)
# memory usage: 4.2 KB

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84 entries, 1 to 167
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Instrument  84 non-null     string
#  1   PUTCALLIND  84 non-null     string
#  2   STRIKE_PRC  84 non-null     Int64
#  3   CF_CLOSE    84 non-null     Float64
#  4   IMP_VOLT    84 non-null     Float64
# dtypes: Float64(2), Int64(1), string(2)
# memory usage: 4.2 KB

# %% [markdown]
# It might make sense, to restrict the options data to those options that are not too far in or out of the money.

# %%
limit = 2000

# %%
puts = puts[abs(puts['STRIKE_PRC'] - GDAXI) < limit]
calls = calls[abs(calls['STRIKE_PRC'] - GDAXI) < limit]

# %%
puts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38 entries, 68 to 142
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Instrument  38 non-null     string
#  1   PUTCALLIND  38 non-null     string
#  2   STRIKE_PRC  38 non-null     Int64
#  3   CF_CLOSE    38 non-null     Float64
#  4   IMP_VOLT    38 non-null     Float64
# dtypes: Float64(2), Int64(1), string(2)
# memory usage: 1.9 KB

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38 entries, 67 to 141
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Instrument  38 non-null     string
#  1   PUTCALLIND  38 non-null     string
#  2   STRIKE_PRC  38 non-null     Int64
#  3   CF_CLOSE    38 non-null     Float64
#  4   IMP_VOLT    38 non-null     Float64
# dtypes: Float64(2), Int64(1), string(2)
# memory usage: 1.9 KB

# %% [markdown]
# ### The Data Visualized

# %% [markdown]
# The separation allows for easily **visualization** of the closing prices and the implied volatilities.

# %%
puts.set_index('STRIKE_PRC')[['CF_CLOSE', 'IMP_VOLT']].iplot(subplots=True,
                                                            mode='lines+markers',
                                                            size=6)
# Out:
# <div>                            <div id="ce81c718-09b0-4abd-afc4-4326759f3072" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("ce81c718-09b0-4abd-afc4-4326759f3072")) {                    Plotly.newPlot(                        "ce81c718-09b0-4abd-afc4-4326759f3072",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"circle"},"mode":"lines+markers","name":"CF_CLOSE","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20300,20400,20500],"xaxis":"x","y":[346.6,375.1,405.9,422.3,439.4,457.3,475.9,495.4,515.7,536.9,558.9,582.0,606.0,631.0,657.1,684.3,712.6,742.0,772.7,804.6,837.7,872.1,907.9,945.0,983.5,1023.5,1064.9,1107.7,1152.1,1197.9,1245.4,1294.7,1345.8,1398.6,1453.2,1509.6,1567.6,1627.3],"yaxis":"y","type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"circle"},"mode":"lines+markers","name":"IMP_VOLT","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20300,20400,20500],"xaxis":"x2","y":[17.4787,17.1422,16.8064,16.6401,16.4748,16.3117,16.1486,15.9883,15.8285,15.6704,15.5118,15.3568,15.2017,15.0477,14.8955,14.7446,14.5944,14.4445,14.297,14.15,14.003,13.8568,13.7124,13.5676,13.4236,13.281,13.1381,12.9944,12.8521,12.7081,12.5659,12.4265,12.2896,12.1536,12.0195,11.8872,11.7537,11.6201],"yaxis":"y2","type":"scatter"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#b ...

# %%
calls.set_index('STRIKE_PRC')[['CF_CLOSE', 'IMP_VOLT']].iplot(subplots=True,
                                                             mode='lines+markers',
                                                             size=6)
# Out:
# <div>                            <div id="e801278d-22a9-429c-9ecd-bed6663e7695" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("e801278d-22a9-429c-9ecd-bed6663e7695")) {                    Plotly.newPlot(                        "e801278d-22a9-429c-9ecd-bed6663e7695",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"circle"},"mode":"lines+markers","name":"CF_CLOSE","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20300,20400,20500],"xaxis":"x","y":[3076.4,2911.8,2749.5,2669.4,2589.9,2511.2,2433.3,2356.2,2280.0,2204.6,2130.2,2056.6,1984.1,1912.6,1842.1,1772.7,1704.5,1637.4,1571.5,1506.8,1443.4,1381.3,1320.5,1261.1,1203.1,1146.5,1091.3,1037.6,985.4,934.7,885.7,838.4,792.9,749.2,707.3,667.1,628.5,591.7],"yaxis":"y","type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"circle"},"mode":"lines+markers","name":"IMP_VOLT","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20300,20400,20500],"xaxis":"x2","y":[20.7605,20.2868,19.8233,19.5974,19.373,19.1531,18.9371,18.7245,18.5162,18.3103,18.1092,17.9093,17.7148,17.5234,17.3348,17.1497,16.9692,16.7912,16.6166,16.445,16.2772,16.1127,15.9511,15.7933,15.6388,15.4872,15.3382,15.1927,15.0504,14.9109,14.7766,14.6474,14.5244,14.4076,14.2969,14.191,14.0886,13.9926],"yaxis":"y2","type":"scatter"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444 ...

# %% [markdown]
# ## Retrieving Data &mdash; Multiple Maturities

# %% [markdown]
# Via the `LSEG Data Libraries`, options data can be retrieved also for all maturities of an options chain at once.

# %% [markdown]
# ### The Raw Data

# %% [markdown]
# The maturity date data field (`EXPIR_DATE`) is added to distinguish the maturity dates.

# %%
fields = ['PUTCALLIND', 'EXPIR_DATE', 'STRIKE_PRC', 'CF_CLOSE', 'IMP_VOLT']

# %%
dax = ld.get_data('0#GDAX*.EX', fields=fields)

# %%
dax.head()
# Out:
#        Instrument PUTCALLIND EXPIR_DATE  STRIKE_PRC  CF_CLOSE  IMP_VOLT
# 0          .GDAXI       <NA>        NaT        <NA>  18557.27      <NA>
# 1  GDAX60000F4.EX       CALL 2024-06-21        6000   12564.1  183.8289
# 2  GDAX60000R4.EX       PUT  2024-06-21        6000       0.1    154.47
# 3  GDAX61000F4.EX       CALL 2024-06-21        6100   12464.3  180.7053
# 4  GDAX61000R4.EX       PUT  2024-06-21        6100       0.1  152.2699

# %% [markdown]
# Again, put and call option data is separated.

# %%
puts = dax[dax['PUTCALLIND'] == 'PUT ']
calls = dax[dax['PUTCALLIND'] == 'CALL']

# %% [markdown]
# Again, options too far in or out of the money are removed.

# %%
puts = puts[abs(puts['STRIKE_PRC'] - GDAXI) < limit]
calls = calls[abs(calls['STRIKE_PRC'] - GDAXI) < limit]

# %%
puts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 539 entries, 132 to 2234
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Instrument  539 non-null    string
#  1   PUTCALLIND  539 non-null    string
#  2   EXPIR_DATE  539 non-null    datetime64[ns]
#  3   STRIKE_PRC  539 non-null    Int64
#  4   CF_CLOSE    539 non-null    Float64
#  5   IMP_VOLT    539 non-null    Float64
# dtypes: Float64(2), Int64(1), datetime64[ns](1), string(2)
# memory usage: 31.1 KB

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 539 entries, 131 to 2233
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Instrument  539 non-null    string
#  1   PUTCALLIND  539 non-null    string
#  2   EXPIR_DATE  539 non-null    datetime64[ns]
#  3   STRIKE_PRC  539 non-null    Int64
#  4   CF_CLOSE    539 non-null    Float64
#  5   IMP_VOLT    539 non-null    Float64
# dtypes: Float64(2), Int64(1), datetime64[ns](1), string(2)
# memory usage: 31.1 KB

# %% [markdown]
# From all option maturites ...

# %%
exp_dates = sorted(list(set(puts['EXPIR_DATE'])))
exp_dates
# Out:
# [Timestamp('2024-06-21 00:00:00'),
#  Timestamp('2024-07-19 00:00:00'),
#  Timestamp('2024-08-16 00:00:00'),
#  Timestamp('2024-09-20 00:00:00'),
#  Timestamp('2024-12-20 00:00:00'),
#  Timestamp('2025-03-21 00:00:00'),
#  Timestamp('2025-06-20 00:00:00'),
#  Timestamp('2025-09-19 00:00:00'),
#  Timestamp('2025-12-19 00:00:00'),
#  Timestamp('2026-03-20 00:00:00'),
#  Timestamp('2026-06-19 00:00:00'),
#  Timestamp('2026-09-18 00:00:00'),
#  Timestamp('2026-12-18 00:00:00'),
#  Timestamp('2027-03-19 00:00:00'),
#  Timestamp('2027-12-17 00:00:00'),
#  Timestamp('2028-12-15 00:00:00')]

# %% [markdown]
# ... only a sub-set selected.

# %%
exp_dates = exp_dates[0:7:3]

# %%
exp_dates
# Out:
# [Timestamp('2024-06-21 00:00:00'),
#  Timestamp('2024-09-20 00:00:00'),
#  Timestamp('2025-06-20 00:00:00')]

# %% [markdown]
# ### The Data Visualized

# %% [markdown]
# The following visualizes **closing prices and implied volatilities in a single plot per maturity**. First, for the **puts**.

# %%
for expiry in exp_dates:
    to_plot = puts[puts['EXPIR_DATE'] == expiry]
    to_plot.set_index('STRIKE_PRC')[['CF_CLOSE', 'IMP_VOLT']].iplot(
                                                                    title=expiry.strftime('%Y-%m-%d'),
                                                                    secondary_y='IMP_VOLT',
                                                                    mode='lines+markers',
                                                                    size=6,
                                                                    xTitle='strike price')
# Out:
# <div>                            <div id="9d825151-df30-42c5-8863-b13ad3d0eb94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("9d825151-df30-42c5-8863-b13ad3d0eb94")) {                    Plotly.newPlot(                        "9d825151-df30-42c5-8863-b13ad3d0eb94",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"circle"},"mode":"lines+markers","name":"CF_CLOSE","text":"","x":[16600,16650,16700,16750,16800,16850,16900,16950,17000,17050,17100,17150,17200,17250,17300,17350,17400,17450,17500,17550,17600,17650,17700,17750,17800,17850,17900,17950,18000,18050,18100,18150,18200,18250,18300,18350,18400,18450,18500,18550,18600,18650,18700,18750,18800,18850,18900,18950,19000,19050,19100,19150,19200,19250,19300,19350,19400,19450,19500
"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","title":{"text":"2024-09-20","font":{"color":"#4D5663"}},"xaxis":{"gridcolor":"#E1E5ED","showgrid":true,"tickfont":{"color":"#4D5663"},"title":{"text":"strike price","font":{"color":"#4D5663"}},"zerolinecolor":"#E1E5ED"},"yaxis":{"gridcolor":"#E1E5ED","showgrid":true,"tickfont":{"color":"#4D5663"},"title":{"text":"","font":{"color":"#4D5663"}},"zerolinecolor":"#E1E5ED"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d088 ...
# <div>                            <div id="9d3738c0-48c7-46f8-a47c-a2914e130d95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("9d3738c0-48c7-46f8-a47c-a2914e130d95")) {                    Plotly.newPlot(                        "9d3738c0-48c7-46f8-a47c-a2914e130d95",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"circle"},"mode":"lines+markers","name":"CF_CLOSE","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20300,20400,20500],"y":[346.6,375.1,405.9,422.3,439.4,457.3,475.9,495.4,515.7,536.9,558.9,582.0,606.0,631.0,657.1,684.3,712.6,742.0,772.7,804.6,837.7,872.1,907.9,945.0,983.5,1023.5,1064.9,1107.7,1152.1,1197.9,1245.4,1294.7,1345.8,1398.6,1453.2,1509.6,1567.6,1627.3],"type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"circle"},"mode":"lines+markers","name":"IMP_VOLT","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20300,20400,20500],"y":[17.4787,17.1422,16.8064,16.6401,16.4748,16.3117,16.1486,15.9883,15.8285,15.6704,15.5118,15.3568,15.2017,15.0477,14.8955,14.7446,14.5944,14.4445,14.297,14.15,14.003,13.8568,13.7124,13.5676,13.4236,13.281,13.1381,12.9944,12.8521,12.7081,12.5659,12.4265,12.2896,12.1536,12.0195,11.8872,11.7537,11.6201],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","title":{"text":"2025-06-20","font":{"color":"#4D5663"}},"xaxis":{"gridcolor":"#E1E5ED","showgrid":true,"tickfont":{"color":"#4D5663"},"title":{"text":"strike price","font":{"color":"#4D5663"}},"zerolinecolor":"#E1E5ED"},"yaxis":{"gridcolor":"#E1E5ED","showgrid":true,"tickfont":{"color":"#4D5663"},"title":{"text":"","font":{"color":"#4D5663"}},"zerolinecolor":"#E1E5ED"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscal ...

# %% [markdown]
# Second, for the **calls**.

# %%
for expiry in exp_dates:
    to_plot = calls[calls['EXPIR_DATE'] == expiry]
    to_plot.set_index('STRIKE_PRC')[['CF_CLOSE', 'IMP_VOLT']].iplot(title=expiry.strftime('%Y-%m-%d'),
                                                                   secondary_y='IMP_VOLT',
                                                                   mode='lines+markers',
                                                                size=6,
                                                                   xTitle='strike price')
# Out:
# <div>                            <div id="d95f8cfd-a50f-4575-b27b-009f6433a1e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("d95f8cfd-a50f-4575-b27b-009f6433a1e2")) {                    Plotly.newPlot(                        "d95f8cfd-a50f-4575-b27b-009f6433a1e2",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"circle"},"mode":"lines+markers","name":"CF_CLOSE","text":"","x":[16600,16650,16700,16750,16800,16850,16900,16950,17000,17050,17100,17150,17200,17250,17300,17350,17400,17450,17500,17550,17600,17650,17700,17750,17800,17850,17900,17950,18000,18050,18100,18150,18200,18250,18300,18350,18400,18450,18500,18550,18600,18650,18700,18750,18800,18850,18900,18950,19000,19050,19100,19150,19200,19250,19300,19350,19400,19450,19500,19550,19600,19650,19700,19750,19800,19850,19900,19950,20000,20050,20100,20200,20400],"y":[1984.2,1934.5,1884.7,1835.1,1785.4,1735.7,1686.1,1636.5,1586.9,1537.3,1487.8,1438.3,1388.8,1339.3,1289.9,1240.5,1191.2,1142.0,1092.9,1044.0,995.1,946.4,897.9,849.6,801.7,754.1,706.9,660.3,614.2,568.8,524.2,480.5,438.0,396.7,356.8,318.4,281.8,247.2,214.7,184.7,157.2,132.5,110.7,91.8,75.7,62.1,50.4,40.6,32.4,25.5,19.9,15.5,12.0,9.3,7.2,5.7,4.5,3.6,2.9,2.4,1.9,1.6,1.4,1.2,1.0,0.9,0.8,0.7,0.7,0.6,0.6,0.5,0.4],"type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"circle"},"mode":"lines+markers","name":
"type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"circle"},"mode":"lines+markers","name":"IMP_VOLT","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20300,20400,20500],"y":[20.7605,20.2868,19.8233,19.5974,19.373,19.1531,18.9371,18.7245,18.5162,18.3103,18.1092,17.9093,17.7148,17.5234,17.3348,17.1497,16.9692,16.7912,16.6166,16.445,16.2772,16.1127,15.9511,15.7933,15.6388,15.4872,15.3382,15.1927,15.0504,14.9109,14.7766,14.6474,14.5244,14.4076,14.2969,14.191,14.0886,13.9926],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","title":{"text":"2025-06-20","font":{"color":"#4D5663"}},"xaxis":{"gridcolor":"#E1E5ED","showgrid":true,"tickfont":{"color":"#4D5663"},"title":{"text":"strike price","font":{"color":"#4D5663"}},"zerolinecolor":"#E1E5ED"},"yaxis":{"gridcolor":"#E1E5ED","showgrid":true,"tickfont":{"color":"#4D5663"},"title":{"text":"","font":{"color":"#4D5663"}},"zerolinecolor":"#E1E5ED"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"tick ...

# %% [markdown]
# ## Comparing Prices & Implied Volatilities

# %% [markdown]
# However, often one wishes to compare prices and implied volatilites, respectively, for **different maturities in a single plot**.

# %% [markdown]
# ### Puts

# %% [markdown]
# The code below collects **put option closing prices and implied volatilities in different columns** of two separate `DataFrame` objects.

# %%
puts_close = pd.DataFrame()
puts_vols = pd.DataFrame()
for expiry in exp_dates:
    sub_set = puts[puts['EXPIR_DATE'] == expiry]
    puts_close[expiry] = sub_set.set_index('STRIKE_PRC')['CF_CLOSE']
    puts_vols[expiry] = sub_set.set_index('STRIKE_PRC')['IMP_VOLT']

# %% [markdown]
# Now, closing prices and implied volatilities can be compared easily in a single plot.

# %%
puts_close.dropna(inplace=True)
puts_vols.dropna(inplace=True)

# %%
puts_close.dropna().iplot(mode='markers', symbol=['circle-dot', 'cross', 'diamond'], size=6, xTitle='strike price')
# Out:
# <div>                            <div id="76c15805-af2b-4f5b-b1be-0b9b2995897e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("76c15805-af2b-4f5b-b1be-0b9b2995897e")) {                    Plotly.newPlot(                        "76c15805-af2b-4f5b-b1be-0b9b2995897e",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"circle-dot"},"mode":"markers","name":"2024-06-21 00:00:00","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20400],"y":[4.1,5.1,6.3,7.0,7.9,8.8,10.0,11.6,13.6,16.2,19.9,25.0,32.1,41.9,55.6,74.2,99.0,131.9,174.2,227.5,292.4,367.0,448.7,536.2,628.0,723.2,820.3,918.5,1017.4,1116.7,1216.2,1315.8,1415.5,1515.3,1615.1,1814.7],"type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"cross"},"mode":"markers","name":"2024-09-20 00:00:00","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20400],"y":[78.1,89.5,103.1,110.9,119.4,128.9,139.4,151.1,164.1,178.4,194.2,211.7,230.9,252.1,275.4,301.0,329.0,360.1,394.7,433.0,475.2,521.3,571.4,625.5,683.5,745.5,811.3,880.7,953.5,1029.5,1108.5,1190.5,1275.0,1361.7,1450.5,1632.9],"type":"scatter"},{"line":{"color":"rgba(50, 171, 96, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"diamond"},"mode":"markers","name":"2025-06-20 00:00:00","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20400],"y":[346.6,375.1,405.9,422.3,439.4,457.3,475.9,495.4,515.7,536.9,558.9,582.0,606.0,631.0,657.1,684.3,712.6,742.0,772.7,804.6,837.7,872.1,907.9,945.0,983.5,1023.5,1064.9,1107.7,1152.1,1197.9,1245.4,1294.7,1345.8,1398.6,1453.2,1567.6],"type":"scatter"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111111111111111 ...

# %%
puts_vols.iplot(mode='markers', symbol=['circle-dot', 'cross', 'diamond'], size=6, xTitle='strike price')
# Out:
# <div>                            <div id="8ff44ebf-5d5f-4281-8f6d-a06ec4ca5fa1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("8ff44ebf-5d5f-4281-8f6d-a06ec4ca5fa1")) {                    Plotly.newPlot(                        "8ff44ebf-5d5f-4281-8f6d-a06ec4ca5fa1",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"circle-dot"},"mode":"markers","name":"2024-06-21 00:00:00","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20400],"y":[25.3933,23.7567,22.035,21.1465,20.2909,19.3683,18.4882,17.6502,16.8179,16.0069,15.2705,14.5837,13.9526,13.368,12.8502,12.3718,11.9248,11.5388,11.2062,10.9747,10.8917,10.905,10.9251,10.9743,11.0584,11.2929,11.6322,12.0602,12.6025,13.2458,13.9458,14.668,15.4436,16.3029,17.1461,18.7859],"type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"cross"},"mode":"markers","name":"2024-09-20 00:00:00","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20400],"y":[17.7135,17.052,16.4001,16.0789,15.758,15.4469,15.1411,14.8439,14.554,14.2666,13.9838,13.7072,13.4314,13.1605,12.892,12.6261,12.3602,12.1073,11.8715,11.6522,11.4495,11.2594,11.0813,10.9134,10.7522,10.6007,10.4551,10.3122,10.1694,10.0244,9.8752,9.7295,9.5743,9.4015,9.2125,8.6865],"type":"scatter"},{"line":{"color":"rgba(50, 171, 96, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"diamond"},"mode":"markers","name":"2025-06-20 00:00:00","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20400],"y":[17.4787,17.1422,16.8064,16.6401,16.4748,16.3117,16.1486,15.9883,15.8285,15.6704,15.5118,15.3568,15.2017,15.0477,14.8955,14.7446,14.5944,14.4445,14.297,14.15,14.003,13.8568,13.7124,13.5676,13.4236,13.281,13.1381,12.9944,12.8521,12.7081,12.5659,12.4265,12.2896,12.1536,12.0195,11.7537],"type":"scatter"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77 ...

# %% [markdown]
# ### Calls

# %% [markdown]
# This code does the same for the **call options**.

# %%
calls_close = pd.DataFrame()
calls_vols = pd.DataFrame()
for expiry in exp_dates:
    sub_set = calls[calls['EXPIR_DATE'] == expiry]
    calls_close[expiry] = sub_set.set_index('STRIKE_PRC')['CF_CLOSE']
    calls_vols[expiry] = sub_set.set_index('STRIKE_PRC')['IMP_VOLT']

# %%
calls_close.dropna(inplace=True)
calls_vols.dropna(inplace=True)

# %%
calls_close.iplot(mode='markers', symbol=['circle-dot', 'cross', 'diamond'], size=6)
# Out:
# <div>                            <div id="ca54068a-b3ab-4883-add2-80ee1ea8b185" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("ca54068a-b3ab-4883-add2-80ee1ea8b185")) {                    Plotly.newPlot(                        "ca54068a-b3ab-4883-add2-80ee1ea8b185",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"circle-dot"},"mode":"markers","name":"2024-06-21 00:00:00","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20400],"y":[1984.2,1785.4,1586.9,1487.8,1388.8,1289.9,1191.2,1092.9,995.1,897.9,801.7,706.9,614.2,524.2,438.0,356.8,281.8,214.7,157.2,110.7,75.7,50.4,32.4,19.9,12.0,7.2,4.5,2.9,1.9,1.4,1.0,0.8,0.7,0.6,0.5,0.4],"type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"cross"},"mode":"markers","name":"2024-09-20 00:00:00","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20400],"y":[2237.7,2051.1,1866.8,1775.7,1685.3,1595.8,1507.4,1420.1,1334.1,1249.4,1166.3,1084.8,1005.1,927.3,851.7,778.3,707.3,639.4,575.1,514.5,457.7,404.8,355.9,311.1,270.2,233.2,200.0,170.5,144.3,121.3,101.5,84.4,70.0,57.8,47.6,32.0],"type":"scatter"},{"line":{"color":"rgba(50, 171, 96, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"diamond"},"mode":"markers","name":"2025-06-20 00:00:00","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20400],"y":[3076.4,2911.8,2749.5,2669.4,2589.9,2511.2,2433.3,2356.2,2280.0,2204.6,2130.2,2056.6,1984.1,1912.6,1842.1,1772.7,1704.5,1637.4,1571.5,1506.8,1443.4,1381.3,1320.5,1261.1,1203.1,1146.5,1091.3,1037.6,985.4,934.7,885.7,838.4,792.9,749.2,707.3,628.5],"type":"scatter"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0 ...

# %%
calls_vols.iplot(mode='markers', symbol=['circle-dot', 'cross', 'diamond'], size=6)
# Out:
# <div>                            <div id="823823fb-b7af-4214-9d44-757c77458574" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("823823fb-b7af-4214-9d44-757c77458574")) {                    Plotly.newPlot(                        "823823fb-b7af-4214-9d44-757c77458574",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"circle-dot"},"mode":"markers","name":"2024-06-21 00:00:00","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20400],"y":[24.5827,23.0344,21.4579,20.6572,19.8343,18.9815,18.1292,17.3222,16.5474,15.7859,15.0735,14.4097,13.8129,13.2555,12.7493,12.2878,11.8529,11.4612,11.1333,10.9022,10.8075,10.8016,10.8133,10.8054,10.8565,10.9685,11.2003,11.4945,11.8106,12.2932,12.7047,13.2583,13.9175,14.5241,15.0679,16.31],"type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"cross"},"mode":"markers","name":"2024-09-20 00:00:00","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20400],"y":[18.9195,18.1366,17.3794,17.0116,16.6466,16.2895,15.9442,15.606,15.2779,14.9551,14.6429,14.3361,14.036,13.7404,13.4527,13.1676,12.8853,12.6187,12.3748,12.1506,11.9437,11.7532,11.5786,11.4209,11.2748,11.1412,11.0195,10.9107,10.8075,10.7124,10.6333,10.5616,10.5084,10.4645,10.4333,10.3979],"type":"scatter"},{"line":{"color":"rgba(50, 171, 96, 1.0)","dash":"solid","shape":"linear","width":1.3},"marker":{"size":6,"symbol":"diamond"},"mode":"markers","name":"2025-06-20 00:00:00","text":"","x":[16600,16800,17000,17100,17200,17300,17400,17500,17600,17700,17800,17900,18000,18100,18200,18300,18400,18500,18600,18700,18800,18900,19000,19100,19200,19300,19400,19500,19600,19700,19800,19900,20000,20100,20200,20400],"y":[20.7605,20.2868,19.8233,19.5974,19.373,19.1531,18.9371,18.7245,18.5162,18.3103,18.1092,17.9093,17.7148,17.5234,17.3348,17.1497,16.9692,16.7912,16.6166,16.445,16.2772,16.1127,15.9511,15.7933,15.6388,15.4872,15.3382,15.1927,15.0504,14.9109,14.7766,14.6474,14.5244,14.4076,14.2969,14.0886],"type":"scatter"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#e ...

# %% [markdown]
# ## Conclusions

# %% [markdown]
# This tutorial covers:
#
# * Retrieving Options Data &mdash; Single Maturity
# * Retrieving Options Data &mdash; Multiple Maturities
# * Selecting Sub Sets of the Options Data
# * Visualization of Sub Sets of the Options Data

# %% [markdown]
# ## LSEG Data Libraries Developer Resources

# %% [markdown]
# * [API Pages](https://developers.lseg.com/en/api-catalog)
# * [Q&A Forums](https://community.developers.refinitiv.com/index.html)
#
# Data Item Browser Application: Type `DIB` into Workspace Search Bar.
#
# * [Article on Chains](https://developers.lseg.com/en/article-catalog/article/simple-chain-objects-ema-part-1)

# %% [markdown]
# <img src="https://developers.lseg.com/content/dam/devportal/icons/logo/lseg-logo.svg" width="28%" align="left" style="vertical-align: top; padding-top: 23px;">
# <img src="http://hilpisch.com/tpq_logo_long.png" width="36%" align="right" style="vertical-align: top;">
