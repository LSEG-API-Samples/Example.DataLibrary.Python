# %% [markdown]
# ----
# <div style="display: flex; align-items: center;">
#     <img src="https://developers.lseg.com/content/dam/devportal/icons/logo/lseg-logo.svg" width="20%" style="vertical-align: top;">
#     <h1 style="margin-left: 20px;">Data Library for Python</h1>
# </div>
#
# ----

# %% [markdown]
# ## Delivery - EndPoint - News Headlines

# %% [markdown]
# This notebook demonstrates how to use the Delivery Layer of the library to retrieve News headlines from the LSEG Data Platform.

# %% [markdown]
# ## Set the location of the configuration file
# For ease of use, you can set various initialization parameters of the LD Library in the **_lseg-data.config.json_** configuration file - as described in the Quick Start -> Sessions example.
#
# ### One config file for the tutorials
# As these tutorial Notebooks are categorised into sub-folders and to avoid the need for multiple config files, we will use the _LD_LIB_CONFIG_PATH_ environment variable to point to a single instance of the config file in the top-level ***Configuration*** folder.
#
# Before proceeding, please **ensure you have entered your credentials** into the config file in the ***Configuration*** folder.

# %%
import os
os.environ["LD_LIB_CONFIG_PATH"] = "../../../Configuration"

# %%
from lseg.data.delivery import endpoint_request
import lseg.data as ld
import json

# %% [markdown]
# ## Open the default session
#
# To open the default session ensure you have a '*lseg-data.config.json*' in the ***Configuration*** directory, populated with your credentials and specified a 'default' session in the config file

# %%
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x267539bda50 {name='workspace'}>

# %% [markdown]
# ## Define the endpoint request

# %%
# Correct syntax but does not work yet
request_definition = ld.delivery.endpoint_request.Definition(
    url = "/data/news/v1/headlines",
    method = ld.delivery.endpoint_request.RequestMethod.GET,
    query_parameters = {"query": "CRUDE OIL"}
)

# %% [markdown]
# ## Send a request

# %%
response = request_definition.get_data()

# %% [markdown]
# ## Display the result

# %%
response.data.raw
# Out:
# {'data': [{'storyId': 'urn:newsml:reuters.com:20171030:nTOPO:159423',
#    'newsItem': {'_version': 159423,
#     'contentMeta': {'audience': [{'_qcode': 'NP:C'},
#       {'_qcode': 'NP:D'},
#       {'_qcode': 'NP:E'},
#       {'_qcode': 'NP:M'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:T'},
#       {'_qcode': 'NP:U'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:NAT'},
#       {'_qcode': 'NP:UKI'},
#       {'_qcode': 'NP:GRO'},
#       {'_qcode': 'NP:MTL'},
#       {'_qcode': 'NP:SOF'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'A:4'},
#       {'_qcode': 'B:11'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'B:9'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:1RS'},
#       {'_qcode': 'M:2CM'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:2CR'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:2CU'},
#       {'_qcode': 'M:2CV'},
#       {'_qcode': 'M:2CY'},
#       {'_qcode': 'M:2D1'},
#       {'_qcode': 'M:3Z'},
#       {'_qcode': 'M:9T'},
#       {'_qcode': 'M:DU'},
#       {'_qcode': 'M:MR'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'M:PG'},
#       {'_qcode': 'MCC:OEC'},
#       {'_qcode': 'MCCL:OEC'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'U:2R'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'U:8'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'U:M'},
#       {'_qcode': 'U:N'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2017-10-30T00:33:59.000Z'},
#      'versionCreated': {'$': '2024-06-21T11:05:28.000Z'},
#      'title': [{'$': '*TOP NEWS* Energy'}],
#      'instanceOf': [{'_qcode': 'RR:9092'}]},
#     'assert': [{'_qcode': 'RR:9092'},
#      {'_qcode': 'A:4'},
#      {'_qcode': 'B:11'},
#      {'_qcode': 'B:2'},
#      {'_qcode': 'B:219'},
#      {'_qcode': 'B:9'},
#      {'_qcode': 'G:4'},
#      {'_qcode': 'G:6J'},
#      {'_qcode': 'G:9'},
#      {'_qcode': 'M:1QD'},
#      {'_qcode': 'M:1RS'},
#      {'_qcode': 'M:2CM'},
#      {'_qcode': 'M:2CN'},
#      {'_qcode': 'M:2CP'},
#      {'_qcode': 'M:2CQ'},
#      {'_qcode': 'M:2CR'},
#      {'_qcode': 'M:2CS'},
#      {'_qcode': 'M:2CT'},
#      {'_qcode': 'M:2CU'},
#      {'_qcode': 'M:2CV'},
#      {'_qcode': 'M:2CY'},
#      {'_qcode': 'M:2D1'},
#      {'_qcode': 'M:3Z'},
#      {'_qcode': 'M:9T'},
#      {'_qcode': 'M:DU'},
#      {'_qcode': 'M:MR'},
#      {'_qcode': 'M:NP'},
#      {'_qcode': 'M:PG'},
#      {'_qcode': 'MCC:OEC'},
#      {'_qcode': 'MCCL:OEC'},
#      {'_qcode': 'U:24'},
#      {'_qcode': 'U:2R'},
#      {'_qcode': 'U:45'},
#      {'_qcode': 'U:8'},
#      {'_qcode': 'U:C'},
#      {'_qcode': 'U:M'},
#      {'_qcode': 'U:N'}]}},
#   {'storyId': 'urn:newsml:reuters.com:20240621:nL4N3IJ0QP:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:E'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:SNI'},
#       {'_qcode': 'NP:SNS'},
#       {'_qcode': 'NP:PSC'},
#       {'_qcode': 'NP:RNP'},
#       {'_qcode': 'NP:PCO'},
#       {'_qcode': 'NP:PEN'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'A:4'},
#       {'_qcode': 'B:1004'},
#       {'_qcode': 'B:1005'},
#       {'_qcode': 'B:1010'},
#       {'_qcode': 'B:1011'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'B:7'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'E:5'},
#       {'_qcode': 'E:9'},
#       {'_qcode': 'F:8'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'G:5B'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'G:CH'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'I:6K'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:2CM'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:2CR'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:2CU'},
#       {'_qcode': 'M:2CV'},
#       {'_qcode': 'M:2CX'},
#       {'_qcode': 'M:2DY'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'M:Z'},
#       {'_qcode': 'MCC:OEC'},
#       {'_qcode': 'MCCL:OEC'},
#       {'_qcode': 'R:BPCL.NS'},
#       {'_qcode': 'R:C}RO7000000001'},
#       {'_qcode': 'R:C}RO7309414180'},
#       {'_qcode': 'R:CHPC.NS'},
#       {'_qcode': 'R:HPCL.NS'},
#       {'_qcode': 'R:IOC.NS'},
#       {'_qcode': 'R:MRPL.NS'},
#       {'_qcode': 'R:OILI.NS'},
#       {'_qcode': 'R:ONGC.NS'},
#       {'_qcode': 'R:RELI.NS'},
#       {'_qcode': 'U:23'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'U:6L'},
#       {'_qcode': 'U:BA'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'P:4295872490'},
#       {'_qcode': 'P:4295872504'},
#       {'_qcode': 'P:4295872506'},
#       {'_qcode': 'P:4295872661'},
#       {'_qcode': 'P:4295872677'},
#       {'_qcode': 'P:4295872684'},
#       {'_qcode': 'P:4295872979'},
#       {'_qcode': 'P:4296617304'},
#       {'_qcode': 'P:5037853419'},
#       {'_qcode': 'P:77000000001'},
#       {'_qcode': 'P:77309414180'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2024-06-21T11:02:22.000Z'},
#      'versionCreated': {'$': '2024-06-21T11:02:22.000Z'},
#      'title': [{'$': "TABLE-Indian refiners' May crude processing up 1.3% y/y"}],
#      'instanceOf': [{'_qcode': 'RR:678'}]},
#     'assert': [{'_qcode': 'RR:678'},
#      {'_qcode': 'A:4'},
#      {'_qcode': 'B:1004'},
#      {'_qcode': 'B:1005'},
#      {'_qcode': 'B:1010'},
#      {'_qcode': 'B:1011'},
#      {'_qcode': 'B:2'},
#      {'_qcode': 'B:219'},
#      {'_qcode': 'B:5'},
#      {'_qcode': 'B:7'},
#      {'_qcode': 'B:8'},
#      {'_qcode': 'E:5'},
#      {'_qcode': 'E:9'},
#      {'_qcode': 'F:8'},
#      {'_qcode': 'G:1'},
#      {'_qcode': 'G:4'},
#      {'_qcode': 'G:5B'},
#      {'_qcode': 'G:6J'},
#      {'_qcode': 'G:9'},
#      {'_qcode': 'G:CH'},
#      {'_qcode': 'G:K'},
#      {'_qcode': 'G:S'},
#      {'_qcode': 'I:6K'},
#      {'_qcode': 'M:1QD'},
#      {'_qcode': 'M:2CM'},
#      {'_qcode': 'M:2CN'},
#      {'_qcode': 'M:2CP'},
#      {'_qcode': 'M:2CQ'},
#      {'_qcode': 'M:2CR'},
#      {'_qcode': 'M:2CS'},
#      {'_qcode': 'M:2CT'},
#      {'_qcode': 'M:2CU'},
#      {'_qcode': 'M:2CV'},
#      {'_qcode': 'M:2CX'},
#      {'_qcode': 'M:2DY'},
#      {'_qcode': 'M:NP'},
#      {'_qcode': 'M:Z'},
#      {'_qcode': 'MCC:OEC'},
#      {'_qcode': 'MCCL:OEC'},
#      {'_qcode': 'R:BPCL.NS'},
#      {'_qcode': 'R:C}RO7000000001'},
#      {'_qcode': 'R:C}RO7309414180'},
#      {'_qcode': 'R:CHPC.NS'},
#      {'_qcode': 'R:HPCL.NS'},
#      {'_qcode': 'R:IOC.NS'},
#      {'_qcode': 'R:MRPL.NS'},
#      {'_qcode': 'R:OILI.NS'},
#      {'_qcode': 'R:ONGC.NS'},
#      {'_qcode': 'R:RELI.NS'},
#      {'_qcode': 'U:23'},
#      {'_qcode': 'U:24'},
#      {'_qcode': 'U:45'},
#      {'_qcode': 'U:6L'},
#      {'_qcode': 'U:BA'},
#      {'_qcode': 'U:C'},
#      {'_qcode': 'P:4295872490'},
#      {'_qcode': 'P:4295872504'},
#      {'_qcode': 'P:4295872506'},
#      {'_qcode': 'P:4295872661'},
#      {'_qcode': 'P:4295872677'},
#      {'_qcode': 'P:4295872684'},
#      {'_qcode': 'P:4295872979'},
#      {'_qcode': 'P:4296617304'},
#      {'_qcode': 'P:5037853419'},
#      {'_qcode': 'P:77000000001'},
#      {'_qcode': 'P:77309414180'}]}},
#   {'storyId': 'urn:newsml:reuters.com:20240621:nNDL6CwRyg:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:PUBTF'}],
#      'creator': [{'_qcode': 'NS:PUBT', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:PUBT', '_role': 'sRole:source'},
#       {'_qcode': 'NS:PUBT', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'it'}],
#      'subject': [{'_qcode': 'A:4'},
#       {'_qcode': 'B:1219'},
#       {'_qcode': 'B:195'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'B:234'},
#       {'_qcode': 'B:239'},
#       {'_qcode': 'B:242'},
#       {'_qcode': 'B:255'},
#       {'_qcode': 'B:34'},
#       {'_qcode': 'B:43'},
#       {'_qcode': 'B:49'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'B:69'},
#       {'_qcode': 'B:7'},
#       {'_qcode': 'B:71'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'E:5'},
#       {'_qcode': 'G:3'},
#       {'_qcode': 'G:5J'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'G:AL'},
#       {'_qcode': 'G:BR'},
#       {'_qcode': 'G:BT'},
#       {'_qcode': 'G:D3'},
#       {'_qcode': 'M:1QC'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:1WJ'},
#       {'_qcode': 'M:1WK'},
#       {'_qcode': 'M:1WN'},
#       {'_qcode': 'M:2CM'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:2CR'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:2CU'},
#       {'_qcode': 'M:2CV'},
#       {'_qcode': 'M:2DY'},
#       {'_qcode': 'M:32'},
#       {'_qcode': 'M:Z'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'U:2R'},
#       {'_qcode': 'U:2Z'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'U:B9'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'P:5037939005'},
#       {'_qcode': 'P:5071118450'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2024-06-21T10:55:43.000Z'},
#      'versionCreated': {'$': '2024-06-21T10:55:43.000Z'},
#      'title': [{'$': 'Confartigianato - AUTORIPARAZIONE – Tutte le novità sull’Ecobonus Veicoli 2024 e sugli incentivi per il settore GPL – Metano'}]},
#     'assert': [{'_qcode': 'A:4'},
#      {'_qcode': 'B:1219'},
#      {'_qcode': 'B:195'},
#      {'_qcode': 'B:2'},
#      {'_qcode': 'B:219'},
#      {'_qcode': 'B:234'},
#      {'_qcode': 'B:239'},
#      {'_qcode': 'B:242'},
#      {'_qcode': 'B:255'},
#      {'_qcode': 'B:34'},
#      {'_qcode': 'B:43'},
#      {'_qcode': 'B:49'},
#      {'_qcode': 'B:5'},
#      {'_qcode': 'B:69'},
#      {'_qcode': 'B:7'},
#      {'_qcode': 'B:71'},
#      {'_qcode': 'B:8'},
#      {'_qcode': 'E:5'},
#      {'_qcode': 'G:3'},
#      {'_qcode': 'G:5J'},
#      {'_qcode': 'G:A'},
#      {'_qcode': 'G:AL'},
#      {'_qcode': 'G:BR'},
#      {'_qcode': 'G:BT'},
#      {'_qcode': 'G:D3'},
#      {'_qcode': 'M:1QC'},
#      {'_qcode': 'M:1QD'},
#      {'_qcode': 'M:1WJ'},
#      {'_qcode': 'M:1WK'},
#      {'_qcode': 'M:1WN'},
#      {'_qcode': 'M:2CM'},
#      {'_qcode': 'M:2CN'},
#      {'_qcode': 'M:2CP'},
#      {'_qcode': 'M:2CQ'},
#      {'_qcode': 'M:2CR'},
#      {'_qcode': 'M:2CS'},
#      {'_qcode': 'M:2CT'},
#      {'_qcode': 'M:2CU'},
#      {'_qcode': 'M:2CV'},
#      {'_qcode': 'M:2DY'},
#      {'_qcode': 'M:32'},
#      {'_qcode': 'M:Z'},
#      {'_qcode': 'U:24'},
#      {'_qcode': 'U:2R'},
#      {'_qcode': 'U:2Z'},
#      {'_qcode': 'U:45'},
#      {'_qcode': 'U:B9'},
#      {'_qcode': 'U:C'},
#      {'_qcode': 'P:5037939005'},
#      {'_qcode': 'P:5071118450'}]}},
#   {'storyId': 'urn:newsml:reuters.com:20240621:nRTV9Vx8Wg:11',
#    'newsItem': {'_version': 11,
#     'contentMeta': {'audience': [{'_qcode': 'NP:RITV'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'A:1'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'B:106'},
#       {'_qcode': 'B:107'},
#       {'_qcode': 'B:108'},
#       {'_qcode': 'B:109'},
#       {'_qcode': 'B:111'},
#       {'_qcode': 'B:125'},
#       {'_qcode': 'B:126'},
#       {'_qcode': 'B:130'},
#       {'_qcode': 'B:1525'},
#       {'_qcode': 'B:1531'},
#       {'_qcode': 'B:1643'},
#       {'_qcode': 'B:208'},
#       {'_qcode': 'B:261'},
#       {'_qcode': 'B:262'},
#       {'_qcode': 'B:263'},
#       {'_qcode': 'E:1'},
#       {'_qcode': 'E:5'},
#       {'_qcode': 'E:9'},
#       {'_qcode': 'E:A'},
#       {'_qcode': 'E:G'},
#       {'_qcode': 'E:J'},
#       {'_qcode': 'E:K'},
#       {'_qcode': 'E:R'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:19'},
#       {'_qcode': 'G:2'},
#       {'_qcode': 'G:3'},
#       {'_qcode': 'G:3D'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'G:7J'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'G:AL'},
#       {'_qcode': 'G:B'},
#       {'_qcode': 'G:B1'},
#       {'_qcode': 'G:D3'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'G:M'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'I:1Z'},
#       {'_qcode': 'I:D'},
#       {'_qcode': 'I:U'},
#       {'_qcode': 'I:W'},
#       {'_qcode': 'M:1Q1'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:1WJ'},
#       {'_qcode': 'M:1WK'},
#       {'_qcode': 'M:1WN'},
#       {'_qcode': 'M:1WQ'},
#       {'_qcode': 'M:2CM'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:2CR'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:2CU'},
#       {'_qcode': 'M:2CV'},
#       {'_qcode': 'M:2D1'},
#       {'_qcode': 'M:2DZ'},
#       {'_qcode': 'M:8'},
#       {'_qcode': 'M:E7'},
#       {'_qcode': 'M:N'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'M:P9'},
#       {'_qcode': 'M:R'},
#       {'_qcode': 'M:Z'},
#       {'_qcode': 'R:BVIC.L'},
#       {'_qcode': 'R:CARLb.CO'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'Meta:Video'},
#       {'_qcode': 'P:4295866057'},
#       {'_qcode': 'P:4295898944'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2024-06-21T10:07:08.118Z'},
#      'versionCreated': {'$': '2024-06-21T10:51:47.119Z'},
#      'title': [{'$': 'Newscasts - Europe Today: UK retail sales surprise to the upside'}],
#      'instanceOf': [{'_qcode': 'RR:10126'}]},
#     'assert': [{'_qcode': 'RR:10126'},
#      {'_qcode': 'A:1'},
#      {'_qcode': 'A:4'},
#      {'_qcode': 'B:106'},
#      {'_qcode': 'B:107'},
#      {'_qcode': 'B:108'},
#      {'_qcode': 'B:109'},
#      {'_qcode': 'B:111'},
#      {'_qcode': 'B:125'},
#      {'_qcode': 'B:126'},
#      {'_qcode': 'B:130'},
#      {'_qcode': 'B:1525'},
#      {'_qcode': 'B:1531'},
#      {'_qcode': 'B:1643'},
#      {'_qcode': 'B:208'},
#      {'_qcode': 'B:261'},
#      {'_qcode': 'B:262'},
#      {'_qcode': 'B:263'},
#      {'_qcode': 'E:1'},
#      {'_qcode': 'E:5'},
#      {'_qcode': 'E:9'},
#      {'_qcode': 'E:A'},
#      {'_qcode': 'E:G'},
#      {'_qcode': 'E:J'},
#      {'_qcode': 'E:K'},
#      {'_qcode': 'E:R'},
#      {'_qcode': 'G:1'},
#      {'_qcode': 'G:19'},
#      {'_qcode': 'G:2'},
#      {'_qcode': 'G:3'},
#      {'_qcode': 'G:3D'},
#      {'_qcode': 'G:4'},
#      {'_qcode': 'G:6'},
#      {'_qcode': 'G:6J'},
#      {'_qcode': 'G:7J'},
#      {'_qcode': 'G:9'},
#      {'_qcode': 'G:A'},
#      {'_qcode': 'G:AL'},
#      {'_qcode': 'G:B'},
#      {'_qcode': 'G:B1'},
#      {'_qcode': 'G:D3'},
#      {'_qcode': 'G:K'},
#      {'_qcode': 'G:M'},
#      {'_qcode': 'G:S'},
#      {'_qcode': 'I:1Z'},
#      {'_qcode': 'I:D'},
#      {'_qcode': 'I:U'},
#      {'_qcode': 'I:W'},
#      {'_qcode': 'M:1Q1'},
#      {'_qcode': 'M:1QD'},
#      {'_qcode': 'M:1WJ'},
#      {'_qcode': 'M:1WK'},
#      {'_qcode': 'M:1WN'},
#      {'_qcode': 'M:1WQ'},
#      {'_qcode': 'M:2CM'},
#      {'_qcode': 'M:2CN'},
#      {'_qcode': 'M:2CP'},
#      {'_qcode': 'M:2CQ'},
#      {'_qcode': 'M:2CR'},
#      {'_qcode': 'M:2CS'},
#      {'_qcode': 'M:2CT'},
#      {'_qcode': 'M:2CU'},
#      {'_qcode': 'M:2CV'},
#      {'_qcode': 'M:2D1'},
#      {'_qcode': 'M:2DZ'},
#      {'_qcode': 'M:8'},
#      {'_qcode': 'M:E7'},
#      {'_qcode': 'M:N'},
#      {'_qcode': 'M:NP'},
#      {'_qcode': 'M:P9'},
#      {'_qcode': 'M:R'},
#      {'_qcode': 'M:Z'},
#      {'_qcode': 'R:BVIC.L'},
#      {'_qcode': 'R:CARLb.CO'},
#      {'_qcode': 'U:45'},
#      {'_qcode': 'U:C'},
#      {'_qcode': 'Meta:Video'},
#      {'_qcode': 'P:4295866057'},
#      {'_qcode': 'P:4295898944'}]}},
#   {'storyId': 'urn:newsml:reuters.com:20240621:nBER9QVFBc:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:BER'}],
#      'creator': [{'_qcode': 'NS:BER', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:BER', '_role': 'sRole:source'},
#       {'_qcode': 'NS:BER', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'A:1F'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'A:7'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:2EK'},
#       {'_qcode': 'G:8S'},
#       {'_qcode': 'G:CI'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:2CM'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:2CR'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:2CU'},
#       {'_qcode': 'M:2CX'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'U:47'},
#       {'_qcode': 'U:8'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'U:F'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2024-06-21T10:51:11.934Z'},
#      'versionCreated': {'$': '2024-06-21T10:51:11.934Z'},
#      'title': [{'$': 'CRUDE PALM OIL FUTURES CLOSING: JUNE 21'}]},
#     'assert': [{'_qcode': 'A:1F'},
#      {'_qcode': 'A:4'},
#      {'_qcode': 'A:7'},
#      {'_qcode': 'G:1'},
#      {'_qcode': 'G:2EK'},
#      {'_qcode': 'G:8S'},
#      {'_qcode': 'G:CI'},
#      {'_qcode': 'G:K'},
#      {'_qcode': 'G:S'},
#      {'_qcode': 'M:1QD'},
#      {'_qcode': 'M:2CM'},
#      {'_qcode': 'M:2CN'},
#      {'_qcode': 'M:2CP'},
#      {'_qcode': 'M:2CQ'},
#      {'_qcode': 'M:2CR'},
#      {'_qcode': 'M:2CS'},
#      {'_qcode': 'M:2CT'},
#      {'_qcode': 'M:2CU'},
#      {'_qcode': 'M:2CX'},
#      {'_qcode': 'U:45'},
#      {'_qcode': 'U:47'},
#      {'_qcode': 'U:8'},
#      {'_qcode': 'U:C'},
#      {'_qcode': 'U:F'}]}},
#   {'storyId': 'urn:link:webnews:20240621:nNRAt19fn8:0',
#    'newsItem': {'_version': 0,
#     'contentMeta': {'audience': [],
#      'creator': [{'_qcode': 'NS:GLOMAI', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:GLOMAI', '_role': 'sRole:source'},
#       {'_qcode': 'NS:GLOMAI', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'G:4'},
#       {'_qcode': 'M:1YN'},
#       {'_qcode': 'E:5'},
#       {'_qcode': 'E:9'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'I:C6'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'M:1LY'},
#       {'_qcode': 'M:8'},
#       {'_qcode': 'M:1YI'},
#       {'_qcode': 'E:A'},
#       {'_qcode': 'G:8T'},
#       {'_qcode': 'M:1YL'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'A:1F'},
#       {'_qcode': 'U:D2'},
#       {'_qcode': 'G:H'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'M:H'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'G:AL'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'G:D3'},
#       {'_qcode': 'U:I'},
#       {'_qcode': 'I:W'},
#       {'_qcode': 'G:Y'},
#       {'_qcode': 'G:64'},
#       {'_qcode': 'U:8J'},
#       {'_qcode': 'G:3S'},
#       {'_qcode': 'I:1P'},
#       {'_qcode': 'L:en'},
#       {'_qcode': 'I:3V'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'M:E7'},
#       {'_qcode': 'A:7'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'Meta:WebNews'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2024-06-21T10:46:26.775Z'},
#      'versionCreated': {'$': '2024-06-21T10:46:27.469Z'},
#      'title': [{'$': 'Oil prices set for second week of gains on signs of improving demand --'}]},
#     'assert': [{'_qcode': 'G:4'},
#      {'_qcode': 'M:1YN'},
#      {'_qcode': 'E:5'},
#      {'_qcode': 'E:9'},
#      {'_qcode': 'G:6J'},
#      {'_qcode': 'I:C6'},
#      {'_qcode': 'G:9'},
#      {'_qcode': 'M:1LY'},
#      {'_qcode': 'M:8'},
#      {'_qcode': 'M:1YI'},
#      {'_qcode': 'E:A'},
#      {'_qcode': 'G:8T'},
#      {'_qcode': 'M:1YL'},
#      {'_qcode': 'G:A'},
#      {'_qcode': 'A:1F'},
#      {'_qcode': 'U:D2'},
#      {'_qcode': 'G:H'},
#      {'_qcode': 'G:K'},
#      {'_qcode': 'M:H'},
#      {'_qcode': 'U:C'},
#      {'_qcode': 'G:AL'},
#      {'_qcode': 'G:Q'},
#      {'_qcode': 'U:24'},
#      {'_qcode': 'U:45'},
#      {'_qcode': 'G:S'},
#      {'_qcode': 'G:D3'},
#      {'_qcode': 'U:I'},
#      {'_qcode': 'I:W'},
#      {'_qcode': 'G:Y'},
#      {'_qcode': 'G:64'},
#      {'_qcode': 'U:8J'},
#      {'_qcode': 'G:3S'},
#      {'_qcode': 'I:1P'},
#      {'_qcode': 'L:en'},
#      {'_qcode': 'I:3V'},
#      {'_qcode': 'A:4'},
#      {'_qcode': 'M:E7'},
#      {'_qcode': 'A:7'},
#      {'_qcode': 'G:1'},
#      {'_qcode': 'Meta:WebNews'}]}},
#   {'storyId': 'urn:newsml:reuters.com:20240621:nL1N3IJ0BV:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:MF'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'A:4'},
#       {'_qcode': 'A:7'},
#       {'_qcode': 'B:12'},
#       {'_qcode': 'B:14'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'B:227'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'F:8'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:2EK'},
#       {'_qcode': 'G:7D'},
#       {'_qcode': 'G:BN'},
#       {'_qcode': 'G:CI'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'I:C6'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:1ZT'},
#       {'_qcode': 'M:1ZZ'},
#       {'_qcode': 'M:2CM'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:2CR'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:2CU'},
#       {'_qcode': 'M:2CV'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'M:E7'},
#       {'_qcode': 'M:N'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'M:R'},
#       {'_qcode': 'MCC:OEC'},
#       {'_qcode': 'MCCL:OEC'},
#       {'_qcode': 'U:23'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'U:2R'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'U:6H'},
#       {'_qcode': 'U:77'},
#       {'_qcode': 'U:B9'},
#       {'_qcode': 'U:C'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2024-06-21T10:43:20.000Z'},
#      'versionCreated': {'$': '2024-06-21T10:43:20.000Z'},
#      'title': [{'$': 'Asia Naphtha/Gasoline-Naphtha, gasoline cracks climb on demand'}],
#      'instanceOf': [{'_qcode': 'RR:2635'}]},
#     'assert': [{'_qcode': 'RR:2635'},
#      {'_qcode': 'A:4'},
#      {'_qcode': 'A:7'},
#      {'_qcode': 'B:12'},
#      {'_qcode': 'B:14'},
#      {'_qcode': 'B:2'},
#      {'_qcode': 'B:219'},
#      {'_qcode': 'B:227'},
#      {'_qcode': 'B:5'},
#      {'_qcode': 'B:8'},
#      {'_qcode': 'F:8'},
#      {'_qcode': 'G:1'},
#      {'_qcode': 'G:2EK'},
#      {'_qcode': 'G:7D'},
#      {'_qcode': 'G:BN'},
#      {'_qcode': 'G:CI'},
#      {'_qcode': 'G:K'},
#      {'_qcode': 'G:S'},
#      {'_qcode': 'I:C6'},
#      {'_qcode': 'M:1QD'},
#      {'_qcode': 'M:1ZT'},
#      {'_qcode': 'M:1ZZ'},
#      {'_qcode': 'M:2CM'},
#      {'_qcode': 'M:2CN'},
#      {'_qcode': 'M:2CP'},
#      {'_qcode': 'M:2CQ'},
#      {'_qcode': 'M:2CR'},
#      {'_qcode': 'M:2CS'},
#      {'_qcode': 'M:2CT'},
#      {'_qcode': 'M:2CU'},
#      {'_qcode': 'M:2CV'},
#      {'_qcode': 'M:3F'},
#      {'_qcode': 'M:E7'},
#      {'_qcode': 'M:N'},
#      {'_qcode': 'M:NP'},
#      {'_qcode': 'M:R'},
#      {'_qcode': 'MCC:OEC'},
#      {'_qcode': 'MCCL:OEC'},
#      {'_qcode': 'U:23'},
#      {'_qcode': 'U:24'},
#      {'_qcode': 'U:2R'},
#      {'_qcode': 'U:45'},
#      {'_qcode': 'U:6H'},
#      {'_qcode': 'U:77'},
#      {'_qcode': 'U:B9'},
#      {'_qcode': 'U:C'}]}},
#   {'storyId': 'urn:newsml:reuters.com:20240621:nRTV1CTKxc:9',
#    'newsItem': {'_version': 9,
#     'contentMeta': {'audience': [{'_qcode': 'NP:RITV'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'A:1'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'A:9'},
#       {'_qcode': 'B:125'},
#       {'_qcode': 'B:126'},
#       {'_qcode': 'B:127'},
#       {'_qcode': 'B:128'},
#       {'_qcode': 'B:1292'},
#       {'_qcode': 'B:161'},
#       {'_qcode': 'B:1615'},
#       {'_qcode': 'B:177'},
#       {'_qcode': 'B:179'},
#       {'_qcode': 'B:1817'},
#       {'_qcode': 'B:255'},
#       {'_qcode': 'B:261'},
#       {'_qcode': 'B:262'},
#       {'_qcode': 'B:278'},
#       {'_qcode': 'B:69'},
#       {'_qcode': 'B:71'},
#       {'_qcode': 'B:72'},
#       {'_qcode': 'E:1'},
#       {'_qcode': 'E:5'},
#       {'_qcode': 'E:9'},
#       {'_qcode': 'E:A'},
#       {'_qcode': 'E:B'},
#       {'_qcode': 'E:C'},
#       {'_qcode': 'E:G'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:2EK'},
#       {'_qcode': 'G:3'},
#       {'_qcode': 'G:3H'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'G:41'},
#       {'_qcode': 'G:5B'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'G:7J'},
#       {'_qcode': 'G:7L'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'G:B1'},
#       {'_qcode': 'G:CH'},
#       {'_qcode': 'G:CI'},
#       {'_qcode': 'G:D3'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'I:B'},
#       {'_qcode': 'I:W'},
#       {'_qcode': 'M:1P2'},
#       {'_qcode': 'M:1Q1'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:1W1'},
#       {'_qcode': 'M:1WJ'},
#       {'_qcode': 'M:1WK'},
#       {'_qcode': 'M:1WN'},
#       {'_qcode': 'M:1Y7'},
#       {'_qcode': 'M:1YA'},
#       {'_qcode': 'M:1YN'},
#       {'_qcode': 'M:21Z'},
#       {'_qcode': 'M:2CM'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:2CR'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:2CU'},
#       {'_qcode': 'M:2CV'},
#       {'_qcode': 'M:2D1'},
#       {'_qcode': 'M:2DZ'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'M:8'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'M:Z'},
#       {'_qcode': 'R:7267.T'},
#       {'_qcode': 'R:9433.T'},
#       {'_qcode': 'R:HSBA.L'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'Meta:Video'},
#       {'_qcode': 'P:4295880577'},
#       {'_qcode': 'P:5000058303'},
#       {'_qcode': 'P:8589934275'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2024-06-21T09:00:38.025Z'},
#      'versionCreated': {'$': '2024-06-21T10:39:35.757Z'},
#      'title': [{'$': "Newscasts - Asia Markets Briefing: Japan's demand-led inflation slows"}],
#      'instanceOf': [{'_qcode': 'RR:10125'}]},
#     'assert': [{'_qcode': 'RR:10125'},
#      {'_qcode': 'A:1'},
#      {'_qcode': 'A:4'},
#      {'_qcode': 'A:9'},
#      {'_qcode': 'B:125'},
#      {'_qcode': 'B:126'},
#      {'_qcode': 'B:127'},
#      {'_qcode': 'B:128'},
#      {'_qcode': 'B:1292'},
#      {'_qcode': 'B:161'},
#      {'_qcode': 'B:1615'},
#      {'_qcode': 'B:177'},
#      {'_qcode': 'B:179'},
#      {'_qcode': 'B:1817'},
#      {'_qcode': 'B:255'},
#      {'_qcode': 'B:261'},
#      {'_qcode': 'B:262'},
#      {'_qcode': 'B:278'},
#      {'_qcode': 'B:69'},
#      {'_qcode': 'B:71'},
#      {'_qcode': 'B:72'},
#      {'_qcode': 'E:1'},
#      {'_qcode': 'E:5'},
#      {'_qcode': 'E:9'},
#      {'_qcode': 'E:A'},
#      {'_qcode': 'E:B'},
#      {'_qcode': 'E:C'},
#      {'_qcode': 'E:G'},
#      {'_qcode': 'G:1'},
#      {'_qcode': 'G:2EK'},
#      {'_qcode': 'G:3'},
#      {'_qcode': 'G:3H'},
#      {'_qcode': 'G:4'},
#      {'_qcode': 'G:41'},
#      {'_qcode': 'G:5B'},
#      {'_qcode': 'G:6'},
#      {'_qcode': 'G:6J'},
#      {'_qcode': 'G:7J'},
#      {'_qcode': 'G:7L'},
#      {'_qcode': 'G:9'},
#      {'_qcode': 'G:A'},
#      {'_qcode': 'G:B1'},
#      {'_qcode': 'G:CH'},
#      {'_qcode': 'G:CI'},
#      {'_qcode': 'G:D3'},
#      {'_qcode': 'G:K'},
#      {'_qcode': 'G:S'},
#      {'_qcode': 'I:B'},
#      {'_qcode': 'I:W'},
#      {'_qcode': 'M:1P2'},
#      {'_qcode': 'M:1Q1'},
#      {'_qcode': 'M:1QD'},
#      {'_qcode': 'M:1W1'},
#      {'_qcode': 'M:1WJ'},
#      {'_qcode': 'M:1WK'},
#      {'_qcode': 'M:1WN'},
#      {'_qcode': 'M:1Y7'},
#      {'_qcode': 'M:1YA'},
#      {'_qcode': 'M:1YN'},
#      {'_qcode': 'M:21Z'},
#      {'_qcode': 'M:2CM'},
#      {'_qcode': 'M:2CN'},
#      {'_qcode': 'M:2CP'},
#      {'_qcode': 'M:2CQ'},
#      {'_qcode': 'M:2CR'},
#      {'_qcode': 'M:2CS'},
#      {'_qcode': 'M:2CT'},
#      {'_qcode': 'M:2CU'},
#      {'_qcode': 'M:2CV'},
#      {'_qcode': 'M:2D1'},
#      {'_qcode': 'M:2DZ'},
#      {'_qcode': 'M:3F'},
#      {'_qcode': 'M:8'},
#      {'_qcode': 'M:NP'},
#      {'_qcode': 'M:Z'},
#      {'_qcode': 'R:7267.T'},
#      {'_qcode': 'R:9433.T'},
#      {'_qcode': 'R:HSBA.L'},
#      {'_qcode': 'U:45'},
#      {'_qcode': 'U:C'},
#      {'_qcode': 'Meta:Video'},
#      {'_qcode': 'P:4295880577'},
#      {'_qcode': 'P:5000058303'},
#      {'_qcode': 'P:8589934275'}]}},
#   {'storyId': 'urn:newsml:reuters.com:20240621:nL1N3IJ0C9:2',
#    'newsItem': {'_version': 2,
#     'contentMeta': {'audience': [{'_qcode': 'NP:O'}, {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'A:4'},
#       {'_qcode': 'B:1010'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'E:5J'},
#       {'_qcode': 'F:4F'},
#       {'_qcode': 'F:8'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'G:7U'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:1RT'},
#       {'_qcode': 'M:2CM'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:2CR'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:2CU'},
#       {'_qcode': 'M:2CV'},
#       {'_qcode': 'M:MR'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'MCC:OEC'},
#       {'_qcode': 'MCCL:OEC'},
#       {'_qcode': 'R:C}RO7000000001'},
#       {'_qcode': 'R:C}RO7309414580'},
#       {'_qcode': 'U:23'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'U:5M'},
#       {'_qcode': 'U:5U'},
#       {'_qcode': 'U:6H'},
#       {'_qcode': 'U:6L'},
#       {'_qcode': 'U:78'},
#       {'_qcode': 'U:BA'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'P:77000000001'},
#       {'_qcode': 'P:77309414580'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2024-06-21T10:36:44.000Z'},
#      'versionCreated': {'$': '2024-06-21T10:36:44.000Z'},
#      'title': [{'$': "UPDATE 1-Taiwan's FPCC plans end-June restart for gasoline unit after outage"}],
#      'instanceOf': [{'_qcode': 'RR:1257 RR:9092'}]},
#     'assert': [{'_qcode': 'RR:1257 RR:9092'},
#      {'_qcode': 'A:4'},
#      {'_qcode': 'B:1010'},
#      {'_qcode': 'B:2'},
#      {'_qcode': 'B:219'},
#      {'_qcode': 'B:5'},
#      {'_qcode': 'B:8'},
#      {'_qcode': 'E:5J'},
#      {'_qcode': 'F:4F'},
#      {'_qcode': 'F:8'},
#      {'_qcode': 'G:1'},
#      {'_qcode': 'G:6'},
#      {'_qcode': 'G:7U'},
#      {'_qcode': 'G:K'},
#      {'_qcode': 'G:S'},
#      {'_qcode': 'M:1QD'},
#      {'_qcode': 'M:1RT'},
#      {'_qcode': 'M:2CM'},
#      {'_qcode': 'M:2CN'},
#      {'_qcode': 'M:2CP'},
#      {'_qcode': 'M:2CQ'},
#      {'_qcode': 'M:2CR'},
#      {'_qcode': 'M:2CS'},
#      {'_qcode': 'M:2CT'},
#      {'_qcode': 'M:2CU'},
#      {'_qcode': 'M:2CV'},
#      {'_qcode': 'M:MR'},
#      {'_qcode': 'M:NP'},
#      {'_qcode': 'MCC:OEC'},
#      {'_qcode': 'MCCL:OEC'},
#      {'_qcode': 'R:C}RO7000000001'},
#      {'_qcode': 'R:C}RO7309414580'},
#      {'_qcode': 'U:23'},
#      {'_qcode': 'U:24'},
#      {'_qcode': 'U:45'},
#      {'_qcode': 'U:5M'},
#      {'_qcode': 'U:5U'},
#      {'_qcode': 'U:6H'},
#      {'_qcode': 'U:6L'},
#      {'_qcode': 'U:78'},
#      {'_qcode': 'U:BA'},
#      {'_qcode': 'U:C'},
#      {'_qcode': 'P:77000000001'},
#      {'_qcode': 'P:77309414580'}]}},
#   {'storyId': 'urn:newsml:reuters.com:20240621:nL4N3IJ0H2:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:GFN'},
#       {'_qcode': 'NP:MF'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:SI'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'A:1'},
#       {'_qcode': 'A:1F'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'A:7'},
#       {'_qcode': 'B:1004'},
#       {'_qcode': 'B:181'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'B:234'},
#       {'_qcode': 'B:34'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'B:56'},
#       {'_qcode': 'B:62'},
#       {'_qcode': 'B:7'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'F:5'},
#       {'_qcode': 'F:8'},
#       {'_qcode': 'F:I'},
#       {'_qcode': 'F:N'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:2EK'},
#       {'_qcode': 'G:7D'},
#       {'_qcode': 'G:7Q'},
#       {'_qcode': 'G:BN'},
#       {'_qcode': 'G:CI'},
#       {'_qcode': 'G:D3'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'G:H'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'I:C6'},
#       {'_qcode': 'M:1P4'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:1SP'},
#       {'_qcode': 'M:1UU'},
#       {'_qcode': 'M:1ZT'},
#       {'_qcode': 'M:1ZZ'},
#       {'_qcode': 'M:21Z'},
#       {'_qcode': 'M:2CM'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:2CR'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:2CU'},
#       {'_qcode': 'M:2CV'},
#       {'_qcode': 'M:2DY'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'M:DU'},
#       {'_qcode': 'M:E7'},
#       {'_qcode': 'M:K'},
#       {'_qcode': 'M:N'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'M:Z'},
#       {'_qcode': 'MCC:OEC'},
#       {'_qcode': 'MCCL:OEC'},
#       {'_qcode': 'R:C}TS7309500001'},
#       {'_qcode': 'R:C}TS7309532061'},
#       {'_qcode': 'R:C}TS7309542371'},
#       {'_qcode': 'U:1U'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'U:2B'},
#       {'_qcode': 'U:2R'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'U:5M'},
#       {'_qcode': 'U:78'},
#       {'_qcode': 'U:B'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'U:EU'},
#       {'_qcode': 'U:G'},
#       {'_qcode': 'P:154087011565'},
#       {'_qcode': 'P:5057564830'},
#       {'_qcode': 'P:77309500001'},
#       {'_qcode': 'P:77309532061'},
#       {'_qcode': 'P:77309542371'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2024-06-21T10:32:26.000Z'},
#      'versionCreated': {'$': '2024-06-21T10:32:26.000Z'},
#      'title': [{'$': 'Asia Fuel Oil-VLSFO dips; bunker demand cautious after oil spill'}],
#      'instanceOf': [{'_qcode': 'RR:324'}]},
#     'assert': [{'_qcode': 'RR:324'},
#      {'_qcode': 'A:1'},
#      {'_qcode': 'A:1F'},
#      {'_qcode': 'A:4'},
#      {'_qcode': 'A:7'},
#      {'_qcode': 'B:1004'},
#      {'_qcode': 'B:181'},
#      {'_qcode': 'B:2'},
#      {'_qcode': 'B:219'},
#      {'_qcode': 'B:234'},
#      {'_qcode': 'B:34'},
#      {'_qcode': 'B:5'},
#      {'_qcode': 'B:56'},
#      {'_qcode': 'B:62'},
#      {'_qcode': 'B:7'},
#      {'_qcode': 'B:8'},
#      {'_qcode': 'F:5'},
#      {'_qcode': 'F:8'},
#      {'_qcode': 'F:I'},
#      {'_qcode': 'F:N'},
#      {'_qcode': 'G:1'},
#      {'_qcode': 'G:2EK'},
#      {'_qcode': 'G:7D'},
#      {'_qcode': 'G:7Q'},
#      {'_qcode': 'G:BN'},
#      {'_qcode': 'G:CI'},
#      {'_qcode': 'G:D3'},
#      {'_qcode': 'G:F'},
#      {'_qcode': 'G:H'},
#      {'_qcode': 'G:K'},
#      {'_qcode': 'G:Q'},
#      {'_qcode': 'G:S'},
#      {'_qcode': 'I:C6'},
#      {'_qcode': 'M:1P4'},
#      {'_qcode': 'M:1QD'},
#      {'_qcode': 'M:1SP'},
#      {'_qcode': 'M:1UU'},
#      {'_qcode': 'M:1ZT'},
#      {'_qcode': 'M:1ZZ'},
#      {'_qcode': 'M:21Z'},
#      {'_qcode': 'M:2CM'},
#      {'_qcode': 'M:2CN'},
#      {'_qcode': 'M:2CP'},
#      {'_qcode': 'M:2CQ'},
#      {'_qcode': 'M:2CR'},
#      {'_qcode': 'M:2CS'},
#      {'_qcode': 'M:2CT'},
#      {'_qcode': 'M:2CU'},
#      {'_qcode': 'M:2CV'},
#      {'_qcode': 'M:2DY'},
#      {'_qcode': 'M:3F'},
#      {'_qcode': 'M:DU'},
#      {'_qcode': 'M:E7'},
#      {'_qcode': 'M:K'},
#      {'_qcode': 'M:N'},
#      {'_qcode': 'M:NP'},
#      {'_qcode': 'M:Z'},
#      {'_qcode': 'MCC:OEC'},
#      {'_qcode': 'MCCL:OEC'},
#      {'_qcode': 'R:C}TS7309500001'},
#      {'_qcode': 'R:C}TS7309532061'},
#      {'_qcode': 'R:C}TS7309542371'},
#      {'_qcode': 'U:1U'},
#      {'_qcode': 'U:24'},
#      {'_qcode': 'U:2B'},
#      {'_qcode': 'U:2R'},
#      {'_qcode': 'U:45'},
#      {'_qcode': 'U:5M'},
#      {'_qcode': 'U:78'},
#      {'_qcode': 'U:B'},
#      {'_qcode': 'U:C'},
#      {'_qcode': 'U:EU'},
#      {'_qcode': 'U:G'},
#      {'_qcode': 'P:154087011565'},
#      {'_qcode': 'P:5057564830'},
#      {'_qcode': 'P:77309500001'},
#      {'_qcode': 'P:77309532061'},
#      {'_qcode': 'P:77309542371'}]}}],
#  'meta': {'count': 10,
#   'pageLimit': 10,
#   'next': '...',
#   'prev': '...'},
#  'notifications': [{'notificationNumber': 2300,
#    'message': 'Your requested language with value en-GB is not supported, using en-us instead.'}]}

# %% [markdown]
# ## Close the session

# %%
ld.close_session()
