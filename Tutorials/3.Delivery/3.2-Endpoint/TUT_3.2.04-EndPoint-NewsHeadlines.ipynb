# %% [markdown]
# ----
# <img src="../../../files/refinitiv.png" width="20%" style="vertical-align: top;">
#
# # Data Library for Python
#
# ----

# %% [markdown]
# ## Delivery - EndPoint - News Headlines

# %% [markdown]
# This notebook demonstrates how to use the Delivery Layer of the library to retrieve News headlines from the Refinitiv Data Platform.

# %% [markdown]
# ## Set the location of the configuration file
# For ease of use, you can set various initialization parameters of the RD Library in the **_refinitiv-data.config.json_** configuration file - as described in the Quick Start -> Sessions example.
#
# ### One config file for the tutorials
# As these tutorial Notebooks are categorised into sub-folders and to avoid the need for multiple config files, we will use the _RD_LIB_CONFIG_PATH_ environment variable to point to a single instance of the config file in the top-level ***Configuration*** folder.
#
# Before proceeding, please **ensure you have entered your credentials** into the config file in the ***Configuration*** folder.

# %%
import os
os.environ["RD_LIB_CONFIG_PATH"] = "../../../Configuration"

# %%
from refinitiv.data.delivery import endpoint_request
import refinitiv.data as rd
import json

# %% [markdown]
# ## Open the default session
#
# To open the default session ensure you have a '*refinitiv-data.config.json*' in the ***Configuration*** directory, populated with your credentials and specified a 'default' session in the config file

# %%
rd.open_session()
# Out:
# <refinitiv.data.session.platform.Definition object at 0x26c8a576970 {session_name='rdp'}>

# %% [markdown]
# ## Define the endpoint request

# %%
# Correct syntax but does not work yet
request_definition = rd.delivery.endpoint_request.Definition(
    url = "/data/news/v1/headlines",
    method = rd.delivery.endpoint_request.RequestMethod.GET,
    query_parameters = {"query": "CRUDE OIL"}
)

# %% [markdown]
# ## Send a request

# %%
response = request_definition.get_data()

# %% [markdown]
# ## Display the result

# %%
response.data.raw
# Out:
# {'data': [{'storyId': 'urn:newsml:reuters.com:20211126:nFWN2SH0E6:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:E'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:U'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'G:4'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'B:1020'},
#       {'_qcode': 'A:1'},
#       {'_qcode': 'B:1004'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:2DZ'},
#       {'_qcode': 'R:CVX.N'},
#       {'_qcode': 'A:C'},
#       {'_qcode': 'R:OVV.N'},
#       {'_qcode': 'R:PSX.N'},
#       {'_qcode': 'B:7'},
#       {'_qcode': 'R:DVN.N'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2D1'},
#       {'_qcode': 'R:MPC.N'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'R:VLO.N'},
#       {'_qcode': 'B:1010'},
#       {'_qcode': 'M:Z'},
#       {'_qcode': 'B:11'},
#       {'_qcode': 'R:MRO.N'},
#       {'_qcode': 'R:SLB.N'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'R:OXY.N'},
#       {'_qcode': 'R:XOM.N'},
#       {'_qcode': 'R:PBF.N'},
#       {'_qcode': 'R:HAL.N'},
#       {'_qcode': 'M:9X'},
#       {'_qcode': 'R:BKR.N'},
#       {'_qcode': 'M:NY'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'B:9'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'P:5037128948'},
#       {'_qcode': 'P:4295904645'},
#       {'_qcode': 'P:5073113072'},
#       {'_qcode': 'P:4295904116'},
#       {'_qcode': 'P:5036398194'},
#       {'_qcode': 'P:4295912121'},
#       {'_qcode': 'P:5055424391'},
#       {'_qcode': 'P:4295905198'},
#       {'_qcode': 'P:4295912097'},
#       {'_qcode': 'P:5001438555'},
#       {'_qcode': 'P:4295903744'},
#       {'_qcode': 'P:4295904888'},
#       {'_qcode': 'P:4295905140'}],
#      'urgency': {'$': 1}},
#     'itemMeta': {'firstCreated': {'$': '2021-11-26T12:34:15.528Z'},
#      'versionCreated': {'$': '2021-11-26T12:34:15.528Z'},
#      'title': [{'$': 'SHARES OF U.S.-LISTED ENERGY COMPANIES DOWN PREMARKET AFTER CRUDE PRICES FALL DUE TO DETECTION OF NEW COVID-19 VARIANT IN SOUTH AFRICA'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20211126:nL1N2SF1GP:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:MF'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'M:2CS'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'M:1ZZ'},
#       {'_qcode': 'U:8J'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'G:CF'},
#       {'_qcode': 'U:91'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'B:6'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'A:7'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:1ZT'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'G:BM'},
#       {'_qcode': 'a1312cat:v'},
#       {'_qcode': 'B:1003'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'M:PB'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'M:2CP'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-11-26T12:00:00Z'},
#      'versionCreated': {'$': '2021-11-26T12:00:00Z'},
#      'title': [{'$': 'ADVISORY-U.S. cash crude report will not be published on Nov. 26'}],
#      'instanceOf': [{'_qcode': '1910'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20211126:nL4N2SH2J6:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:MF'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'G:5B'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'B:227'},
#       {'_qcode': 'E:4A'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'M:21Z'},
#       {'_qcode': 'M:E7'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:N'},
#       {'_qcode': 'E:5'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'U:23'},
#       {'_qcode': 'B:12'},
#       {'_qcode': 'I:C6'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'G:7D'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'R:HOEX.NS'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'U:6H'},
#       {'_qcode': 'G:CH'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'G:2EK'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'M:Z'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'M:R'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'E:E'},
#       {'_qcode': 'M:1QR'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:CI'},
#       {'_qcode': 'M:224'},
#       {'_qcode': 'M:29E'},
#       {'_qcode': 'B:14'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'U:77'},
#       {'_qcode': 'E:1'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'M:1QY'},
#       {'_qcode': 'M:1ZT'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'P:4295874219'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-11-26T10:27:42Z'},
#      'versionCreated': {'$': '2021-11-26T10:27:42Z'},
#      'title': [{'$': 'Asia Naphtha/Gasoline-Gasoline crack inches higher as crude oil slides'}],
#      'instanceOf': [{'_qcode': '2635'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20211126:nS8N2IB061:3',
#    'newsItem': {'_version': 3,
#     'contentMeta': {'audience': [{'_qcode': 'NP:C'},
#       {'_qcode': 'NP:D'},
#       {'_qcode': 'NP:E'},
#       {'_qcode': 'NP:GFN'},
#       {'_qcode': 'NP:GRO'},
#       {'_qcode': 'NP:J'},
#       {'_qcode': 'NP:M'},
#       {'_qcode': 'NP:MF'},
#       {'_qcode': 'NP:MTL'},
#       {'_qcode': 'NP:NAT'},
#       {'_qcode': 'NP:NAW'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:SOF'},
#       {'_qcode': 'NP:T'},
#       {'_qcode': 'NP:U'},
#       {'_qcode': 'NP:UKI'},
#       {'_qcode': 'NP:Z'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'U:C'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'M:2CY'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'U:9T'},
#       {'_qcode': 'G:92'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'A:1'},
#       {'_qcode': 'E:C'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'M:E7'},
#       {'_qcode': 'A:9'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'F:8'},
#       {'_qcode': 'M:N'},
#       {'_qcode': 'G:3'},
#       {'_qcode': 'E:5'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:2CX'},
#       {'_qcode': 'G:CG'},
#       {'_qcode': 'G:H'},
#       {'_qcode': 'R:CLc1'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2D1'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'M:NT'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'G:G'},
#       {'_qcode': 'G:8W'},
#       {'_qcode': 'G:2K'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'M:R'},
#       {'_qcode': 'F:49'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:9T'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:AE'},
#       {'_qcode': 'M:9X'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'U:2R'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:DU'},
#       {'_qcode': 'G:7J'}],
#      'urgency': {'$': 1}},
#     'itemMeta': {'firstCreated': {'$': '2021-11-26T08:05:18.487Z'},
#      'versionCreated': {'$': '2021-11-26T09:33:13.141Z'},
#      'title': [{'$': 'WTI U.S. CRUDE OIL FUTURES FALL MORE THAN $5 TO NEW SESSION LOW OF $73.14/BBL'}],
#      'instanceOf': [{'_qcode': '529'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20211126:nL1N2SH0HB:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:GFN'},
#       {'_qcode': 'NP:MF'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'U:C'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'MCC:OEC'},
#       {'_qcode': 'G:7B'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'U:9T'},
#       {'_qcode': 'U:B9'},
#       {'_qcode': 'R:LKOH.MM'},
#       {'_qcode': 'G:92'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'U:A'},
#       {'_qcode': 'R:GGL.UL'},
#       {'_qcode': 'MCCL:OEC'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:1ZT'},
#       {'_qcode': 'F:8'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'U:A8'},
#       {'_qcode': 'R:XOM.N'},
#       {'_qcode': 'G:H'},
#       {'_qcode': 'R:C}RO7000000001'},
#       {'_qcode': 'R:EQNR.OL'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'G:BR'},
#       {'_qcode': 'M:1ZZ'},
#       {'_qcode': 'G:BN'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'G:7Q'},
#       {'_qcode': 'A:1F'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'A:7'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'G:A4'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'G:8G'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'R:C}RO7309414615'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'U:2R'},
#       {'_qcode': 'G:51'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'P:77309414615'},
#       {'_qcode': 'P:5000657254'},
#       {'_qcode': 'P:4295887034'},
#       {'_qcode': 'P:4295885689'},
#       {'_qcode': 'P:77000000001'},
#       {'_qcode': 'P:4297348198'},
#       {'_qcode': 'P:4295912121'},
#       {'_qcode': 'P:5000057716'},
#       {'_qcode': 'P:5037653855'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-11-26T09:23:03Z'},
#      'versionCreated': {'$': '2021-11-26T09:23:03Z'},
#      'title': [{'$': 'Middle East Crude-Oman slumps, Dubai weakens; new virus variant roils markets'}],
#      'instanceOf': [{'_qcode': '1701'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20211126:nS8N2IB069:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:C'},
#       {'_qcode': 'NP:D'},
#       {'_qcode': 'NP:E'},
#       {'_qcode': 'NP:GFN'},
#       {'_qcode': 'NP:GRO'},
#       {'_qcode': 'NP:J'},
#       {'_qcode': 'NP:M'},
#       {'_qcode': 'NP:MF'},
#       {'_qcode': 'NP:MTL'},
#       {'_qcode': 'NP:NAT'},
#       {'_qcode': 'NP:NAW'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:SOF'},
#       {'_qcode': 'NP:T'},
#       {'_qcode': 'NP:U'},
#       {'_qcode': 'NP:UKI'},
#       {'_qcode': 'NP:Z'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'U:C'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'M:2CY'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'U:9T'},
#       {'_qcode': 'R:LCOc1'},
#       {'_qcode': 'R:LCOC2'},
#       {'_qcode': 'G:92'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'A:1'},
#       {'_qcode': 'E:C'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'M:E7'},
#       {'_qcode': 'A:9'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'F:8'},
#       {'_qcode': 'M:N'},
#       {'_qcode': 'G:3'},
#       {'_qcode': 'E:5'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:2CX'},
#       {'_qcode': 'G:CG'},
#       {'_qcode': 'G:H'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2D1'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'M:NT'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'G:G'},
#       {'_qcode': 'G:8W'},
#       {'_qcode': 'G:2K'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'M:R'},
#       {'_qcode': 'F:49'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:9T'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'R:LCOC1'},
#       {'_qcode': 'G:AE'},
#       {'_qcode': 'M:9X'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'U:2R'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:DU'},
#       {'_qcode': 'G:7J'}],
#      'urgency': {'$': 1}},
#     'itemMeta': {'firstCreated': {'$': '2021-11-26T08:29:19.949Z'},
#      'versionCreated': {'$': '2021-11-26T08:29:19.949Z'},
#      'title': [{'$': 'BRENT CRUDE OIL FUTURES <LCOC1> FALL $4 TO $78.22 A BARREL'}],
#      'instanceOf': [{'_qcode': '529'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20211126:nL4N2SH1VE:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:C'},
#       {'_qcode': 'NP:D'},
#       {'_qcode': 'NP:E'},
#       {'_qcode': 'NP:M'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:T'},
#       {'_qcode': 'NP:U'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:NAT'},
#       {'_qcode': 'NP:UKI'},
#       {'_qcode': 'NP:GRO'},
#       {'_qcode': 'NP:MTL'},
#       {'_qcode': 'NP:SOF'},
#       {'_qcode': 'NP:AUF'},
#       {'_qcode': 'NP:AUP'},
#       {'_qcode': 'NP:GFN'},
#       {'_qcode': 'NP:J'},
#       {'_qcode': 'NP:Z'},
#       {'_qcode': 'NP:DNP'},
#       {'_qcode': 'NP:PEN'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'M:2CS'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'MCC:OEC'},
#       {'_qcode': 'M:2CY'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'R:LCOc1'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'MCCL:OEC'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'G:V'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'G:3'},
#       {'_qcode': 'M:1L'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'M:2CX'},
#       {'_qcode': 'G:AE'},
#       {'_qcode': 'R:CLc1'},
#       {'_qcode': 'M:9X'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2D1'}],
#      'urgency': {'$': 1}},
#     'itemMeta': {'firstCreated': {'$': '2021-11-26T07:29:38Z'},
#      'versionCreated': {'$': '2021-11-26T07:29:38Z'},
#      'title': [{'$': 'BRENT CRUDE <LCOc1> DROPS $3 TO $79.22/BBL'}],
#      'instanceOf': [{'_qcode': '529'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20211126:nL4N2SH1UX:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:C'},
#       {'_qcode': 'NP:D'},
#       {'_qcode': 'NP:E'},
#       {'_qcode': 'NP:M'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:T'},
#       {'_qcode': 'NP:U'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:NAT'},
#       {'_qcode': 'NP:UKI'},
#       {'_qcode': 'NP:GRO'},
#       {'_qcode': 'NP:MTL'},
#       {'_qcode': 'NP:SOF'},
#       {'_qcode': 'NP:AUF'},
#       {'_qcode': 'NP:AUP'},
#       {'_qcode': 'NP:GFN'},
#       {'_qcode': 'NP:J'},
#       {'_qcode': 'NP:Z'},
#       {'_qcode': 'NP:DNP'},
#       {'_qcode': 'NP:PEN'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'M:2CS'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'MCC:OEC'},
#       {'_qcode': 'M:2CY'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'R:LCOc1'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'MCCL:OEC'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'G:V'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'G:3'},
#       {'_qcode': 'M:1L'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'M:2CX'},
#       {'_qcode': 'G:AE'},
#       {'_qcode': 'R:CLc1'},
#       {'_qcode': 'M:9X'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2D1'}],
#      'urgency': {'$': 1}},
#     'itemMeta': {'firstCreated': {'$': '2021-11-26T07:26:19Z'},
#      'versionCreated': {'$': '2021-11-26T07:26:19Z'},
#      'title': [{'$': 'U.S. CRUDE <CLc1> DROPS MORE THAN $3 TO $75.25/BBL'}],
#      'instanceOf': [{'_qcode': '529'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20211126:nL4N2SH1KU:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:C'},
#       {'_qcode': 'NP:D'},
#       {'_qcode': 'NP:E'},
#       {'_qcode': 'NP:M'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:T'},
#       {'_qcode': 'NP:U'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:NAT'},
#       {'_qcode': 'NP:UKI'},
#       {'_qcode': 'NP:GRO'},
#       {'_qcode': 'NP:MTL'},
#       {'_qcode': 'NP:SOF'},
#       {'_qcode': 'NP:AUF'},
#       {'_qcode': 'NP:AUP'},
#       {'_qcode': 'NP:GFN'},
#       {'_qcode': 'NP:J'},
#       {'_qcode': 'NP:Z'},
#       {'_qcode': 'NP:DNP'},
#       {'_qcode': 'NP:PEN'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'M:2CS'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'MCC:OEC'},
#       {'_qcode': 'M:2CY'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'R:LCOc1'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'MCCL:OEC'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'G:V'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'G:3'},
#       {'_qcode': 'M:1L'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'M:2CX'},
#       {'_qcode': 'G:AE'},
#       {'_qcode': 'R:CLc1'},
#       {'_qcode': 'M:9X'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2D1'}],
#      'urgency': {'$': 1}},
#     'itemMeta': {'firstCreated': {'$': '2021-11-26T06:31:01Z'},
#      'versionCreated': {'$': '2021-11-26T06:31:01Z'},
#      'title': [{'$': 'BRENT CRUDE <LCOc1> FALLS BELOW $80/BBL AS NEW VARIANT, OIL SURPLUS CONCERNS DEPRESS PRICES'}],
#      'instanceOf': [{'_qcode': '529'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20211126:nL4N2SH0J6:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:C'},
#       {'_qcode': 'NP:D'},
#       {'_qcode': 'NP:E'},
#       {'_qcode': 'NP:M'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:T'},
#       {'_qcode': 'NP:U'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:NAT'},
#       {'_qcode': 'NP:UKI'},
#       {'_qcode': 'NP:GRO'},
#       {'_qcode': 'NP:MTL'},
#       {'_qcode': 'NP:SOF'},
#       {'_qcode': 'NP:AUF'},
#       {'_qcode': 'NP:AUP'},
#       {'_qcode': 'NP:GFN'},
#       {'_qcode': 'NP:J'},
#       {'_qcode': 'NP:Z'},
#       {'_qcode': 'NP:DNP'},
#       {'_qcode': 'NP:PEN'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'M:2CS'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'MCC:OEC'},
#       {'_qcode': 'M:2CY'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'R:LCOc1'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'MCCL:OEC'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'G:V'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'G:3'},
#       {'_qcode': 'M:1L'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'M:2CX'},
#       {'_qcode': 'G:AE'},
#       {'_qcode': 'R:CLc1'},
#       {'_qcode': 'M:9X'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2D1'}],
#      'urgency': {'$': 1}},
#     'itemMeta': {'firstCreated': {'$': '2021-11-26T04:49:31Z'},
#      'versionCreated': {'$': '2021-11-26T04:49:31Z'},
#      'title': [{'$': 'BRENT CRUDE <LCOc1> DROPS MORE THAN $2 TO $80.11/BBL'}],
#      'instanceOf': [{'_qcode': '529'}]}}}],
#  'meta': {'count': 10,
#   'pageLimit': 10,
#   'next': '',
#   'prev': ''}}

# %% [markdown]
# ## Close the session

# %%
rd.close_session()
