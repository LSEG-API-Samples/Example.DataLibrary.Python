# %% [markdown]
# # Refinitiv Data Platform Library for Python
# ## Delivery - EndPoint - News Headlines

# %% [markdown]
# This notebook demonstrates how to use the Delivery Layer of the library to retrieve News headlines from the Refinitiv Data Platform.

# %% [markdown]
# ## Import the library and load credentials
#
# Credentials used by this and the other tutorials notebooks are stored in the **Configuration/credentials.ipynb** file.
#
# You should have edited the **Configuration/credentials.ipynb** to set your credentials as part of the **Quick Start** step.

# %%
from refinitiv.data.delivery import endpoint_request
import datetime
import json
# %run ../../Configuration/credentials.ipynb

# %% [markdown]
# ## Open the session of your choice
#
# Use our helper function in the Credentials notebook, **open_session(session_type)**, to create and open a session to connect to the
# - Refinitiv Data Platform directly (session_type="rdp") or via
# - Eikon 4 or Refinitiv Workspace (session_type="desktop")
#
# You can also set a default in the **credentials** notebook
#
# **Note**: You cannot currently perform Endpoint requests using a Deployed session

# %%
open_session('rdp')
# Out:
# <refinitiv.data.session._platform_session.Definition object at 0x138bf553a90 {session_name='default-session'}>

# %% [markdown]
# # Example

# %% [markdown]
# ## Define the endpoint request

# %%
# Correct syntax but does not work yet
request_definition = rd.delivery.endpoint_request.Definition(
    url = "/data/news/v1/headlines",
    method = rd.delivery.endpoint_request.RequestMethod.GET,
    query_parameters = {"query": "CRUDE OIL"}
)

# %% [markdown]
# ## Send a request

# %%
response = request_definition.get_data()

# %% [markdown]
# ## Display the result

# %%
response.data.raw
# Out:
# {'data': [{'storyId': 'urn:newsml:reuters.com:20210913:nL1N2QF0VZ:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:E'},
#       {'_qcode': 'NP:ELN'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:U'},
#       {'_qcode': 'NP:NAW'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:PSC'},
#       {'_qcode': 'NP:RNP'},
#       {'_qcode': 'NP:DNP'},
#       {'_qcode': 'NP:PCO'},
#       {'_qcode': 'NP:PEN'},
#       {'_qcode': 'NP:PCU'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'U:C'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'U:8J'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'a1312cat:w'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'M:E7'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'F:8'},
#       {'_qcode': 'M:N'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'R:CVX.N'},
#       {'_qcode': 'E:1'},
#       {'_qcode': 'M:1T4'},
#       {'_qcode': 'R:PSX.N'},
#       {'_qcode': 'M:258'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'R:MPC.N'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2D1'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'R:VLO.N'},
#       {'_qcode': 'B:1010'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'M:AJ'},
#       {'_qcode': 'M:Z'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'R:XOM.N'},
#       {'_qcode': 'B:1011'},
#       {'_qcode': 'R:MOTIV.UL'},
#       {'_qcode': 'E:D'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'P:5037128948'},
#       {'_qcode': 'P:5000035357'},
#       {'_qcode': 'P:4295912121'},
#       {'_qcode': 'P:4298443411'},
#       {'_qcode': 'P:5000661878'},
#       {'_qcode': 'P:4295905198'},
#       {'_qcode': 'P:4298368896'},
#       {'_qcode': 'P:4298210565'},
#       {'_qcode': 'P:5001438555'},
#       {'_qcode': 'P:4295903744'},
#       {'_qcode': 'P:4296460611'},
#       {'_qcode': 'P:5035094814'},
#       {'_qcode': 'P:4296797524'}],
#      'urgency': {'$': 2}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-13T12:18:13Z'},
#      'versionCreated': {'$': '2021-09-13T12:28:33Z'},
#      'title': [{'$': 'U.S. allows eight companies to purchase SPR crude oil -statement'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210913:nL9N2ID02F:6',
#    'newsItem': {'_version': 6,
#     'contentMeta': {'audience': [{'_qcode': 'NP:AFN'},
#       {'_qcode': 'NP:C'},
#       {'_qcode': 'NP:D'},
#       {'_qcode': 'NP:E'},
#       {'_qcode': 'NP:GFN'},
#       {'_qcode': 'NP:GRO'},
#       {'_qcode': 'NP:M'},
#       {'_qcode': 'NP:MTL'},
#       {'_qcode': 'NP:NAT'},
#       {'_qcode': 'NP:NAW'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:SOF'},
#       {'_qcode': 'NP:T'},
#       {'_qcode': 'NP:U'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'M:2CS'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'G:AJ'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'G:38'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'G:E'},
#       {'_qcode': 'G:92'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'A:7'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'G:3'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:9T'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:H'},
#       {'_qcode': 'M:9X'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'G:B'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:DU'},
#       {'_qcode': 'G:7J'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2D1'}],
#      'urgency': {'$': 1}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-13T12:20:00Z'},
#      'versionCreated': {'$': '2021-09-13T12:20:00Z'},
#      'title': [{'$': 'OPEC RAISES 2022 FORECAST FOR GLOBAL DEMAND FOR ITS CRUDE BY 1.1 MBPD TO 28.75 MILLION BPD'}],
#      'instanceOf': [{'_qcode': '2162'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210913:nL1N2QF0VZ:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:E'},
#       {'_qcode': 'NP:U'},
#       {'_qcode': 'NP:NAW'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:ELN'},
#       {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'M:2CS'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'a1312cat:w'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'M:AJ'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'M:E7'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'F:8'},
#       {'_qcode': 'M:N'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'E:1'},
#       {'_qcode': 'M:9X'},
#       {'_qcode': 'E:D'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2D1'}],
#      'urgency': {'$': 1}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-13T12:15:47Z'},
#      'versionCreated': {'$': '2021-09-13T12:15:47Z'},
#      'title': [{'$': 'U.S. ENERGY DEPARTMENT SAYS HAS AWARDED CONTRACTS TO EIGHT COMPANIES FOLLOWING BIDS FOR SPR CRUDE OIL SALE -STATEMENT'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210913:nL1N2QF07J:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:C'},
#       {'_qcode': 'NP:GRO'},
#       {'_qcode': 'NP:MTL'},
#       {'_qcode': 'NP:SOF'},
#       {'_qcode': 'NP:M'},
#       {'_qcode': 'NP:T'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:Z'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:DNP'},
#       {'_qcode': 'NP:PEN'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'G:5B'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'G:AJ'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'U:9T'},
#       {'_qcode': 'A:7'},
#       {'_qcode': 'G:E'},
#       {'_qcode': 'M:1TG'},
#       {'_qcode': 'G:92'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'MCC:QAN'},
#       {'_qcode': 'M:1VA'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'F:8'},
#       {'_qcode': 'M:1V9'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:1TH'},
#       {'_qcode': 'M:2CX'},
#       {'_qcode': 'MCCL:QAN'},
#       {'_qcode': 'U:A8'},
#       {'_qcode': 'G:H'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'I:C6'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'G:B1'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'M:23G'},
#       {'_qcode': 'G:38'},
#       {'_qcode': 'G:CH'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'A:1F'},
#       {'_qcode': 'M:PC'},
#       {'_qcode': 'U:9B'},
#       {'_qcode': 'M:R'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:1L'},
#       {'_qcode': 'M:9T'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'G:B'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'M:P8'},
#       {'_qcode': 'M:DU'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-13T12:00:00Z'},
#      'versionCreated': {'$': '2021-09-13T12:00:00Z'},
#      'title': [{'$': "RPT-COLUMN-China's crude oil sales are more about the message than the volume: Russell"}],
#      'instanceOf': [{'_qcode': '3592'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210913:nIGB5C1F5C:2',
#    'newsItem': {'_version': 2,
#     'contentMeta': {'audience': [{'_qcode': 'NP:O'}, {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'M:2CS'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'G:56'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'U:9T'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'U:8K'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:9T'},
#       {'_qcode': 'U:9K'},
#       {'_qcode': 'U:9B'},
#       {'_qcode': 'M:23N'},
#       {'_qcode': 'U:A8'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'M:DU'},
#       {'_qcode': 'G:H'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-13T10:06:01.364Z'},
#      'versionCreated': {'$': '2021-09-13T10:06:05.812Z'},
#      'title': [{'$': 'Table - Crude OSP (Updates Iran)'}],
#      'instanceOf': [{'_qcode': '552'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210913:nL1N2QF0M4:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:GFN'},
#       {'_qcode': 'NP:MF'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'U:C'},
#       {'_qcode': 'R:OIL.HNO'},
#       {'_qcode': 'U:B9'},
#       {'_qcode': 'M:1TG'},
#       {'_qcode': 'G:92'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'R:2222.SE'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'M:1ZT'},
#       {'_qcode': 'F:8'},
#       {'_qcode': 'M:1TH'},
#       {'_qcode': 'U:A8'},
#       {'_qcode': 'R:8031.T'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'G:BN'},
#       {'_qcode': 'R:GLEN.L'},
#       {'_qcode': 'G:7Q'},
#       {'_qcode': 'A:1F'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'A:7'},
#       {'_qcode': 'G:A4'},
#       {'_qcode': 'M:1UT'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'U:2R'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'M:1S8'},
#       {'_qcode': 'MCC:OEC'},
#       {'_qcode': 'R:ONGC.NS'},
#       {'_qcode': 'G:7B'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'M:1SK'},
#       {'_qcode': 'U:9T'},
#       {'_qcode': 'R:600028.SS'},
#       {'_qcode': 'MCCL:OEC'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'R:PVO.HNO'},
#       {'_qcode': 'G:H'},
#       {'_qcode': 'M:1Y3'},
#       {'_qcode': 'R:EQNR.OL'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'G:BR'},
#       {'_qcode': 'M:1ZZ'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'R:VITOLV.UL'},
#       {'_qcode': 'R:QATPE.UL'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'U:9B'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'G:8G'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'R:1605.T'},
#       {'_qcode': 'G:51'},
#       {'_qcode': 'U:9C'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'P:5034844193'},
#       {'_qcode': 'P:5000441056'},
#       {'_qcode': 'P:4296463303'},
#       {'_qcode': 'P:5040145126'},
#       {'_qcode': 'P:4295880574'},
#       {'_qcode': 'P:4295885689'},
#       {'_qcode': 'P:4298459348'},
#       {'_qcode': 'P:5000060264'},
#       {'_qcode': 'P:4296627232'},
#       {'_qcode': 'P:4295880393'},
#       {'_qcode': 'P:4295872684'},
#       {'_qcode': 'P:4295864455'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-13T10:01:54Z'},
#      'versionCreated': {'$': '2021-09-13T10:01:54Z'},
#      'title': [{'$': 'Middle East Crude-Benchmarks slip after buyers get full Saudi allocation'}],
#      'instanceOf': [{'_qcode': '1701'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210913:nPGEZcwkGa:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:CRFO'}, {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:CRF', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:CRF', '_role': 'sRole:source'},
#       {'_qcode': 'NS:CRF', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'M:2CS'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'U:8J'},
#       {'_qcode': 'M:2CY'},
#       {'_qcode': 'R:ADNOC.UL'},
#       {'_qcode': 'U:9T'},
#       {'_qcode': 'U:91'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'G:92'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'U:6B'},
#       {'_qcode': 'M:R'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:1TD'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'G:H'},
#       {'_qcode': 'P:5000061603'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-13T09:57:11.708Z'},
#      'versionCreated': {'$': '2021-09-13T09:57:11.708Z'},
#      'title': [{'$': 'CRF: Middle-East Weekly Crude Oil Flows- Saudi promises full volumes to Asian refiners for Oct'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210913:nS8N2GW078:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:C'},
#       {'_qcode': 'NP:D'},
#       {'_qcode': 'NP:E'},
#       {'_qcode': 'NP:GFN'},
#       {'_qcode': 'NP:GRO'},
#       {'_qcode': 'NP:J'},
#       {'_qcode': 'NP:M'},
#       {'_qcode': 'NP:MF'},
#       {'_qcode': 'NP:MTL'},
#       {'_qcode': 'NP:NAT'},
#       {'_qcode': 'NP:NAW'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:SOF'},
#       {'_qcode': 'NP:T'},
#       {'_qcode': 'NP:U'},
#       {'_qcode': 'NP:UKI'},
#       {'_qcode': 'NP:Z'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'U:C'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'M:2CY'},
#       {'_qcode': 'R:CLC1'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'U:9T'},
#       {'_qcode': 'R:LCOc1'},
#       {'_qcode': 'G:92'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'A:1'},
#       {'_qcode': 'E:C'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'M:E7'},
#       {'_qcode': 'A:9'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'F:8'},
#       {'_qcode': 'M:N'},
#       {'_qcode': 'G:3'},
#       {'_qcode': 'E:5'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:2CX'},
#       {'_qcode': 'G:CG'},
#       {'_qcode': 'G:H'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2D1'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'M:NT'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'G:G'},
#       {'_qcode': 'G:8W'},
#       {'_qcode': 'G:2K'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'M:R'},
#       {'_qcode': 'F:49'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:9T'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:AE'},
#       {'_qcode': 'M:9X'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'U:2R'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:DU'},
#       {'_qcode': 'G:7J'}],
#      'urgency': {'$': 1}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-13T09:45:45.338Z'},
#      'versionCreated': {'$': '2021-09-13T09:45:45.338Z'},
#      'title': [{'$': 'BRENT CRUDE OIL FUTURES <LCOc1> RISE $1 TO $73.92 A BARREL'}],
#      'instanceOf': [{'_qcode': '529'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210913:nS8N2GW077:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:C'},
#       {'_qcode': 'NP:D'},
#       {'_qcode': 'NP:E'},
#       {'_qcode': 'NP:GFN'},
#       {'_qcode': 'NP:GRO'},
#       {'_qcode': 'NP:J'},
#       {'_qcode': 'NP:M'},
#       {'_qcode': 'NP:MF'},
#       {'_qcode': 'NP:MTL'},
#       {'_qcode': 'NP:NAT'},
#       {'_qcode': 'NP:NAW'},
#       {'_qcode': 'NP:O'},
#       {'_qcode': 'NP:OIL'},
#       {'_qcode': 'NP:SOF'},
#       {'_qcode': 'NP:T'},
#       {'_qcode': 'NP:U'},
#       {'_qcode': 'NP:UKI'},
#       {'_qcode': 'NP:Z'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'U:C'},
#       {'_qcode': 'G:4'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'M:2CY'},
#       {'_qcode': 'R:CLC1'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'U:9T'},
#       {'_qcode': 'R:LCOc1'},
#       {'_qcode': 'G:92'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'A:1'},
#       {'_qcode': 'E:C'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'G:9'},
#       {'_qcode': 'M:E7'},
#       {'_qcode': 'A:9'},
#       {'_qcode': 'M:2CQ'},
#       {'_qcode': 'F:8'},
#       {'_qcode': 'M:N'},
#       {'_qcode': 'G:3'},
#       {'_qcode': 'E:5'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'M:2CX'},
#       {'_qcode': 'G:CG'},
#       {'_qcode': 'G:H'},
#       {'_qcode': 'G:6J'},
#       {'_qcode': 'M:2CP'},
#       {'_qcode': 'M:2D1'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'M:NT'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'G:G'},
#       {'_qcode': 'G:8W'},
#       {'_qcode': 'G:2K'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'M:3F'},
#       {'_qcode': 'M:R'},
#       {'_qcode': 'F:49'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'M:9T'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:AE'},
#       {'_qcode': 'M:9X'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'U:2R'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'M:2CN'},
#       {'_qcode': 'M:DU'},
#       {'_qcode': 'G:7J'}],
#      'urgency': {'$': 1}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-13T09:45:27.987Z'},
#      'versionCreated': {'$': '2021-09-13T09:45:27.987Z'},
#      'title': [{'$': 'U.S. CRUDE OIL FUTURES <CLC1> RISE $1 TO $70.72 A BARREL'}],
#      'instanceOf': [{'_qcode': '529'}]}}},
#   {'storyId': 'urn:newsml:reuters.com:20210913:nL4N2QF1YS:1',
#    'newsItem': {'_version': 1,
#     'contentMeta': {'audience': [{'_qcode': 'NP:O'}, {'_qcode': 'NP:OIL'}],
#      'creator': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'}],
#      'infoSource': [{'_qcode': 'NS:RTRS', '_role': 'sRole:source'},
#       {'_qcode': 'NS:RTRS', '_role': 'sRole:origProv'}],
#      'language': [{'_tag': 'en'}],
#      'subject': [{'_qcode': 'G:5B'},
#       {'_qcode': 'U:C'},
#       {'_qcode': 'U:78'},
#       {'_qcode': 'B:2'},
#       {'_qcode': 'R:036460.KS'},
#       {'_qcode': 'U:DR'},
#       {'_qcode': 'R:GGL.UL'},
#       {'_qcode': 'G:3'},
#       {'_qcode': 'G:41'},
#       {'_qcode': 'R:8031.T'},
#       {'_qcode': 'M:258'},
#       {'_qcode': 'R:SASADA.UL'},
#       {'_qcode': 'R:IRPC.BK'},
#       {'_qcode': 'M:2CS'},
#       {'_qcode': 'G:6'},
#       {'_qcode': 'G:AL'},
#       {'_qcode': 'G:CH'},
#       {'_qcode': 'R:GSCAL.UL'},
#       {'_qcode': 'R:GLEN.L'},
#       {'_qcode': 'G:CI'},
#       {'_qcode': 'G:N'},
#       {'_qcode': 'M:1UT'},
#       {'_qcode': 'G:AE'},
#       {'_qcode': 'G:F'},
#       {'_qcode': 'G:3R'},
#       {'_qcode': 'B:1003'},
#       {'_qcode': 'U:45'},
#       {'_qcode': 'R:STO.AX'},
#       {'_qcode': 'U:2R'},
#       {'_qcode': 'B:5'},
#       {'_qcode': 'G:Q'},
#       {'_qcode': 'M:1S8'},
#       {'_qcode': 'MCC:OEC'},
#       {'_qcode': 'R:ONGC.NS'},
#       {'_qcode': 'R:096770.KS'},
#       {'_qcode': 'B:219'},
#       {'_qcode': 'R:CNNCC.UL'},
#       {'_qcode': 'G:A'},
#       {'_qcode': 'R:PERTM.UL'},
#       {'_qcode': 'R:034730.KS'},
#       {'_qcode': 'B:6'},
#       {'_qcode': 'MCCL:OEC'},
#       {'_qcode': 'G:7K'},
#       {'_qcode': 'M:2CT'},
#       {'_qcode': 'R:601857.SS'},
#       {'_qcode': 'R:PETR.UL'},
#       {'_qcode': 'R:RDSa.AS'},
#       {'_qcode': 'G:H'},
#       {'_qcode': 'R:GAZP.MM'},
#       {'_qcode': 'G:AX'},
#       {'_qcode': 'G:7D'},
#       {'_qcode': 'G:B1'},
#       {'_qcode': 'G:S'},
#       {'_qcode': 'G:K'},
#       {'_qcode': 'R:MRPL.NS'},
#       {'_qcode': 'M:NP'},
#       {'_qcode': 'G:2EK'},
#       {'_qcode': 'R:5017.T'},
#       {'_qcode': 'R:VITOLV.UL'},
#       {'_qcode': 'G:7U'},
#       {'_qcode': 'U:24'},
#       {'_qcode': 'B:8'},
#       {'_qcode': 'M:1QD'},
#       {'_qcode': 'G:1'},
#       {'_qcode': 'G:5Z'},
#       {'_qcode': 'R:CVX.N'},
#       {'_qcode': 'A:4'},
#       {'_qcode': 'G:51'},
#       {'_qcode': 'R:SIBN.MM'},
#       {'_qcode': 'P:5034844193'},
#       {'_qcode': 'P:4295864860'},
#       {'_qcode': 'P:5000049504'},
#       {'_qcode': 'P:4295903744'},
#       {'_qcode': 'P:4297272438'},
#       {'_qcode': 'P:4295892850'},
#       {'_qcode': 'P:5040145126'},
#       {'_qcode': 'P:4295880574'},
#       {'_qcode': 'P:4295885039'},
#       {'_qcode': 'P:5000751966'},
#       {'_qcode': 'P:4295882288'},
#       {'_qcode': 'P:4296540346'},
#       {'_qcode': 'P:5000004460'},
#       {'_qcode': 'P:4295887091'},
#       {'_qcode': 'P:4298008784'},
#       {'_qcode': 'P:4295857141'},
#       {'_qcode': 'P:4295880278'},
#       {'_qcode': 'P:4295887074'},
#       {'_qcode': 'P:4296627232'},
#       {'_qcode': 'P:5000068405'},
#       {'_qcode': 'P:4295872684'},
#       {'_qcode': 'P:4297739955'},
#       {'_qcode': 'P:5000067369'},
#       {'_qcode': 'P:4295872506'},
#       {'_qcode': 'P:5000057716'},
#       {'_qcode': 'P:5037653855'},
#       {'_qcode': 'P:5001089539'}],
#      'urgency': {'$': 3}},
#     'itemMeta': {'firstCreated': {'$': '2021-09-13T08:55:37Z'},
#      'versionCreated': {'$': '2021-09-13T08:55:37Z'},
#      'title': [{'$': 'Asia Crude Oil Tenders Summary-Producers offer Nov al-Shaheen, Dai Hung, Kimanis'}],
#      'instanceOf': [{'_qcode': '2258'}]}}}],
#  'meta': {'count': 10,
#   'pageLimit': 10,
#   'next': '',
#   'prev': ''}}

# %% [markdown]
# ## Close the session

# %%
close_session()
