# %% [markdown]
# ----
# <img src="../../../files/refinitiv.png" width="20%" style="vertical-align: top;">
#
# # Data Library for Python
#
# ----

# %% [markdown]
# ## Delivery - OMM Stream - Market By Price data via callback
#
# This notebook demonstrates how to use the OMM Stream interface to request streaming Full Depth Orderbook data

# %% [markdown]
# ## Set the location of the configuration file
# For ease of use, you can set various initialization parameters of the RD Library in the **_refinitiv-data.config.json_** configuration file - as described in the Quick Start -> Sessions example.
#
# ### One config file for the tutorials
# As these tutorial Notebooks are categorised into sub-folders and to avoid the need for multiple config files, we will use the _RD_LIB_CONFIG_PATH_ environment variable to point to a single instance of the config file in the top-level ***Configuration*** folder.
#
# Before proceeding, please **ensure you have entered your credentials** into the config file in the ***Configuration*** folder.

# %%
import os
os.environ["RD_LIB_CONFIG_PATH"] = "../../../Configuration"

# %%
from refinitiv.data.delivery import omm_stream
import refinitiv.data as rd
import datetime
import json

# %% [markdown]
# ## Open the default session
#
# To open the default session ensure you have a '*refinitiv-data.config.json*' in the ***Configuration*** directory, populated with your credentials and specified a 'default' session in the config file

# %%
rd.open_session()
# Out:
# <refinitiv.data.session.platform.Definition object at 0x1ba9ce49fa0 {session_name='rdp'}>

# %% [markdown]
# # Example

# %% [markdown]
# ## Define a function to display events

# %%
# Callback function to display data or status events
def display_event(eventType, event):
    currentTime = datetime.datetime.now().time()
    print("----------------------------------------------------------")
    print(">>> {} event received at {}".format(eventType, currentTime))
    # Print only 1000 characters to limit the output
    print(json.dumps(event, indent=2)[0:1000])
    return

# %% [markdown]
# ## Create an OMM Stream and register the event callbacks

# %%
stream = omm_stream.Definition(name="VOD.L", domain='MarketByPrice').get_stream()

# Refresh - the first full imaage we get back from the server
stream.on_refresh(lambda event, stream : display_event("Refresh", event))
# Update - as and when field values change, we receive updates from the server
stream.on_update(lambda event, stream : display_event("Update", event))
# Status - if data goes stale or item closes, we get a status message
stream.on_status(lambda event, stream : display_event("Status", event))
# Other errors
stream.on_error(lambda event, stream : display_event("Error", event))

# %% [markdown]
# ## Open the Item Stream
# The **open()** call to open the OMM Stream is a synchronous one. This means the first event (either via on_refresh(), on_status() or on_error()) can occur before the open() method returns.
# However, if we use the **open_async()** asynchronous method instead, the first event callback will be after  open_async() returns.

# %%
# Library will request OrderBook from server
stream.open()
# We should intially receive the full orderbook, 
# after which we will receive updates for specific order (Add, Update, Delete)
# Note from the above display_event() function that I am dumping just the first 1000 characters to minimise output
# You should remove this limit to see the full response.
# Out:
# ----------------------------------------------------------
# >>> Refresh event received at 12:31:14.074440
# {
#   "ID": 1,
#   "Type": "Refresh",
#   "Domain": "MarketByPrice",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "State": {
#     "Stream": "Open",
#     "Data": "Ok",
#     "Text": "**All is well"
#   },
#   "Complete": false,
#   "Qos": {
#     "Timeliness": "Realtime",
#     "Rate": "JitConflated"
#   },
#   "PermData": "AwEBJJw=",
#   "SeqNumber": 40736,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "PROD_PERM": 249,
#         "DSPLY_NAME": "VODAFONE GROUP",
#         "CURRENCY": "GBp",
#         "ACTIV_DATE": "2021-11-26",
#         "LOT_SIZE_A": 1,
#         "RECORDTYPE": 113,
#         "SEQNUM": 16976099,
#         "RDN_EXCHD2": "LSE",
#         "PROV_SYMB": "133215",
#         "PR_RNK_RUL": "NOR",
#         "OR_RNK_RUL": "PT  ",
#         "MNEMONIC": "VOD",
#         "PERIOD_CDE": "T",
#         "TRD_TYPE": null,
#         "TIMACT_MS": 45070891,
#         "CONTEXT_ID": 2105,
#         "DDS_DSO_ID": 12477,
#         "SPS_SP_RIC": ".[SPSLSEGTP02L2",
#         "BOOK_STATE": "N",
# <OpenState.Opened: 1>
# ----------------------------------------------------------
# >>> Update event received at 12:31:14.580127
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 40752,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45073867,
#         "SEQNUM": 16976699
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE4QQ==",
#         "Fields": {
#           "ORDER_PRC": 111.18,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 11586,
#           "NO_ORD": 5,
#           "LV_TIM_MS": 45073867
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 12:31:14.921960
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 40880,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45074040,
#         "SEQNUM": 16976800
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE0Qg==",
#         "Fields": {
#           "ORDER_PRC": 111.14,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 24796,
#           "NO_ORD": 4,
#           "LV_TIM_MS": 45073867
#         }
#       },
#       {
#         "Action": "Update",
#         "Key": "MTExLjE4QQ==",
#         "Fields": {
#           "ORDER_PRC": 111.18,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 8522,
#           "NO_ORD": 4,
#           "LV_TIM_MS": 45074040
#         }
#       },
#       {
#         "Action": "Update",
#         "Key": "MTExLjJB",
#         "Fields": {
#           "ORDER_PRC": 111.2,
#           "ORDER_SIDE": "ASK",
#           "
# ----------------------------------------------------------
# >>> Update event received at 12:31:15.282357
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 40928,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45074436,
#         "SEQNUM": 16977054
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjFC",
#         "Fields": {
#           "ORDER_PRC": 111.1,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 47606,
#           "NO_ORD": 12,
#           "LV_TIM_MS": 45074436
#         }
#       },
#       {
#         "Action": "Update",
#         "Key": "MTExQg==",
#         "Fields": {
#           "ORDER_PRC": 111.0,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 45331,
#           "NO_ORD": 10,
#           "LV_TIM_MS": 45074436
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 12:31:16.234560
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 40944,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45075517,
#         "SEQNUM": 16977537
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjJB",
#         "Fields": {
#           "ORDER_PRC": 111.2,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 17134,
#           "NO_ORD": 5,
#           "LV_TIM_MS": 45075517
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 12:31:16.578505
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 41008,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45075617,
#         "SEQNUM": 16977614
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE0Qg==",
#         "Fields": {
#           "ORDER_PRC": 111.14,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 21732,
#           "NO_ORD": 3,
#           "LV_TIM_MS": 45075617
#         }
#       },
#       {
#         "Action": "Update",
#         "Key": "MTExLjE4QQ==",
#         "Fields": {
#           "ORDER_PRC": 111.18,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 12913,
#           "NO_ORD": 6,
#           "LV_TIM_MS": 45075524
#         }
#       },
#       {
#         "Action": "Update",
#         "Key": "MTExLjZB",
#         "Fields": {
#           "ORDER_PRC": 111.6,
#           "ORDER_SIDE": "ASK",
#
# ----------------------------------------------------------
# >>> Update event received at 12:31:17.076925
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 41024,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45076370,
#         "SEQNUM": 16977883
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE4QQ==",
#         "Fields": {
#           "ORDER_PRC": 111.18,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 11586,
#           "NO_ORD": 5,
#           "LV_TIM_MS": 45076370
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 12:31:17.429606
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 41088,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45076629,
#         "SEQNUM": 16977949
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE4QQ==",
#         "Fields": {
#           "ORDER_PRC": 111.18,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 11586,
#           "NO_ORD": 5,
#           "LV_TIM_MS": 45076629
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 12:31:17.784186
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 41104,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45076855,
#         "SEQNUM": 16977984
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE4QQ==",
#         "Fields": {
#           "ORDER_PRC": 111.18,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 12913,
#           "NO_ORD": 6,
#           "LV_TIM_MS": 45076855
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 12:31:18.121026
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 41184,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45077366,
#         "SEQNUM": 16978089
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE0Qg==",
#         "Fields": {
#           "ORDER_PRC": 111.14,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 24796,
#           "NO_ORD": 4,
#           "LV_TIM_MS": 45077265
#         }
#       },
#       {
#         "Action": "Update",
#         "Key": "MTExLjE4QQ==",
#         "Fields": {
#           "ORDER_PRC": 111.18,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 8522,
#           "NO_ORD": 4,
#           "LV_TIM_MS": 45077366
#         }
#       },
#       {
#         "Action": "Update",
#         "Key": "MTExLjJB",
#         "Fields": {
#           "ORDER_PRC": 111.2,
#           "ORDER_SIDE": "ASK",
#           "
# ----------------------------------------------------------
# >>> Update event received at 12:31:18.524344
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 41200,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45077798,
#         "SEQNUM": 16978228
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE4QQ==",
#         "Fields": {
#           "ORDER_PRC": 111.18,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 6325,
#           "NO_ORD": 3,
#           "LV_TIM_MS": 45077798
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 12:31:18.882977
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 41280,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45078065,
#         "SEQNUM": 16978359
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE0Qg==",
#         "Fields": {
#           "ORDER_PRC": 111.14,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 21732,
#           "NO_ORD": 3,
#           "LV_TIM_MS": 45078065
#         }
#       },
#       {
#         "Action": "Update",
#         "Key": "MTExLjE4QQ==",
#         "Fields": {
#           "ORDER_PRC": 111.18,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 10520,
#           "NO_ORD": 5,
#           "LV_TIM_MS": 45078065
#         }
#       },
#       {
#         "Action": "Update",
#         "Key": "MTExLjJB",
#         "Fields": {
#           "ORDER_PRC": 111.2,
#           "ORDER_SIDE": "ASK",
#
# ----------------------------------------------------------
# >>> Update event received at 12:31:19.193329
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 41296,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45078267,
#         "SEQNUM": 16978379
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjZB",
#         "Fields": {
#           "ORDER_PRC": 111.6,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 4448,
#           "NO_ORD": 2,
#           "LV_TIM_MS": 45078267
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 12:31:19.615785
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 41312,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45078889,
#         "SEQNUM": 16978482
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE4QQ==",
#         "Fields": {
#           "ORDER_PRC": 111.18,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 9389,
#           "NO_ORD": 4,
#           "LV_TIM_MS": 45078889
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 12:31:19.952062
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 41440,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45079053,
#         "SEQNUM": 16978552
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE0Qg==",
#         "Fields": {
#           "ORDER_PRC": 111.14,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 24796,
#           "NO_ORD": 4,
#           "LV_TIM_MS": 45078890
#         }
#       },
#       {
#         "Action": "Update",
#         "Key": "MTExLjE4QQ==",
#         "Fields": {
#           "ORDER_PRC": 111.18,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 6325,
#           "NO_ORD": 3,
#           "LV_TIM_MS": 45079053
#         }
#       },
#       {
#         "Action": "Update",
#         "Key": "MTExLjJB",
#         "Fields": {
#           "ORDER_PRC": 111.2,
#           "ORDER_SIDE": "ASK",
#           "
# ----------------------------------------------------------
# >>> Update event received at 12:31:20.706904
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 41456,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45079974,
#         "SEQNUM": 16978715
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE0Qg==",
#         "Fields": {
#           "ORDER_PRC": 111.14,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 21732,
#           "NO_ORD": 3,
#           "LV_TIM_MS": 45079974
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 12:31:21.028202
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 41616,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45080254,
#         "SEQNUM": 16978947
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE0Qg==",
#         "Fields": {
#           "ORDER_PRC": 111.14,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 24796,
#           "NO_ORD": 4,
#           "LV_TIM_MS": 45080064
#         }
#       },
#       {
#         "Action": "Update",
#         "Key": "MTExLjE4QQ==",
#         "Fields": {
#           "ORDER_PRC": 111.18,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 9389,
#           "NO_ORD": 4,
#           "LV_TIM_MS": 45080254
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 12:31:21.379339
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 41696,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45080617,
#         "SEQNUM": 16979163
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE0Qg==",
#         "Fields": {
#           "ORDER_PRC": 111.14,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 21732,
#           "NO_ORD": 3,
#           "LV_TIM_MS": 45080617
#         }
#       },
#       {
#         "Action": "Update",
#         "Key": "MTEwLjc4Qg==",
#         "Fields": {
#           "ORDER_PRC": 110.78,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 5648,
#           "NO_ORD": 3,
#           "LV_TIM_MS": 45080617
#         }
#       },
#       {
#         "Action": "Update",
#         "Key": "MTEwLjc2Qg==",
#         "Fields": {
#           "ORDER_PRC": 110.76,
#           "ORDER_SIDE": "BID",
#
# ----------------------------------------------------------
# >>> Update event received at 12:31:21.713942
# {
#   "ID": 1,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "VOD.L"
#   },
#   "SeqNumber": 41712,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 45080765,
#         "SEQNUM": 16979207
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "MTExLjE4QQ==",
#         "Fields": {
#           "ORDER_PRC": 111.18,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 10716,
#           "NO_ORD": 5,
#           "LV_TIM_MS": 45080765
#         }
#       }
#     ]
#   }
# }

# %% [markdown]
# You may notice that there are multiple Refresh events - this is often the case for the more actively traded instruments with large orders books.
# Once all Refresh events have been received, you can then expect to receive Update events with just the Order changes i.e. Add, Update or Delete orders.
# **NOTE:** I am truncating the output to the 1st 1000 character of each response payload - for ease of viewing.

# %% [markdown]
# ## Close Stream

# %%
stream.close()
# Out:
# <OpenState.Closed: 3>

# %% [markdown]
# ### Close Session

# %%
rd.close_session()
