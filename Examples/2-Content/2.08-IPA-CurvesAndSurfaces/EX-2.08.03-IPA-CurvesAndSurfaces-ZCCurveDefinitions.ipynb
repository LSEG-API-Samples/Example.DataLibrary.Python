# %% [markdown]
# ----
# <div style="display: flex; align-items: center;">
#     <img src="https://developers.lseg.com/content/dam/devportal/icons/logo/lseg-logo.svg" width="20%" style="vertical-align: top;">
#     <h1 style="margin-left: 20px;">Data Library for Python</h1>
# </div>
#
# ----

# %% [markdown]
# ## Content layer - IPA - ZC Curve Definition
# This notebook demonstrates how to retrieve Zero Coupon Curve Definitions.

# %% [markdown]
# #### Learn more
#
# To learn more about the LSEG Data Library for Python please join the LSEG Developer Community. By [registering](https://developers.refinitiv.com/iam/register) and [logging](https://developers.refinitiv.com/content/devportal/en_us/initCookie.html) into the LSEG Developer Community portal you will have free access to a number of learning materials
#  on the [LSEG Developer Portal](https://developers.lseg.com/en)
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# the [LSEG Data Q&A Forum](https://community.developers.refinitiv.com/spaces/321/index.html).
# The LSEG Developer Community will be happy to help.

# %% [markdown]
# ## Set the configuration file location
# For a better ease of use, you have the option to set initialization parameters of the LSEG Data Library in the _lseg-data.config.json_ configuration file. This file must be located beside your notebook, in your user folder or in a folder defined by the _LD_LIB_CONFIG_PATH_ environment variable. The _LD_LIB_CONFIG_PATH_ environment variable is the option used by this series of examples. The following code sets this environment variable.

# %%
import os
os.environ["LD_LIB_CONFIG_PATH"] = "../../../Configuration"

# %% [markdown]
# ## Some Imports to start with

# %%
import lseg.data as ld
from lseg.data.content.ipa.curves import zc_curve_definitions

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the lseg-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x10b4708b0 {name='workspace'}>

# %% [markdown]
# ## Retrieve data

# %%
response = zc_curve_definitions.Definition(source="Refinitiv").get_data()
response.data.df
# Out:
#    currency mainConstituentAssetClass      riskType indexName     source  \
# 0       AED                      Swap  InterestRate    AEIBOR  Refinitiv
# 1       AED                   Deposit  InterestRate    AEIBOR  Refinitiv
# 2       AUD                      Swap  InterestRate     AONIA  Refinitiv
# 3       AUD                      Swap  InterestRate      BBSW  Refinitiv
# 4       AUD                      Swap  InterestRate      BBSW  Refinitiv
# ..      ...                       ...           ...       ...        ...
# 92      USD                      Swap  InterestRate      SOFR  Refinitiv
# 93      USD                   Futures  InterestRate      SOFR  Refinitiv
# 94      VND                      Swap  InterestRate    VNIBOR  Refinitiv
# 95      ZAR                   Deposit  InterestRate     JIBAR  Refinitiv
# 96      ZAR                      Swap  InterestRate     JIBAR  Refinitiv
#
#                              name firstHistoricalAvailabilityDate  \
# 0        AED AEIBOR Swap ZC Curve                      2016-12-07
# 1             AED Depo, IRS vs 3M                      2013-03-07
# 2         AUD AONIA Swap ZC Curve                      2016-11-07
# 3   AUD BBSW (EMEA) Swap ZC Curve                      2016-11-07
# 4          AUD BBSW Swap ZC Curve                      2016-11-07
# ..                            ...                             ...
# 92         USD SOFR Swap ZC Curve                      2020-06-17
# 93        USD SRA Future ZC Curve                      2018-05-04
# 94    VND VNDVNIBOR Swap ZC Curve                      2020-06-24
# 95            ZAR Depo, IRS vs 3M                      2007-07-09
# 96        ZAR JIBAR Swap ZC Curve                      2007-07-09
#
#                                       id      owner    availableTenors  \
# 0   95da64b1-e96f-4d60-8df1-63d8484017d6  Refinitiv       [3M, 6M, 1Y]
# 1   13774131-76cf-4ffb-9b69-2faad16f5254  Refinitiv               [3M]
# 2   9b694f33-df76-46ca-901e-53e917863d67  Refinitiv              [OIS]
# 3   083d08c9-e049-4c3f-997e-f29c0f5b82f4  Refinitiv  [OIS, 1M, 3M, 6M]
# 4   a69788a8-114a-476a-998e-48404dab43ee  Refinitiv  [OIS, 1M, 3M, 6M]
# ..                                   ...        ...                ...
# 92  34d8c1f9-8fd1-4ca3-bb37-5464c41de2f7  Refinitiv              [OIS]
# 93  a9e53645-bcf6-4372-86d5-5a2eb559c121  Refinitiv              [OIS]
# 94  34505484-6279-430e-a219-62aa97e03b15  Refinitiv               [3M]
# 95  9ad13c47-d9a1-4a6c-b0a5-9d780d5e952d  Refinitiv               [3M]
# 96  cddabbc7-5e83-4c01-93d7-51da53ee6f64  Refinitiv               [3M]
#
#    availableDiscountingTenors marketDataLocation
# 0                [3M, 6M, 1Y]               <NA>
# 1                        [3M]               <NA>
# 2                       [OIS]               <NA>
# 3           [OIS, 1M, 3M, 6M]               EMEA
# 4           [OIS, 1M, 3M, 6M]               <NA>
# ..                        ...                ...
# 92                      [OIS]               <NA>
# 93                      [OIS]               <NA>
# 94                       [3M]               <NA>
# 95                       [3M]               <NA>
# 96                       [3M]               <NA>
#
# [97 rows x 12 columns]

# %% [markdown]
# ## Close the session

# %%
ld.close_session()
