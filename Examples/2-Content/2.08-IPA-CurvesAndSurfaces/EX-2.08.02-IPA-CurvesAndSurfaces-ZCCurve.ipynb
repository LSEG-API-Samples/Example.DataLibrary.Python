# %% [markdown]
# # Refinitiv Data Library for Python

# %% [markdown]
# ## Content layer - IPA - ZC Curve
# This notebook demonstrates how to retrieve Zero Coupon Curves.

# %% [markdown]
# #### Learn more
#
# To learn more about the Refinitiv Data Library for Python please join the Refinitiv Developer Community. By [registering](https://developers.refinitiv.com/iam/register) and [logging](https://developers.refinitiv.com/content/devportal/en_us/initCookie.html) into the Refinitiv Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/quick-start),
#  [Tutorials](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/learning),
#  [Documentation](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/docs)
#  and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# the [Refinitiv Data Q&A Forum](https://community.developers.refinitiv.com/spaces/321/index.html).
# The Refinitiv Developer Community will be happy to help.

# %% [markdown]
# ## Set the configuration file location
# For a better ease of use, you have the option to set initialization parameters of the Refinitiv Data Library in the _refinitiv-data.config.json_ configuration file. This file must be located beside your notebook, in your user folder or in a folder defined by the _RD_LIB_CONFIG_PATH_ environment variable. The _RD_LIB_CONFIG_PATH_ environment variable is the option used by this series of examples. The following code sets this environment variable.

# %%
import os
os.environ["RD_LIB_CONFIG_PATH"] = "../../../Configuration"

# %% [markdown]
# ## Some Imports to start with

# %%
import refinitiv.data as rd
from refinitiv.data.content.ipa.curves import zc_curve

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the refinitiv-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
rd.open_session()
# Out:
# <refinitiv.data.session.Definition object at 0x7fb21b304bd0 {name='workspace'}>

# %% [markdown]
# ## Retrieve data

# %%
response = zc_curve.Definition(
    constituents={},
    curve_parameters=zc_curve.ZcCurveParameters(
        valuation_date="2019-08-21",
        price_side="Mid",
        interpolation_mode=zc_curve.ZcInterpolationMode.CUBIC_DISCOUNT,
    ),
    curve_definition=zc_curve.ZcCurveDefinitions(
        currency="EUR",
        index_name="EURIBOR",
        source="Refinitiv",
        discounting_tenor="OIS",
    ),
    curve_tag="TAG",
).get_data()

response.data.df
# Out:
#                                instruments tenor  discountFactor     endDate  \
# 0                                     None    0D             1.0  2019-08-21
# 1          [{'instrumentCode': 'EUROND='}]    ON         1.00001  2019-08-22
# 2          [{'instrumentCode': 'EURTND='}]    TN        1.000023  2019-08-23
# 3    [{'instrumentCode': 'EUREONSW=ICAP'}]    SW        1.000093  2019-08-30
# 4    [{'instrumentCode': 'EUREON2W=ICAP'}]    2W        1.000163  2019-09-06
# 5    [{'instrumentCode': 'EUREON3W=ICAP'}]    3W        1.000233  2019-09-13
# 6    [{'instrumentCode': 'EUREON1M=ICAP'}]    1M        1.000354  2019-09-23
# 7    [{'instrumentCode': 'EUREON2M=ICAP'}]    2M        1.000776  2019-10-23
# 8    [{'instrumentCode': 'EUREON3M=ICAP'}]    3M        1.001266  2019-11-25
# 9    [{'instrumentCode': 'EUREON4M=ICAP'}]    4M        1.001686  2019-12-23
# 10   [{'instrumentCode': 'EUREON5M=ICAP'}]    5M        1.002199  2020-01-23
# 11   [{'instrumentCode': 'EUREON6M=ICAP'}]    6M        1.002746  2020-02-24
# 12   [{'instrumentCode': 'EUREON7M=ICAP'}]    7M        1.003228  2020-03-23
# 13   [{'instrumentCode': 'EUREON8M=ICAP'}]    8M        1.003792  2020-04-23
# 14   [{'instrumentCode': 'EUREON9M=ICAP'}]    9M        1.004395  2020-05-25
# 15  [{'instrumentCode': 'EUREON10M=ICAP'}]   10M        1.004944  2020-06-23
# 16  [{'instrumentCode': 'EUREON11M=ICAP'}]   11M        1.005534  2020-07-23
# 17   [{'instrumentCode': 'EUREON1Y=ICAP'}]    1Y         1.00617  2020-08-24
# 18  [{'instrumentCode': 'EUREON15M=ICAP'}]  1Y3M        1.008014  2020-11-23
# 19  [{'instrumentCode': 'EUREON18M=ICAP'}]  1Y6M         1.00992  2021-02-23
# 20  [{'instrumentCode': 'EUREON19M=TTKL'}]  1Y7M        1.010525  2021-03-23
# 21  [{'instrumentCode': 'EUREON20M=TTKL'}]  1Y8M        1.011177  2021-04-23
# 22  [{'instrumentCode': 'EUREON21M=ICAP'}]  1Y9M        1.011769  2021-05-24
# 23   [{'instrumentCode': 'EUREON2Y=ICAP'}]    2Y        1.013639  2021-08-23
# 24   [{'instrumentCode': 'EUREON3Y=ICAP'}]    3Y        1.021038  2022-08-23
# 25   [{'instrumentCode': 'EUREON4Y=ICAP'}]    4Y         1.02822  2023-08-23
# 26   [{'instrumentCode': 'EUREON5Y=ICAP'}]    5Y         1.03447  2024-08-23
# 27   [{'instrumentCode': 'EUREON6Y=ICAP'}]    6Y        1.039508  2025-08-25
# 28   [{'instrumentCode': 'EUREON7Y=ICAP'}]    7Y        1.043345  2026-08-24
# 29   [{'instrumentCode': 'EUREON8Y=ICAP'}]    8Y        1.045541  2027-08-23
# 30   [{'instrumentCode': 'EUREON9Y=ICAP'}]    9Y        1.046348  2028-08-23
# 31  [{'instrumentCode': 'EUREON10Y=ICAP'}]   10Y        1.046329  2029-08-23
# 32  [{'instrumentCode': 'EUREON11Y=ICAP'}]   11Y        1.045013  2030-08-23
# 33  [{'instrumentCode': 'EUREON12Y=ICAP'}]   12Y        1.042951  2031-08-25
# 34  [{'instrumentCode': 'EUREON15Y=ICAP'}]   15Y        1.032937  2034-08-23
# 35  [{'instrumentCode': 'EUREON20Y=ICAP'}]   20Y        1.017192  2039-08-23
# 36  [{'instrumentCode': 'EUREON25Y=ICAP'}]   25Y        1.006538  2044-08-23
# 37  [{'instrumentCode': 'EUREON30Y=ICAP'}]   30Y        1.003761  2049-08-23
# 38  [{'instrumentCode': 'EUREON40Y=ICAP'}]   40Y        1.013273  2059-08-25
# 39  [{'instrumentCode': 'EUREON50Y=ICAP'}]   50Y        1.032115  2069-08-23
#
#     ratePercent   startDate
# 0     -0.379488  2019-08-21
# 1     -0.379488  2019-08-21
# 2     -0.417358  2019-08-21
# 3     -0.376916  2019-08-21
# 4     -0.370102  2019-08-21
# 5     -0.368981  2019-08-21
# 6     -0.390381  2019-08-21
# 7     -0.448309  2019-08-21
# 8     -0.479746  2019-08-21
# 9     -0.494717  2019-08-21
# 10    -0.516029  2019-08-21
# 11    -0.533839  2019-08-21
# 12    -0.547163  2019-08-21
# 13    -0.561533  2019-08-21
# 14    -0.575694  2019-08-21
# 15    -0.586246  2019-08-21
# 16    -0.597596  2019-08-21
# 17    -0.608259  2019-08-21
# 18     -0.63276  2019-08-21
# 19    -0.651784  2019-08-21
# 20    -0.657362  2019-08-21
# 21    -0.662535  2019-08-21
# 22    -0.663757  2019-08-21
# 23    -0.673221  2019-08-21
# 24     -0.69032  2019-08-21
# 25    -0.692359  2019-08-21
# 26    -0.674763  2019-08-21
# 27    -0.642547  2019-08-21
# 28    -0.603624  2019-08-21
# 29     -0.55475  2019-08-21
# 30    -0.501828  2019-08-21
# 31    -0.451607  2019-08-21
# 32    -0.399269  2019-08-21
# 33    -0.349523  2019-08-21
# 34    -0.215729  2019-08-21
# 35    -0.085168  2019-08-21
# 36    -0.026058  2019-08-21
# 37    -0.012509  2019-08-21
# 38    -0.032949  2019-08-21
# 39    -0.063194  2019-08-21

# %% [markdown]
# ## Close the session

# %%
rd.close_session()
