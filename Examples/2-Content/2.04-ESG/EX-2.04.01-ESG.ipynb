# %% [markdown]
# ----
# <img src="../../../files/refinitiv.png" width="20%" style="vertical-align: top;">
#
# # Data Library for Python
#
# ----

# %% [markdown]
# ## Content layer - Environmental Social and Governance (ESG)
# This notebook demonstrates how to retrieve Environmental Social and Governance data.

# %% [markdown]
# #### Learn more
#
# To learn more about the Refinitiv Data Library for Python please join the Refinitiv Developer Community. By [registering](https://developers.refinitiv.com/iam/register) and [logging](https://developers.refinitiv.com/content/devportal/en_us/initCookie.html) into the Refinitiv Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/quick-start),
#  [Tutorials](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/learning),
#  [Documentation](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/docs)
#  and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# the [Refinitiv Data Q&A Forum](https://community.developers.refinitiv.com/spaces/321/index.html).
# The Refinitiv Developer Community will be happy to help.

# %% [markdown]
# ## Set the configuration file location
# For a better ease of use, you have the option to set initialization parameters of the Refinitiv Data Library in the _refinitiv-data.config.json_ configuration file. This file must be located beside your notebook, in your user folder or in a folder defined by the _RD_LIB_CONFIG_PATH_ environment variable. The _RD_LIB_CONFIG_PATH_ environment variable is the option used by this series of examples. The following code sets this environment variable.

# %%
import os
os.environ["RD_LIB_CONFIG_PATH"] = "../../../Configuration"

# %% [markdown]
# ## Some Imports to start with

# %%
import refinitiv.data as rd
from refinitiv.data.content import esg

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the refinitiv-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
rd.open_session('platform.rdp')
# Out:
# <refinitiv.data.session.platform.Definition object at 0x7fb7f8284290 {session_name='rdp'}>

# %% [markdown]
# ## Retrieve data

# %% [markdown]
# ### Get all universe

# %%
response = esg.universe.Definition().get_data()
response.data.df
# Out:
#       TR.OrganizationID TR.PrimaryRIC  \
# 0            4295533401       RST^J20
# 1            4295613014    PWF.TO^B20
# 2            4295641240          KE.O
# 3            4295856018       PATA.BA
# 4            4295856019       COME.BA
# ...                 ...           ...
# 11744        8589934336    BSAN.S^E13
# 11745        8589934339           BAC
# 11746        8589934340          AV.L
# 11747        8589934377        SNBN.S
# 11748        8589934459       BOGr.AT
#
#                                       TR.CommonName
# 0                                 Rosetta Stone Inc
# 1                              Power Financial Corp
# 2                           Kimball Electronics Inc
# 3      Importadora y Exportadora de la Patagonia SA
# 4                   Sociedad Comercial del Plata SA
# ...                                             ...
# 11744                       Bank J Safra Sarasin AG
# 11745                          Bank of America Corp
# 11746                                     Aviva PLC
# 11747                   Schweizerische Nationalbank
# 11748                                Bank of Greece
#
# [11749 rows x 3 columns]

# %% [markdown]
# ### Basic Overview for one instrument

# %%
response = esg.basic_overview.Definition("MSFT.O").get_data()
response.data.df
# Out:
#   instrument periodenddate TR.CSRReportingScope  \
# 0     MSFT.O    2020-06-30                  100
#
#   TR.CSRReportingExternalAuditName TR.ESGPeriodLastUpdateDate  \
# 0              Apex Companies, LLC        2021-12-09T00:00:00
#
#   TR.CO2EmissionTotal TR.WomenManagers
# 0             4220550             26.3

# %% [markdown]
# ### Standard Scores

# %%
response = esg.standard_scores.Definition("6758.T").get_data()
response.data.df
# Out:
#   instrument periodenddate    TR.TRESGCScore     TR.TRESGScore  \
# 0     6758.T    2020-03-31  48.1554496470698  82.4220104052507
# 1     6758.T    2019-03-31  78.4837562477529  81.9675124955058
# 2     6758.T    2018-03-31  83.5213946217964  83.5213946217964
#
#   TR.TRESGCConvroversiesScore TR.EnvironmentPillarScore TR.SocialPillarScore  \
# 0            13.8888888888888          85.5531724448061     73.3011274466503
# 1                          75          85.1619047619047     73.1641212673808
# 2                         100          87.2218362282878     75.1605080105204
#
#   TR.GovernancePillarScore TR.TRESGResourceUseScore TR.TRESGEmissionsScore  \
# 0         96.0782833151254         82.3170731707317        98.235294117647
# 1         95.0048999636631                    81.25       99.2857142857142
# 2         95.3479410731626         83.8461538461538       99.1935483870967
#
#    ... TR.TRESGWorkforceScore TR.TRESGHumanRightsScore TR.TRESGCommunityScore  \
# 0  ...       97.3684210526315         43.6708860759493       95.2631578947368
# 1  ...       98.1707317073171                       45       95.7317073170731
# 2  ...        94.078947368421         51.7543859649122       96.7105263157894
#
#   TR.TRESGProductResponsibilityScore TR.TRESGManagementScore  \
# 0                   81.3186813186813        99.2521367521367
# 1                   77.3333333333333        98.5900216919739
# 2                   78.0821917808219        98.3031674208144
#
#   TR.TRESGShareholdersScore TR.TRESGCSRStrategyScore TR.CSRReportingScope  \
# 0          84.7222222222222         97.2431077694235                  100
# 1          81.6702819956616         97.0812182741116                  100
# 2          90.1583710407239         88.3561643835616                   44
#
#   TR.CSRReportingExternalAuditName TR.ESGPeriodLastUpdateDate
# 0      Bureau Veritas Japan Co Ltd        2021-12-09T00:00:00
# 1    Bureau Veritas Japan Co., Ltd        2021-07-16T00:00:00
# 2                   Bureau Veritas        2021-02-12T00:00:00
#
# [3 rows x 21 columns]

# %%
response = esg.standard_scores.Definition('AAPL.O').get_data()
response.data.df
# Out:
#   instrument periodenddate    TR.TRESGCScore     TR.TRESGScore  \
# 0     AAPL.O    2020-09-26  38.3723103192643  73.9668428607508
# 1     AAPL.O    2019-09-28  36.0964717707038  67.1929435414077
# 2     AAPL.O    2018-09-29  37.8825851393841  70.7651702787683
#
#   TR.TRESGCConvroversiesScore TR.EnvironmentPillarScore TR.SocialPillarScore  \
# 0            2.77777777777777          59.6934666695218     75.6879720800969
# 1                           5          57.1873015873015     63.8193906238127
# 2                           5          57.8290598290598     68.3745314188043
#
#   TR.GovernancePillarScore TR.TRESGResourceUseScore TR.TRESGEmissionsScore  \
# 0         82.7919759122745         93.2926829268292       87.6470588235294
# 1          81.547147872874         92.3611111111111       86.4285714285714
# 2         85.8085682871279         96.1538461538461                     75
#
#    ... TR.TRESGWorkforceScore TR.TRESGHumanRightsScore TR.TRESGCommunityScore  \
# 0  ...       81.5789473684211         82.9113924050632       72.1052631578947
# 1  ...       72.5609756097561         58.3333333333333       70.1219512195121
# 2  ...       75.6578947368421         67.5438596491228       69.7368421052631
#
#   TR.TRESGProductResponsibilityScore TR.TRESGManagementScore  \
# 0                   60.9890109890109        84.8278985507246
# 1                   59.3333333333333        83.5780402170443
# 2                   61.6438356164383        89.1688918558077
#
#   TR.TRESGShareholdersScore TR.TRESGCSRStrategyScore TR.CSRReportingScope  \
# 0          79.1817632850241         78.0276816608996                  100
# 1          77.8327481646983         76.9642857142857                  100
# 2          81.2249666221628         75.8823529411764                  100
#
#                    TR.CSRReportingExternalAuditName TR.ESGPeriodLastUpdateDate
# 0                Fraunhofer IZM, Apex Companies LLC        2021-12-09T00:00:00
# 1                Apex Companies LLC, Fraunhofer IZM        2021-11-05T00:00:00
# 2  Fraunhofer IZM, Bureau Veritas North America Inc        2021-08-28T00:00:00
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Full Scores

# %%
response = esg.full_scores.Definition(
    universe="4295904307",
    start=0, 
    end=-5
).get_data()

response.data.df
# Out:
#    instrument periodenddate    TR.TRESGCScore     TR.TRESGScore  \
# 0  4295904307    2020-12-31  73.3005404816844  73.3005404816844
# 1  4295904307    2019-12-31  71.0168728662629  71.0168728662629
# 2  4295904307    2018-12-31  80.5248642967012  80.5248642967012
# 3  4295904307    2017-12-31  77.1959167718654  77.1959167718654
# 4  4295904307    2016-12-31  76.0876726774966  76.0876726774966
# 5  4295904307    2015-12-31  73.1134441146797  81.0094969250116
#
#   TR.TRESGCControversiesScore TR.EnvironmentPillarScore TR.SocialPillarScore  \
# 0                         100          78.9800773596806      96.625022435838
# 1            81.9672131147541          79.6280934587128     97.8935711423807
# 2                         100          78.6786497258389     97.7776230076168
# 3                       83.75          79.0203367079219     97.8716457177097
# 4            77.5862068965517          79.7944810331058     96.3880478572182
# 5            65.2173913043478          80.5281474978444     94.2391635609935
#
#   TR.GovernancePillarScore TR.TRESGResourceUseScore TR.TRESGEmissionsScore  \
# 0         51.5117088466531         98.9825581395348       99.3093922651933
# 1         45.2896831729819         98.6641221374045       99.8039215686274
# 2         66.2221864446713         98.2233502538071       98.0769230769231
# 3         58.8444908654602         97.7419354838709       97.5862068965517
# 4         57.4947515438312         96.0144927536231       98.8372093023255
# 5         69.7616888166218         97.1074380165289       99.5726495726495
#
#   TR.TRESGInnovationScore TR.TRESGWorkforceScore TR.TRESGHumanRightsScore  \
# 0        53.8135593220339       99.6099843993759         83.3850931677018
# 1        55.2631578947368       99.5107632093933         91.0869565217391
# 2        54.3209876543209       97.7594339622641         93.5028248587571
# 3        55.6962025316455       97.4666666666666         93.6090225563909
# 4        58.1081081081081       98.2026143790849         85.6435643564356
# 5        58.5714285714285       96.9262295081967         76.6666666666666
#
#   TR.TRESGCommunityScore TR.TRESGProductResponsibilityScore  \
# 0       99.4539781591263                   98.1574539363484
# 1       99.3150684931506                   98.6754966887417
# 2        98.938679245283                   98.5372340425531
# 3       99.3333333333333                   98.4520123839009
# 4       98.8562091503268                   97.7695167286245
# 5       97.7459016393442                   97.3933649289099
#
#   TR.TRESGManagementScore TR.TRESGShareholdersScore TR.TRESGCSRStrategyScore  \
# 0        39.6890096618357            78.06461352657          70.795847750865
# 1        27.5933609958506          74.3217363549313         90.2232142857142
# 2        58.6615487316421           75.650867823765         89.8823529411764
# 3        53.5984848484848          69.0599173553719         69.7513812154696
# 4        53.1746031746031          63.5993135993136         69.9386503067484
# 5        70.6662553979025          66.8414558914251         69.6192052980132
#
#   TR.CSRReportingScope TR.ESGPeriodLastUpdateDate
# 0                  100        2021-08-28T00:00:00
# 1                  100        2021-08-21T00:00:00
# 2                  100        2020-10-03T00:00:00
# 3                  100        2021-08-21T00:00:00
# 4                  100        2021-08-21T00:00:00
# 5                  100        2021-08-21T00:00:00

# %% [markdown]
# ### Standard Measures

# %%
response = esg.standard_measures.Definition("BNPP.PA").get_data()

response.data.df
# Out:
#   instrument periodenddate  TR.TRESGCScore  TR.TRESGScore  \
# 0    BNPP.PA    2020-12-31       59.827224      92.697927
# 1    BNPP.PA    2019-12-31       55.720616      94.094293
# 2    BNPP.PA    2018-12-31       75.389727       93.98933
#
#    TR.TRESGCControversiesScore  TR.EnvironmentPillarScore  \
# 0                    26.956522                  94.538996
# 1                    17.346939                  94.805462
# 2                    56.790123                  95.201468
#
#    TR.SocialPillarScore  TR.GovernancePillarScore  TR.TRESGResourceUseScore  \
# 0             96.105758                 87.266265                 86.645963
# 1             96.414931                   90.6125                 82.593458
# 2             96.460391                 90.099903                 82.909605
#
#    TR.TRESGEmissionsScore  ...  TR.SustainabilityComm  \
# 0                93.45351  ...                   True
# 1               97.032967  ...                   True
# 2                97.39011  ...                   True
#
#    TR.IntegratedStrategyMD&A  TR.GlobalCompact  TR.StakeholderEngagement  \
# 0                      False              True                      True
# 1                      False              True                      True
# 2                      False              True                      True
#
#    TR.CSRReporting  TR.CSRReportingGRI  TR.CSRReportingGlobalActivities  \
# 0             True                True                            False
# 1             True                True                             True
# 2             True                True                             True
#
#    TR.CSRReportingExternalAudit TR.CSRReportingExternalAuditName  \
# 0                          True     PricewaterhouseCoopers Audit
# 1                          True     PricewaterhouseCoopers Audit
# 2                          True     PricewaterhouseCoopers Audit
#
#   TR.CSRReportingScope
# 0               33.824
# 1                 90.0
# 2                 77.0
#
# [3 rows x 311 columns]

# %% [markdown]
# ### Full Measures

# %%
response = esg.full_measures.Definition("BNPP.PA").get_data()
response.data.df
# Out:
#    instrument periodenddate  TR.TRESGCScore  TR.TRESGScore  \
# 0     BNPP.PA    2020-12-31       59.827224      92.697927
# 1     BNPP.PA    2019-12-31       55.720616      94.094293
# 2     BNPP.PA    2018-12-31       75.389727       93.98933
# 3     BNPP.PA    2017-12-31       53.725052       94.25566
# 4     BNPP.PA    2016-12-31       86.370281      91.754646
# 5     BNPP.PA    2015-12-31         53.3599      91.502409
# 6     BNPP.PA    2014-12-31        49.76454      80.862414
# 7     BNPP.PA    2013-12-31       50.130448      82.359661
# 8     BNPP.PA    2013-12-31            <NA>           <NA>
# 9     BNPP.PA    2013-12-31            <NA>           <NA>
# 10    BNPP.PA    2012-12-31       82.323558      82.323558
# 11    BNPP.PA    2012-12-31            <NA>           <NA>
# 12    BNPP.PA    2011-12-31       54.377574      72.326576
# 13    BNPP.PA    2011-12-31            <NA>           <NA>
# 14    BNPP.PA    2011-12-31            <NA>           <NA>
# 15    BNPP.PA    2011-12-31            <NA>           <NA>
# 16    BNPP.PA    2011-12-31            <NA>           <NA>
# 17    BNPP.PA    2011-12-31            <NA>           <NA>
# 18    BNPP.PA    2010-12-31       72.338463      74.042006
# 19    BNPP.PA    2009-12-31       50.146242      69.181373
# 20    BNPP.PA    2009-12-31            <NA>           <NA>
# 21    BNPP.PA    2009-12-31            <NA>           <NA>
# 22    BNPP.PA    2009-12-31            <NA>           <NA>
# 23    BNPP.PA    2009-12-31            <NA>           <NA>
# 24    BNPP.PA    2009-12-31            <NA>           <NA>
# 25    BNPP.PA    2008-12-31       57.459376      67.299705
# 26    BNPP.PA    2008-12-31            <NA>           <NA>
# 27    BNPP.PA    2008-12-31            <NA>           <NA>
# 28    BNPP.PA    2007-12-31       69.524986      69.524986
# 29    BNPP.PA    2006-12-31       45.875919      72.054869
# 30    BNPP.PA    2005-12-31       56.754917      56.754917
# 31    BNPP.PA    2004-12-31       43.080526      43.080526
# 32    BNPP.PA    2003-12-31        45.92352       45.92352
# 33    BNPP.PA    2002-12-31       37.669694      37.669694
#
#     TR.TRESGCControversiesScore  TR.EnvironmentPillarScore  \
# 0                     26.956522                  94.538996
# 1                     17.346939                  94.805462
# 2                     56.790123                  95.201468
# 3                     13.194444                  95.615879
# 4                     80.985915                  88.177435
# 5                     15.217391                  95.887564
# 6                     18.666667                  95.342314
# 7                     17.901235                  94.269132
# 8                          <NA>                       <NA>
# 9                          <NA>                       <NA>
# 10                    90.909091                  93.460796
# 11                         <NA>                       <NA>
# 12                    36.428571                  92.276231
# 13                         <NA>                       <NA>
# 14                         <NA>                       <NA>
# 15                         <NA>                       <NA>
# 16                         <NA>                       <NA>
# 17                         <NA>                       <NA>
# 18                    70.634921                  94.259919
# 19                    31.111111                  92.751339
# 20                         <NA>                       <NA>
# 21                         <NA>                       <NA>
# 22                         <NA>                       <NA>
# 23                         <NA>                       <NA>
# 24                         <NA>                       <NA>
# 25                    47.619048                  85.744262
# 26                         <NA>                       <NA>
# 27                         <NA>                       <NA>
# 28                        100.0                  85.934758
# 29                     19.69697                  82.494517
# 30                        100.0                   42.11507
# 31                        100.0                  30.670136
# 32                    77.777778                  57.539683
# 33                        100.0                  36.730296
#
#     TR.SocialPillarScore  TR.GovernancePillarScore  TR.TRESGResourceUseScore  \
# 0              96.105758                 87.266265                 86.645963
# 1              96.414931                   90.6125                 82.593458
# 2              96.460391                 90.099903                 82.909605
# 3               97.57783                  89.13436                 80.169492
# 4              97.109624                  85.80756                 80.639098
# 5              96.380085                 84.639175                  96.95122
# 6              79.071144                 78.877193                 98.017621
# 7              79.071834                 83.691756                 96.606335
# 8                   <NA>                      <NA>                      <NA>
# 9                   <NA>                      <NA>                      <NA>
# 10             78.412211                 84.982079                 96.919431
# 11                  <NA>                      <NA>                      <NA>
# 12             66.402162                  74.23648                     87.75
# 13                  <NA>                      <NA>                      <NA>
# 14                  <NA>                      <NA>                      <NA>
# 15                  <NA>                      <NA>                      <NA>
# 16                  <NA>                      <NA>                      <NA>
# 17                  <NA>                      <NA>                      <NA>
# 18               60.2062                 86.309452                 91.315789
# 19             49.127037                 88.104504                 82.142857
# 20                  <NA>                      <NA>                      <NA>
# 21                  <NA>                      <NA>                      <NA>
# 22                  <NA>                      <NA>                      <NA>
# 23                  <NA>                      <NA>                      <NA>
# 24                  <NA>                      <NA>                      <NA>
# 25             50.708183                 85.492424                 72.619048
# 26                  <NA>                      <NA>                      <NA>
# 27                  <NA>                      <NA>                      <NA>
# 28             57.922609                 80.184012                 61.881188
# 29             66.580159                 86.311688                 78.289474
# 30             68.586083                 56.535088                 50.724638
# 31             53.670516                 43.779843                 15.740741
# 32             48.991935                 47.338061                       0.0
# 33              48.90121                 33.404255                 29.310345
#
#     TR.TRESGEmissionsScore  ...  TR.SustainabilityComm  \
# 0                 93.45351  ...                   True
# 1                97.032967  ...                   True
# 2                 97.39011  ...                   True
# 3                97.854785  ...                   True
# 4                97.940075  ...                   True
# 5                98.185484  ...                   True
# 6                97.136564  ...                   True
# 7                96.681416  ...                   True
# 8                     <NA>  ...                   <NA>
# 9                     <NA>  ...                   <NA>
# 10               94.266055  ...                   True
# 11                    <NA>  ...                   <NA>
# 12               91.314554  ...                   True
# 13                    <NA>  ...                   <NA>
# 14                    <NA>  ...                   <NA>
# 15                    <NA>  ...                   <NA>
# 16                    <NA>  ...                   <NA>
# 17                    <NA>  ...                   <NA>
# 18               92.364532  ...                   True
# 19               85.260116  ...                   True
# 20                    <NA>  ...                   <NA>
# 21                    <NA>  ...                   <NA>
# 22                    <NA>  ...                   <NA>
# 23                    <NA>  ...                   <NA>
# 24                    <NA>  ...                   <NA>
# 25               75.179856  ...                   True
# 26                    <NA>  ...                   <NA>
# 27                    <NA>  ...                   <NA>
# 28               68.932039  ...                  False
# 29               83.766234  ...                  False
# 30               48.591549  ...                  False
# 31               13.392857  ...                  False
# 32                     0.0  ...                  False
# 33               28.571429  ...                  False
#
#     TR.IntegratedStrategyMD&A  TR.GlobalCompact  TR.StakeholderEngagement  \
# 0                       False              True                      True
# 1                       False              True                      True
# 2                       False              True                      True
# 3                        <NA>              True                      True
# 4                        <NA>              True                      True
# 5                        <NA>              True                      True
# 6                        <NA>              True                      True
# 7                        <NA>              True                      True
# 8                        <NA>              <NA>                      <NA>
# 9                        <NA>              <NA>                      <NA>
# 10                       <NA>              True                      True
# 11                       <NA>              <NA>                      <NA>
# 12                      False              True                      True
# 13                       <NA>              <NA>                      <NA>
# 14                       <NA>              <NA>                      <NA>
# 15                       <NA>              <NA>                      <NA>
# 16                       <NA>              <NA>                      <NA>
# 17                       <NA>              <NA>                      <NA>
# 18                      False              True                      True
# 19                       <NA>              True                      True
# 20                       <NA>              <NA>                      <NA>
# 21                       <NA>              <NA>                      <NA>
# 22                       <NA>              <NA>                      <NA>
# 23                       <NA>              <NA>                      <NA>
# 24                       <NA>              <NA>                      <NA>
# 25                      False              True                      True
# 26                       <NA>              <NA>                      <NA>
# 27                       <NA>              <NA>                      <NA>
# 28                      False              True                      True
# 29                       <NA>              True                      True
# 30                       <NA>              True                     False
# 31                       <NA>              True                     False
# 32                       <NA>              True                     False
# 33                       <NA>             False                     False
#
#     TR.CSRReporting  TR.CSRReportingGRI  TR.CSRReportingGlobalActivities  \
# 0              True                True                            False
# 1              True                True                             True
# 2              True                True                             True
# 3              True                True                             True
# 4              True                <NA>                             True
# 5              True                <NA>                             True
# 6              True                <NA>                             True
# 7              True                <NA>                             True
# 8              <NA>                <NA>                             <NA>
# 9              <NA>                <NA>                             <NA>
# 10             True                True                             True
# 11             <NA>                <NA>                             <NA>
# 12             True                True                             True
# 13             <NA>                <NA>                             <NA>
# 14             <NA>                <NA>                             <NA>
# 15             <NA>                <NA>                             <NA>
# 16             <NA>                <NA>                             <NA>
# 17             <NA>                <NA>                             <NA>
# 18             True                True                             True
# 19             True                True                             True
# 20             <NA>                <NA>                             <NA>
# 21             <NA>                <NA>                             <NA>
# 22             <NA>                <NA>                             <NA>
# 23             <NA>                <NA>                             <NA>
# 24             <NA>                <NA>                             <NA>
# 25             True                True                             True
# 26             <NA>                <NA>                             <NA>
# 27             <NA>                <NA>                             <NA>
# 28             True                True                             True
# 29            False                <NA>                             True
# 30            False                <NA>                             True
# 31            False                <NA>                             True
# 32            False                <NA>                            False
# 33            False                <NA>                            False
#
#     TR.CSRReportingExternalAudit       TR.CSRReportingExternalAuditName  \
# 0                           True           PricewaterhouseCoopers Audit
# 1                           True           PricewaterhouseCoopers Audit
# 2                           True           PricewaterhouseCoopers Audit
# 3                           True                 PricewaterhouseCoopers
# 4                           True                 PricewaterhouseCoopers
# 5                           True                 PricewaterhouseCoopers
# 6                           True                 PricewaterhouseCoopers
# 7                           True           PricewaterhouseCoopers Audit
# 8                           <NA>                                   <NA>
# 9                           <NA>                                   <NA>
# 10                          True           PricewaterhouseCoopers Audit
# 11                          <NA>                                   <NA>
# 12                          True           PricewaterhouseCoopers Audit
# 13                          <NA>                                   <NA>
# 14                          <NA>                                   <NA>
# 15                          <NA>                                   <NA>
# 16                          <NA>                                   <NA>
# 17                          <NA>                                   <NA>
# 18                          True           PricewaterhouseCoopers Audit
# 19                          True           PricewaterhouseCoopers Audit
# 20                          <NA>                                   <NA>
# 21                          <NA>                                   <NA>
# 22                          <NA>                                   <NA>
# 23                          <NA>                                   <NA>
# 24                          <NA>                                   <NA>
# 25                          True                 PricewaterhouseCoopers
# 26                          <NA>                                   <NA>
# 27                          <NA>                                   <NA>
# 28                          True           PricewaterhouseCoopers Audit
# 29                          True           PricewaterhouseCoopers Audit
# 30                          True  Ernst & Young, PricewaterhouseCoopers
# 31                         False                                   <NA>
# 32                         False                                   <NA>
# 33                         False                                   <NA>
#
#    TR.CSRReportingScope
# 0                33.824
# 1                  90.0
# 2                  77.0
# 3                  95.0
# 4                  95.0
# 5                  95.0
# 6                  87.0
# 7                  75.0
# 8                  <NA>
# 9                  <NA>
# 10                 69.0
# 11                 <NA>
# 12                 82.1
# 13                 <NA>
# 14                 <NA>
# 15                 <NA>
# 16                 <NA>
# 17                 <NA>
# 18                 82.9
# 19                 <NA>
# 20                 <NA>
# 21                 <NA>
# 22                 <NA>
# 23                 <NA>
# 24                 <NA>
# 25                 <NA>
# 26                 <NA>
# 27                 <NA>
# 28                 <NA>
# 29                 <NA>
# 30                 <NA>
# 31                 <NA>
# 32                 <NA>
# 33                 <NA>
#
# [34 rows x 338 columns]

# %% [markdown]
# ## Close the session

# %%
rd.close_session()
