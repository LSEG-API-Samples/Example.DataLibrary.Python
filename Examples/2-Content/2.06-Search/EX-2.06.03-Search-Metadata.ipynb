# %% [markdown]
# ----
# <img src="../../../files/refinitiv.png" width="20%" style="vertical-align: top;">
#
# # Data Library for Python
#
# ----

# %% [markdown]
# ## Content layer - Search Metadata
# This notebook demonstrates how to use the Search service of the Refinitiv Data Platform.

# %% [markdown]
# #### Learn more
#
# To learn more about the Refinitiv Data Library for Python please join the Refinitiv Developer Community. By [registering](https://developers.refinitiv.com/iam/register) and [logging](https://developers.refinitiv.com/content/devportal/en_us/initCookie.html) into the Refinitiv Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/quick-start),
#  [Tutorials](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/learning),
#  [Documentation](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/docs)
#  and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# the [Refinitiv Data Q&A Forum](https://community.developers.refinitiv.com/spaces/321/index.html).
# The Refinitiv Developer Community will be happy to help.

# %% [markdown]
# ## Set the configuration file location
# For a better ease of use, you have the option to set initialization parameters of the Refinitiv Data Library in the _refinitiv-data.config.json_ configuration file. This file must be located beside your notebook, in your user folder or in a folder defined by the _RD_LIB_CONFIG_PATH_ environment variable. The _RD_LIB_CONFIG_PATH_ environment variable is the option used by this series of examples. The following code sets this environment variable.

# %%
import os
os.environ["RD_LIB_CONFIG_PATH"] = "../../../Configuration"

# %% [markdown]
# ## Some Imports to start with

# %%
import refinitiv.data as rd
from refinitiv.data.content import search

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the refinitiv-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
rd.open_session()
# Out:
# <refinitiv.data.session.Definition object at 0x7f8ed0d5d910 {name='workspace'}>

# %% [markdown]
# ## Retrieve data

# %% [markdown]
# ### Metadata

# %%
response = search.metadata.Definition(
    view = search.Views.PEOPLE  # Required parameterc
).get_data()

response.data.df
# Out:
#                                              Type  Searchable  Sortable  \
# AccountName          AccountName           String        True      True
# AccountType          AccountType           String        True      True
# Address              Address               String        True      True
# AllRoles             AllRoles              String        True     False
# AnalystCode          AnalystCode           String        True     False
# ...                                           ...         ...       ...
# SUMTotalEquityAssets SUMTotalEquityAssets  Double        True      True
# TelephoneNumber      TelephoneNumber       String        True     False
# UltimateParentId     UltimateParentId      String        True      True
# UUID                 UUID                  String        True     False
# YearOfBirth          YearOfBirth           Double        True      True
#
#                                            Navigable  Groupable  Exact  Symbol
# AccountName          AccountName                True       True   True   False
# AccountType          AccountType               False      False  False   False
# Address              Address                   False      False  False   False
# AllRoles             AllRoles                  False      False  False   False
# AnalystCode          AnalystCode               False       True  False    True
# ...                                              ...        ...    ...     ...
# SUMTotalEquityAssets SUMTotalEquityAssets       True      False  False   False
# TelephoneNumber      TelephoneNumber           False      False  False   False
# UltimateParentId     UltimateParentId          False      False  False   False
# UUID                 UUID                      False      False  False   False
# YearOfBirth          YearOfBirth                True      False  False   False
#
# [252 rows x 7 columns]

# %% [markdown]
# #### viewmeta with nested type

# %%
response = search.metadata.Definition(
    view = search.Views.INSTRUMENTS  
).get_data()

response.data.df
# Out:
#                                                   Type  Searchable  Sortable  \
# AccrualBondCode        AccrualBondCode          String        True     False
# AccrualBondDescription AccrualBondDescription   String        True     False
# AccrualDate            AccrualDate                Date        True      True
# AccruedInterest        AccruedInterest          Double        True      True
# ActiveEstimatesExist   ActiveEstimatesExist    Boolean        True     False
# ...                                                ...         ...       ...
# WorstStandardYield     WorstStandardYield       Double        True      True
# WorstYearsToRedem      WorstYearsToRedem        Double        True      True
# YieldCurveBenchmarkRIC YieldCurveBenchmarkRIC   String       False     False
# YieldTypeDescription   YieldTypeDescription     String        True     False
# ZCodeValue             ZCodeValue               String        True      True
#
#                                                Navigable  Groupable  Exact  \
# AccrualBondCode        AccrualBondCode             False       True  False
# AccrualBondDescription AccrualBondDescription       True       True   True
# AccrualDate            AccrualDate                  True      False  False
# AccruedInterest        AccruedInterest              True      False  False
# ActiveEstimatesExist   ActiveEstimatesExist        False      False  False
# ...                                                  ...        ...    ...
# WorstStandardYield     WorstStandardYield           True      False  False
# WorstYearsToRedem      WorstYearsToRedem            True      False  False
# YieldCurveBenchmarkRIC YieldCurveBenchmarkRIC      False      False  False
# YieldTypeDescription   YieldTypeDescription        False      False  False
# ZCodeValue             ZCodeValue                  False       True  False
#
#                                                Symbol
# AccrualBondCode        AccrualBondCode           True
# AccrualBondDescription AccrualBondDescription   False
# AccrualDate            AccrualDate              False
# AccruedInterest        AccruedInterest          False
# ActiveEstimatesExist   ActiveEstimatesExist     False
# ...                                               ...
# WorstStandardYield     WorstStandardYield       False
# WorstYearsToRedem      WorstYearsToRedem        False
# YieldCurveBenchmarkRIC YieldCurveBenchmarkRIC   False
# YieldTypeDescription   YieldTypeDescription     False
# ZCodeValue             ZCodeValue                True
#
# [1490 rows x 7 columns]

# %% [markdown]
# ## Close the session

# %%
rd.close_session()
