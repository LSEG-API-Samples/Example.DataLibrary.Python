# %% [markdown]
# ----
# <img src="../../../files/refinitiv.png" width="20%" style="vertical-align: top;">
#
# # Data Library for Python
#
# ----

# %% [markdown]
# ## Content layer - Estimates - Summary
# This notebook demonstrates how to retrieve Estimates.
#
# I/B/E/S (Institutional Brokers' Estimate System) delivers a complete suite of Estimates content with a global view and is the largest contributor base in the industry. RDP I/B/E/S Estimates API provides information about consensus and aggregates data(26 generic measures, 23 KPI measures), company guidance data and advanced analytics. With over 40 years of collection experience and extensive quality controls that include thousands of automated error checks and stringent manual analysis, RDP I/B/E/S gives the clients the content they need for superior insight, research and investment decision making.
#
# The I/B/E/S database currently covers over 56,000 companies in 100 markets.
# More than 900 firms contribute data to I/B/E/S, from the largest global houses to regional and local brokers, with US data back to 1976 and international data back to 1987.

# %% [markdown]
# #### Learn more
#
# To learn more about the Refinitiv Data Library for Python please join the Refinitiv Developer Community. By [registering](https://developers.refinitiv.com/iam/register) and [logging](https://developers.refinitiv.com/content/devportal/en_us/initCookie.html) into the Refinitiv Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/quick-start),
#  [Tutorials](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/learning),
#  [Documentation](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/docs)
#  and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# the [Refinitiv Data Q&A Forum](https://community.developers.refinitiv.com/spaces/321/index.html).
# The Refinitiv Developer Community will be happy to help.
#
# ----

# %% [markdown]
# ## Set the configuration file location
# For a better ease of use, you have the option to set initialization parameters of the Refinitiv Data Library in the _refinitiv-data.config.json_ configuration file. This file must be located beside your notebook, in your user folder or in a folder defined by the _RD_LIB_CONFIG_PATH_ environment variable. The _RD_LIB_CONFIG_PATH_ environment variable is the option used by this series of examples. The following code sets this environment variable.

# %%
import os
os.environ["RD_LIB_CONFIG_PATH"] = "../../../Configuration"

# %% [markdown]
# ## Some Imports to start with

# %%
import refinitiv.data as rd
from refinitiv.data.content import estimates
from refinitiv.data.content.estimates import Package

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the refinitiv-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
rd.open_session("platform.rdp")
# Out:
# <refinitiv.data.session.platform.Definition object at 0x7f925f2e90a0 {session_name='rdp'}>

# %% [markdown]
# ## Retrieve Data

# %% [markdown]
# ### Summary - Annual

# %%
response = estimates.view_summary.annual.Definition("BNPP.PA", Package.BASIC).get_data()
response.data.df
# Out:
#   Instrument Period End Date Financial Period Absolute  \
# 0    BNPP.PA      2022-12-31                    FY2022
# 1    BNPP.PA      2023-12-31                    FY2023
#
#   Financial Period Relative  EBIT - Mean  EBIT - Median  EBIT - High  \
# 0                       FY1  13853347000    14914500000  15905000000
# 1                       FY2  14362123330    15221000000  16676000000
#
#    EBIT - Low  EBIT - Standard Deviation  EBIT - Number of Estimates  ...  \
# 0  7662056000                 2514861920                          14  ...
# 1  9018644000                 2291386430                          13  ...
#
#    Revenue - Number of Included Estimates  \
# 0                                      15
# 1                                      17
#
#    Revenue - Company Footnote Category  Revenue - Company Footnote Currency  \
# 0                                   MS                                  EUR
# 1                                 <NA>                                 <NA>
#
#    Revenue - Company Footnote Date  Revenue - Company Footnote Period Month  \
# 0              2022-03-28T12:03:49                                       12
# 1                             <NA>                                     <NA>
#
#    Revenue - Company Footnote Period Year  \
# 0                                    2022
# 1                                    <NA>
#
#    Revenue - Company Footnote Stop Date  \
# 0                                  <NA>
# 1                                  <NA>
#
#                   Revenue - Company Footnote Text  \
# 0  Revenue represents Net operating/Total income.
# 1                                            <NA>
#
#    Revenue - Company Footnote Type  Revenue - Company Footnote Value
# 0                                G                              <NA>
# 1                             <NA>                              <NA>
#
# [2 rows x 34 columns]

# %% [markdown]
# ### Summary - Historical snapshots non-periodic measures

# %%
response = estimates.view_summary.historical_snapshots_non_periodic_measures.Definition("BNPP.PA", Package.BASIC).get_data()
response.data.df
# Out:
#   Instrument Price Target - Current Price Target - 1 Week Ago  \
# 0    BNPP.PA                69.4081                   69.9581
#
#   Price Target - 1 Month Ago Price Target - 2 Months Ago  \
# 0                    73.0381                    69.59819
#
#   Price Target - 3 Months Ago Price Target - 4 Months Ago  \
# 0                     65.9016                    65.06343
#
#   Price Target - 5 Months Ago Price Target - 6 Months Ago  \
# 0                    63.68248                      62.195
#
#   Price Target - 7 Months Ago  ... Long Term Growth - 3 Months Ago  \
# 0                       61.83  ...                        12.27275
#
#   Long Term Growth - 4 Months Ago Long Term Growth - 5 Months Ago  \
# 0                        12.26375                          11.478
#
#   Long Term Growth - 6 Months Ago Long Term Growth - 7 Months Ago  \
# 0                        11.33733                        11.33733
#
#   Long Term Growth - 8 Months Ago Long Term Growth - 9 Months Ago  \
# 0                          10.913                          10.913
#
#   Long Term Growth - 10 Months Ago Long Term Growth - 11 Months Ago  \
# 0                           10.963                            4.044
#
#   Long Term Growth - 12 Months Ago
# 0                         -0.31933
#
# [1 rows x 29 columns]

# %% [markdown]
# ### Summary - Historical snapshots periodic measures annual

# %%
response = estimates.view_summary.historical_snapshots_periodic_measures_annual.Definition("BNPP.PA", Package.BASIC).get_data()
response.data.df
# Out:
#   Instrument Period End Date Financial Period Relative  \
# 0    BNPP.PA      2023-12-31                       FY2
# 1    BNPP.PA      2022-12-31                       FY1
#
#   Financial Period Absolute Earnings Per Share - Current  \
# 0                    FY2023                      7.15286
# 1                    FY2022                       6.9861
#
#   Earnings Per Share -  1 Week Ago Earnings Per Share -  1 Month Ago  \
# 0                          7.28896                           7.62327
# 1                          7.13724                           7.29061
#
#   Earnings Per Share -  2 Months Ago Earnings Per Share -  3 Months Ago  \
# 0                            7.55157                            7.36235
# 1                            7.38617                            7.05948
#
#   Earnings Per Share -  4 Months Ago  ... Revenue - 3 Months Ago  \
# 0                            7.30215  ...            47596680770
# 1                              6.832  ...            46553732280
#
#   Revenue - 4 Months Ago Revenue - 5 Months Ago Revenue - 6 Months Ago  \
# 0            47974433650            47656472180            47593916110
# 1            46783230940            46547335720            46491242580
#
#   Revenue - 7 Months Ago Revenue - 8 Months Ago Revenue - 9 Months Ago  \
# 0            47497375170            47192476000            47138190650
# 1            46400959110            46069758610            46046249670
#
#   Revenue - 10 Months Ago Revenue - 11 Months Ago Revenue - 12 Months Ago
# 0             47103347730             46786345130             46653026640
# 1             46019070630             45764641440             45725198940
#
# [2 rows x 32 columns]

# %% [markdown]
# ### Summary - Historical snapshots periodic measures interim

# %%
response = estimates.view_summary.historical_snapshots_periodic_measures_interim.Definition("BNPP.PA", Package.BASIC).get_data()
response.data.df
# Out:
#   Instrument Period End Date Financial Period Relative  \
# 0    BNPP.PA      2022-06-30                       FQ2
# 1    BNPP.PA      2022-03-31                       FQ1
#
#   Financial Period Absolute  \
# 0                  FY2022Q2
# 1                  FY2022Q1
#
#   Earnings Before Interest, Taxes, Depreciation and Amortization -  3 Months Ago  \
# 0                                               <NA>
# 1                                               <NA>
#
#   Earnings Before Interest, Taxes, Depreciation and Amortization -  4 Months Ago  \
# 0                                               <NA>
# 1                                               <NA>
#
#   Earnings Before Interest, Taxes, Depreciation and Amortization -  5 Months Ago  \
# 0                                               <NA>
# 1                                               <NA>
#
#   Earnings Before Interest, Taxes, Depreciation and Amortization -  6 Months Ago  \
# 0                                               <NA>
# 1                                               <NA>
#
#   Earnings Before Interest, Taxes, Depreciation and Amortization -  7 Months Ago  \
# 0                                               <NA>
# 1                                               <NA>
#
#   Earnings Before Interest, Taxes, Depreciation and Amortization -  8 Months Ago  \
# 0                                               <NA>
# 1                                               <NA>
#
#   Earnings Before Interest, Taxes, Depreciation and Amortization -  9 Months Ago  \
# 0                                               <NA>
# 1                                               <NA>
#
#   Earnings Before Interest, Taxes, Depreciation and Amortization -  10 Months Ago  \
# 0                                               <NA>
# 1                                               <NA>
#
#   Earnings Before Interest, Taxes, Depreciation and Amortization -  11 Months Ago  \
# 0                                               <NA>
# 1                                               <NA>
#
#   Earnings Before Interest, Taxes, Depreciation and Amortization -  12 Months Ago  \
# 0                                               <NA>
# 1                                               <NA>
#
#    Earnings Per Share - Current  Earnings Per Share -  1 Week Ago  \
# 0                       1.90667                           1.90667
# 1                        1.1785                           1.27467
#
#    Earnings Per Share -  1 Month Ago  Earnings Per Share -  2 Months Ago  \
# 0                              2.065                                2.14
# 1                               1.66                                1.27
#
#    Revenue -Current  Revenue - 1 Week Ago
# 0       11605519000           11605519000
# 1       11457407000           11419814000

# %% [markdown]
# ### Summary - Historical snapshots recommendations

# %%
response = estimates.view_summary.historical_snapshots_recommendations.Definition("BNPP.PA", Package.BASIC).get_data()
response.data.df
# Out:
#   Instrument Recommendation - Current Recommendation - 1 Week Ago  \
# 0    BNPP.PA                     1.92                        1.92
#
#   Recommendation - 1 Month Ago Recommendation - 2 Months Ago  \
# 0                         1.96                          1.92
#
#   Recommendation - 3 Months Ago Recommendation - 4 Months Ago  \
# 0                          1.96                       1.96154
#
#   Recommendation - 5 Months Ago Recommendation - 6 Months Ago  \
# 0                       1.96154                             2
#
#   Recommendation - 7 Months Ago Recommendation - 8 Months Ago  \
# 0                          1.96                          1.96
#
#   Recommendation - 9 Months Ago Recommendation - 10 Months Ago  \
# 0                          1.96                           1.92
#
#   Recommendation - 11 Months Ago Recommendation - 12 Months Ago
# 0                              2                              2

# %% [markdown]
# ### Summary - Interim

# %%
response = estimates.view_summary.interim.Definition("BNPP.PA", Package.BASIC).get_data()
response.data.df
# Out:
#   Instrument Period End Date Financial Period Absolute  \
# 0    BNPP.PA      2021-06-30                  FY2021Q2
# 1    BNPP.PA      2021-09-30                  FY2021Q3
# 2    BNPP.PA      2021-12-31                  FY2021Q4
# 3    BNPP.PA      2022-03-31                  FY2022Q1
# 4    BNPP.PA      2022-03-31                  FY2022Q2
# 5    BNPP.PA      2022-06-30                  FY2022Q2
#
#   Financial Period Relative EBIT - Mean EBIT - Median EBIT - High  EBIT - Low  \
# 0                      FQ-2  3810142860    3827000000  4263000000  3046000000
# 1                      FQ-1  3287000000    3201000000  3784000000  2876000000
# 2                       FQ0  3439000000    3450500000  3902000000  2792000000
# 3                       FQ1  2919000000    2919000000  2919000000  2919000000
# 4                       FQ2  2919000000    2919000000  2919000000  2919000000
# 5                       FQ2        <NA>          <NA>        <NA>        <NA>
#
#   EBIT - Standard Deviation EBIT - Number of Estimates  ...  \
# 0                 360146170                          7  ...
# 1                 375644340                          3  ...
# 2                 361690480                          6  ...
# 3                         0                          1  ...
# 4                         0                          1  ...
# 5                      <NA>                       <NA>  ...
#
#     Earnings Per Share - Company Footnote Text  \
# 0  JUN21 Majority Basis is Fully-Reported/GAAP
# 1                                         <NA>
# 2                                         <NA>
# 3                                         <NA>
# 4                                         <NA>
# 5                                         <NA>
#
#   Earnings Per Share - Company Footnote Type  \
# 0                                          M
# 1                                       <NA>
# 2                                       <NA>
# 3                                       <NA>
# 4                                       <NA>
# 5                                       <NA>
#
#   Earnings Per Share - Company Footnote Value Revenue - Mean Revenue - Median  \
# 0                                        <NA>    11194702560      11177000000
# 1                                        <NA>    11216809000      11230000000
# 2                                        <NA>    11374842750      11345000000
# 3                                        <NA>    11457407000      11457407000
# 4                                        <NA>           <NA>             <NA>
# 5                                        <NA>    11605519000      11605519000
#
#   Revenue - High Revenue - Low Revenue - Standard Deviation  \
# 0    11618921000   10984000000                    177085240
# 1    11309000000   11064265000                     87101920
# 2    11713415000   11232000000                    157835480
# 3    11495000000   11419814000                     37593000
# 4           <NA>          <NA>                         <NA>
# 5    11605519000   11605519000                            0
#
#   Revenue - Number of Estimates Revenue - Number of Included Estimates
# 0                             9                                      9
# 1                             5                                      5
# 2                             8                                      8
# 3                             2                                      2
# 4                          <NA>                                   <NA>
# 5                             1                                      1
#
# [6 rows x 42 columns]

# %% [markdown]
# #### Summary - Non-periodic measures

# %%
response = estimates.view_summary.non_periodic_measures.Definition("BNPP.PA", Package.BASIC).get_data()
response.data.df
# Out:
#   Instrument  Long Term Growth - Mean  Long Term Growth - Median  \
# 0    BNPP.PA                    8.388                      8.245
#
#    Long Term Growth - High  Long Term Growth - Low  \
# 0                     11.4                   5.662
#
#    Long Term Growth - Standard Deviation  \
# 0                                2.38245
#
#    Long Term Growth - Number Of Estimates  \
# 0                                       5
#
#    Long Term Growth - Number of Included Estimates  \
# 0                                                4
#
#    Price Target - Mean Estimate  Price Target - Mean  Price Target - Median  \
# 0                       69.4081              69.4081                     69
#
#    Price Target - High  Price Target - Low  Price Target - Standard Deviation  \
# 0                86.44                  55                            7.76393
#
#    Price Target - Number of Estimates  \
# 0                                  24
#
#    Price Target - Number of Included Estimates Price Target - Currency
# 0                                           20                    <NA>

# %% [markdown]
# #### Summary - Recommendations

# %%
response = estimates.view_summary.recommendations.Definition("BNPP.PA", Package.BASIC).get_data()
response.data.df
# Out:
#   Instrument Recommendation - Mean (1-5) Recommendation - Mean Label  \
# 0    BNPP.PA                        1.92                         BUY
#
#   Recommendation - Median (1-5) Recommendation - Median Label  \
# 0                             2                           BUY
#
#   Recommendation - High (1-5) Recommendation - High Label  \
# 0                           1                  STRONG BUY
#
#   Recommendation - Low (1-5) Recommendation - Low Label  \
# 0                          3                       HOLD
#
#   Recommendation - Number Of Strong Buy Recommendation - Number Of Buy  \
# 0                                     7                             13
#
#   Recommendation - Number Of Hold Recommendation - Number Of Sell  \
# 0                               5                               0
#
#   Recommendation - Number Of Strong Sell  \
# 0                                      0
#
#   Recommendation - Number Of No Opinion Recommendation - Number Of Total  \
# 0                                     0                               25
#
#   Days Since 2-Level Rec Change Days Since New Sell Recommendation  \
# 0                            75                                425
#
#   Days Since New Recommendation
# 0                            17

# %% [markdown]
# ### Close the session

# %%
rd.close_session()
