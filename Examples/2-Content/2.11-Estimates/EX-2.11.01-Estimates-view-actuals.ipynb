# %% [markdown]
# ----
# <img src="../../../files/refinitiv.png" width="20%" style="vertical-align: top;">
#
# # Data Library for Python
#
# ----

# %% [markdown]
# This notebook demonstrates how to work with Estimates API db from Refinitiv Data Library.

# %% [markdown]
# #### Learn more
#
# To learn more about the Refinitiv Data Library for Python please join the Refinitiv Developer Community. By [registering](https://developers.refinitiv.com/iam/register) and [logging](https://developers.refinitiv.com/content/devportal/en_us/initCookie.html) into the Refinitiv Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/quick-start),
#  [Tutorials](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/learning),
#  [Documentation](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/docs)
#  and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# the [Refinitiv Data Q&A Forum](https://community.developers.refinitiv.com/spaces/321/index.html).
# The Refinitiv Developer Community will be happy to help.

# %% [markdown]
# ## Set the configuration file location
# For a better ease of use, you have the option to set initialization parameters of the Refinitiv Data Library in the _refinitiv-data.config.json_ configuration file. This file must be located beside your notebook, in your user folder or in a folder defined by the _RD_LIB_CONFIG_PATH_ environment variable. The _RD_LIB_CONFIG_PATH_ environment variable is the option used by this series of examples. The following code sets this environment variable.

# %%
import os
os.environ["RD_LIB_CONFIG_PATH"] = "../../../Configuration"

# %% [markdown]
# ## Some Imports to start with

# %%
import asyncio
import refinitiv.data as rd
from refinitiv.data.content import estimates
from refinitiv.data.content.estimates import Package

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the refinitiv-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
rd.open_session("platform.rdp")
# Out:
# <refinitiv.data.session.platform.Definition object at 0x22181b6fa90 {session_name='rdp'}>

# %% [markdown]
# ### Retrieve Data

# %% [markdown]
# #### view_actuals - Annual

# %% [markdown]
# ##### Get data with default title as headers

# %%
response = estimates.view_actuals.annual.Definition(["BNPP.PA","ORCL.N"], Package.BASIC).get_data()
response.data.df
# Out:
# ---------------------------------------------------------------------------
# RDError                                   Traceback (most recent call last)
# Input In [48], in <module>
# ----> 1 response = estimates.view_actuals.annual.Definition(["BNPP.PA","ORCL.N"], Package.BASIC, extended_params={"universe": ""}).get_data()
#       2 response.data.df
#
# File ~\workspace\lseg\refinitiv-data\dataplatform_project\refinitiv\data\_data\delivery\data\_data_provider.py:568, in DataProviderLayer.get_data(self, session, on_response, **kwargs)
#     564 session = get_valid_session(session)
#     565 response = session.run_until_complete(
#     566     self.get_data_async(session, on_response, **kwargs)
#     567 )
# --> 568 self._check_response(response)
#     569 return response
#
# File ~\workspace\lseg\refinitiv-data\dataplatform_project\refinitiv\data\_data\delivery\data\_data_provider.py:541, in DataProviderLayer._check_response(self, response)
#     540 def _check_response(self, response):
# --> 541     _check_response(response)
#
# File ~\workspace\lseg\refinitiv-data\dataplatform_project\refinitiv\data\_data\delivery\data\_data_provider.py:442, in _check_response(response)
#     439     raise exception_class(error_code, error_message)
#     441 else:
# --> 442     raise RDError(error_code, error_message)
#
# RDError: Error code 400 | Validation error: validation failure list:
# universe.0 in query should be at least 1 chars long

# %%
response = estimates.view_actuals.annual.Definition(["BNPP.PA","ORCL.N"], Package.STANDARD).get_data()
response.data.df
# Out:
#   instrument periodenddate fperiod rfperiod  TR.BVPSActValue  \
# 0    BNPP.PA    2021-12-31  FY2021      FY0         95.56183
# 1     ORCL.N    2021-05-31  FY2021      FY0          2.06413
# 2    BNPP.PA    2020-12-31  FY2020     FY-1             82.3
# 3     ORCL.N    2020-05-31  FY2020     FY-1          4.03255
#
#   TR.BVPSActReportDate  TR.BVPSActSueScore  TR.BVPSActSueScore60Day  \
# 0  2022-02-08T10:58:00             1.95788                  1.97715
# 1  2021-06-15T16:06:00            -1.17556                 -1.07431
# 2  2021-02-05T05:58:00            -0.08861                 -0.06829
# 3  2020-06-16T16:02:00            -0.59247                 -0.59131
#
#    TR.BVPSActSurprise  TR.BVPSActSurprise60Day  ...  TR.ROEActSueScore  \
# 0              10.115                    10.55  ...            0.69016
# 1              -53.49                  -50.342  ...            0.67868
# 2              -0.341                    -0.26  ...            1.01657
# 3             -23.396                  -22.083  ...            0.27074
#
#   TR.ROEActSueScore60Day  TR.ROEActSurprise  TR.ROEActSurprise60Day  \
# 0                0.66895              5.198                   6.864
# 1                0.81261             21.272                  24.418
# 2                0.64929              9.022                   7.029
# 3                0.29128              6.593                   7.402
#
#    TR.RevenueActValue  TR.RevenueActReportDate  TR.RevenueActSueScore  \
# 0         46235000000      2022-02-08T10:47:00               -0.29111
# 1         40481000000      2021-06-15T16:06:00                2.21591
# 2         44275000000      2021-02-05T05:58:00                0.17323
# 3         39072000000      2020-06-16T16:02:00               -0.81465
#
#   TR.RevenueActSueScore60Day  TR.RevenueActSurprise  \
# 0                   -0.16022                 -0.202
# 1                    2.27272                  0.451
# 2                    0.20404                  0.182
# 3                    -1.7988                 -0.574
#
#    TR.RevenueActSurprise60Day
# 0                      -0.118
# 1                       0.461
# 2                       0.218
# 3                      -1.338
#
# [4 rows x 58 columns]

# %% [markdown]
# ##### Get data with field name as headers

# %%
response = estimates.view_actuals.annual.Definition("BNPP.PA", Package.BASIC, use_field_names_in_headers=True).get_data()
response.data.df
# Out:
#   Instrument Period End Date Financial Period Absolute  \
# 0    BNPP.PA      2021-12-31                    FY2021
# 1    BNPP.PA      2020-12-31                    FY2020
#
#   Financial Period Relative EBIT - Actual Value EBIT - Actual Reported Date  \
# 0                       FY0         15124000000         2022-02-08T10:47:00
# 1                      FY-1         14081000000         2021-02-05T05:58:00
#
#   EBIT - Actual Standard Unexpected Earnings  \
# 0                                    0.30156
# 1                                   -0.00651
#
#   EBIT - Actual Standard Unexpected Earnings 60Days EBIT - Actual Surprise  \
# 0                                           0.27586                  2.873
# 1                                           0.00162                 -0.012
#
#   EBIT - Actual Surprise 60Days  ...  \
# 0                         2.654  ...
# 1                         0.003  ...
#
#   EPS - Actual Standard Unexpected Earnings  \
# 0                                   1.20288
# 1                                   1.01614
#
#   EPS - Actual Standard Unexpected Earnings 60Days EPS - Actual Surprise  \
# 0                                          1.19773                 4.472
# 1                                          0.87655                 8.968
#
#   EPS - Actual Surprise 60Days Revenue - Actual Value  \
# 0                        5.754            46235000000
# 1                        10.72            44275000000
#
#   Revenue - Actual Reported Date  \
# 0            2022-02-08T10:47:00
# 1            2021-02-05T05:58:00
#
#   Revenue - Actual Standard Unexpected Earnings  \
# 0                                      -0.29111
# 1                                       0.17323
#
#   Revenue - Actual Standard Unexpected Earnings 60Days  \
# 0                                           -0.16022
# 1                                            0.20404
#
#   Revenue - Actual Surprise Revenue - Actual Surprise 60Days
# 0                    -0.202                           -0.118
# 1                     0.182                            0.218
#
# [2 rows x 22 columns]

# %% [markdown]
# ##### Get data async with title as headers

# %%
response = asyncio.run(estimates.view_actuals.annual.Definition("BNPP.PA", Package.BASIC).get_data_async())
response.data.df
# Out:
#   Instrument Period End Date Financial Period Absolute  \
# 0    BNPP.PA      2021-12-31                    FY2021
# 1    BNPP.PA      2020-12-31                    FY2020
#
#   Financial Period Relative EBIT - Actual Value EBIT - Actual Reported Date  \
# 0                       FY0         15124000000         2022-02-08T10:47:00
# 1                      FY-1         14081000000         2021-02-05T05:58:00
#
#   EBIT - Actual Standard Unexpected Earnings  \
# 0                                    0.30156
# 1                                   -0.00651
#
#   EBIT - Actual Standard Unexpected Earnings 60Days EBIT - Actual Surprise  \
# 0                                           0.27586                  2.873
# 1                                           0.00162                 -0.012
#
#   EBIT - Actual Surprise 60Days  ...  \
# 0                         2.654  ...
# 1                         0.003  ...
#
#   EPS - Actual Standard Unexpected Earnings  \
# 0                                   1.20288
# 1                                   1.01614
#
#   EPS - Actual Standard Unexpected Earnings 60Days EPS - Actual Surprise  \
# 0                                          1.19773                 4.472
# 1                                          0.87655                 8.968
#
#   EPS - Actual Surprise 60Days Revenue - Actual Value  \
# 0                        5.754            46235000000
# 1                        10.72            44275000000
#
#   Revenue - Actual Reported Date  \
# 0            2022-02-08T10:47:00
# 1            2021-02-05T05:58:00
#
#   Revenue - Actual Standard Unexpected Earnings  \
# 0                                      -0.29111
# 1                                       0.17323
#
#   Revenue - Actual Standard Unexpected Earnings 60Days  \
# 0                                           -0.16022
# 1                                            0.20404
#
#   Revenue - Actual Surprise Revenue - Actual Surprise 60Days
# 0                    -0.202                           -0.118
# 1                     0.182                            0.218
#
# [2 rows x 22 columns]

# %% [markdown]
# ##### Get data Standard package

# %%
response = estimates.view_actuals.annual.Definition("BNPP.PA", Package.STANDARD).get_data()
response.data.df
# Out:
#   Instrument Period End Date Financial Period Absolute  \
# 0    BNPP.PA      2021-12-31                    FY2021
# 1    BNPP.PA      2020-12-31                    FY2020
#
#   Financial Period Relative  BVPS - Actual Value BVPS - Actual Reported Date  \
# 0                       FY0             95.56183         2022-02-08T10:58:00
# 1                      FY-1                 82.3         2021-02-05T05:58:00
#
#    BVPS - Actual Standard Unexpected Earnings  \
# 0                                     1.95788
# 1                                    -0.08861
#
#    BVPS - Actual Standard Unexpected Earnings 60Days  BVPS - Actual Surprise  \
# 0                                            1.97715                  10.115
# 1                                           -0.06829                  -0.341
#
#    BVPS - Actual Surprise 60Days  ...  \
# 0                          10.55  ...
# 1                          -0.26  ...
#
#    ROE - Actual Standard Unexpected Earnings  \
# 0                                    0.69016
# 1                                    1.01657
#
#   ROE - Actual Standard Unexpected Earnings 60Days  ROE - Actual Surprise  \
# 0                                          0.66895                  5.198
# 1                                          0.64929                  9.022
#
#    ROE - Actual Surprise 60Days  Revenue - Actual Value  \
# 0                         6.864             46235000000
# 1                         7.029             44275000000
#
#    Revenue - Actual Reported Date  \
# 0             2022-02-08T10:47:00
# 1             2021-02-05T05:58:00
#
#    Revenue - Actual Standard Unexpected Earnings  \
# 0                                       -0.29111
# 1                                        0.17323
#
#   Revenue - Actual Standard Unexpected Earnings 60Days  \
# 0                                           -0.16022
# 1                                            0.20404
#
#    Revenue - Actual Surprise  Revenue - Actual Surprise 60Days
# 0                     -0.202                            -0.118
# 1                      0.182                             0.218
#
# [2 rows x 52 columns]

# %% [markdown]
# ##### Get data Professional package

# %%
response = estimates.view_actuals.annual.Definition("BNPP.PA", Package.PROFESSIONAL).get_data()
response.data.df
# Out:
#   Instrument Period End Date Financial Period Absolute  \
# 0    BNPP.PA      2021-12-31                    FY2021
# 1    BNPP.PA      2020-12-31                    FY2020
# 2    BNPP.PA      2019-12-31                    FY2019
# 3    BNPP.PA      2018-12-31                    FY2018
# 4    BNPP.PA      2017-12-31                    FY2017
#
#   Financial Period Relative  BVPS - Actual Value BVPS - Actual Reported Date  \
# 0                       FY0             95.56183         2022-02-08T10:58:00
# 1                      FY-1                 82.3         2021-02-05T05:58:00
# 2                      FY-2                 86.1         2020-02-05T05:59:00
# 3                      FY-3                81.19         2019-02-06T06:44:00
# 4                      FY-4                 75.1         2018-02-06T06:51:00
#
#    BVPS - Actual Standard Unexpected Earnings  \
# 0                                     1.95788
# 1                                    -0.08861
# 2                                     2.50041
# 3                                     1.98981
# 4                                     0.19564
#
#    BVPS - Actual Standard Unexpected Earnings 60Days  BVPS - Actual Surprise  \
# 0                                            1.97715                  10.115
# 1                                           -0.06829                  -0.341
# 2                                            2.49557                  10.594
# 3                                            1.98077                   8.567
# 4                                            0.16906                   1.033
#
#    BVPS - Actual Surprise 60Days  ...  \
# 0                          10.55  ...
# 1                          -0.26  ...
# 2                         10.595  ...
# 3                          8.332  ...
# 4                          0.893  ...
#
#    ROE - Actual Standard Unexpected Earnings  \
# 0                                    0.69016
# 1                                    1.01657
# 2                                   -0.40744
# 3                                   -0.69384
# 4                                    0.80204
#
#   ROE - Actual Standard Unexpected Earnings 60Days ROE - Actual Surprise  \
# 0                                          0.66895                 5.198
# 1                                          0.64929                 9.022
# 2                                         -0.32243                -3.544
# 3                                         -0.90318                -6.168
# 4                                          0.65364                 7.046
#
#   ROE - Actual Surprise 60Days  Revenue - Actual Value  \
# 0                        6.864             46235000000
# 1                        7.029             44275000000
# 2                       -2.672             44597000000
# 3                       -8.449             42516000000
# 4                        5.949             43161000000
#
#    Revenue - Actual Reported Date  \
# 0             2022-02-08T10:47:00
# 1             2021-02-05T05:58:00
# 2             2020-02-05T05:59:00
# 3             2019-02-06T06:44:00
# 4             2018-02-06T06:51:00
#
#    Revenue - Actual Standard Unexpected Earnings  \
# 0                                       -0.29111
# 1                                        0.17323
# 2                                        1.44666
# 3                                       -0.98174
# 4                                         -0.173
#
#   Revenue - Actual Standard Unexpected Earnings 60Days  \
# 0                                           -0.16022
# 1                                            0.20404
# 2                                             1.5016
# 3                                           -1.67774
# 4                                           -0.76151
#
#    Revenue - Actual Surprise  Revenue - Actual Surprise 60Days
# 0                     -0.202                            -0.118
# 1                      0.182                             0.218
# 2                      0.888                             1.028
# 3                     -0.921                             -1.38
# 4                     -0.131                            -0.622
#
# [5 rows x 118 columns]

# %% [markdown]
# ##### Get data with invalid RIC

# %%
response = estimates.view_actuals.annual.Definition(["BNPP.PA","INVALID"], Package.PROFESSIONAL).get_data()
response.data.df
# Out:
#   Instrument Period End Date Financial Period Absolute  \
# 0    BNPP.PA      2021-12-31                    FY2021
# 1    BNPP.PA      2020-12-31                    FY2020
# 2    BNPP.PA      2019-12-31                    FY2019
# 3    BNPP.PA      2018-12-31                    FY2018
# 4    BNPP.PA      2017-12-31                    FY2017
#
#   Financial Period Relative  BVPS - Actual Value BVPS - Actual Reported Date  \
# 0                       FY0             95.56183         2022-02-08T10:58:00
# 1                      FY-1                 82.3         2021-02-05T05:58:00
# 2                      FY-2                 86.1         2020-02-05T05:59:00
# 3                      FY-3                81.19         2019-02-06T06:44:00
# 4                      FY-4                 75.1         2018-02-06T06:51:00
#
#    BVPS - Actual Standard Unexpected Earnings  \
# 0                                     1.95788
# 1                                    -0.08861
# 2                                     2.50041
# 3                                     1.98981
# 4                                     0.19564
#
#    BVPS - Actual Standard Unexpected Earnings 60Days  BVPS - Actual Surprise  \
# 0                                            1.97715                  10.115
# 1                                           -0.06829                  -0.341
# 2                                            2.49557                  10.594
# 3                                            1.98077                   8.567
# 4                                            0.16906                   1.033
#
#    BVPS - Actual Surprise 60Days  ...  \
# 0                          10.55  ...
# 1                          -0.26  ...
# 2                         10.595  ...
# 3                          8.332  ...
# 4                          0.893  ...
#
#    Revenue - Actual Standard Unexpected Earnings  \
# 0                                       -0.29111
# 1                                        0.17323
# 2                                        1.44666
# 3                                       -0.98174
# 4                                         -0.173
#
#   Revenue - Actual Standard Unexpected Earnings 60Days  \
# 0                                           -0.16022
# 1                                            0.20404
# 2                                             1.5016
# 3                                           -1.67774
# 4                                           -0.76151
#
#   Revenue - Actual Surprise Revenue - Actual Surprise 60Days  \
# 0                    -0.202                           -0.118
# 1                     0.182                            0.218
# 2                     0.888                            1.028
# 3                    -0.921                            -1.38
# 4                    -0.131                           -0.622
#
#    FFO Per Share - Actual Value  FFO Per Share - Actual Reported Date  \
# 0                          None                                  None
# 1                          None                                  None
# 2                          None                                  None
# 3                          None                                  None
# 4                          None                                  None
#
#    FFO Per Share - Actual Standard Unexpected Earnings  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   FFO Per Share - Actual Standard Unexpected Earnings 60Days  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#    FFO Per Share - Actual Surprise  FFO Per Share - Actual Surprise 60Days
# 0                             None                                    None
# 1                             None                                    None
# 2                             None                                    None
# 3                             None                                    None
# 4                             None                                    None
#
# [5 rows x 142 columns]

# %%
response.data.raw
# Out:
# {'links': {'count': 5},
#  'variability': 'fixed',
#  'universe': [{'Instrument': 'BNPP.PA',
#    'Organization PermID': '8589934326',
#    'Company Common Name': 'BNP Paribas SA',
#    'Currency': 'EUR'},
#   {'Instrument': 'INVALID',
#    'Organization PermID': 'Failed to resolve identifier(s).',
#    'Company Common Name': 'Failed to resolve identifier(s).',
#    'Currency': 'Failed to resolve identifier(s).'}],
#  'data': [['BNPP.PA',
#    '2021-12-31',
#    'FY2021',
#    'FY0',
#    95.56183,
#    '2022-02-08T10:58:00',
#    1.95788,
#    1.97715,
#    10.115,
#    10.55,
#    1664000000,
#    '2022-02-08T10:47:00',
#    None,
#    None,
#    -7.886,
#    -7.886,
#    33.979,
#    '2022-02-08T10:47:00',
#    15.71329,
#    15.75793,
#    227.177,
#    227.303,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    15124000000,
#    '2022-02-08T10:47:00',
#    0.30156,
#    0.27586,
#    2.873,
#    2.654,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    7.26,
#    '2022-02-08T10:47:00',
#    1.20288,
#    1.19773,
#    4.472,
#    5.754,
#    7.26,
#    '2022-02-08T10:47:00',
#    0.87886,
#    0.94304,
#    3.428,
#    5.189,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    9488000000,
#    '2022-02-08T10:47:00',
#    1.96581,
#    2.224,
#    9.225,
#    11.5,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    13637000000,
#    '2022-02-08T10:47:00',
#    1.24117,
#    1.50051,
#    5.468,
#    6.303,
#    9488000000,
#    '2022-02-08T10:47:00',
#    1.75777,
#    1.38722,
#    5.606,
#    7.426,
#    13637000000,
#    '2022-02-08T10:47:00',
#    1.17184,
#    1.17395,
#    5.132,
#    5.313,
#    0.37,
#    '2022-02-08T10:47:00',
#    0.20556,
#    0.20556,
#    3.604,
#    3.604,
#    8.23,
#    '2022-02-08T10:47:00',
#    0.69016,
#    0.66895,
#    5.198,
#    6.864,
#    46235000000,
#    '2022-02-08T10:47:00',
#    -0.29111,
#    -0.16022,
#    -0.202,
#    -0.118,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   ['BNPP.PA',
#    '2020-12-31',
#    'FY2020',
#    'FY-1',
#    82.3,
#    '2021-02-05T05:58:00',
#    -0.08861,
#    -0.06829,
#    -0.341,
#    -0.26,
#    773000000,
#    '2021-02-05T05:58:00',
#    None,
#    None,
#    8993.048,
#    8993.048,
#    111.65,
#    '2021-02-05T05:58:00',
#    154.94635,
#    154.94635,
#    1353.587,
#    1353.587,
#    1.1,
#    '2021-02-05T05:58:00',
#    -0.69619,
#    -0.73651,
#    -29.691,
#    -40.678,
#    14081000000,
#    '2021-02-05T05:58:00',
#    -0.00651,
#    0.00162,
#    -0.012,
#    0.003,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    7.66,
#    '2021-02-05T05:58:00',
#    127.82353,
#    33.76191,
#    16.529,
#    0.16122,
#    5.31,
#    '2021-02-05T05:58:00',
#    1.01614,
#    0.87655,
#    8.968,
#    10.72,
#    5.31,
#    '2021-02-05T05:58:00',
#    0.8826,
#    0.85251,
#    7.397,
#    10.628,
#    13.101,
#    '2021-02-05T05:58:00',
#    None,
#    None,
#    50.517,
#    50.517,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    94.02,
#    '2021-02-05T05:58:00',
#    2.16506,
#    2.16506,
#    18.632,
#    18.632,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    7067000000,
#    '2021-02-05T05:58:00',
#    1.61033,
#    1.48251,
#    15.382,
#    14.446,
#    9822000000,
#    '2021-02-05T05:58:00',
#    7.05089,
#    4.95237,
#    16.831,
#    18.159,
#    9822000000,
#    '2021-02-05T05:58:00',
#    1.28778,
#    1.25314,
#    10.131,
#    10.288,
#    7067000000,
#    '2021-02-05T05:58:00',
#    1.33403,
#    1.50338,
#    9.204,
#    10.325,
#    9822000000,
#    '2021-02-05T05:58:00',
#    1.40739,
#    1.68764,
#    7.139,
#    8.737,
#    0.3,
#    '2021-02-05T05:58:00',
#    -0.25183,
#    -0.21632,
#    -3.744,
#    -2.834,
#    6.7,
#    '2021-02-05T05:58:00',
#    1.01657,
#    0.64929,
#    9.022,
#    7.029,
#    44275000000,
#    '2021-02-05T05:58:00',
#    0.17323,
#    0.20404,
#    0.182,
#    0.218,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   ['BNPP.PA',
#    '2019-12-31',
#    'FY2019',
#    'FY-2',
#    86.1,
#    '2020-02-05T05:59:00',
#    2.50041,
#    2.49557,
#    10.594,
#    10.595,
#    1998000000,
#    '2020-02-05T05:59:00',
#    None,
#    None,
#    26217.176,
#    26217.176,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    0,
#    '2020-02-05T05:59:00',
#    -29.319,
#    -26.68245,
#    -100,
#    -100,
#    13260000000,
#    '2020-02-05T05:59:00',
#    0.01637,
#    0.03837,
#    0.097,
#    0.213,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    6.21,
#    '2020-02-05T05:59:00',
#    0.3808,
#    0.33183,
#    1.618,
#    1.587,
#    6.21,
#    '2020-02-05T05:59:00',
#    0.25788,
#    0.26201,
#    0.993,
#    1.166,
#    15.519,
#    '2020-02-05T05:59:00',
#    None,
#    None,
#    54.556,
#    54.556,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    89.62,
#    '2020-02-05T05:59:00',
#    11.20673,
#    11.20673,
#    35.153,
#    35.153,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    8173000000,
#    '2020-02-05T05:59:00',
#    1.11397,
#    1.0726,
#    5.802,
#    6.274,
#    10057000000,
#    '2020-02-05T05:59:00',
#    -0.67024,
#    -0.44386,
#    -2.765,
#    -1.816,
#    11394000000,
#    '2020-02-05T05:59:00',
#    0.3461,
#    0.37543,
#    1.988,
#    2.177,
#    8173000000,
#    '2020-02-05T05:59:00',
#    1.07282,
#    1.00972,
#    5.169,
#    4.966,
#    11394000000,
#    '2020-02-05T05:59:00',
#    0.40376,
#    0.43886,
#    2.647,
#    2.897,
#    0.39,
#    '2020-02-05T05:59:00',
#    0.06739,
#    0.06739,
#    1.002,
#    1.002,
#    7.82,
#    '2020-02-05T05:59:00',
#    -0.40744,
#    -0.32243,
#    -3.544,
#    -2.672,
#    44597000000,
#    '2020-02-05T05:59:00',
#    1.44666,
#    1.5016,
#    0.888,
#    1.028,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   ['BNPP.PA',
#    '2018-12-31',
#    'FY2018',
#    'FY-3',
#    81.19,
#    '2019-02-06T06:44:00',
#    1.98981,
#    1.98077,
#    8.567,
#    8.332,
#    1827000000,
#    '2019-02-06T06:44:00',
#    None,
#    None,
#    22840.733,
#    22840.733,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    3.02,
#    '2019-02-06T06:44:00',
#    0.43569,
#    -0.01431,
#    1.97,
#    -0.043,
#    11933000000,
#    '2019-02-06T06:44:00',
#    -0.3791,
#    -0.66447,
#    -2.897,
#    -4.58,
#    13609000000,
#    '2019-02-06T06:44:00',
#    None,
#    None,
#    20.434,
#    20.434,
#    10.15,
#    '2019-02-06T06:44:00',
#    15.40865,
#    11.86837,
#    46.148,
#    0.42366,
#    5.73,
#    '2019-02-06T06:44:00',
#    -0.75925,
#    -1.23469,
#    -3.082,
#    -4.773,
#    5.73,
#    '2019-02-06T06:44:00',
#    -0.48117,
#    -1.32963,
#    -1.474,
#    -3.251,
#    13.68,
#    '2019-02-06T06:44:00',
#    None,
#    None,
#    42.426,
#    38.574,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    84.59,
#    '2019-02-06T06:44:00',
#    137.51501,
#    107.27255,
#    36.223,
#    36.128,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    7526000000,
#    '2019-02-06T06:44:00',
#    0.24731,
#    -0.21016,
#    1.205,
#    -0.873,
#    9169000000,
#    '2019-02-06T06:44:00',
#    None,
#    -3.80319,
#    -5.465,
#    -10.955,
#    10208000000,
#    '2019-02-06T06:44:00',
#    -1.62526,
#    -2.2203,
#    -5.864,
#    -6.895,
#    7526000000,
#    '2019-02-06T06:44:00',
#    0.25477,
#    -0.0704,
#    1.276,
#    -0.242,
#    10208000000,
#    '2019-02-06T06:44:00',
#    -1.57963,
#    -1.86489,
#    -5.78,
#    -7.368,
#    0.38,
#    '2019-02-06T06:44:00',
#    -0.39107,
#    -0.96536,
#    -4.554,
#    -7.964,
#    7.4,
#    '2019-02-06T06:44:00',
#    -0.69384,
#    -0.90318,
#    -6.168,
#    -8.449,
#    42516000000,
#    '2019-02-06T06:44:00',
#    -0.98174,
#    -1.67774,
#    -0.921,
#    -1.38,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   ['BNPP.PA',
#    '2017-12-31',
#    'FY2017',
#    'FY-4',
#    75.1,
#    '2018-02-06T06:51:00',
#    0.19564,
#    0.16906,
#    1.033,
#    0.893,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    23.25,
#    '2018-02-06T06:51:00',
#    4.4224,
#    4.19003,
#    197.163,
#    191.524,
#    3.02,
#    '2018-02-06T06:51:00',
#    0.26235,
#    0.03998,
#    0.993,
#    0.147,
#    13217000000,
#    '2018-02-06T06:51:00',
#    0.13751,
#    -0.0222,
#    0.889,
#    -0.131,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    9.89,
#    '2018-02-06T06:51:00',
#    6.60082,
#    5.33379,
#    40.816,
#    0.38541,
#    6.05,
#    '2018-02-06T06:51:00',
#    -0.57808,
#    -0.7097,
#    -2.529,
#    -3.337,
#    6.05,
#    '2018-02-06T06:51:00',
#    -0.25427,
#    -0.51566,
#    -1.011,
#    -1.977,
#    14.27,
#    '2018-02-06T06:51:00',
#    None,
#    None,
#    37.489,
#    34.192,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    85.9,
#    '2018-02-06T06:51:00',
#    9.8952,
#    8.44176,
#    36.876,
#    35.212,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    7759000000,
#    '2018-02-06T06:51:00',
#    0.00165,
#    -0.34954,
#    0.008,
#    -1.65,
#    10310000000,
#    '2018-02-06T06:51:00',
#    -1.85204,
#    -2.53328,
#    -7.808,
#    -8.473,
#    11310000000,
#    '2018-02-06T06:51:00',
#    -0.71059,
#    -0.94575,
#    -2.797,
#    -3.341,
#    7759000000,
#    '2018-02-06T06:51:00',
#    -0.03218,
#    -0.26319,
#    -0.19,
#    -1.403,
#    11310000000,
#    '2018-02-06T06:51:00',
#    -0.64408,
#    -0.98062,
#    -2.77,
#    -3.49,
#    0.38,
#    '2018-02-06T06:51:00',
#    -0.80009,
#    -0.79863,
#    -8.764,
#    -8.96,
#    8.9,
#    '2018-02-06T06:51:00',
#    0.80204,
#    0.65364,
#    7.046,
#    5.949,
#    43161000000,
#    '2018-02-06T06:51:00',
#    -0.173,
#    -0.76151,
#    -0.131,
#    -0.622,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None]],
#  'headers': [{'name': 'instrument',
#    'title': 'Instrument',
#    'type': 'string',
#    'description': 'The requested Instrument as defined by the user.'},
#   {'name': 'periodenddate',
#    'title': 'Period End Date',
#    'type': 'date',
#    'description': 'The last day of the financial period in question.'},
#   {'name': 'fperiod',
#    'title': 'Financial Period Absolute',
#    'type': 'string',
#    'description': 'The Absolute Financial Period of the Record e.g. 2020.'},
#   {'name': 'rfperiod',
#    'title': 'Financial Period Relative',
#    'type': 'string',
#    'description': 'The Relative Financial Period of the Record e.g. FY-1.'},
#   {'name': 'TR.BVPSActValue',
#    'title': 'BVPS - Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Book Value Per Share is a company's common stock equity as it appears on a balance sheet equal to total assets minus liabilities, preferred stock, and intangible assets such as goodwill, divided by the weighted average number of total shares outstanding for the year."},
#   {'name': 'TR.BVPSActReportDate',
#    'title': 'BVPS - Actual Reported Date',
#    'type': 'datetime',
#    'description': "The date the company announced its actual. Book Value Per Share is a company's common stock equity as it appears on a balance sheet equal to total assets minus liabilities, preferred stock, and intangible assets such as goodwill, divided by the weighted average number of total shares outstanding for the year."},
#   {'name': 'TR.BVPSActSueScore',
#    'title': 'BVPS - Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Book Value Per Share is a company's common stock equity as it appears on a balance sheet equal to total assets minus liabilities, preferred stock, and intangible assets such as goodwill, divided by the weighted average number of total shares outstanding for the year."},
#   {'name': 'TR.BVPSActSueScore60Day',
#    'title': 'BVPS - Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Book Value Per Share is a company's common stock equity as it appears on a balance sheet equal to total assets minus liabilities, preferred stock, and intangible assets such as goodwill, divided by the weighted average number of total shares outstanding for the year."},
#   {'name': 'TR.BVPSActSurprise',
#    'title': 'BVPS - Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the last mean of the period, expressed as a percentage. Book Value Per Share is a company's common stock equity as it appears on a balance sheet equal to total assets minus liabilities, preferred stock, and intangible assets such as goodwill, divided by the weighted average number of total shares outstanding for the year."},
#   {'name': 'TR.BVPSActSurprise60Day',
#    'title': 'BVPS - Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the mean 60 days ago, expressed as a percentage. Book Value Per Share is a company's common stock equity as it appears on a balance sheet equal to total assets minus liabilities, preferred stock, and intangible assets such as goodwill, divided by the weighted average number of total shares outstanding for the year."},
#   {'name': 'TR.CapexActValue',
#    'title': 'CAPEX - Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Capital Expenditure are the funds used by a company to acquire or upgrade physical assets such as property, industrial buildings, or equipment or the amount used during a particular period to acquire or improve long term assets such as property, plant, or equipment."},
#   {'name': 'TR.CapexActReportDate',
#    'title': 'CAPEX - Actual Reported Date',
#    'type': 'datetime',
#    'description': 'The date the company announced its actual. Capital Expenditure are the funds used by a company to acquire or upgrade physical assets such as property, industrial buildings, or equipment or the amount used during a particular period to acquire or improve long term assets such as property, plant, or equipment.'},
#   {'name': 'TR.CapexActSueScore',
#    'title': 'CAPEX - Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Capital Expenditure are the funds used by a company to acquire or upgrade physical assets such as property, industrial buildings, or equipment or the amount used during a particular period to acquire or improve long term assets such as property, plant, or equipment.'},
#   {'name': 'TR.CapexActSueScore60Day',
#    'title': 'CAPEX - Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Capital Expenditure are the funds used by a company to acquire or upgrade physical assets such as property, industrial buildings, or equipment or the amount used during a particular period to acquire or improve long term assets such as property, plant, or equipment.'},
#   {'name': 'TR.CapexActSurprise',
#    'title': 'CAPEX - Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The difference between the actual and the last mean of the period, expressed as a percentage. Capital Expenditure are the funds used by a company to acquire or upgrade physical assets such as property, industrial buildings, or equipment or the amount used during a particular period to acquire or improve long term assets such as property, plant, or equipment.'},
#   {'name': 'TR.CapexActSurprise60Day',
#    'title': 'CAPEX - Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The difference between the actual and the mean 60 days ago, expressed as a percentage. Capital Expenditure are the funds used by a company to acquire or upgrade physical assets such as property, industrial buildings, or equipment or the amount used during a particular period to acquire or improve long term assets such as property, plant, or equipment.'},
#   {'name': 'TR.CFPSActValue',
#    'title': 'CFPS - Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Cash Flow Per Share is a corporation's cash flow from operations, before investing and financing activities, divided by the weighted average number of common shares outstanding for the year."},
#   {'name': 'TR.CFPSActReportDate',
#    'title': 'CFPS - Actual Reported Date',
#    'type': 'datetime',
#    'description': "The date the company announced its actual. Cash Flow Per Share is a corporation's cash flow from operations, before investing and financing activities, divided by the weighted average number of common shares outstanding for the year."},
#   {'name': 'TR.CFPSActSueScore',
#    'title': 'CFPS - Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Cash Flow Per Share is a corporation's cash flow from operations, before investing and financing activities, divided by the weighted average number of common shares outstanding for the year."},
#   {'name': 'TR.CFPSActSueScore60Day',
#    'title': 'CFPS - Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Cash Flow Per Share is a corporation's cash flow from operations, before investing and financing activities, divided by the weighted average number of common shares outstanding for the year."},
#   {'name': 'TR.CFPSActSurprise',
#    'title': 'CFPS - Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the last mean of the period, expressed as a percentage. Cash Flow Per Share is a corporation's cash flow from operations, before investing and financing activities, divided by the weighted average number of common shares outstanding for the year."},
#   {'name': 'TR.CFPSActSurprise60Day',
#    'title': 'CFPS - Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the mean 60 days ago, expressed as a percentage. Cash Flow Per Share is a corporation's cash flow from operations, before investing and financing activities, divided by the weighted average number of common shares outstanding for the year."},
#   {'name': 'TR.DPSActValue',
#    'title': 'DPS - Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Dividends Per Share are a corporation's common stock dividends on an annualized basis, divided by the weighted average number of common shares outstanding for the year. In the US dividend per share is calculated before withholding taxes (though for some non-US companies DPS is calculated after withholding taxes)."},
#   {'name': 'TR.DPSActReportDate',
#    'title': 'DPS - Actual Reported Date',
#    'type': 'datetime',
#    'description': "The date the company announced its actual. Dividends Per Share are a corporation's common stock dividends on an annualized basis, divided by the weighted average number of common shares outstanding for the year. In the US dividend per share is calculated before withholding taxes (though for some non-US companies DPS is calculated after withholding taxes)."},
#   {'name': 'TR.DPSActSueScore',
#    'title': 'DPS - Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Dividends Per Share are a corporation's common stock dividends on an annualized basis, divided by the weighted average number of common shares outstanding for the year. In the US dividend per share is calculated before withholding taxes (though for some non-US companies DPS is calculated after withholding taxes)."},
#   {'name': 'TR.DPSActSueScore60Day',
#    'title': 'DPS - Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Dividends Per Share are a corporation's common stock dividends on an annualized basis, divided by the weighted average number of common shares outstanding for the year. In the US dividend per share is calculated before withholding taxes (though for some non-US companies DPS is calculated after withholding taxes)."},
#   {'name': 'TR.DPSActSurprise',
#    'title': 'DPS - Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the last mean of the period, expressed as a percentage. Dividends Per Share are a corporation's common stock dividends on an annualized basis, divided by the weighted average number of common shares outstanding for the year. In the US dividend per share is calculated before withholding taxes (though for some non-US companies DPS is calculated after withholding taxes)."},
#   {'name': 'TR.DPSActSurprise60Day',
#    'title': 'DPS - Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the mean 60 days ago, expressed as a percentage. Dividends Per Share are a corporation's common stock dividends on an annualized basis, divided by the weighted average number of common shares outstanding for the year. In the US dividend per share is calculated before withholding taxes (though for some non-US companies DPS is calculated after withholding taxes)."},
#   {'name': 'TR.EBITActValue',
#    'title': 'EBIT - Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). EBIT represents the earnings of a company before interest expense and income taxes paid. As such, EBIT is a gauge of corporate earnings before any debt servicing to creditors (including bondholders) and the payment of corporate taxes. It is calculated in general form by taking the pre-tax corporate income of a company, adding back interest expense on debt, and subtracting any interest capitalized."},
#   {'name': 'TR.EBITActReportDate',
#    'title': 'EBIT - Actual Reported Date',
#    'type': 'datetime',
#    'description': 'The date the company announced its actual. EBIT represents the earnings of a company before interest expense and income taxes paid. As such, EBIT is a gauge of corporate earnings before any debt servicing to creditors (including bondholders) and the payment of corporate taxes. It is calculated in general form by taking the pre-tax corporate income of a company, adding back interest expense on debt, and subtracting any interest capitalized.'},
#   {'name': 'TR.EBITActSueScore',
#    'title': 'EBIT - Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. EBIT represents the earnings of a company before interest expense and income taxes paid. As such, EBIT is a gauge of corporate earnings before any debt servicing to creditors (including bondholders) and the payment of corporate taxes. It is calculated in general form by taking the pre-tax corporate income of a company, adding back interest expense on debt, and subtracting any interest capitalized.'},
#   {'name': 'TR.EBITActSueScore60Day',
#    'title': 'EBIT - Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. EBIT represents the earnings of a company before interest expense and income taxes paid. As such, EBIT is a gauge of corporate earnings before any debt servicing to creditors (including bondholders) and the payment of corporate taxes. It is calculated in general form by taking the pre-tax corporate income of a company, adding back interest expense on debt, and subtracting any interest capitalized.'},
#   {'name': 'TR.EBITActSurprise',
#    'title': 'EBIT - Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The difference between the actual and the last mean of the period, expressed as a percentage. EBIT represents the earnings of a company before interest expense and income taxes paid. As such, EBIT is a gauge of corporate earnings before any debt servicing to creditors (including bondholders) and the payment of corporate taxes. It is calculated in general form by taking the pre-tax corporate income of a company, adding back interest expense on debt, and subtracting any interest capitalized.'},
#   {'name': 'TR.EBITActSurprise60Day',
#    'title': 'EBIT - Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The difference between the actual and the mean 60 days ago, expressed as a percentage. EBIT represents the earnings of a company before interest expense and income taxes paid. As such, EBIT is a gauge of corporate earnings before any debt servicing to creditors (including bondholders) and the payment of corporate taxes. It is calculated in general form by taking the pre-tax corporate income of a company, adding back interest expense on debt, and subtracting any interest capitalized.'},
#   {'name': 'TR.EBITDAActValue',
#    'title': 'EBITDA - Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). EBITDA gauges the raw earnings power of a company before debt servicing, corporate taxes, and any allowances made for depreciation and amortization costs the company faces. It is calculated in general form by taking the pre-tax corporate income of a company, adding back any depreciation and amortization costs charged, plus any interest expense on debt (subtracting any capitalized interest)."},
#   {'name': 'TR.EBITDAActReportDate',
#    'title': 'EBITDA - Actual Reported Date',
#    'type': 'datetime',
#    'description': 'The date the company announced its actual. EBITDA gauges the raw earnings power of a company before debt servicing, corporate taxes, and any allowances made for depreciation and amortization costs the company faces. It is calculated in general form by taking the pre-tax corporate income of a company, adding back any depreciation and amortization costs charged, plus any interest expense on debt (subtracting any capitalized interest).'},
#   {'name': 'TR.EBITDAActSueScore',
#    'title': 'EBITDA - Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. EBITDA gauges the raw earnings power of a company before debt servicing, corporate taxes, and any allowances made for depreciation and amortization costs the company faces. It is calculated in general form by taking the pre-tax corporate income of a company, adding back any depreciation and amortization costs charged, plus any interest expense on debt (subtracting any capitalized interest).'},
#   {'name': 'TR.EBITDAActSueScore60Day',
#    'title': 'EBITDA - Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. EBITDA gauges the raw earnings power of a company before debt servicing, corporate taxes, and any allowances made for depreciation and amortization costs the company faces. It is calculated in general form by taking the pre-tax corporate income of a company, adding back any depreciation and amortization costs charged, plus any interest expense on debt (subtracting any capitalized interest).'},
#   {'name': 'TR.EBITDAActSurprise',
#    'title': 'EBITDA - Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The difference between the actual and the last mean of the period, expressed as a percentage. EBITDA gauges the raw earnings power of a company before debt servicing, corporate taxes, and any allowances made for depreciation and amortization costs the company faces. It is calculated in general form by taking the pre-tax corporate income of a company, adding back any depreciation and amortization costs charged, plus any interest expense on debt (subtracting any capitalized interest).'},
#   {'name': 'TR.EBITDAActSurprise60Day',
#    'title': 'EBITDA - Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The difference between the actual and the mean 60 days ago, expressed as a percentage. EBITDA gauges the raw earnings power of a company before debt servicing, corporate taxes, and any allowances made for depreciation and amortization costs the company faces. It is calculated in general form by taking the pre-tax corporate income of a company, adding back any depreciation and amortization costs charged, plus any interest expense on debt (subtracting any capitalized interest).'},
#   {'name': 'TR.EPSCashActValue',
#    'title': 'EPS Cash - Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Cash EPS is a company's net income, plus depreciation, plus amortization of goodwill, intangibles, and prepaid assets (non-cash items), divided by weighted or diluted number of shares outstanding."},
#   {'name': 'TR.EPSCashActReportDate',
#    'title': 'EPS Cash - Actual Reported Date',
#    'type': 'datetime',
#    'description': "The date the company announced its actual. Cash EPS is a company's net income, plus depreciation, plus amortization of goodwill, intangibles, and prepaid assets (non-cash items), divided by weighted or diluted number of shares outstanding."},
#   {'name': 'TR.EPSCashActSueScore',
#    'title': 'EPS Cash - Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Cash EPS is a company's net income, plus depreciation, plus amortization of goodwill, intangibles, and prepaid assets (non-cash items), divided by weighted or diluted number of shares outstanding."},
#   {'name': 'TR.EPSCashActSueScore60Day',
#    'title': 'EPS Cash - Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Cash EPS is a company's net income, plus depreciation, plus amortization of goodwill, intangibles, and prepaid assets (non-cash items), divided by weighted or diluted number of shares outstanding."},
#   {'name': 'TR.EPSCashActSurprise',
#    'title': 'EPS Cash - Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the last mean of the period, expressed as a percentage. Cash EPS is a company's net income, plus depreciation, plus amortization of goodwill, intangibles, and prepaid assets (non-cash items), divided by weighted or diluted number of shares outstanding."},
#   {'name': 'TR.EPSCashActSurprise60Day',
#    'title': 'EPS Cash - Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the mean 60 days ago, expressed as a percentage. Cash EPS is a company's net income, plus depreciation, plus amortization of goodwill, intangibles, and prepaid assets (non-cash items), divided by weighted or diluted number of shares outstanding."},
#   {'name': 'TR.EPSActValue',
#    'title': 'EPS - Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Earnings Per Share is defined as the EPS that the contributing analyst considers to be that with which to value a security. This figure may include or exclude certain items depending on the contributing analyst's specific model."},
#   {'name': 'TR.EPSActReportDate',
#    'title': 'EPS - Actual Reported Date',
#    'type': 'datetime',
#    'description': "The date the company announced its actual. Earnings Per Share is defined as the EPS that the contributing analyst considers to be that with which to value a security. This figure may include or exclude certain items depending on the contributing analyst's specific model."},
#   {'name': 'TR.EPSActSueScore',
#    'title': 'EPS - Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Earnings Per Share is defined as the EPS that the contributing analyst considers to be that with which to value a security. This figure may include or exclude certain items depending on the contributing analyst's specific model."},
#   {'name': 'TR.EPSActSueScore60Day',
#    'title': 'EPS - Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Earnings Per Share is defined as the EPS that the contributing analyst considers to be that with which to value a security. This figure may include or exclude certain items depending on the contributing analyst's specific model."},
#   {'name': 'TR.EPSActSurprise',
#    'title': 'EPS - Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the last mean of the period, expressed as a percentage. Earnings Per Share is defined as the EPS that the contributing analyst considers to be that with which to value a security. This figure may include or exclude certain items depending on the contributing analyst's specific model."},
#   {'name': 'TR.EPSActSurprise60Day',
#    'title': 'EPS - Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the mean 60 days ago, expressed as a percentage. Earnings Per Share is defined as the EPS that the contributing analyst considers to be that with which to value a security. This figure may include or exclude certain items depending on the contributing analyst's specific model."},
#   {'name': 'TR.EPSFRActValue',
#    'title': 'EPS Reported- Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Earnings Per Share Reported is statutory or reported earnings per share, defined as net profit (on continuous activities) divided by the weighted average number of shares outstanding during the period. Where a company carries exceptional items or goodwill amortization, this measure is post-exceptional, post-goodwill."},
#   {'name': 'TR.EPSFRActReportDate',
#    'title': 'EPS Reported- Actual Reported Date',
#    'type': 'datetime',
#    'description': 'The date the company announced its actual. Earnings Per Share Reported is statutory or reported earnings per share, defined as net profit (on continuous activities) divided by the weighted average number of shares outstanding during the period. Where a company carries exceptional items or goodwill amortization, this measure is post-exceptional, post-goodwill.'},
#   {'name': 'TR.EPSFRActSueScore',
#    'title': 'EPS Reported- Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Earnings Per Share Reported is statutory or reported earnings per share, defined as net profit (on continuous activities) divided by the weighted average number of shares outstanding during the period. Where a company carries exceptional items or goodwill amortization, this measure is post-exceptional, post-goodwill.'},
#   {'name': 'TR.EPSFRActSueScore60Day',
#    'title': 'EPS Reported- Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Earnings Per Share Reported is statutory or reported earnings per share, defined as net profit (on continuous activities) divided by the weighted average number of shares outstanding during the period. Where a company carries exceptional items or goodwill amortization, this measure is post-exceptional, post-goodwill.'},
#   {'name': 'TR.EPSFRActSurprise',
#    'title': 'EPS Reported- Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The difference between the actual and the last mean of the period, expressed as a percentage. Earnings Per Share Reported is statutory or reported earnings per share, defined as net profit (on continuous activities) divided by the weighted average number of shares outstanding during the period. Where a company carries exceptional items or goodwill amortization, this measure is post-exceptional, post-goodwill.'},
#   {'name': 'TR.EPSFRActSurprise60Day',
#    'title': 'EPS Reported- Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The difference between the actual and the mean 60 days ago, expressed as a percentage. Earnings Per Share Reported is statutory or reported earnings per share, defined as net profit (on continuous activities) divided by the weighted average number of shares outstanding during the period. Where a company carries exceptional items or goodwill amortization, this measure is post-exceptional, post-goodwill.'},
#   {'name': 'TR.EBITDAPSActValue',
#    'title': 'EBITDA Per Share - Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). EBITDA Per Share represents earnings before interest, taxes, depreciation, and amortization divided by the weighted average number of shares outstanding."},
#   {'name': 'TR.EBITDAPSActReportDate',
#    'title': 'EBITDA Per Share - Actual Reported Date',
#    'type': 'datetime',
#    'description': 'The date the company announced its actual. EBITDA Per Share represents earnings before interest, taxes, depreciation, and amortization divided by the weighted average number of shares outstanding.'},
#   {'name': 'TR.EBITDAPSActSueScore',
#    'title': 'EBITDA Per Share - Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. EBITDA Per Share represents earnings before interest, taxes, depreciation, and amortization divided by the weighted average number of shares outstanding.'},
#   {'name': 'TR.EBITDAPSActSueScore60Day',
#    'title': 'EBITDA Per Share - Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. EBITDA Per Share represents earnings before interest, taxes, depreciation, and amortization divided by the weighted average number of shares outstanding.'},
#   {'name': 'TR.EBITDAPSActSurprise',
#    'title': 'EBITDA Per Share - Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The difference between the actual and the last mean of the period, expressed as a percentage. EBITDA Per Share represents earnings before interest, taxes, depreciation, and amortization divided by the weighted average number of shares outstanding.'},
#   {'name': 'TR.EBITDAPSActSurprise60Day',
#    'title': 'EBITDA Per Share - Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The difference between the actual and the mean 60 days ago, expressed as a percentage. EBITDA Per Share represents earnings before interest, taxes, depreciation, and amortization divided by the weighted average number of shares outstanding.'},
#   {'name': 'TR.EVActValue',
#    'title': 'EV - Actual Value',
#    'type': 'string',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Enterprise Value is calculated as market capitalization, plus debt, minority interest and preferred shares, minus total cash and cash equivalents."},
#   {'name': 'TR.EVActReportDate',
#    'title': 'EV - Actual Reported Date',
#    'type': 'datetime',
#    'description': 'The date the company announced its actual. Enterprise Value is calculated as market capitalization, plus debt, minority interest and preferred shares, minus total cash and cash equivalents.'},
#   {'name': 'TR.EVActSueScore',
#    'title': 'EV - Actual Standard Unexpected Earnings',
#    'type': 'string',
#    'description': 'The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Enterprise Value is calculated as market capitalization, plus debt, minority interest and preferred shares, minus total cash and cash equivalents.'},
#   {'name': 'TR.EVActSueScore60Day',
#    'title': 'EV - Actual Standard Unexpected Earnings 60Days',
#    'type': 'string',
#    'description': 'The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Enterprise Value is calculated as market capitalization, plus debt, minority interest and preferred shares, minus total cash and cash equivalents.'},
#   {'name': 'TR.EVActSurprise',
#    'title': 'EV - Actual Surprise',
#    'type': 'string',
#    'description': 'The difference between the actual and the last mean of the period, expressed as a percentage. Enterprise Value is calculated as market capitalization, plus debt, minority interest and preferred shares, minus total cash and cash equivalents.'},
#   {'name': 'TR.EVActSurprise60Day',
#    'title': 'EV - Actual Surprise 60Days',
#    'type': 'string',
#    'description': 'The difference between the actual and the mean 60 days ago, expressed as a percentage. Enterprise Value is calculated as market capitalization, plus debt, minority interest and preferred shares, minus total cash and cash equivalents.'},
#   {'name': 'TR.GPMActValue',
#    'title': 'GPM - Actual Value',
#    'type': 'string',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Gross (Profit) Margin is a company's total sales revenue minus cost of goods sold, divided by the total sales revenue, expressed as a percentage."},
#   {'name': 'TR.GPMActReportDate',
#    'title': 'GPM - Actual Reported Date',
#    'type': 'datetime',
#    'description': "The date the company announced its actual. Gross (Profit) Margin is a company's total sales revenue minus cost of goods sold, divided by the total sales revenue, expressed as a percentage."},
#   {'name': 'TR.GPMActSueScore',
#    'title': 'GPM - Actual Standard Unexpected Earnings',
#    'type': 'string',
#    'description': "The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Gross (Profit) Margin is a company's total sales revenue minus cost of goods sold, divided by the total sales revenue, expressed as a percentage."},
#   {'name': 'TR.GPMActSueScore60Day',
#    'title': 'GPM - Actual Standard Unexpected Earnings 60Days',
#    'type': 'string',
#    'description': "The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Gross (Profit) Margin is a company's total sales revenue minus cost of goods sold, divided by the total sales revenue, expressed as a percentage."},
#   {'name': 'TR.GPMActSurprise',
#    'title': 'GPM - Actual Surprise',
#    'type': 'string',
#    'description': "The difference between the actual and the last mean of the period, expressed as a percentage. Gross (Profit) Margin is a company's total sales revenue minus cost of goods sold, divided by the total sales revenue, expressed as a percentage."},
#   {'name': 'TR.GPMActSurprise60Day',
#    'title': 'GPM - Actual Surprise 60Days',
#    'type': 'string',
#    'description': "The difference between the actual and the mean 60 days ago, expressed as a percentage. Gross (Profit) Margin is a company's total sales revenue minus cost of goods sold, divided by the total sales revenue, expressed as a percentage."},
#   {'name': 'TR.NAVPSActValue',
#    'title': 'NAV per Share - Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Net Asset Value Per Share is an expression for net asset value that represents a fund's (mutual, exchange-traded, and closed-end) or a company's value per share. It is calculated by dividing the total net asset value of the fund or company by the number of shares out"},
#   {'name': 'TR.NAVPSActReportDate',
#    'title': 'NAV per Share - Actual Reported Date',
#    'type': 'datetime',
#    'description': "The date the company announced its actual. Net Asset Value Per Share is an expression for net asset value that represents a fund's (mutual, exchange-traded, and closed-end) or a company's value per share. It is calculated by dividing the total net asset value of the fund or company by the number of shares out"},
#   {'name': 'TR.NAVPSActSueScore',
#    'title': 'NAV per Share - Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Net Asset Value Per Share is an expression for net asset value that represents a fund's (mutual, exchange-traded, and closed-end) or a company's value per share. It is calculated by dividing the total net asset value of the fund or company by the number of shares out"},
#   {'name': 'TR.NAVPSActSueScore60Day',
#    'title': 'NAV per Share - Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Net Asset Value Per Share is an expression for net asset value that represents a fund's (mutual, exchange-traded, and closed-end) or a company's value per share. It is calculated by dividing the total net asset value of the fund or company by the number of shares out"},
#   {'name': 'TR.NAVPSActSurprise',
#    'title': 'NAV per Share - Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the last mean of the period, expressed as a percentage. Net Asset Value Per Share is an expression for net asset value that represents a fund's (mutual, exchange-traded, and closed-end) or a company's value per share. It is calculated by dividing the total net asset value of the fund or company by the number of shares out"},
#   {'name': 'TR.NAVPSActSurprise60Day',
#    'title': 'NAV per Share - Actual Surprise 60Days',
#    'type': 'number',
# ...
#   {'name': 'TR.NetProfitRepActSurprise60Day',
#    'title': 'Reported Net Income - Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The difference between the actual and the mean 60 days ago, expressed as a percentage. Net Income Reported is the net income earned after deducting all expenses including operating and non operating, interest expense and income and taxation. It is inclusive of all amortization and one-time charges.'},
#   {'name': 'TR.PreTaxProfitRepActValue',
#    'title': 'Reported PTP- Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Pre-Tax Profit Reported is the Pre-Tax Profit reported by the company inclusive of all amortization and one-time charges."},
#   {'name': 'TR.PreTaxProfitRepActReportDate',
#    'title': 'Reported PTP- Actual Reported Date',
#    'type': 'datetime',
#    'description': 'The date the company announced its actual. Pre-Tax Profit Reported is the Pre-Tax Profit reported by the company inclusive of all amortization and one-time charges.'},
#   {'name': 'TR.PreTaxProfitRepActSueScore',
#    'title': 'Reported PTP- Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Pre-Tax Profit Reported is the Pre-Tax Profit reported by the company inclusive of all amortization and one-time charges.'},
#   {'name': 'TR.PreTaxProfitRepActSueScore60Day',
#    'title': 'Reported PTP- Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Pre-Tax Profit Reported is the Pre-Tax Profit reported by the company inclusive of all amortization and one-time charges.'},
#   {'name': 'TR.PreTaxProfitRepActSurprise',
#    'title': 'Reported PTP- Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The difference between the actual and the last mean of the period, expressed as a percentage. Pre-Tax Profit Reported is the Pre-Tax Profit reported by the company inclusive of all amortization and one-time charges.'},
#   {'name': 'TR.PreTaxProfitRepActSurprise60Day',
#    'title': 'Reported PTP- Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': 'The difference between the actual and the mean 60 days ago, expressed as a percentage. Pre-Tax Profit Reported is the Pre-Tax Profit reported by the company inclusive of all amortization and one-time charges.'},
#   {'name': 'TR.ROAActValue',
#    'title': 'ROA - Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Return On Assets is a profitability ratio and as such gauges the return on investment of a company. Specifically, ROA measures a company's operating efficiency regardless of its financial structure (in particular, without regard to the degree of leverage a company uses) and is calculated by dividing a company’s net income prior to financing costs by total assets."},
#   {'name': 'TR.ROAActReportDate',
#    'title': 'ROA - Actual Reported Date',
#    'type': 'datetime',
#    'description': "The date the company announced its actual. Return On Assets is a profitability ratio and as such gauges the return on investment of a company. Specifically, ROA measures a company's operating efficiency regardless of its financial structure (in particular, without regard to the degree of leverage a company uses) and is calculated by dividing a company’s net income prior to financing costs by total assets."},
#   {'name': 'TR.ROAActSueScore',
#    'title': 'ROA - Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Return On Assets is a profitability ratio and as such gauges the return on investment of a company. Specifically, ROA measures a company's operating efficiency regardless of its financial structure (in particular, without regard to the degree of leverage a company uses) and is calculated by dividing a company’s net income prior to financing costs by total assets."},
#   {'name': 'TR.ROAActSueScore60Day',
#    'title': 'ROA - Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Return On Assets is a profitability ratio and as such gauges the return on investment of a company. Specifically, ROA measures a company's operating efficiency regardless of its financial structure (in particular, without regard to the degree of leverage a company uses) and is calculated by dividing a company’s net income prior to financing costs by total assets."},
#   {'name': 'TR.ROAActSurprise',
#    'title': 'ROA - Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the last mean of the period, expressed as a percentage. Return On Assets is a profitability ratio and as such gauges the return on investment of a company. Specifically, ROA measures a company's operating efficiency regardless of its financial structure (in particular, without regard to the degree of leverage a company uses) and is calculated by dividing a company’s net income prior to financing costs by total assets."},
#   {'name': 'TR.ROAActSurprise60Day',
#    'title': 'ROA - Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the mean 60 days ago, expressed as a percentage. Return On Assets is a profitability ratio and as such gauges the return on investment of a company. Specifically, ROA measures a company's operating efficiency regardless of its financial structure (in particular, without regard to the degree of leverage a company uses) and is calculated by dividing a company’s net income prior to financing costs by total assets."},
#   {'name': 'TR.ROEActValue',
#    'title': 'ROE - Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Return On Equity is a profitability ratio calculated by dividing a company's net income by total equity of common shares."},
#   {'name': 'TR.ROEActReportDate',
#    'title': 'ROE - Actual Reported Date',
#    'type': 'datetime',
#    'description': "The date the company announced its actual. Return On Equity is a profitability ratio calculated by dividing a company's net income by total equity of common shares."},
#   {'name': 'TR.ROEActSueScore',
#    'title': 'ROE - Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Return On Equity is a profitability ratio calculated by dividing a company's net income by total equity of common shares."},
#   {'name': 'TR.ROEActSueScore60Day',
#    'title': 'ROE - Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Return On Equity is a profitability ratio calculated by dividing a company's net income by total equity of common shares."},
#   {'name': 'TR.ROEActSurprise',
#    'title': 'ROE - Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the last mean of the period, expressed as a percentage. Return On Equity is a profitability ratio calculated by dividing a company's net income by total equity of common shares."},
#   {'name': 'TR.ROEActSurprise60Day',
#    'title': 'ROE - Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the mean 60 days ago, expressed as a percentage. Return On Equity is a profitability ratio calculated by dividing a company's net income by total equity of common shares."},
#   {'name': 'TR.RevenueActValue',
#    'title': 'Revenue - Actual Value',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Revenue (or Sales) is a corporation's net revenue, generally derived from core business activities. For non-financial companies, the calculation of net revenue (or net turnover) in most markets generally involves subtracting transportation and related operational costs from gross revenue/sales. Revenue recognition practices vary significantly from market to market, though generally the recording of revenue is based upon sales invoices issued (or anticipated for forecast purposes) during the accounting period."},
#   {'name': 'TR.RevenueActReportDate',
#    'title': 'Revenue - Actual Reported Date',
#    'type': 'datetime',
#    'description': "The date the company announced its actual. Revenue (or Sales) is a corporation's net revenue, generally derived from core business activities. For non-financial companies, the calculation of net revenue (or net turnover) in most markets generally involves subtracting transportation and related operational costs from gross revenue/sales. Revenue recognition practices vary significantly from market to market, though generally the recording of revenue is based upon sales invoices issued (or anticipated for forecast purposes) during the accounting period."},
#   {'name': 'TR.RevenueActSueScore',
#    'title': 'Revenue - Actual Standard Unexpected Earnings',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Revenue (or Sales) is a corporation's net revenue, generally derived from core business activities. For non-financial companies, the calculation of net revenue (or net turnover) in most markets generally involves subtracting transportation and related operational costs from gross revenue/sales. Revenue recognition practices vary significantly from market to market, though generally the recording of revenue is based upon sales invoices issued (or anticipated for forecast purposes) during the accounting period."},
#   {'name': 'TR.RevenueActSueScore60Day',
#    'title': 'Revenue - Actual Standard Unexpected Earnings 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Revenue (or Sales) is a corporation's net revenue, generally derived from core business activities. For non-financial companies, the calculation of net revenue (or net turnover) in most markets generally involves subtracting transportation and related operational costs from gross revenue/sales. Revenue recognition practices vary significantly from market to market, though generally the recording of revenue is based upon sales invoices issued (or anticipated for forecast purposes) during the accounting period."},
#   {'name': 'TR.RevenueActSurprise',
#    'title': 'Revenue - Actual Surprise',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the last mean of the period, expressed as a percentage. Revenue (or Sales) is a corporation's net revenue, generally derived from core business activities. For non-financial companies, the calculation of net revenue (or net turnover) in most markets generally involves subtracting transportation and related operational costs from gross revenue/sales. Revenue recognition practices vary significantly from market to market, though generally the recording of revenue is based upon sales invoices issued (or anticipated for forecast purposes) during the accounting period."},
#   {'name': 'TR.RevenueActSurprise60Day',
#    'title': 'Revenue - Actual Surprise 60Days',
#    'type': 'number',
#    'decimalChar': '.',
#    'description': "The difference between the actual and the mean 60 days ago, expressed as a percentage. Revenue (or Sales) is a corporation's net revenue, generally derived from core business activities. For non-financial companies, the calculation of net revenue (or net turnover) in most markets generally involves subtracting transportation and related operational costs from gross revenue/sales. Revenue recognition practices vary significantly from market to market, though generally the recording of revenue is based upon sales invoices issued (or anticipated for forecast purposes) during the accounting period."},
#   {'name': 'TR.FFOActValue',
#    'title': 'FFO Per Share - Actual Value',
#    'type': 'string',
#    'description': "The company's actual value normalized to reflect the I/B/E/S default currency and corporate actions (e.g. stock splits). Funds From Operations Per Share is a measure used for real estate companies and other investment trusts to define the cash flow from trust operations. It is earnings with depreciation and amortization added back."},
#   {'name': 'TR.FFOActReportDate',
#    'title': 'FFO Per Share - Actual Reported Date',
#    'type': 'datetime',
#    'description': 'The date the company announced its actual. Funds From Operations Per Share is a measure used for real estate companies and other investment trusts to define the cash flow from trust operations. It is earnings with depreciation and amortization added back.'},
#   {'name': 'TR.FFOActSueScore',
#    'title': 'FFO Per Share - Actual Standard Unexpected Earnings',
#    'type': 'string',
#    'description': 'The SUE score is the the actual value, minus the mean, divided by the standard deviation of the mean. Funds From Operations Per Share is a measure used for real estate companies and other investment trusts to define the cash flow from trust operations. It is earnings with depreciation and amortization added back.'},
#   {'name': 'TR.FFOActSueScore60Day',
#    'title': 'FFO Per Share - Actual Standard Unexpected Earnings 60Days',
#    'type': 'string',
#    'description': 'The 60 day SUE score is the actual, minus the mean 60 days ago, divided by the standard deviation of the mean 60 days ago. Funds From Operations Per Share is a measure used for real estate companies and other investment trusts to define the cash flow from trust operations. It is earnings with depreciation and amortization added back.'},
#   {'name': 'TR.FFOActSurprise',
#    'title': 'FFO Per Share - Actual Surprise',
#    'type': 'string',
#    'description': 'The difference between the actual and the last mean of the period, expressed as a percentage. Funds From Operations Per Share is a measure used for real estate companies and other investment trusts to define the cash flow from trust operations. It is earnings with depreciation and amortization added back.'},
#   {'name': 'TR.FFOActSurprise60Day',
#    'title': 'FFO Per Share - Actual Surprise 60Days',
#    'type': 'string',
#    'description': 'The difference between the actual and the mean 60 days ago, expressed as a percentage. Funds From Operations Per Share is a measure used for real estate companies and other investment trusts to define the cash flow from trust operations. It is earnings with depreciation and amortization added back.'}]}

# %%
response.errors
# Out:
# [Error(code=None, message="Failed to resolve identifiers ['INVALID']")]

# %% [markdown]
# #### view_actuals - Interim

# %%
response = estimates.view_actuals.interim.Definition("BNPP.PA", Package.BASIC).get_data()
response.data.df
# Out:
#   Instrument Period End Date Financial Period Absolute  \
# 0    BNPP.PA      2021-12-31                  FY2021Q4
# 1    BNPP.PA      2021-09-30                  FY2021Q3
#
#   Financial Period Relative  EBIT - Actual Value EBIT - Actual Reported Date  \
# 0                       FQ0           3302000000         2022-02-08T10:47:00
# 1                      FQ-1           3280000000         2021-10-29T05:58:00
#
#    EBIT - Actual Standard Unexpected Earnings  \
# 0                                    -0.37878
# 1                                    -0.01864
#
#   EBIT - Actual Standard Unexpected Earnings 60Days  EBIT - Actual Surprise  \
# 0                                              None                  -3.984
# 1                                              None                  -0.213
#
#   EBIT - Actual Surprise 60Days  ...  \
# 0                          None  ...
# 1                          None  ...
#
#    EPS - Actual Standard Unexpected Earnings  \
# 0                                    1.50847
# 1                                    1.53461
#
#   EPS - Actual Standard Unexpected Earnings 60Days  EPS - Actual Surprise  \
# 0                                          1.35453                  7.741
# 1                                          1.96371                  8.717
#
#    EPS - Actual Surprise 60Days  Revenue - Actual Value  \
# 0                         3.914             11232000000
# 1                        15.963             11398000000
#
#    Revenue - Actual Reported Date  \
# 0             2022-02-08T10:47:00
# 1             2021-10-29T05:58:00
#
#    Revenue - Actual Standard Unexpected Earnings  \
# 0                                       -0.90501
# 1                                        2.08022
#
#   Revenue - Actual Standard Unexpected Earnings 60Days  \
# 0                                           -1.35991
# 1                                            3.92143
#
#    Revenue - Actual Surprise  Revenue - Actual Surprise 60Days
# 0                     -1.256                            -2.215
# 1                      1.615                             3.285
#
# [2 rows x 22 columns]

# %% [markdown]
# ### Close the session

# %%
rd.close_session()
