# %% [markdown]
# ----
# <img src="../../../files/refinitiv.png" width="20%" style="vertical-align: top;">
#
# # Data Library for Python
#
# ----

# %% [markdown]
# ## Content layer - Ownership - Fund
# This notebook demonstrates how to retrieve Ownership fund data.

# %% [markdown]
# #### Learn more
#
# To learn more about the Refinitiv Data Library for Python please join the Refinitiv Developer Community. By [registering](https://developers.refinitiv.com/iam/register) and [logging](https://developers.refinitiv.com/content/devportal/en_us/initCookie.html) into the Refinitiv Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/quick-start),
#  [Tutorials](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/learning),
#  [Documentation](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/docs)
#  and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# the [Refinitiv Data Q&A Forum](https://community.developers.refinitiv.com/spaces/321/index.html).
# The Refinitiv Developer Community will be happy to help.

# %% [markdown]
# ## Set the configuration file location
# For a better ease of use, you have the option to set initialization parameters of the Refinitiv Data Library in the _refinitiv-data.config.json_ configuration file. This file must be located beside your notebook, in your user folder or in a folder defined by the _RD_LIB_CONFIG_PATH_ environment variable. The _RD_LIB_CONFIG_PATH_ environment variable is the option used by this series of examples. The following code sets this environment variable.

# %%
import os
os.environ["RD_LIB_CONFIG_PATH"] = "../../../Configuration"

# %% [markdown]
# ## Some Imports to start with

# %%
import refinitiv.data as rd
from refinitiv.data.content import ownership

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the refinitiv-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
rd.open_session("platform.rdp")
# Out:
# <refinitiv.data.session.platform.Definition object at 0x7fc6b61f90d0 {session_name='rdp'}>

# %% [markdown]
# ## Retrieve data

# %% [markdown]
# ### Fund - Breakdown

# %%
response = ownership.fund.breakdown.Definition("LSEG.L", 1).get_data()
response.data.df
# Out:
#   instrument                categoryvalue TR.CatFundInvestorCount  \
# 0     LSEG.L                  Mutual Fund                    1897
# 1     LSEG.L         Exchange-Traded Fund                     306
# 2     LSEG.L  Insurance Company Portfolio                     160
# 3     LSEG.L       Pension Fund Portfolio                      62
# 4     LSEG.L   Investment Trust Portfolio                      10
# 5     LSEG.L              Closed-End Fund                       5
#
#   TR.CatFundOwnershipPct TR.InstrFdStatCatShrsHld TR.InstrFdStatCatShHldVal
# 0                29.1594                143484991            14700664287.21
# 1                 2.8323                 14271751             1271041481.19
# 2                 0.7006                  3547925              350309704.72
# 3                  0.604                  2823875              303592476.95
# 4                 0.5892                  2982427              292151583.67
# 5                 0.0235                   118622               11861417.04

# %% [markdown]
# ### Fund - Concentration

# %%
response = ownership.fund.concentration.Definition("LSEG.L").get_data()
response.data.df
# Out:
#   instrument Investors Total % SharesOutstandingAll SharesHeldAll  \
# 0     LSEG.L            2440       33.0331000000006     167229591
#
#   SharesHeld ValueAll
# 0      16929620950.78

# %% [markdown]
# ### Fund - Holdings

# %%
response = ownership.fund.holdings.Definition("LP40189339").get_data()
response.data.df
# Out:
#    instrument TR.FundName  Total Holdings Count TR.FdSecurityOwnedRIC  \
# 0  LP40189339        None                     0                  None
#
#   TR.FdSecurityOwnedName TR.FdInvPortfolioRank TR.FdInvestorSharesHeld  \
# 0                   None                  None                    None
#
#   TR.FdPctSecuritySharesOut TR.FdInvestorPctPortfolio TR.FdInvestorValueHeld  \
# 0                      None                      None                   None
#
#   TR.FdInvestorFilingDate TR.FdInvestorFilingType TR.FdInvestorShrsHeldChg  \
# 0                    None                    None                     None
#
#   TR.FdInvestorValueHeldChg TR.FdInvestorPosPctChg
# 0                      None                   None

# %% [markdown]
# ### Fund - Investors

# %%
response = ownership.fund.investors.Definition("LSEG.L").get_data()
response.data.df
# Out:
#    instrument investorid investorpermid  \
# 0      LSEG.L    2833468    48469266648
# 1      LSEG.L    5729825    48469250420
# 2      LSEG.L    2832222    48469264451
# 3      LSEG.L    5263396    48469184949
# 4      LSEG.L    2851488    48469311703
# 5      LSEG.L    2808986    48469210077
# 6      LSEG.L    9832789    48469722899
# 7      LSEG.L    2848423    48469304170
# 8      LSEG.L    2851490    48469311705
# 9      LSEG.L    2812185    48469219142
# 10     LSEG.L    2790893    48469171694
# 11     LSEG.L    2848405    48469304152
# 12     LSEG.L    5716115    48469309918
# 13     LSEG.L    2991554    48469304081
# 14     LSEG.L    2834421    48469268785
# 15     LSEG.L   10222171    48469763320
# 16     LSEG.L    4197588    48469240551
# 17     LSEG.L    2810158    48469212798
# 18     LSEG.L    5834356    48469240413
# 17                 142870          2021-09-30                   LOW
# 18                  36118          2021-11-30                   LOW
# 19                 -16044          2021-07-31                   LOW

# %% [markdown]
# ### Fund - Recent activity

# %%
response = ownership.fund.recent_activity.Definition("LSEG.L", "asc").get_data()
response.data.df
# Out:
#   instrument                                       investorname investorid  \
# 0     LSEG.L             American Funds EuroPacific Growth Fund    2808986
# 1     LSEG.L                American Funds New Perspective Fund    2833468
# 2     LSEG.L  American Funds Capital World Growth & Income Fund    2800362
# 3     LSEG.L              Fidelity International Discovery Fund    2810473
# 4     LSEG.L            Fidelity Diversified International Fund    2810232
#
#   TR.NetAdjSharesHeldChange TR.NetAdjSharesHeldValChg
# 0                  -4157497             -430691413.43
# 1                  -1229893             -135536174.47
# 2                  -1029600             -113463565.72
# 3                   -946315               -98640040.6
# 4                   -791800              -82440494.88

# %% [markdown]
# ### Fund - Shareholders history report

# %%
response = ownership.fund.shareholders_history_report.Definition("LSEG.L", "M", start="-1Q").get_data()
response.data.df
# Out:
#    instrument investorpermid                             TR.FundPortfolioName  \
# 0      LSEG.L    48469266648              American Funds New Perspective Fund
# 1      LSEG.L    48469250420                Lindsell Train Global Equity Fund
# 2      LSEG.L    48469264451                      Statens Pensjonsfond Utland
# 3      LSEG.L    48469210077           American Funds EuroPacific Growth Fund
# 4      LSEG.L    48469184949                 LF Lindsell Train UK Equity Fund
# ..        ...            ...                                              ...
# 95     LSEG.L    48469259521  Liontrust Sustainable Future Global Growth Fund
# 96     LSEG.L    48469217677     AXA Framlington UK Select Opportunities Fund
# 97     LSEG.L    48469240808               iShares MSCI Europe Financials ETF
# 98     LSEG.L    48469240412  iShares Core MSCI Total International Stock ETF
# 99     LSEG.L    48469738047                  Fiera International Equity Fund
#
#    TR.FundParentType TR.FundClassId   TR.FundInvestorType   TR.FundRegion  \
# 0              Funds     LP40000669           Mutual Fund   North America
# 1              Funds     LP68094532           Mutual Fund          Europe
# 2              Funds                          Mutual Fund          Europe
# 3              Funds     LP40001258           Mutual Fund  Asia / Pacific
# 4              Funds     LP65022060           Mutual Fund          Europe
# ..               ...            ...                   ...             ...
# 95             Funds     LP60052206           Mutual Fund          Europe
# 96             Funds     LP60009708           Mutual Fund          Europe
# 97             Funds     LP40181428  Exchange-Traded Fund   North America
# 98             Funds     LP40201018  Exchange-Traded Fund   North America
# 99             Funds                          Mutual Fund   North America
#
#    TR.FundInvtStyleCode TR.FundInvtOrientation TR.FundTurnoverRating  ...  \
# 0           Core Growth                 Active                   LOW  ...
# 1                                       Active                   LOW  ...
# 2            Core Value                 Active                   LOW  ...
# 3                Growth                 Active                   LOW  ...
# 4                 Yield                 Active                   LOW  ...
# ..                  ...                    ...                   ...  ...
# 95          Core Growth                 Active                   MED  ...
# 96            Specialty                 Active                   LOW  ...
# 97                Index                Passive                   MED  ...
# 98                Index                Passive                   LOW  ...
# 99                                      Active                        ...
#
#     TR.FdAdjSharesHeldValue  TR.FundHoldingsDate  TR.FundFilingType  \
# 0              991580978.68           2021-06-30                 MF
# 1              897603039.18           2021-06-30                 MF
# 2              924212523.23           2020-12-31                 MF
# 3              806551723.54           2021-06-30                 MF
# 4              739618027.71           2021-06-30                 MF
# ..                      ...                  ...                ...
# 95              32613501.84           2021-06-30                 MF
# 96              32547601.28           2021-06-30                 MF
# 97              32484014.96           2021-06-30                 MF
# 98              32323120.63           2021-06-30                 MF
# 99              35447330.46           2020-12-31                 MF
#
#     TR.FdAdjShrsHeldChange  TR.FdAdjShrsHeldValChg TR.PrevFundAdjSharesHeld  \
# 0                 -1229893           -135536174.47                 10227775
# 1                   153553             16921786.04                  7991547
# 2                   984875            121303225.45                  6518914
# 3                 -1364314           -150349583.53                  8683189
# 4                   -17500             -1928527.97                  6729000
# ..                     ...                     ...                      ...
# 95                   13544              1492570.45                   282400
# 96                       0                     0.0                   295346
# 97                    9659              1064437.24                   285110
# 98                    4392               484005.42                   288917
# 99                       0                     0.0                   287801
#
#    TR.PrevAdjSharesHeldValue  TR.PrevAdjPctShrsOutHeld  \
# 0               978046662.72                    2.0939
# 1               834822532.43                    1.5791
# 2               669869842.22                    1.8639
# 3               830343258.74                    1.7777
# 4                702932839.0                    1.3297
# ..                       ...                       ...
# 95               29500406.26                    0.0558
# 96               30852786.78                    0.0584
# 97               29783501.52                    0.0563
# 98                30181192.9                    0.0571
# 99               29824936.24                    0.0819
#
#     TR.PrevFundHoldingsDate  TR.PrevFundFilingType
# 0                2021-03-31                     MF
# 1                2021-05-31                     MF
# 2                2019-12-31                     MF
# 3                2021-03-31                     MF
# 4                2021-05-31                     MF
# ..                      ...                    ...
# 95               2021-05-31                     MF
# 96               2021-05-31                     MF
# 97               2021-05-31                     MF
# 98               2021-05-31                     MF
# 99               2020-06-30                     MF
#
# [100 rows x 24 columns]

# %% [markdown]
# ### Fund - Shareholders report

# %%
response = ownership.fund.shareholders_report.Definition("LSEG.L").get_data()
response.data.df
# Out:
#       calcdate investorid investorpermid  \
# 0   2021-12-16    2833468    48469266648
# 1   2021-12-16    5729825    48469250420
# 2   2021-12-16    2832222    48469264451
# 3   2021-12-16    5263396    48469184949
# 4   2021-12-16    2851488    48469311703
# ..         ...        ...            ...
# 95  2021-12-16    5540861    48469314065
# 96  2021-12-16    2812510    48469217677
# 97  2021-12-16    2815148    48469224564
# 98  2021-12-16    6040825    48469698848
# 99  2021-12-16    2818525    48469232789
#
#                              TR.FundPortfolioName TR.FundParentType  \
# 0             American Funds New Perspective Fund             Funds
# 1               Lindsell Train Global Equity Fund             Funds
# 2                     Statens Pensjonsfond Utland             Funds
# 3                LF Lindsell Train UK Equity Fund             Funds
# 4   Vanguard Total International Stock Index Fund             Funds
# ..                                            ...               ...
# 95      iShares Core FTSE 100 UCITS ETF GBP (Acc)             Funds
# 96   AXA Framlington UK Select Opportunities Fund             Funds
# 97            Ninety One GSF European Equity Fund             Funds
# 98           Standard Life UK Equity Pension Fund             Funds
# 99                 HSBC FTSE All-Share Index Fund             Funds
#
#    TR.FundClassId     TR.FundInvestorType  TR.FundRegion TR.FundInvtStyleCode  \
# 0      LP40000669             Mutual Fund  North America          Core Growth
# 1      LP68094532             Mutual Fund         Europe
# 2                             Mutual Fund         Europe           Core Value
# 3      LP65022060             Mutual Fund         Europe                Yield
# 4      LP40018504             Mutual Fund  North America                Index
# ..            ...                     ...            ...                  ...
# 95     LP68038689    Exchange-Traded Fund         Europe                Index
# 96     LP60009708             Mutual Fund         Europe            Specialty
# 97     LP65098436             Mutual Fund         Europe            Specialty
# 98     LP72008378  Pension Fund Portfolio         Europe
# 99     LP60010111             Mutual Fund         Europe                Index
#
#    TR.FundInvtOrientation  ... TR.FundContactFirstName  \
# 0                  Active  ...                  Joanna
# 1                  Active  ...                 Michael
# 2                  Active  ...
# 3                  Active  ...                Nicholas
# 4                 Passive  ...                 Michael
# ..                    ...  ...                     ...
# 95                Passive  ...                 Eleanor
# 96                 Active  ...             Christopher
# 97                 Active  ...                 Kenneth
# 98                 Active  ...                  Lesley
# 99                Passive  ...               Viswanath
#
#     TR.FundContactMiddleInit  TR.FundContactLastName  TR.FundContactTelCntry  \
# 0                         F.                 Jonsson                       1
# 1                         J.                Lindsell                      44
# 2
# 3                         J.                   Train                      44
# 4                                              Perre                       1
# ..                       ...                     ...                     ...
# 95                        J.              de Freitas                      44
# 96                        M.                St. John                      44
# 97                        Y.                    Hsia                      44
# 98                        E.                  Duncan                      44
# 99                                             Nayar                      44
#
#     TR.FundContactTelAreaCode  TR.FundContactTelNumber  TR.FundContactTelExt  \
# 0                         213                  4869200
# 1                          20                7227-8288
# 2                        <NA>
# 3                          20                7808-1210
# 4                         610                  6696311
# ..                        ...                      ...                   ...
# 95                         20                7743-3000
# 96                         20                7330-6694
# 97                         20                7597-1894
# 98                        131                 245-6833
# 99                         20                7991-8888                     0
#
#                         TR.FundContactMetroArea TR.FundAddressCity  \
# 0          Los Angeles-Long Beach-Santa Ana, CA        Los Angeles
# 1                                                           London
# 2                                                             Oslo
# 3                                                           London
# 4   Philadelphia-Camden-Wilmington, PA-NJ-DE-MD            Malvern
# ..                                          ...                ...
# 95                                                          London
# 96                                                          London
# 97                                                          London
# 98                                                       Edinburgh
# 99                                                          London
#
#     TR.FundAddrCountry
# 0        United States
# 1       United Kingdom
# 2               Norway
# 3       United Kingdom
# 4        United States
# ..                 ...
# 95      United Kingdom
# 96      United Kingdom
# 97      United Kingdom
# 98      United Kingdom
# 99      United Kingdom
#
# [100 rows x 44 columns]

# %% [markdown]
# ### Fund - Top n concentration

# %%
response = ownership.fund.top_n_concentration.Definition("LSEG.L", 30).get_data()
response.data.df
# Out:
#   instrument Investors Total % SharesOutstandingAll SharesHeldAll  \
# 0     LSEG.L              30                 16.608      84074980
#
#   SharesHeld ValueAll
# 0       8611717413.92

# %% [markdown]
# ### Close the session

# %%
rd.close_session()
