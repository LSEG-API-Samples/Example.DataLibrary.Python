# %% [markdown]
# ----
# <img src="../../../files/refinitiv.png" width="20%" style="vertical-align: top;">
#
# # Data Library for Python
#
# ----

# %% [markdown]
# ## Delivery layer - OMM Stream - Level 2 orderbook subscription
# This notebook demonstrates how to use an OMM stream of the low level Delivery layer to subscribe to retrieve level 2 orderbooks.

# %% [markdown]
# #### Learn more
#
# To learn more about the Refinitiv Data Library for Python please join the Refinitiv Developer Community. By [registering](https://developers.refinitiv.com/iam/register) and [logging](https://developers.refinitiv.com/content/devportal/en_us/initCookie.html) into the Refinitiv Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/quick-start),
#  [Tutorials](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/learning),
#  [Documentation](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/docs)
#  and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# the [Refinitiv Data Q&A Forum](https://community.developers.refinitiv.com/spaces/321/index.html).
# The Refinitiv Developer Community will be happy to help.

# %% [markdown]
# ## Set the configuration file location
# For a better ease of use, you have the option to set initialization parameters of the Refinitiv Data Library in the _refinitiv-data.config.json_ configuration file. This file must be located beside your notebook, in your user folder or in a folder defined by the _RD_LIB_CONFIG_PATH_ environment variable. The _RD_LIB_CONFIG_PATH_ environment variable is the option used by this series of examples. The following code sets this environment variable.

# %%
import os
os.environ["RD_LIB_CONFIG_PATH"] = "../../../Configuration"

# %% [markdown]
# ## Some Imports to start with

# %%
import refinitiv.data as rd
from refinitiv.data.delivery import omm_stream
import datetime
import json

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the refinitiv-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
rd.open_session("platform.deployed")
# Out:
# <refinitiv.data.session.platform.Definition object at 0x7faead4616a0 {session_name='deployed-cipsnylab2'}>

# %% [markdown]
# ## Retrieve data

# %% [markdown]
# ### Define a calback to display received events

# %%
def display_event(eventType, event):
    currentTime = datetime.datetime.now().time()
    print("----------------------------------------------------------")
    print(">>> {} event received at {}".format(eventType, currentTime))
    print(json.dumps(event, indent=2))
    return

# %% [markdown]
# ### Create an OMM stream and register event callback

# %%
stream = omm_stream.Definition(
    domain="MarketByPrice", 
    name="BB.TO",
    service="ELEKTRON_DD"
).get_stream()

stream.on_refresh(lambda event, item_stream : display_event("Refresh", event))
stream.on_update(lambda event, item_stream : display_event("Update", event))
stream.on_status(lambda event, item_stream : display_event("Status", event))
stream.on_error(lambda event, item_stream : display_event("Error", event))

# %% [markdown]
# ### Open the stream
# This example uses the open() synchronous call to open the stream. Because it is a synchronous call, the first notification (either via on_refresh(), on_status() or on_error()) happens before the open() method returns. If the open_async() asynchronous method is used instead, the first notification happens after open_async() returns.

# %%
stream.open()
# Out:
# ----------------------------------------------------------
# >>> Refresh event received at 15:59:19.980556
# {
#   "ID": 5,
#   "Type": "Refresh",
#   "Domain": "MarketByPrice",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "State": {
#     "Stream": "Open",
#     "Data": "Ok",
#     "Text": "All is well"
#   },
#   "Complete": false,
#   "Qos": {
#     "Timeliness": "Realtime",
#     "Rate": "TickByTick"
#   },
#   "PartNumber": 0,
#   "PermData": "AwFkMETA",
#   "SeqNumber": 30688,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "PROD_PERM": 3044,
#         "DSPLY_NAME": "BLACKBERRY LTD",
#         "CURRENCY": "CAD",
#         "ACTIV_DATE": "2022-06-22",
#         "PRC_QL2": " AU",
#         "LOT_SIZE_A": 100,
#         "RECORDTYPE": 113,
#         "PREF_DISP": null,
#         "RDN_EXCHD2": "TOR",
#         "LIST_MKT": "TOR",
#         "PROV_SYMB": "BB",
#         "PR_RNK_RUL": "NOR",
#         "OR_RNK_RUL": "PTS ",
#         "MNEMONIC": "BB",
#         "MKT_STATUS": "S",
#         "TIMACT_MS": 50359070,
#         "CONTEXT_ID": 2171,
#         "DDS_DSO_ID": 8244,
#         "SPS_SP_RIC": ".[SPSTL2TRL2",
#         "BOOK_STATE": "N",
#         "HALT_REASN": null,
#         "ORD_ENT_ST": "E",
#         "MKT_OR_RUL": " ",
#         "TRD_STATUS": "N ",
#         "HALT_RSN": null
#       }
#     },
#     "CountHint": 655,
#     "Entries": [
#       {
#         "Action": "Add",
#         "Key": "MjkuMDAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 29.0,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 41402015,
#           "LV_TIM_MSP": 21,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni44NzAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.87,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 16,
#           "ACC_SIZE": 15600,
#           "LV_TIM_MS": 50352984,
#           "LV_TIM_MSP": 115,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OC44NjAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 8.86,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 400,
#           "LV_TIM_MS": 40342373,
#           "LV_TIM_MSP": 875,
#           "LV_DATE": "2022-04-19"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MjIuMDAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 22.0,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 19,
#           "ACC_SIZE": 22600,
#           "LV_TIM_MS": 41412131,
#           "LV_TIM_MSP": 37,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTIuMzkwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 12.39,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 40923930,
#           "LV_TIM_MSP": 394,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny4yODAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.28,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 1300,
#           "LV_TIM_MS": 57256220,
#           "LV_TIM_MSP": 61,
#           "LV_DATE": "2022-06-21"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "NS41MDAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 5.5,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 13,
#           "ACC_SIZE": 19500,
#           "LV_TIM_MS": 54938618,
#           "LV_TIM_MSP": 198,
#           "LV_DATE": "2022-06-13"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTIuNjAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 12.6,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 600,
#           "LV_TIM_MS": 39613562,
#           "LV_TIM_MSP": 917,
#           "LV_DATE": "2022-05-13"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTUuMTAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 15.1,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 40918538,
#           "LV_TIM_MSP": 976,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTMuOTkwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 13.99,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 300,
#           "LV_TIM_MS": 56724508,
#           "LV_TIM_MSP": 358,
#           "LV_DATE": "2022-01-31"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTEuMDIwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 11.02,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 400,
#           "LV_TIM_MS": 59395751,
#           "LV_TIM_MSP": 926,
#           "LV_DATE": "2022-05-13"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OS4yNzAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 9.27,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 900,
#           "LV_TIM_MS": 45008713,
#           "LV_TIM_MSP": 179,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTUuOTgwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 15.98,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 1100,
#           "LV_TIM_MS": 40836848,
#           "LV_TIM_MSP": 257,
#           "LV_DATE": "2022-06-01"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni43NzAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.77,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 4,
#           "ACC_SIZE": 6600,
#           "LV_TIM_MS": 50290037,
#           "LV_TIM_MSP": 693,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OS45MjAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 9.92,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 46704945,
#           "LV_TIM_MSP": 991,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTIuMjkwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 12.29,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 200,
#           "LV_TIM_MS": 71513607,
#           "LV_TIM_MSP": 219,
#           "LV_DATE": "2022-04-20"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTMuNDUwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 13.45,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 5300,
#           "LV_TIM_MS": 47724279,
#           "LV_TIM_MSP": 572,
#           "LV_DATE": "2022-02-03"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MjMuNTAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 23.5,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 1500,
#           "LV_TIM_MS": 41402218,
#           "LV_TIM_MSP": 60,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MC4wMDUwMDBC",
#         "Fields": {
#           "ORDER_PRC": 0.005,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 1,
#           "ACC_SIZE": 1000,
#           "LV_TIM_MS": 42390977,
#           "LV_TIM_MSP": 557,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTAuNTMwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 10.53,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 1200,
#           "LV_TIM_MS": 41402020,
#           "LV_TIM_MSP": 48,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTUuMDAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 15.0,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 49,
#           "ACC_SIZE": 31400,
#           "LV_TIM_MS": 42053314,
#           "LV_TIM_MSP": 56,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTMuODkwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 13.89,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 60649603,
#           "LV_TIM_MSP": 508,
#           "LV_DATE": "2021-12-06"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny44MzAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.83,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 1000,
#           "LV_TIM_MS": 41412131,
#           "LV_TIM_MSP": 59,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTQuMjgwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 14.28,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 200,
#           "LV_TIM_MS": 39625032,
#           "LV_TIM_MSP": 398,
#           "LV_DATE": "2022-06-14"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OS4xNzAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 9.17,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 800,
#           "LV_TIM_MS": 40917457,
#           "LV_TIM_MSP": 648,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTUuODgwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 15.88,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 700,
#           "LV_TIM_MS": 41025287,
#           "LV_TIM_MSP": 739,
#           "LV_DATE": "2022-06-20"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "NS4wOTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 5.09,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 2,
#           "ACC_SIZE": 2600,
#           "LV_TIM_MS": 62017232,
#           "LV_TIM_MSP": 569,
#           "LV_DATE": "2022-06-21"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni4yNTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.25,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 5,
#           "ACC_SIZE": 2100,
#           "LV_TIM_MS": 41412125,
#           "LV_TIM_MSP": 39,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTIuOTYwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 12.96,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 65929014,
#           "LV_TIM_MSP": 589,
#           "LV_DATE": "2022-06-03"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OS44MjAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 9.82,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 39612698,
#           "LV_TIM_MSP": 677,
#           "LV_DATE": "2022-03-31"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "NS4zMDAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 5.3,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 68727818,
#           "LV_TIM_MSP": 911,
#           "LV_DATE": "2022-06-09"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MzUwLjAwMDAwMEE=",
#         "Fields": {
#           "ORDER_PRC": 350.0,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 5,
#           "ACC_SIZE": 13000,
#           "LV_TIM_MS": 42847128,
#           "LV_TIM_MSP": 938,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTcuODcwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 17.87,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 1000,
#           "LV_TIM_MS": 40990734,
#           "LV_TIM_MSP": 990,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni42OTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.69,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 49864686,
#           "LV_TIM_MSP": 291,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OC4yNDAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 8.24,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 3,
#           "ACC_SIZE": 400,
#           "LV_TIM_MS": 70614014,
#           "LV_TIM_MSP": 764,
#           "LV_DATE": "2022-06-06"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTMuNzkwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 13.79,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 63206621,
#           "LV_TIM_MSP": 154,
#           "LV_DATE": "2022-06-16"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTQuOTUwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 14.95,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 1200,
#           "LV_TIM_MS": 39667938,
#           "LV_TIM_MSP": 600,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OC42ODAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 8.68,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 3000,
#           "LV_TIM_MS": 61149545,
#           "LV_TIM_MSP": 683,
#           "LV_DATE": "2022-06-06"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni45MDAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.9,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 16,
#           "ACC_SIZE": 26900,
#           "LV_TIM_MS": 50338001,
#           "LV_TIM_MSP": 631,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTc1LjAwMDAwMEE=",
#         "Fields": {
#           "ORDER_PRC": 175.0,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 10200,
#           "LV_TIM_MS": 56650539,
#           "LV_TIM_MSP": 241,
#           "LV_DATE": "2022-06-03"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny43MzAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.73,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 5,
#           "ACC_SIZE": 8500,
#           "LV_TIM_MS": 39612644,
#           "LV_TIM_MSP": 597,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTYuNTAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 16.5,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 40252194,
#           "LV_TIM_MSP": 30,
#           "LV_DATE": "2022-03-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "NDUuMzkwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 45.39,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 56068362,
#           "LV_TIM_MSP": 617,
#           "LV_DATE": "2022-04-26"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OS43MjAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 9.72,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 1000,
#           "LV_TIM_MS": 44131346,
#           "LV_TIM_MSP": 70,
#           "LV_DATE": "2022-06-03"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni4xNTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.15,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 6,
#           "ACC_SIZE": 5800,
#           "LV_TIM_MS": 57639194,
#           "LV_TIM_MSP": 615,
#           "LV_DATE": "2022-06-16"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MS42ODAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 1.68,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 1,
#           "ACC_SIZE": 11800,
#           "LV_TIM_MS": 41400525,
#           "LV_TIM_MSP": 134,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTMuMjUwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 13.25,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 70028733,
#           "LV_TIM_MSP": 815,
#           "LV_DATE": "2022-06-21"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "My4yMzAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 3.23,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 1,
#           "ACC_SIZE": 300,
#           "LV_TIM_MS": 40518195,
#           "LV_TIM_MSP": 818,
#           "LV_DATE": "2022-06-17"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MjMuMzAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 23.3,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 200,
#           "LV_TIM_MS": 40917852,
#           "LV_TIM_MSP": 493,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OC4xNDAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 8.14,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 40934328,
#           "LV_TIM_MSP": 312,
#           "LV_DATE": "2022-06-02"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTcuNzcwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 17.77,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 41402216,
#           "LV_TIM_MSP": 473,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni41OTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.59,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 49879034,
#           "LV_TIM_MSP": 831,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTQuODUwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 14.85,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 41086100,
#           "LV_TIM_MSP": 16,
#           "LV_DATE": "2022-05-02"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OC41ODAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 8.58,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 3,
#           "ACC_SIZE": 800,
#           "LV_TIM_MS": 56722358,
#           "LV_TIM_MSP": 956,
#           "LV_DATE": "2022-05-31"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni44MDAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.8,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 8,
#           "ACC_SIZE": 16700,
#           "LV_TIM_MS": 50300846,
#           "LV_TIM_MSP": 677,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTYuNDAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 16.4,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 3,
#           "ACC_SIZE": 2700,
#           "LV_TIM_MS": 55985505,
#           "LV_TIM_MSP": 177,
#           "LV_DATE": "2022-05-13"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTIuMzIwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 12.32,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 70973191,
#           "LV_TIM_MSP": 106,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny4yMTAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.21,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 39606012,
#           "LV_TIM_MSP": 555,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny42NTAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.65,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 4000,
#           "LV_TIM_MS": 48900235,
#           "LV_TIM_MSP": 164,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTI1LjAwMDAwMEE=",
#         "Fields": {
#           "ORDER_PRC": 125.0,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 3000,
#           "LV_TIM_MS": 40925798,
#           "LV_TIM_MSP": 890,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni4wNTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.05,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 2,
#           "ACC_SIZE": 1400,
#           "LV_TIM_MS": 41412126,
#           "LV_TIM_MSP": 18,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni40OTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.49,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 1,
#           "ACC_SIZE": 1500,
#           "LV_TIM_MS": 48600126,
#           "LV_TIM_MSP": 199,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OS4yMDAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 9.2,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 3,
#           "ACC_SIZE": 900,
#           "LV_TIM_MS": 41402018,
#           "LV_TIM_MSP": 28,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "NDguMDAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 48.0,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 41402015,
#           "LV_TIM_MSP": 39,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni43MDAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.7,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 49863715,
#           "LV_TIM_MSP": 986,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MjYuMTQwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 26.14,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 41412130,
#           "LV_TIM_MSP": 28,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTQuNzUwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 14.75,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 600,
#           "LV_TIM_MS": 41459547,
#           "LV_TIM_MSP": 504,
#           "LV_DATE": "2022-05-05"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MjQuODAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 24.8,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 1900,
#           "LV_TIM_MS": 42724263,
#           "LV_TIM_MSP": 988,
#           "LV_DATE": "2022-06-01"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OC40ODAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 8.48,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 3,
#           "ACC_SIZE": 1400,
#           "LV_TIM_MS": 41059889,
#           "LV_TIM_MSP": 45,
#           "LV_DATE": "2022-06-09"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "NDEuMDAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 41.0,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 800,
#           "LV_TIM_MS": 41402019,
#           "LV_TIM_MSP": 28,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "NS4xMjAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 5.12,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 54132564,
#           "LV_TIM_MSP": 345,
#           "LV_DATE": "2022-06-13"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTEuODMwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 11.83,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 400,
#           "LV_TIM_MS": 55085590,
#           "LV_TIM_MSP": 331,
#           "LV_DATE": "2022-04-26"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny4xMTAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.11,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 3,
#           "ACC_SIZE": 900,
#           "LV_TIM_MS": 50198703,
#           "LV_TIM_MSP": 505,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny41NTAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.55,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 5000,
#           "LV_TIM_MS": 40814710,
#           "LV_TIM_MSP": 901,
#           "LV_DATE": "2022-06-16"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MjQuNDkwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 24.49,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 18500,
#           "LV_TIM_MS": 52590083,
#           "LV_TIM_MSP": 792,
#           "LV_DATE": "2021-06-14"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OS4xMDAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 9.1,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 200,
#           "LV_TIM_MS": 39660458,
#           "LV_TIM_MSP": 28,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny45OTAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.99,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 3,
#           "ACC_SIZE": 13100,
#           "LV_TIM_MS": 39660274,
#           "LV_TIM_MSP": 966,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OC4zODAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 8.38,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 4,
#           "ACC_SIZE": 13700,
#           "LV_TIM_MS": 43831042,
#           "LV_TIM_MSP": 552,
#           "LV_DATE": "2022-06-14"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OS45ODAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 9.98,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 67547908,
#           "LV_TIM_MSP": 394,
#           "LV_DATE": "2022-03-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny4wMTAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.01,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 50224739,
#           "LV_TIM_MSP": 293,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTcuODAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 17.8,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 1200,
#           "LV_TIM_MS": 54285902,
#           "LV_TIM_MSP": 955,
#           "LV_DATE": "2022-06-01"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni42MjAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.62,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 1,
#           "ACC_SIZE": 1800,
#           "LV_TIM_MS": 48603143,
#           "LV_TIM_MSP": 528,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MzQuMDAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 34.0,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 41402015,
#           "LV_TIM_MSP": 22,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OC42MTAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 8.61,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 1000,
#           "LV_TIM_MS": 44242928,
#           "LV_TIM_MSP": 731,
#           "LV_DATE": "2022-06-06"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OS4wMDAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 9.0,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 20,
#           "ACC_SIZE": 24200,
#           "LV_TIM_MS": 41412125,
#           "LV_TIM_MSP": 42,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny44OTAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.89,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 2000,
#           "LV_TIM_MS": 58585412,
#           "LV_TIM_MSP": 886,
#           "LV_DATE": "2022-05-31"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTAuODAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 10.8,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 6,
#           "ACC_SIZE": 14900,
#           "LV_TIM_MS": 41402217,
#           "LV_TIM_MSP": 51,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OS40NDAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 9.44,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 5500,
#           "LV_TIM_MS": 60653047,
#           "LV_TIM_MSP": 70,
#           "LV_DATE": "2022-05-27"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MC4wMTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 0.01,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 1,
#           "ACC_SIZE": 1000,
#           "LV_TIM_MS": 60804543,
#           "LV_TIM_MSP": 809,
#           "LV_DATE": "2022-06-20"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MzkuNzkwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 39.79,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 9000,
#           "LV_TIM_MS": 40924873,
#           "LV_TIM_MSP": 639,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MjMuMDIwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 23.02,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 41412128,
#           "LV_TIM_MSP": 36,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OS44ODAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 9.88,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 6,
#           "ACC_SIZE": 3500,
#           "LV_TIM_MS": 41412129,
#           "LV_TIM_MSP": 26,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTAuMDUwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 10.05,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 41839090,
#           "LV_TIM_MSP": 765,
#           "LV_DATE": "2022-05-24"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTcuNzAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 17.7,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 39624093,
#           "LV_TIM_MSP": 40,
#           "LV_DATE": "2022-06-20"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Mi4wMDAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 2.0,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 1,
#           "ACC_SIZE": 200,
#           "LV_TIM_MS": 41402019,
#           "LV_TIM_MSP": 24,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni45NjAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 6.96,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 9,
#           "ACC_SIZE": 25700,
#           "LV_TIM_MS": 50350002,
#           "LV_TIM_MSP": 621,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTAuNDkwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 10.49,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 200,
#           "LV_TIM_MS": 40986470,
#           "LV_TIM_MSP": 449,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTEuNjUwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 11.65,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 2300,
#           "LV_TIM_MS": 52821989,
#           "LV_TIM_MSP": 177,
#           "LV_DATE": "2022-03-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny4zNTAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.35,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 700,
#           "LV_TIM_MS": 41412130,
#           "LV_TIM_MSP": 53,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny43OTAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.79,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 3,
#           "ACC_SIZE": 12700,
#           "LV_TIM_MS": 43506397,
#           "LV_TIM_MSP": 174,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTYuNTYwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 16.56,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 800,
#           "LV_TIM_MS": 55701440,
#           "LV_TIM_MSP": 95,
#           "LV_DATE": "2022-04-01"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MjcuMDAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 27.0,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 3,
#           "ACC_SIZE": 7900,
#           "LV_TIM_MS": 41402018,
#           "LV_TIM_MSP": 22,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTIuNDgwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 12.48,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 49082166,
#           "LV_TIM_MSP": 182,
#           "LV_DATE": "2022-06-13"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OS4zNDAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 9.34,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 200,
#           "LV_TIM_MS": 40989755,
#           "LV_TIM_MSP": 118,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MzkuNjkwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 39.69,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 68844621,
#           "LV_TIM_MSP": 92,
#           "LV_DATE": "2022-05-05"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTQuNDcwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 14.47,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 400,
#           "LV_TIM_MS": 52943436,
#           "LV_TIM_MSP": 479,
#           "LV_DATE": "2022-03-25"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTEuMTEwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 11.11,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 3,
#           "ACC_SIZE": 900,
#           "LV_TIM_MS": 51300155,
#           "LV_TIM_MSP": 555,
#           "LV_DATE": "2022-05-27"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MjAuMDAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 20.0,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 49,
#           "ACC_SIZE": 40200,
#           "LV_TIM_MS": 39660296,
#           "LV_TIM_MSP": 177,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni40MjAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.42,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 2,
#           "ACC_SIZE": 1400,
#           "LV_TIM_MS": 61918433,
#           "LV_TIM_MSP": 83,
#           "LV_DATE": "2022-06-16"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "My41MDAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 3.5,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 2,
#           "ACC_SIZE": 3700,
#           "LV_TIM_MS": 67311536,
#           "LV_TIM_MSP": 408,
#           "LV_DATE": "2022-05-24"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni44NjAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.86,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 9,
#           "ACC_SIZE": 22700,
#           "LV_TIM_MS": 50336996,
#           "LV_TIM_MSP": 769,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "NS4yODAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 5.28,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 3,
#           "ACC_SIZE": 1100,
#           "LV_TIM_MS": 39612004,
#           "LV_TIM_MSP": 877,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTMuMTAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 13.1,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 55346936,
#           "LV_TIM_MSP": 424,
#           "LV_DATE": "2022-03-29"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTEuOTkwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 11.99,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 3,
#           "ACC_SIZE": 1400,
#           "LV_TIM_MS": 51592114,
#           "LV_TIM_MSP": 981,
#           "LV_DATE": "2022-04-04"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OC44NTAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 8.85,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 300,
#           "LV_TIM_MS": 41402019,
#           "LV_TIM_MSP": 32,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "NC4zMzAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 4.33,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 1,
#           "ACC_SIZE": 400,
#           "LV_TIM_MS": 42391804,
#           "LV_TIM_MSP": 259,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTMuOTgwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 13.98,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 44108734,
#           "LV_TIM_MSP": 462,
#           "LV_DATE": "2022-04-05"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Refresh event received at 15:59:20.198569
# {
#   "ID": 5,
#   "Type": "Refresh",
#   "Domain": "MarketByPrice",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "State": {
#     "Stream": "Open",
#     "Data": "Ok",
#     "Text": "All is well"
#   },
#   "Complete": false,
#   "Qos": {
#     "Timeliness": "Realtime",
#     "Rate": "TickByTick"
#   },
#   "ClearCache": false,
#   "PartNumber": 1,
#   "PermData": "AwFkMETA",
#   "SeqNumber": 30688,
#   "Map": {
#     "KeyType": "Buffer",
#     "Entries": [
#       {
#         "Action": "Add",
#         "Key": "MTcxLjExMDAwMEE=",
#         "Fields": {
#           "ORDER_PRC": 171.11,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 62705831,
#           "LV_TIM_MSP": 860,
#           "LV_DATE": "2022-05-16"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny45MjAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.92,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 2000,
#           "LV_TIM_MS": 54625734,
#           "LV_TIM_MSP": 954,
#           "LV_DATE": "2022-06-21"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTEuNDUwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 11.45,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 59754424,
#           "LV_TIM_MSP": 311,
#           "LV_DATE": "2022-04-18"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni43NjAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.76,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 1,
#           "ACC_SIZE": 200,
#           "LV_TIM_MS": 50213010,
#           "LV_TIM_MSP": 465,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MjEuNTAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 21.5,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 1500,
#           "LV_TIM_MS": 39611237,
#           "LV_TIM_MSP": 988,
#           "LV_DATE": "2022-04-11"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MjkuMzMwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 29.33,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 42392394,
#           "LV_TIM_MSP": 813,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OC43NTAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 8.75,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 6,
#           "ACC_SIZE": 6900,
#           "LV_TIM_MS": 41412128,
#           "LV_TIM_MSP": 46,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MjUuMjUwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 25.25,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 200,
#           "LV_TIM_MS": 40145304,
#           "LV_TIM_MSP": 437,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "NjAuMDAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 60.0,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 700,
#           "LV_TIM_MS": 40983413,
#           "LV_TIM_MSP": 723,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MzUuMzAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 35.3,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 600,
#           "LV_TIM_MS": 46953855,
#           "LV_TIM_MSP": 329,
#           "LV_DATE": "2021-07-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTMuMDAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 13.0,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 19,
#           "ACC_SIZE": 18500,
#           "LV_TIM_MS": 41412132,
#           "LV_TIM_MSP": 62,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny4xNzAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.17,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 50064074,
#           "LV_TIM_MSP": 504,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MjUuNjkwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 25.69,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 59308636,
#           "LV_TIM_MSP": 332,
#           "LV_DATE": "2022-06-14"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTIuMjgwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 12.28,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 6000,
#           "LV_TIM_MS": 40992964,
#           "LV_TIM_MSP": 736,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTMuODgwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 13.88,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 3,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 52440603,
#           "LV_TIM_MSP": 738,
#           "LV_DATE": "2022-05-26"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTAuNTIwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 10.52,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 200,
#           "LV_TIM_MS": 39662350,
#           "LV_TIM_MSP": 873,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTkuOTUwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 19.95,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 1000,
#           "LV_TIM_MS": 51358894,
#           "LV_TIM_MSP": 507,
#           "LV_DATE": "2022-05-20"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTIuNTEwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 12.51,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 39660314,
#           "LV_TIM_MSP": 52,
#           "LV_DATE": "2022-06-15"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ni4yNDAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.24,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 2,
#           "ACC_SIZE": 1700,
#           "LV_TIM_MS": 41484092,
#           "LV_TIM_MSP": 253,
#           "LV_DATE": "2022-06-13"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTIuOTUwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 12.95,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 9100,
#           "LV_TIM_MS": 40923930,
#           "LV_TIM_MSP": 740,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTQuNTAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 14.5,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 5,
#           "ACC_SIZE": 8800,
#           "LV_TIM_MS": 43588257,
#           "LV_TIM_MSP": 585,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "Ny4wNzAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 7.07,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 500,
#           "LV_TIM_MS": 50225971,
#           "LV_TIM_MSP": 269,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OC42NzAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 8.67,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 2500,
#           "LV_TIM_MS": 44157654,
#           "LV_TIM_MSP": 95,
#           "LV_DATE": "2022-06-15"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OS4wNjAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 9.06,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 1300,
#           "LV_TIM_MS": 40995922,
#           "LV_TIM_MSP": 545,
#           "LV_DATE": "2022-05-30"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTAuODYwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 10.86,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 100,
#           "LV_TIM_MS": 59138011,
#           "LV_TIM_MSP": 837,
#           "LV_DATE": "2022-06-09"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTkuODUwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 19.85,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 200,
#           "LV_TIM_MS": 39613568,
#           "LV_TIM_MSP": 801,
#           "LV_DATE": "2022-03-28"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTEuMjUwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 11.25,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 2500,
#           "LV_TIM_MS": 41056875,
#           "LV_TIM_MSP": 305,
#           "LV_DATE": "2022-06-09"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "NC44MDAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 4.8,
#           "ORDER_SIDE": "BID",
#           "NO_ORD": 2,
#           "ACC_SIZE": 300,
#           "LV_TIM_MS": 48537728,
#           "LV_TIM_MSP": 320,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTQuNDAwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 14.4,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 2,
#           "ACC_SIZE": 200,
#           "LV_TIM_MS": 41402016,
#           "LV_TIM_MSP": 19,
#           "LV_DATE": "2022-06-22"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "OC41NzAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 8.57,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 4,
#           "ACC_SIZE": 1300,
#           "LV_TIM_MS": 59164318,
#           "LV_TIM_MSP": 614,
#           "LV_DATE": "2022-05-31"
#         }
#       },
#       {
#         "Action": "Add",
#         "Key": "MTQuODQwMDAwQQ==",
#         "Fields": {
#           "ORDER_PRC": 14.84,
#           "ORDER_SIDE": "ASK",
#           "NO_ORD": 1,
#           "ACC_SIZE": 300,
#           "LV_TIM_MS": 48637622,
#           "LV_TIM_MSP": 334,
# ...
#         "TIMACT_MS": 50360893
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45MTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.91,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 15300,
#           "NO_ORD": 15,
#           "LV_TIM_MS": 50328073,
#           "LV_TIM_MSP": 536,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:20.884896
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31072,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50360893
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45MTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.91,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 21100,
#           "NO_ORD": 16,
#           "LV_TIM_MS": 50328073,
#           "LV_TIM_MSP": 536,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:21.057063
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31088,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50361066
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni44ODAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.88,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 18700,
#           "NO_ORD": 13,
#           "LV_TIM_MS": 50360885,
#           "LV_TIM_MSP": 313,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:21.057582
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31104,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50361066
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni44ODAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.88,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 20200,
#           "NO_ORD": 14,
#           "LV_TIM_MS": 50360885,
#           "LV_TIM_MSP": 313,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:21.168062
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31120,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50361175
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45MTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.91,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 15300,
#           "NO_ORD": 15,
#           "LV_TIM_MS": 50328073,
#           "LV_TIM_MSP": 536,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:21.168439
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31136,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50361175
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45MTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.91,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 20600,
#           "NO_ORD": 16,
#           "LV_TIM_MS": 50328073,
#           "LV_TIM_MSP": 536,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:21.168793
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31152,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50361176
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45MTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.91,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 15300,
#           "NO_ORD": 15,
#           "LV_TIM_MS": 50328073,
#           "LV_TIM_MSP": 536,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:21.169025
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31168,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50361176
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45MTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.91,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 17900,
#           "NO_ORD": 16,
#           "LV_TIM_MS": 50328073,
#           "LV_TIM_MSP": 536,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:21.169240
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31184,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50361176
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45MTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.91,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 15300,
#           "NO_ORD": 15,
#           "LV_TIM_MS": 50328073,
#           "LV_TIM_MSP": 536,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:21.169742
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31200,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50361176
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45MTAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.91,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 17700,
#           "NO_ORD": 16,
#           "LV_TIM_MS": 50328073,
#           "LV_TIM_MSP": 536,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:21.235552
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31216,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50361244
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni44ODAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.88,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 25600,
#           "NO_ORD": 15,
#           "LV_TIM_MS": 50361244,
#           "LV_TIM_MSP": 861,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:21.513423
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31232,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50361521
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45NDAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 6.94,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 5800,
#           "NO_ORD": 13,
#           "LV_TIM_MS": 50360445,
#           "LV_TIM_MSP": 176,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:21.535597
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31248,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50361545
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45MzAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.93,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 500,
#           "NO_ORD": 3,
#           "LV_TIM_MS": 50361545,
#           "LV_TIM_MSP": 531,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:21.589789
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31264,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50361601
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45MjAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.92,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 6000,
#           "NO_ORD": 7,
#           "LV_TIM_MS": 50361601,
#           "LV_TIM_MSP": 548,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:22.038850
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31280,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50362047
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45NTAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 6.95,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 30000,
#           "NO_ORD": 11,
#           "LV_TIM_MS": 50358911,
#           "LV_TIM_MSP": 850,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:22.039185
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31296,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50362047
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45NDAwMDBB",
#         "Fields": {
#           "ORDER_PRC": 6.94,
#           "ORDER_SIDE": "ASK",
#           "ACC_SIZE": 6000,
#           "NO_ORD": 14,
#           "LV_TIM_MS": 50362047,
#           "LV_TIM_MSP": 880,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:22.631957
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31312,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50362640
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45MjAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.92,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 5800,
#           "NO_ORD": 6,
#           "LV_TIM_MS": 50361601,
#           "LV_TIM_MSP": 548,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:22.632563
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31328,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50362640
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45MjAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.92,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 5900,
#           "NO_ORD": 7,
#           "LV_TIM_MS": 50361601,
#           "LV_TIM_MSP": 548,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:22.639583
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31344,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50362650
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45MjAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.92,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 5800,
#           "NO_ORD": 6,
#           "LV_TIM_MS": 50361601,
#           "LV_TIM_MSP": 548,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:22.683100
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31360,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50362692
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni45MzAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.93,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 300,
#           "NO_ORD": 2,
#           "LV_TIM_MS": 50361545,
#           "LV_TIM_MSP": 531,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:23.897803
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31376,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50363902
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni44ODAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.88,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 20200,
#           "NO_ORD": 14,
#           "LV_TIM_MS": 50361244,
#           "LV_TIM_MSP": 861,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }
# ----------------------------------------------------------
# >>> Update event received at 15:59:23.898146
# {
#   "ID": 5,
#   "Type": "Update",
#   "Domain": "MarketByPrice",
#   "UpdateType": "Unspecified",
#   "Key": {
#     "Service": "ELEKTRON_DD",
#     "Name": "BB.TO"
#   },
#   "SeqNumber": 31392,
#   "Map": {
#     "KeyType": "Buffer",
#     "Summary": {
#       "Fields": {
#         "TIMACT_MS": 50363902
#       }
#     },
#     "Entries": [
#       {
#         "Action": "Update",
#         "Key": "Ni44ODAwMDBC",
#         "Fields": {
#           "ORDER_PRC": 6.88,
#           "ORDER_SIDE": "BID",
#           "ACC_SIZE": 20300,
#           "NO_ORD": 15,
#           "LV_TIM_MS": 50361244,
#           "LV_TIM_MSP": 861,
#           "LV_DATE": "2022-06-22"
#         }
#       }
#     ]
#   }
# }

# %% [markdown]
# ### Close the stream

# %%
stream.close()
# Out:
# <OpenState.Closed: 'Closed'>

# %% [markdown]
# ## Close the session

# %%
rd.close_session()
